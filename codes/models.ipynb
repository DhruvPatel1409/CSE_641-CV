# %% [markdown]
# # ROTATED RETINANET

# %%
import os
import cv2
import torch
import mmrotate
import numpy as np
from mmdet.apis import init_detector, inference_detector

# -------------------- Path Setup --------------------
IMAGE_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\images\train\images"
OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_rrn"
CONFIG_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\mmrotate\configs\rotated_retinanet\rotated_retinanet_obb_r50_fpn_1x_dota_le135.py"
CHECKPOINT_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\rotated_retinanet_obb_r50_fpn_1x_dota_le135-e4131166.pth"
LOW_CONFIDENCE = 0.1

os.makedirs(OUTPUT_DIR, exist_ok=True)
TXT_FOLDER = os.path.join(OUTPUT_DIR, "txt_annotations")
os.makedirs(TXT_FOLDER, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"✅ Using device: {device}")

model = init_detector(CONFIG_FILE, CHECKPOINT_FILE, device=device)
class_names = model.CLASSES if hasattr(model, 'CLASSES') else model.dataset_meta['CLASSES']
print(f"✅ Model loaded with {len(class_names)} classes: {class_names}")

def draw_obb(img, obb, label, score, color=(0, 255, 0), thickness=2):
    cx, cy, w, h, angle = obb
    rect = ((cx, cy), (w, h), angle * 180 / np.pi)
    box = cv2.boxPoints(rect)
    box = np.int0(box)
    cv2.drawContours(img, [box], 0, color, thickness)
    label_text = f"{class_names[label] if label < len(class_names) else 'No_Detection'}: {score:.2f}"
    cv2.putText(img, label_text, (int(cx), int(cy) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

# Gather image files
image_files = [f for f in os.listdir(IMAGE_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
if not image_files:
    print(f"❌ No image files found in {IMAGE_DIR}")
else:
    print(f"✅ Found {len(image_files)} image(s) to process")

total_images = 0
images_with_detections = 0
skipped_images = []
class_detection_counts = {i: 0 for i in range(len(class_names))}
class_detection_counts["No_Detection"] = 0

for img_name in image_files:
    total_images += 1
    img_path = os.path.join(IMAGE_DIR, img_name)
    print(f"Processing {img_name}...")

    img = cv2.imread(img_path)
    if img is None:
        print(f"⚠️ Failed to load image: {img_path}")
        skipped_images.append(img_name)
        continue

    result = inference_detector(model, img_path)

    drawn_any = False
    pred_data = []

    if isinstance(result, tuple):
        bbox_results, _ = result
        for class_id, bboxes in enumerate(bbox_results):
            for bbox in bboxes:
                score = bbox[5]
                obb = bbox[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })
    elif hasattr(result, 'pred_instances'):
        pred_instances = result.pred_instances
        bboxes = pred_instances.bboxes.cpu().numpy()
        scores = pred_instances.scores.cpu().numpy()
        labels = pred_instances.labels.cpu().numpy()
        for bbox, score, label in zip(bboxes, scores, labels):
            obb = bbox.tolist()
            if score >= LOW_CONFIDENCE:
                draw_obb(img, obb, label, score)
                drawn_any = True
                class_detection_counts[label.item()] += 1
                pred_data.append({
                    "obb": obb,
                    "score": float(score),
                    "label": int(label),
                    "label_name": class_names[label]
                })
    else:
        for class_id, class_result in enumerate(result):
            for res in class_result:
                score = res[-1]
                obb = res[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })

    # If no detection, draw dummy red box
    if not drawn_any:
        print(f"⚠️ No predictions for {img_name}, drawing dummy box.")
        h, w = img.shape[:2]
        dummy_cx, dummy_cy = w // 2, h // 2
        dummy_w, dummy_h = w // 5, h // 5
        dummy_angle = 0
        dummy_obb = [dummy_cx, dummy_cy, dummy_w, dummy_h, dummy_angle]
        dummy_score = 0.0
        draw_obb(img, dummy_obb, len(class_names), dummy_score, color=(0, 0, 255))
        pred_data.append({
            "obb": dummy_obb,
            "score": dummy_score,
            "label": len(class_names),
            "label_name": "No_Detection"
        })
        class_detection_counts["No_Detection"] += 1
    else:
        print(f"✅ Predictions drawn for {img_name}")
        images_with_detections += 1

    # Save image
    output_path = os.path.join(OUTPUT_DIR, img_name)
    cv2.imwrite(output_path, img)

    # Save .txt annotation
    txt_filename = os.path.splitext(img_name)[0] + ".txt"
    txt_path = os.path.join(TXT_FOLDER, txt_filename)

    with open(txt_path, 'w') as f:
        for pred in pred_data:
            cx, cy, w, h, angle = pred['obb']
            rect = ((cx, cy), (w, h), angle * 180 / np.pi)
            box = cv2.boxPoints(rect)
            box = np.int0(box)
            points_flat = box.flatten()
            coords = " ".join(map(str, points_flat))
            label_name = pred['label_name'].replace(" ", "_")  # Prevent space in label
            score = pred['score']
            line = f"{coords} {label_name} {score:.4f}\n"
            f.write(line)

    print(f"📄 TXT saved: {txt_filename}")

# ========== Summary ==========
print("\n===== Detection Summary =====")
print(f"Total images processed: {total_images}")
print(f"Images with detections: {images_with_detections} ({images_with_detections / total_images * 100:.1f}%)")
print(f"Images with dummy boxes: {total_images - images_with_detections} ({(total_images - images_with_detections) / total_images * 100:.1f}%)")

print("\n📊 Detections by class:")
for class_id, count in class_detection_counts.items():
    name = class_names[class_id] if isinstance(class_id, int) and class_id < len(class_names) else class_id
    if count > 0:
        print(f"  {name}: {count} detections")

if skipped_images:
    print("\n⚠️ Skipped the following images (could not load):")
    for name in skipped_images:
        print(f" - {name}")

print("\n🎉 All images processed and saved with OBBs and TXT annotations.")
# Out:
# d:\Anaconda\envs\cfi_net\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ✅ Using device: cuda
# load checkpoint from local path: D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\rotated_retinanet_obb_r50_fpn_1x_dota_le135-e4131166.pth
# ✅ Model loaded with 15 classes: ('plane', 'baseball-diamond', 'bridge', 'ground-track-field', 'small-vehicle', 'large-vehicle', 'ship', 'tennis-court', 'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout', 'harbor', 'swimming-pool', 'helicopter')
# ✅ Found 1411 image(s) to process
# Processing P0000.png...
# ✅ Predictions drawn for P0000.png
# 📄 TXT saved: P0000.txt
# Processing P0001.png...
# ✅ Predictions drawn for P0001.png
# 📄 TXT saved: P0001.txt
# Processing P0002.png...
# ✅ Predictions drawn for P0002.png
# 📄 TXT saved: P0002.txt
# Processing P0005.png...
# ✅ Predictions drawn for P0005.png
# 📄 TXT saved: P0005.txt
# Processing P0008.png...
# ✅ Predictions drawn for P0008.png
# 📄 TXT saved: P0008.txt
# Processing P0010.png...
# ✅ Predictions drawn for P0010.png
# 📄 TXT saved: P0010.txt
# Processing P0011.png...
# ✅ Predictions drawn for P0011.png
# 📄 TXT saved: P0011.txt
# Processing P0012.png...
# ✅ Predictions drawn for P0012.png
# 📄 TXT saved: P0012.txt
# Processing P0013.png...
# ✅ Predictions drawn for P0013.png
# 📄 TXT saved: P0013.txt
# Processing P0018.png...
# ✅ Predictions drawn for P0018.png
# 📄 TXT saved: P0018.txt
# Processing P0020.png...
# ✅ Predictions drawn for P0020.png
# 📄 TXT saved: P0020.txt
# Processing P0021.png...
# ✅ Predictions drawn for P0021.png
# 📄 TXT saved: P0021.txt
# Processing P0022.png...
# ✅ Predictions drawn for P0022.png
# 📄 TXT saved: P0022.txt
# Processing P0023.png...
# ✅ Predictions drawn for P0023.png
# 📄 TXT saved: P0023.txt
# Processing P0025.png...
# ✅ Predictions drawn for P0025.png
# 📄 TXT saved: P0025.txt
# Processing P0029.png...
# ✅ Predictions drawn for P0029.png
# 📄 TXT saved: P0029.txt
# Processing P0030.png...
# ✅ Predictions drawn for P0030.png
# 📄 TXT saved: P0030.txt
# Processing P0032.png...
# ✅ Predictions drawn for P0032.png
# 📄 TXT saved: P0032.txt
# Processing P0036.png...
# ✅ Predictions drawn for P0036.png
# 📄 TXT saved: P0036.txt
# Processing P0038.png...
# ✅ Predictions drawn for P0038.png
# 📄 TXT saved: P0038.txt
# Processing P0039.png...
# ✅ Predictions drawn for P0039.png
# 📄 TXT saved: P0039.txt
# Processing P0041.png...
# ✅ Predictions drawn for P0041.png
# 📄 TXT saved: P0041.txt
# Processing P0042.png...
# ✅ Predictions drawn for P0042.png
# 📄 TXT saved: P0042.txt
# Processing P0044.png...
# ✅ Predictions drawn for P0044.png
# 📄 TXT saved: P0044.txt
# Processing P0049.png...
# ✅ Predictions drawn for P0049.png
# 📄 TXT saved: P0049.txt
# Processing P0050.png...
# ✅ Predictions drawn for P0050.png
# 📄 TXT saved: P0050.txt
# Processing P0052.png...
# ✅ Predictions drawn for P0052.png
# 📄 TXT saved: P0052.txt
# Processing P0054.png...
# ✅ Predictions drawn for P0054.png
# 📄 TXT saved: P0054.txt
# Processing P0058.png...
# ✅ Predictions drawn for P0058.png
# 📄 TXT saved: P0058.txt
# Processing P0061.png...
# ✅ Predictions drawn for P0061.png
# 📄 TXT saved: P0061.txt
# Processing P0063.png...
# ✅ Predictions drawn for P0063.png
# 📄 TXT saved: P0063.txt
# Processing P0064.png...
# ✅ Predictions drawn for P0064.png
# 📄 TXT saved: P0064.txt
# Processing P0065.png...
# ✅ Predictions drawn for P0065.png
# 📄 TXT saved: P0065.txt
# Processing P0066.png...
# ✅ Predictions drawn for P0066.png
# 📄 TXT saved: P0066.txt
# Processing P0067.png...
# ✅ Predictions drawn for P0067.png
# 📄 TXT saved: P0067.txt
# Processing P0068.png...
# ✅ Predictions drawn for P0068.png
# 📄 TXT saved: P0068.txt
# Processing P0070.png...
# ✅ Predictions drawn for P0070.png
# 📄 TXT saved: P0070.txt
# Processing P0071.png...
# ✅ Predictions drawn for P0071.png
# 📄 TXT saved: P0071.txt
# Processing P0074.png...
# ✅ Predictions drawn for P0074.png
# 📄 TXT saved: P0074.txt
# Processing P0076.png...
# ✅ Predictions drawn for P0076.png
# 📄 TXT saved: P0076.txt
# Processing P0078.png...
# ✅ Predictions drawn for P0078.png
# 📄 TXT saved: P0078.txt
# Processing P0082.png...
# ✅ Predictions drawn for P0082.png
# 📄 TXT saved: P0082.txt
# Processing P0083.png...
# ✅ Predictions drawn for P0083.png
# 📄 TXT saved: P0083.txt
# Processing P0085.png...
# ✅ Predictions drawn for P0085.png
# 📄 TXT saved: P0085.txt
# Processing P0087.png...
# ✅ Predictions drawn for P0087.png
# 📄 TXT saved: P0087.txt
# Processing P0091.png...
# ✅ Predictions drawn for P0091.png
# 📄 TXT saved: P0091.txt
# Processing P0093.png...
# ✅ Predictions drawn for P0093.png
# 📄 TXT saved: P0093.txt
# Processing P0094.png...
# ✅ Predictions drawn for P0094.png
# 📄 TXT saved: P0094.txt
# Processing P0095.png...
# ✅ Predictions drawn for P0095.png
# 📄 TXT saved: P0095.txt
# Processing P0096.png...
# ✅ Predictions drawn for P0096.png
# 📄 TXT saved: P0096.txt
# Processing P0098.png...
# ✅ Predictions drawn for P0098.png
# 📄 TXT saved: P0098.txt
# Processing P0099.png...
# ✅ Predictions drawn for P0099.png
# 📄 TXT saved: P0099.txt
# Processing P0100.png...
# ✅ Predictions drawn for P0100.png
# 📄 TXT saved: P0100.txt
# Processing P0103.png...
# ✅ Predictions drawn for P0103.png
# 📄 TXT saved: P0103.txt
# Processing P0109.png...
# ✅ Predictions drawn for P0109.png
# 📄 TXT saved: P0109.txt
# Processing P0111.png...
# ✅ Predictions drawn for P0111.png
# 📄 TXT saved: P0111.txt
# Processing P0113.png...
# ✅ Predictions drawn for P0113.png
# 📄 TXT saved: P0113.txt
# Processing P0116.png...
# ✅ Predictions drawn for P0116.png
# 📄 TXT saved: P0116.txt
# Processing P0119.png...
# ✅ Predictions drawn for P0119.png
# 📄 TXT saved: P0119.txt
# Processing P0122.png...
# ✅ Predictions drawn for P0122.png
# 📄 TXT saved: P0122.txt
# Processing P0124.png...
# ✅ Predictions drawn for P0124.png
# 📄 TXT saved: P0124.txt
# Processing P0126.png...
# ✅ Predictions drawn for P0126.png
# 📄 TXT saved: P0126.txt
# Processing P0129.png...
# ✅ Predictions drawn for P0129.png
# 📄 TXT saved: P0129.txt
# Processing P0133.png...
# ✅ Predictions drawn for P0133.png
# 📄 TXT saved: P0133.txt
# Processing P0136.png...
# ✅ Predictions drawn for P0136.png
# 📄 TXT saved: P0136.txt
# Processing P0139.png...
# ✅ Predictions drawn for P0139.png
# 📄 TXT saved: P0139.txt
# Processing P0140.png...
# ✅ Predictions drawn for P0140.png
# 📄 TXT saved: P0140.txt
# Processing P0141.png...
# ✅ Predictions drawn for P0141.png
# 📄 TXT saved: P0141.txt
# Processing P0142.png...
# ✅ Predictions drawn for P0142.png
# 📄 TXT saved: P0142.txt
# Processing P0144.png...
# ✅ Predictions drawn for P0144.png
# 📄 TXT saved: P0144.txt
# Processing P0147.png...
# ✅ Predictions drawn for P0147.png
# 📄 TXT saved: P0147.txt
# Processing P0149.png...
# ✅ Predictions drawn for P0149.png
# 📄 TXT saved: P0149.txt
# Processing P0151.png...
# ✅ Predictions drawn for P0151.png
# 📄 TXT saved: P0151.txt
# Processing P0152.png...
# ✅ Predictions drawn for P0152.png
# 📄 TXT saved: P0152.txt
# Processing P0158.png...
# ✅ Predictions drawn for P0158.png
# 📄 TXT saved: P0158.txt
# Processing P0159.png...
# ✅ Predictions drawn for P0159.png
# 📄 TXT saved: P0159.txt
# Processing P0160.png...
# ✅ Predictions drawn for P0160.png
# 📄 TXT saved: P0160.txt
# Processing P0162.png...
# ✅ Predictions drawn for P0162.png
# 📄 TXT saved: P0162.txt
# Processing P0163.png...
# ✅ Predictions drawn for P0163.png
# 📄 TXT saved: P0163.txt
# Processing P0164.png...
# ✅ Predictions drawn for P0164.png
# 📄 TXT saved: P0164.txt
# Processing P0167.png...
# ✅ Predictions drawn for P0167.png
# 📄 TXT saved: P0167.txt
# Processing P0169.png...
# ✅ Predictions drawn for P0169.png
# 📄 TXT saved: P0169.txt
# Processing P0171.png...
# ✅ Predictions drawn for P0171.png
# 📄 TXT saved: P0171.txt
# Processing P0172.png...
# ✅ Predictions drawn for P0172.png
# 📄 TXT saved: P0172.txt
# Processing P0174.png...
# ✅ Predictions drawn for P0174.png
# 📄 TXT saved: P0174.txt
# Processing P0176.png...
# ✅ Predictions drawn for P0176.png
# 📄 TXT saved: P0176.txt
# Processing P0178.png...
# ✅ Predictions drawn for P0178.png
# 📄 TXT saved: P0178.txt
# Processing P0183.png...
# ✅ Predictions drawn for P0183.png
# 📄 TXT saved: P0183.txt
# Processing P0187.png...
# ✅ Predictions drawn for P0187.png
# 📄 TXT saved: P0187.txt
# Processing P0188.png...
# ✅ Predictions drawn for P0188.png
# 📄 TXT saved: P0188.txt
# Processing P0190.png...
# ✅ Predictions drawn for P0190.png
# 📄 TXT saved: P0190.txt
# Processing P0200.png...
# ✅ Predictions drawn for P0200.png
# 📄 TXT saved: P0200.txt
# Processing P0201.png...
# ✅ Predictions drawn for P0201.png
# 📄 TXT saved: P0201.txt
# Processing P0202.png...
# ✅ Predictions drawn for P0202.png
# 📄 TXT saved: P0202.txt
# Processing P0203.png...
# ✅ Predictions drawn for P0203.png
# 📄 TXT saved: P0203.txt
# Processing P0204.png...
# ✅ Predictions drawn for P0204.png
# 📄 TXT saved: P0204.txt
# Processing P0207.png...
# ✅ Predictions drawn for P0207.png
# 📄 TXT saved: P0207.txt
# Processing P0209.png...
# ✅ Predictions drawn for P0209.png
# 📄 TXT saved: P0209.txt
# Processing P0210.png...
# ✅ Predictions drawn for P0210.png
# 📄 TXT saved: P0210.txt
# Processing P0212.png...
# ✅ Predictions drawn for P0212.png
# 📄 TXT saved: P0212.txt
# Processing P0215.png...
# ✅ Predictions drawn for P0215.png
# 📄 TXT saved: P0215.txt
# Processing P0218.png...
# ✅ Predictions drawn for P0218.png
# 📄 TXT saved: P0218.txt
# Processing P0219.png...
# ✅ Predictions drawn for P0219.png
# 📄 TXT saved: P0219.txt
# Processing P0220.png...
# ✅ Predictions drawn for P0220.png
# 📄 TXT saved: P0220.txt
# Processing P0221.png...
# ✅ Predictions drawn for P0221.png
# 📄 TXT saved: P0221.txt
# Processing P0222.png...
# ✅ Predictions drawn for P0222.png
# 📄 TXT saved: P0222.txt
# Processing P0223.png...
# ✅ Predictions drawn for P0223.png
# 📄 TXT saved: P0223.txt
# Processing P0224.png...
# ✅ Predictions drawn for P0224.png
# 📄 TXT saved: P0224.txt
# Processing P0225.png...
# ✅ Predictions drawn for P0225.png
# 📄 TXT saved: P0225.txt
# Processing P0226.png...
# ✅ Predictions drawn for P0226.png
# 📄 TXT saved: P0226.txt
# Processing P0227.png...
# ✅ Predictions drawn for P0227.png
# 📄 TXT saved: P0227.txt
# Processing P0229.png...
# ✅ Predictions drawn for P0229.png
# 📄 TXT saved: P0229.txt
# Processing P0232.png...
# ✅ Predictions drawn for P0232.png
# 📄 TXT saved: P0232.txt
# Processing P0233.png...
# ✅ Predictions drawn for P0233.png
# 📄 TXT saved: P0233.txt
# Processing P0235.png...
# ✅ Predictions drawn for P0235.png
# 📄 TXT saved: P0235.txt
# Processing P0236.png...
# ✅ Predictions drawn for P0236.png
# 📄 TXT saved: P0236.txt
# Processing P0238.png...
# ✅ Predictions drawn for P0238.png
# 📄 TXT saved: P0238.txt
# Processing P0241.png...
# ✅ Predictions drawn for P0241.png
# 📄 TXT saved: P0241.txt
# Processing P0244.png...
# ✅ Predictions drawn for P0244.png
# 📄 TXT saved: P0244.txt
# Processing P0248.png...
# ✅ Predictions drawn for P0248.png
# 📄 TXT saved: P0248.txt
# Processing P0250.png...
# ✅ Predictions drawn for P0250.png
# 📄 TXT saved: P0250.txt
# Processing P0251.png...
# ✅ Predictions drawn for P0251.png
# 📄 TXT saved: P0251.txt
# Processing P0252.png...
# ✅ Predictions drawn for P0252.png
# 📄 TXT saved: P0252.txt
# Processing P0254.png...
# ✅ Predictions drawn for P0254.png
# 📄 TXT saved: P0254.txt
# Processing P0255.png...
# ✅ Predictions drawn for P0255.png
# 📄 TXT saved: P0255.txt
# Processing P0256.png...
# ✅ Predictions drawn for P0256.png
# 📄 TXT saved: P0256.txt
# Processing P0258.png...
# ✅ Predictions drawn for P0258.png
# 📄 TXT saved: P0258.txt
# Processing P0260.png...
# ✅ Predictions drawn for P0260.png
# 📄 TXT saved: P0260.txt
# Processing P0263.png...
# ✅ Predictions drawn for P0263.png
# 📄 TXT saved: P0263.txt
# Processing P0264.png...
# ✅ Predictions drawn for P0264.png
# 📄 TXT saved: P0264.txt
# Processing P0270.png...
# ✅ Predictions drawn for P0270.png
# 📄 TXT saved: P0270.txt
# Processing P0272.png...
# ✅ Predictions drawn for P0272.png
# 📄 TXT saved: P0272.txt
# Processing P0273.png...
# ✅ Predictions drawn for P0273.png
# 📄 TXT saved: P0273.txt
# Processing P0275.png...
# ✅ Predictions drawn for P0275.png
# 📄 TXT saved: P0275.txt
# Processing P0276.png...
# ✅ Predictions drawn for P0276.png
# 📄 TXT saved: P0276.txt
# Processing P0280.png...
# ✅ Predictions drawn for P0280.png
# 📄 TXT saved: P0280.txt
# Processing P0281.png...
# ✅ Predictions drawn for P0281.png
# 📄 TXT saved: P0281.txt
# Processing P0282.png...
# ✅ Predictions drawn for P0282.png
# 📄 TXT saved: P0282.txt
# Processing P0283.png...
# ✅ Predictions drawn for P0283.png
# 📄 TXT saved: P0283.txt
# Processing P0285.png...
# ✅ Predictions drawn for P0285.png
# 📄 TXT saved: P0285.txt
# Processing P0286.png...
# ✅ Predictions drawn for P0286.png
# 📄 TXT saved: P0286.txt
# Processing P0288.png...
# ✅ Predictions drawn for P0288.png
# 📄 TXT saved: P0288.txt
# Processing P0289.png...
# ✅ Predictions drawn for P0289.png
# 📄 TXT saved: P0289.txt
# Processing P0292.png...
# ✅ Predictions drawn for P0292.png
# 📄 TXT saved: P0292.txt
# Processing P0293.png...
# ✅ Predictions drawn for P0293.png
# 📄 TXT saved: P0293.txt
# Processing P0294.png...
# ✅ Predictions drawn for P0294.png
# 📄 TXT saved: P0294.txt
# Processing P0296.png...
# ✅ Predictions drawn for P0296.png
# 📄 TXT saved: P0296.txt
# Processing P0299.png...
# ✅ Predictions drawn for P0299.png
# 📄 TXT saved: P0299.txt
# Processing P0301.png...
# ✅ Predictions drawn for P0301.png
# 📄 TXT saved: P0301.txt
# Processing P0303.png...
# ✅ Predictions drawn for P0303.png
# 📄 TXT saved: P0303.txt
# Processing P0308.png...
# ✅ Predictions drawn for P0308.png
# 📄 TXT saved: P0308.txt
# Processing P0310.png...
# ✅ Predictions drawn for P0310.png
# 📄 TXT saved: P0310.txt
# Processing P0313.png...
# ✅ Predictions drawn for P0313.png
# 📄 TXT saved: P0313.txt
# Processing P0314.png...
# ✅ Predictions drawn for P0314.png
# 📄 TXT saved: P0314.txt
# Processing P0315.png...
# ✅ Predictions drawn for P0315.png
# 📄 TXT saved: P0315.txt
# Processing P0317.png...
# ✅ Predictions drawn for P0317.png
# 📄 TXT saved: P0317.txt
# Processing P0321.png...
# ✅ Predictions drawn for P0321.png
# 📄 TXT saved: P0321.txt
# Processing P0322.png...
# ✅ Predictions drawn for P0322.png
# 📄 TXT saved: P0322.txt
# Processing P0324.png...
# ✅ Predictions drawn for P0324.png
# 📄 TXT saved: P0324.txt
# Processing P0327.png...
# ✅ Predictions drawn for P0327.png
# 📄 TXT saved: P0327.txt
# Processing P0330.png...
# ✅ Predictions drawn for P0330.png
# 📄 TXT saved: P0330.txt
# Processing P0332.png...
# ✅ Predictions drawn for P0332.png
# 📄 TXT saved: P0332.txt
# Processing P0334.png...
# ✅ Predictions drawn for P0334.png
# 📄 TXT saved: P0334.txt
# Processing P0335.png...
# ✅ Predictions drawn for P0335.png
# 📄 TXT saved: P0335.txt
# Processing P0337.png...
# ✅ Predictions drawn for P0337.png
# 📄 TXT saved: P0337.txt
# Processing P0338.png...
# ✅ Predictions drawn for P0338.png
# 📄 TXT saved: P0338.txt
# Processing P0339.png...
# ✅ Predictions drawn for P0339.png
# 📄 TXT saved: P0339.txt
# Processing P0340.png...
# ✅ Predictions drawn for P0340.png
# 📄 TXT saved: P0340.txt
# Processing P0343.png...
# ✅ Predictions drawn for P0343.png
# 📄 TXT saved: P0343.txt
# Processing P0344.png...
# ✅ Predictions drawn for P0344.png
# 📄 TXT saved: P0344.txt
# Processing P0345.png...
# ✅ Predictions drawn for P0345.png
# 📄 TXT saved: P0345.txt
# Processing P0346.png...
# ✅ Predictions drawn for P0346.png
# 📄 TXT saved: P0346.txt
# Processing P0349.png...
# ✅ Predictions drawn for P0349.png
# 📄 TXT saved: P0349.txt
# Processing P0350.png...
# ✅ Predictions drawn for P0350.png
# 📄 TXT saved: P0350.txt
# Processing P0355.png...
# ✅ Predictions drawn for P0355.png
# 📄 TXT saved: P0355.txt
# Processing P0357.png...
# ✅ Predictions drawn for P0357.png
# 📄 TXT saved: P0357.txt
# Processing P0358.png...
# ✅ Predictions drawn for P0358.png
# 📄 TXT saved: P0358.txt
# Processing P0360.png...
# ✅ Predictions drawn for P0360.png
# 📄 TXT saved: P0360.txt
# Processing P0361.png...
# ✅ Predictions drawn for P0361.png
# 📄 TXT saved: P0361.txt
# Processing P0362.png...
# ✅ Predictions drawn for P0362.png
# 📄 TXT saved: P0362.txt
# Processing P0363.png...
# ✅ Predictions drawn for P0363.png
# 📄 TXT saved: P0363.txt
# Processing P0364.png...
# ✅ Predictions drawn for P0364.png
# 📄 TXT saved: P0364.txt
# Processing P0365.png...
# ✅ Predictions drawn for P0365.png
# 📄 TXT saved: P0365.txt
# Processing P0366.png...
# ✅ Predictions drawn for P0366.png
# 📄 TXT saved: P0366.txt
# Processing P0367.png...
# ✅ Predictions drawn for P0367.png
# 📄 TXT saved: P0367.txt
# Processing P0370.png...
# ✅ Predictions drawn for P0370.png
# 📄 TXT saved: P0370.txt
# Processing P0371.png...
# ✅ Predictions drawn for P0371.png
# 📄 TXT saved: P0371.txt
# Processing P0373.png...
# ✅ Predictions drawn for P0373.png
# 📄 TXT saved: P0373.txt
# Processing P0376.png...
# ✅ Predictions drawn for P0376.png
# 📄 TXT saved: P0376.txt
# Processing P0378.png...
# ✅ Predictions drawn for P0378.png
# 📄 TXT saved: P0378.txt
# Processing P0379.png...
# ✅ Predictions drawn for P0379.png
# 📄 TXT saved: P0379.txt
# Processing P0380.png...
# ✅ Predictions drawn for P0380.png
# 📄 TXT saved: P0380.txt
# Processing P0381.png...
# ✅ Predictions drawn for P0381.png
# 📄 TXT saved: P0381.txt
# Processing P0383.png...
# ✅ Predictions drawn for P0383.png
# 📄 TXT saved: P0383.txt
# Processing P0384.png...
# ✅ Predictions drawn for P0384.png
# 📄 TXT saved: P0384.txt
# Processing P0386.png...
# ✅ Predictions drawn for P0386.png
# 📄 TXT saved: P0386.txt
# Processing P0387.png...
# ✅ Predictions drawn for P0387.png
# 📄 TXT saved: P0387.txt
# Processing P0388.png...
# ✅ Predictions drawn for P0388.png
# 📄 TXT saved: P0388.txt
# Processing P0389.png...
# ✅ Predictions drawn for P0389.png
# 📄 TXT saved: P0389.txt
# Processing P0391.png...
# ✅ Predictions drawn for P0391.png
# 📄 TXT saved: P0391.txt
# Processing P0392.png...
# ✅ Predictions drawn for P0392.png
# 📄 TXT saved: P0392.txt
# Processing P0393.png...
# ✅ Predictions drawn for P0393.png
# 📄 TXT saved: P0393.txt
# Processing P0395.png...
# ✅ Predictions drawn for P0395.png
# 📄 TXT saved: P0395.txt
# Processing P0400.png...
# ✅ Predictions drawn for P0400.png
# 📄 TXT saved: P0400.txt
# Processing P0401.png...
# ✅ Predictions drawn for P0401.png
# 📄 TXT saved: P0401.txt
# Processing P0404.png...
# ✅ Predictions drawn for P0404.png
# 📄 TXT saved: P0404.txt
# Processing P0405.png...
# ✅ Predictions drawn for P0405.png
# 📄 TXT saved: P0405.txt
# Processing P0406.png...
# ✅ Predictions drawn for P0406.png
# 📄 TXT saved: P0406.txt
# Processing P0407.png...
# ✅ Predictions drawn for P0407.png
# 📄 TXT saved: P0407.txt
# Processing P0413.png...
# ✅ Predictions drawn for P0413.png
# 📄 TXT saved: P0413.txt
# Processing P0415.png...
# ✅ Predictions drawn for P0415.png
# 📄 TXT saved: P0415.txt
# Processing P0416.png...
# ✅ Predictions drawn for P0416.png
# 📄 TXT saved: P0416.txt
# Processing P0417.png...
# ✅ Predictions drawn for P0417.png
# 📄 TXT saved: P0417.txt
# Processing P0418.png...
# ✅ Predictions drawn for P0418.png
# 📄 TXT saved: P0418.txt
# Processing P0419.png...
# ✅ Predictions drawn for P0419.png
# 📄 TXT saved: P0419.txt
# Processing P0421.png...
# ✅ Predictions drawn for P0421.png
# 📄 TXT saved: P0421.txt
# Processing P0422.png...
# ✅ Predictions drawn for P0422.png
# 📄 TXT saved: P0422.txt
# Processing P0424.png...
# ✅ Predictions drawn for P0424.png
# 📄 TXT saved: P0424.txt
# Processing P0425.png...
# ✅ Predictions drawn for P0425.png
# 📄 TXT saved: P0425.txt
# Processing P0426.png...
# ✅ Predictions drawn for P0426.png
# 📄 TXT saved: P0426.txt
# Processing P0428.png...
# ✅ Predictions drawn for P0428.png
# 📄 TXT saved: P0428.txt
# Processing P0430.png...
# ✅ Predictions drawn for P0430.png
# 📄 TXT saved: P0430.txt
# Processing P0431.png...
# ✅ Predictions drawn for P0431.png
# 📄 TXT saved: P0431.txt
# Processing P0434.png...
# ✅ Predictions drawn for P0434.png
# 📄 TXT saved: P0434.txt
# Processing P0435.png...
# ✅ Predictions drawn for P0435.png
# 📄 TXT saved: P0435.txt
# Processing P0436.png...
# ✅ Predictions drawn for P0436.png
# 📄 TXT saved: P0436.txt
# Processing P0437.png...
# ✅ Predictions drawn for P0437.png
# 📄 TXT saved: P0437.txt
# Processing P0438.png...
# ✅ Predictions drawn for P0438.png
# 📄 TXT saved: P0438.txt
# Processing P0439.png...
# ✅ Predictions drawn for P0439.png
# 📄 TXT saved: P0439.txt
# Processing P0440.png...
# ✅ Predictions drawn for P0440.png
# 📄 TXT saved: P0440.txt
# Processing P0441.png...
# ✅ Predictions drawn for P0441.png
# 📄 TXT saved: P0441.txt
# Processing P0442.png...
# ✅ Predictions drawn for P0442.png
# 📄 TXT saved: P0442.txt
# Processing P0443.png...
# ✅ Predictions drawn for P0443.png
# 📄 TXT saved: P0443.txt
# Processing P0445.png...
# ✅ Predictions drawn for P0445.png
# 📄 TXT saved: P0445.txt
# Processing P0446.png...
# ✅ Predictions drawn for P0446.png
# 📄 TXT saved: P0446.txt
# Processing P0448.png...
# ✅ Predictions drawn for P0448.png
# 📄 TXT saved: P0448.txt
# Processing P0450.png...
# ✅ Predictions drawn for P0450.png
# 📄 TXT saved: P0450.txt
# Processing P0452.png...
# ✅ Predictions drawn for P0452.png
# 📄 TXT saved: P0452.txt
# Processing P0453.png...
# ✅ Predictions drawn for P0453.png
# 📄 TXT saved: P0453.txt
# Processing P0455.png...
# ✅ Predictions drawn for P0455.png
# 📄 TXT saved: P0455.txt
# Processing P0458.png...
# ✅ Predictions drawn for P0458.png
# 📄 TXT saved: P0458.txt
# Processing P0459.png...
# ✅ Predictions drawn for P0459.png
# 📄 TXT saved: P0459.txt
# Processing P0460.png...
# ✅ Predictions drawn for P0460.png
# 📄 TXT saved: P0460.txt
# Processing P0461.png...
# ✅ Predictions drawn for P0461.png
# 📄 TXT saved: P0461.txt
# Processing P0464.png...
# ✅ Predictions drawn for P0464.png
# 📄 TXT saved: P0464.txt
# Processing P0465.png...
# ✅ Predictions drawn for P0465.png
# 📄 TXT saved: P0465.txt
# Processing P0468.png...
# ✅ Predictions drawn for P0468.png
# 📄 TXT saved: P0468.txt
# Processing P0469.png...
# ✅ Predictions drawn for P0469.png
# 📄 TXT saved: P0469.txt
# Processing P0471.png...
# ✅ Predictions drawn for P0471.png
# 📄 TXT saved: P0471.txt
# Processing P0475.png...
# ✅ Predictions drawn for P0475.png
# 📄 TXT saved: P0475.txt
# Processing P0477.png...
# ✅ Predictions drawn for P0477.png
# 📄 TXT saved: P0477.txt
# Processing P0478.png...
# ✅ Predictions drawn for P0478.png
# 📄 TXT saved: P0478.txt
# Processing P0479.png...
# ✅ Predictions drawn for P0479.png
# 📄 TXT saved: P0479.txt
# Processing P0481.png...
# ✅ Predictions drawn for P0481.png
# 📄 TXT saved: P0481.txt
# Processing P0482.png...
# ✅ Predictions drawn for P0482.png
# 📄 TXT saved: P0482.txt
# Processing P0483.png...
# ✅ Predictions drawn for P0483.png
# 📄 TXT saved: P0483.txt
# Processing P0484.png...
# ✅ Predictions drawn for P0484.png
# 📄 TXT saved: P0484.txt
# Processing P0487.png...
# ✅ Predictions drawn for P0487.png
# 📄 TXT saved: P0487.txt
# Processing P0488.png...
# ✅ Predictions drawn for P0488.png
# 📄 TXT saved: P0488.txt
# Processing P0489.png...
# ✅ Predictions drawn for P0489.png
# 📄 TXT saved: P0489.txt
# Processing P0493.png...
# ✅ Predictions drawn for P0493.png
# 📄 TXT saved: P0493.txt
# Processing P0494.png...
# ✅ Predictions drawn for P0494.png
# 📄 TXT saved: P0494.txt
# Processing P0495.png...
# ✅ Predictions drawn for P0495.png
# 📄 TXT saved: P0495.txt
# Processing P0503.png...
# ✅ Predictions drawn for P0503.png
# 📄 TXT saved: P0503.txt
# Processing P0504.png...
# ✅ Predictions drawn for P0504.png
# 📄 TXT saved: P0504.txt
# Processing P0505.png...
# ✅ Predictions drawn for P0505.png
# 📄 TXT saved: P0505.txt
# Processing P0510.png...
# ✅ Predictions drawn for P0510.png
# 📄 TXT saved: P0510.txt
# Processing P0512.png...
# ✅ Predictions drawn for P0512.png
# 📄 TXT saved: P0512.txt
# Processing P0516.png...
# ✅ Predictions drawn for P0516.png
# 📄 TXT saved: P0516.txt
# Processing P0517.png...
# ✅ Predictions drawn for P0517.png
# 📄 TXT saved: P0517.txt
# Processing P0520.png...
# ✅ Predictions drawn for P0520.png
# 📄 TXT saved: P0520.txt
# Processing P0521.png...
# ✅ Predictions drawn for P0521.png
# 📄 TXT saved: P0521.txt
# Processing P0522.png...
# ✅ Predictions drawn for P0522.png
# 📄 TXT saved: P0522.txt
# Processing P0527.png...
# ✅ Predictions drawn for P0527.png
# 📄 TXT saved: P0527.txt
# Processing P0531.png...
# ✅ Predictions drawn for P0531.png
# 📄 TXT saved: P0531.txt
# Processing P0533.png...
# ✅ Predictions drawn for P0533.png
# 📄 TXT saved: P0533.txt
# Processing P0535.png...
# ✅ Predictions drawn for P0535.png
# 📄 TXT saved: P0535.txt
# Processing P0537.png...
# ✅ Predictions drawn for P0537.png
# 📄 TXT saved: P0537.txt
# Processing P0538.png...
# ✅ Predictions drawn for P0538.png
# 📄 TXT saved: P0538.txt
# Processing P0541.png...
# ✅ Predictions drawn for P0541.png
# 📄 TXT saved: P0541.txt
# Processing P0542.png...
# ✅ Predictions drawn for P0542.png
# 📄 TXT saved: P0542.txt
# Processing P0544.png...
# ✅ Predictions drawn for P0544.png
# 📄 TXT saved: P0544.txt
# Processing P0546.png...
# ✅ Predictions drawn for P0546.png
# 📄 TXT saved: P0546.txt
# Processing P0548.png...
# ✅ Predictions drawn for P0548.png
# 📄 TXT saved: P0548.txt
# Processing P0549.png...
# ✅ Predictions drawn for P0549.png
# 📄 TXT saved: P0549.txt
# Processing P0553.png...
# ✅ Predictions drawn for P0553.png
# 📄 TXT saved: P0553.txt
# Processing P0554.png...
# ✅ Predictions drawn for P0554.png
# 📄 TXT saved: P0554.txt
# Processing P0555.png...
# ✅ Predictions drawn for P0555.png
# 📄 TXT saved: P0555.txt
# Processing P0556.png...
# ✅ Predictions drawn for P0556.png
# 📄 TXT saved: P0556.txt
# Processing P0562.png...
# ✅ Predictions drawn for P0562.png
# 📄 TXT saved: P0562.txt
# Processing P0563.png...
# ✅ Predictions drawn for P0563.png
# 📄 TXT saved: P0563.txt
# Processing P0565.png...
# ✅ Predictions drawn for P0565.png
# 📄 TXT saved: P0565.txt
# Processing P0567.png...
# ✅ Predictions drawn for P0567.png
# 📄 TXT saved: P0567.txt
# Processing P0568.png...
# ✅ Predictions drawn for P0568.png
# 📄 TXT saved: P0568.txt
# Processing P0569.png...
# ✅ Predictions drawn for P0569.png
# 📄 TXT saved: P0569.txt
# Processing P0571.png...
# ✅ Predictions drawn for P0571.png
# 📄 TXT saved: P0571.txt
# Processing P0572.png...
# ✅ Predictions drawn for P0572.png
# 📄 TXT saved: P0572.txt
# Processing P0573.png...
# ✅ Predictions drawn for P0573.png
# 📄 TXT saved: P0573.txt
# Processing P0578.png...
# ✅ Predictions drawn for P0578.png
# 📄 TXT saved: P0578.txt
# Processing P0580.png...
# ✅ Predictions drawn for P0580.png
# 📄 TXT saved: P0580.txt
# Processing P0581.png...
# ✅ Predictions drawn for P0581.png
# 📄 TXT saved: P0581.txt
# Processing P0582.png...
# ✅ Predictions drawn for P0582.png
# 📄 TXT saved: P0582.txt
# Processing P0586.png...
# ✅ Predictions drawn for P0586.png
# 📄 TXT saved: P0586.txt
# Processing P0587.png...
# ✅ Predictions drawn for P0587.png
# 📄 TXT saved: P0587.txt
# Processing P0591.png...
# ✅ Predictions drawn for P0591.png
# 📄 TXT saved: P0591.txt
# Processing P0593.png...
# ✅ Predictions drawn for P0593.png
# 📄 TXT saved: P0593.txt
# Processing P0595.png...
# ✅ Predictions drawn for P0595.png
# 📄 TXT saved: P0595.txt
# Processing P0596.png...
# ✅ Predictions drawn for P0596.png
# 📄 TXT saved: P0596.txt
# Processing P0597.png...
# ✅ Predictions drawn for P0597.png
# 📄 TXT saved: P0597.txt
# Processing P0601.png...
# ✅ Predictions drawn for P0601.png
# 📄 TXT saved: P0601.txt
# Processing P0602.png...
# ✅ Predictions drawn for P0602.png
# 📄 TXT saved: P0602.txt
# Processing P0603.png...
# ✅ Predictions drawn for P0603.png
# 📄 TXT saved: P0603.txt
# Processing P0605.png...
# ✅ Predictions drawn for P0605.png
# 📄 TXT saved: P0605.txt
# Processing P0607.png...
# ✅ Predictions drawn for P0607.png
# 📄 TXT saved: P0607.txt
# Processing P0609.png...
# ✅ Predictions drawn for P0609.png
# 📄 TXT saved: P0609.txt
# Processing P0610.png...
# ✅ Predictions drawn for P0610.png
# 📄 TXT saved: P0610.txt
# Processing P0611.png...
# ✅ Predictions drawn for P0611.png
# 📄 TXT saved: P0611.txt
# Processing P0612.png...
# ✅ Predictions drawn for P0612.png
# 📄 TXT saved: P0612.txt
# Processing P0614.png...
# ✅ Predictions drawn for P0614.png
# 📄 TXT saved: P0614.txt
# Processing P0617.png...
# ✅ Predictions drawn for P0617.png
# 📄 TXT saved: P0617.txt
# Processing P0618.png...
# ✅ Predictions drawn for P0618.png
# 📄 TXT saved: P0618.txt
# Processing P0619.png...
# ✅ Predictions drawn for P0619.png
# 📄 TXT saved: P0619.txt
# Processing P0620.png...
# ✅ Predictions drawn for P0620.png
# 📄 TXT saved: P0620.txt
# Processing P0624.png...
# ✅ Predictions drawn for P0624.png
# 📄 TXT saved: P0624.txt
# Processing P0625.png...
# ✅ Predictions drawn for P0625.png
# 📄 TXT saved: P0625.txt
# Processing P0626.png...
# ✅ Predictions drawn for P0626.png
# 📄 TXT saved: P0626.txt
# Processing P0627.png...
# ✅ Predictions drawn for P0627.png
# 📄 TXT saved: P0627.txt
# Processing P0629.png...
# ✅ Predictions drawn for P0629.png
# 📄 TXT saved: P0629.txt
# Processing P0630.png...
# ✅ Predictions drawn for P0630.png
# 📄 TXT saved: P0630.txt
# Processing P0631.png...
# ✅ Predictions drawn for P0631.png
# 📄 TXT saved: P0631.txt
# Processing P0632.png...
# ✅ Predictions drawn for P0632.png
# 📄 TXT saved: P0632.txt
# Processing P0634.png...
# ✅ Predictions drawn for P0634.png
# 📄 TXT saved: P0634.txt
# Processing P0637.png...
# ✅ Predictions drawn for P0637.png
# 📄 TXT saved: P0637.txt
# Processing P0638.png...
# ✅ Predictions drawn for P0638.png
# 📄 TXT saved: P0638.txt
# Processing P0641.png...
# ✅ Predictions drawn for P0641.png
# 📄 TXT saved: P0641.txt
# Processing P0642.png...
# ✅ Predictions drawn for P0642.png
# 📄 TXT saved: P0642.txt
# Processing P0646.png...
# ✅ Predictions drawn for P0646.png
# 📄 TXT saved: P0646.txt
# Processing P0648.png...
# ✅ Predictions drawn for P0648.png
# 📄 TXT saved: P0648.txt
# Processing P0649.png...
# ✅ Predictions drawn for P0649.png
# 📄 TXT saved: P0649.txt
# Processing P0652.png...
# ✅ Predictions drawn for P0652.png
# 📄 TXT saved: P0652.txt
# Processing P0653.png...
# ✅ Predictions drawn for P0653.png
# 📄 TXT saved: P0653.txt
# Processing P0656.png...
# ✅ Predictions drawn for P0656.png
# 📄 TXT saved: P0656.txt
# Processing P0658.png...
# ✅ Predictions drawn for P0658.png
# 📄 TXT saved: P0658.txt
# Processing P0664.png...
# ✅ Predictions drawn for P0664.png
# 📄 TXT saved: P0664.txt
# Processing P0666.png...
# ✅ Predictions drawn for P0666.png
# 📄 TXT saved: P0666.txt
# Processing P0668.png...
# ✅ Predictions drawn for P0668.png
# 📄 TXT saved: P0668.txt
# Processing P0676.png...
# ✅ Predictions drawn for P0676.png
# 📄 TXT saved: P0676.txt
# Processing P0677.png...
# ✅ Predictions drawn for P0677.png
# 📄 TXT saved: P0677.txt
# Processing P0685.png...
# ✅ Predictions drawn for P0685.png
# 📄 TXT saved: P0685.txt
# Processing P0687.png...
# ✅ Predictions drawn for P0687.png
# 📄 TXT saved: P0687.txt
# Processing P0688.png...
# ✅ Predictions drawn for P0688.png
# 📄 TXT saved: P0688.txt
# Processing P0689.png...
# ✅ Predictions drawn for P0689.png
# 📄 TXT saved: P0689.txt
# Processing P0691.png...
# ✅ Predictions drawn for P0691.png
# 📄 TXT saved: P0691.txt
# Processing P0692.png...
# ✅ Predictions drawn for P0692.png
# 📄 TXT saved: P0692.txt
# Processing P0693.png...
# ✅ Predictions drawn for P0693.png
# 📄 TXT saved: P0693.txt
# Processing P0695.png...
# ✅ Predictions drawn for P0695.png
# 📄 TXT saved: P0695.txt
# Processing P0697.png...
# ✅ Predictions drawn for P0697.png
# 📄 TXT saved: P0697.txt
# Processing P0699.png...
# ✅ Predictions drawn for P0699.png
# 📄 TXT saved: P0699.txt
# Processing P0700.png...
# ✅ Predictions drawn for P0700.png
# 📄 TXT saved: P0700.txt
# Processing P0702.png...
# ✅ Predictions drawn for P0702.png
# 📄 TXT saved: P0702.txt
# Processing P0703.png...
# ✅ Predictions drawn for P0703.png
# 📄 TXT saved: P0703.txt
# Processing P0707.png...
# ✅ Predictions drawn for P0707.png
# 📄 TXT saved: P0707.txt
# Processing P0711.png...
# ✅ Predictions drawn for P0711.png
# 📄 TXT saved: P0711.txt
# Processing P0713.png...
# ✅ Predictions drawn for P0713.png
# 📄 TXT saved: P0713.txt
# Processing P0714.png...
# ✅ Predictions drawn for P0714.png
# 📄 TXT saved: P0714.txt
# Processing P0716.png...
# ✅ Predictions drawn for P0716.png
# 📄 TXT saved: P0716.txt
# Processing P0719.png...
# ✅ Predictions drawn for P0719.png
# 📄 TXT saved: P0719.txt
# Processing P0722.png...
# ✅ Predictions drawn for P0722.png
# 📄 TXT saved: P0722.txt
# Processing P0723.png...
# ✅ Predictions drawn for P0723.png
# 📄 TXT saved: P0723.txt
# Processing P0724.png...
# ✅ Predictions drawn for P0724.png
# 📄 TXT saved: P0724.txt
# Processing P0726.png...
# ✅ Predictions drawn for P0726.png
# 📄 TXT saved: P0726.txt
# Processing P0727.png...
# ✅ Predictions drawn for P0727.png
# 📄 TXT saved: P0727.txt
# Processing P0728.png...
# ✅ Predictions drawn for P0728.png
# 📄 TXT saved: P0728.txt
# Processing P0730.png...
# ✅ Predictions drawn for P0730.png
# 📄 TXT saved: P0730.txt
# Processing P0731.png...
# ✅ Predictions drawn for P0731.png
# 📄 TXT saved: P0731.txt
# Processing P0732.png...
# ✅ Predictions drawn for P0732.png
# 📄 TXT saved: P0732.txt
# Processing P0733.png...
# ✅ Predictions drawn for P0733.png
# 📄 TXT saved: P0733.txt
# Processing P0734.png...
# ✅ Predictions drawn for P0734.png
# 📄 TXT saved: P0734.txt
# Processing P0737.png...
# ✅ Predictions drawn for P0737.png
# 📄 TXT saved: P0737.txt
# Processing P0738.png...
# ✅ Predictions drawn for P0738.png
# 📄 TXT saved: P0738.txt
# Processing P0743.png...
# ✅ Predictions drawn for P0743.png
# 📄 TXT saved: P0743.txt
# Processing P0744.png...
# ✅ Predictions drawn for P0744.png
# 📄 TXT saved: P0744.txt
# Processing P0745.png...
# ✅ Predictions drawn for P0745.png
# 📄 TXT saved: P0745.txt
# Processing P0746.png...
# ✅ Predictions drawn for P0746.png
# 📄 TXT saved: P0746.txt
# Processing P0750.png...
# ✅ Predictions drawn for P0750.png
# 📄 TXT saved: P0750.txt
# Processing P0753.png...
# ✅ Predictions drawn for P0753.png
# 📄 TXT saved: P0753.txt
# Processing P0754.png...
# ✅ Predictions drawn for P0754.png
# 📄 TXT saved: P0754.txt
# Processing P0755.png...
# ✅ Predictions drawn for P0755.png
# 📄 TXT saved: P0755.txt
# Processing P0757.png...
# ✅ Predictions drawn for P0757.png
# 📄 TXT saved: P0757.txt
# Processing P0759.png...
# ✅ Predictions drawn for P0759.png
# 📄 TXT saved: P0759.txt
# Processing P0760.png...
# ✅ Predictions drawn for P0760.png
# 📄 TXT saved: P0760.txt
# Processing P0762.png...
# ✅ Predictions drawn for P0762.png
# 📄 TXT saved: P0762.txt
# Processing P0766.png...
# ✅ Predictions drawn for P0766.png
# 📄 TXT saved: P0766.txt
# Processing P0768.png...
# ✅ Predictions drawn for P0768.png
# 📄 TXT saved: P0768.txt
# Processing P0769.png...
# ✅ Predictions drawn for P0769.png
# 📄 TXT saved: P0769.txt
# Processing P0775.png...
# ✅ Predictions drawn for P0775.png
# 📄 TXT saved: P0775.txt
# Processing P0777.png...
# ✅ Predictions drawn for P0777.png
# 📄 TXT saved: P0777.txt
# Processing P0778.png...
# ✅ Predictions drawn for P0778.png
# 📄 TXT saved: P0778.txt
# Processing P0779.png...
# ✅ Predictions drawn for P0779.png
# 📄 TXT saved: P0779.txt
# Processing P0780.png...
# ✅ Predictions drawn for P0780.png
# 📄 TXT saved: P0780.txt
# Processing P0781.png...
# ✅ Predictions drawn for P0781.png
# 📄 TXT saved: P0781.txt
# Processing P0782.png...
# ✅ Predictions drawn for P0782.png
# 📄 TXT saved: P0782.txt
# Processing P0783.png...
# ✅ Predictions drawn for P0783.png
# 📄 TXT saved: P0783.txt
# Processing P0785.png...
# ✅ Predictions drawn for P0785.png
# 📄 TXT saved: P0785.txt
# Processing P0786.png...
# ✅ Predictions drawn for P0786.png
# 📄 TXT saved: P0786.txt
# Processing P0790.png...
# ✅ Predictions drawn for P0790.png
# 📄 TXT saved: P0790.txt
# Processing P0792.png...
# ✅ Predictions drawn for P0792.png
# 📄 TXT saved: P0792.txt
# Processing P0794.png...
# ✅ Predictions drawn for P0794.png
# 📄 TXT saved: P0794.txt
# Processing P0800.png...
# ✅ Predictions drawn for P0800.png
# 📄 TXT saved: P0800.txt
# Processing P0803.png...
# ✅ Predictions drawn for P0803.png
# 📄 TXT saved: P0803.txt
# Processing P0804.png...
# ✅ Predictions drawn for P0804.png
# 📄 TXT saved: P0804.txt
# Processing P0805.png...
# ✅ Predictions drawn for P0805.png
# 📄 TXT saved: P0805.txt
# Processing P0806.png...
# ✅ Predictions drawn for P0806.png
# 📄 TXT saved: P0806.txt
# Processing P0809.png...
# ✅ Predictions drawn for P0809.png
# 📄 TXT saved: P0809.txt
# Processing P0810.png...
# ✅ Predictions drawn for P0810.png
# 📄 TXT saved: P0810.txt
# Processing P0817.png...
# ✅ Predictions drawn for P0817.png
# 📄 TXT saved: P0817.txt
# Processing P0818.png...
# ✅ Predictions drawn for P0818.png
# 📄 TXT saved: P0818.txt
# Processing P0819.png...
# ✅ Predictions drawn for P0819.png
# 📄 TXT saved: P0819.txt
# Processing P0821.png...
# ✅ Predictions drawn for P0821.png
# 📄 TXT saved: P0821.txt
# Processing P0823.png...
# ✅ Predictions drawn for P0823.png
# 📄 TXT saved: P0823.txt
# Processing P0825.png...
# ✅ Predictions drawn for P0825.png
# 📄 TXT saved: P0825.txt
# Processing P0826.png...
# ✅ Predictions drawn for P0826.png
# 📄 TXT saved: P0826.txt
# Processing P0827.png...
# ✅ Predictions drawn for P0827.png
# 📄 TXT saved: P0827.txt
# Processing P0828.png...
# ✅ Predictions drawn for P0828.png
# 📄 TXT saved: P0828.txt
# Processing P0829.png...
# ✅ Predictions drawn for P0829.png
# 📄 TXT saved: P0829.txt
# Processing P0831.png...
# ✅ Predictions drawn for P0831.png
# 📄 TXT saved: P0831.txt
# Processing P0832.png...
# ✅ Predictions drawn for P0832.png
# 📄 TXT saved: P0832.txt
# Processing P0835.png...
# ✅ Predictions drawn for P0835.png
# 📄 TXT saved: P0835.txt
# Processing P0840.png...
# ✅ Predictions drawn for P0840.png
# 📄 TXT saved: P0840.txt
# Processing P0843.png...
# ✅ Predictions drawn for P0843.png
# 📄 TXT saved: P0843.txt
# Processing P0845.png...
# ✅ Predictions drawn for P0845.png
# 📄 TXT saved: P0845.txt
# Processing P0846.png...
# ✅ Predictions drawn for P0846.png
# 📄 TXT saved: P0846.txt
# Processing P0848.png...
# ✅ Predictions drawn for P0848.png
# 📄 TXT saved: P0848.txt
# Processing P0849.png...
# ✅ Predictions drawn for P0849.png
# 📄 TXT saved: P0849.txt
# Processing P0850.png...
# ✅ Predictions drawn for P0850.png
# 📄 TXT saved: P0850.txt
# Processing P0851.png...
# ✅ Predictions drawn for P0851.png
# 📄 TXT saved: P0851.txt
# Processing P0853.png...
# ✅ Predictions drawn for P0853.png
# 📄 TXT saved: P0853.txt
# Processing P0855.png...
# ✅ Predictions drawn for P0855.png
# 📄 TXT saved: P0855.txt
# Processing P0856.png...
# ✅ Predictions drawn for P0856.png
# 📄 TXT saved: P0856.txt
# Processing P0857.png...
# ✅ Predictions drawn for P0857.png
# 📄 TXT saved: P0857.txt
# Processing P0860.png...
# ✅ Predictions drawn for P0860.png
# 📄 TXT saved: P0860.txt
# Processing P0861.png...
# ✅ Predictions drawn for P0861.png
# 📄 TXT saved: P0861.txt
# Processing P0867.png...
# ✅ Predictions drawn for P0867.png
# 📄 TXT saved: P0867.txt
# Processing P0868.png...
# ✅ Predictions drawn for P0868.png
# 📄 TXT saved: P0868.txt
# Processing P0869.png...
# ✅ Predictions drawn for P0869.png
# 📄 TXT saved: P0869.txt
# Processing P0870.png...
# ✅ Predictions drawn for P0870.png
# 📄 TXT saved: P0870.txt
# Processing P0871.png...
# ✅ Predictions drawn for P0871.png
# 📄 TXT saved: P0871.txt
# Processing P0872.png...
# ✅ Predictions drawn for P0872.png
# 📄 TXT saved: P0872.txt
# Processing P0873.png...
# ✅ Predictions drawn for P0873.png
# 📄 TXT saved: P0873.txt
# Processing P0874.png...
# ✅ Predictions drawn for P0874.png
# 📄 TXT saved: P0874.txt
# Processing P0875.png...
# ✅ Predictions drawn for P0875.png
# 📄 TXT saved: P0875.txt
# Processing P0878.png...
# ✅ Predictions drawn for P0878.png
# 📄 TXT saved: P0878.txt
# Processing P0879.png...
# ✅ Predictions drawn for P0879.png
# 📄 TXT saved: P0879.txt
# Processing P0881.png...
# ✅ Predictions drawn for P0881.png
# 📄 TXT saved: P0881.txt
# Processing P0883.png...
# ✅ Predictions drawn for P0883.png
# 📄 TXT saved: P0883.txt
# Processing P0884.png...
# ✅ Predictions drawn for P0884.png
# 📄 TXT saved: P0884.txt
# Processing P0885.png...
# ✅ Predictions drawn for P0885.png
# 📄 TXT saved: P0885.txt
# Processing P0888.png...
# ✅ Predictions drawn for P0888.png
# 📄 TXT saved: P0888.txt
# Processing P0890.png...
# ✅ Predictions drawn for P0890.png
# 📄 TXT saved: P0890.txt
# Processing P0892.png...
# ✅ Predictions drawn for P0892.png
# 📄 TXT saved: P0892.txt
# Processing P0893.png...
# ✅ Predictions drawn for P0893.png
# 📄 TXT saved: P0893.txt
# Processing P0894.png...
# ✅ Predictions drawn for P0894.png
# 📄 TXT saved: P0894.txt
# Processing P0895.png...
# ✅ Predictions drawn for P0895.png
# 📄 TXT saved: P0895.txt
# Processing P0896.png...
# ✅ Predictions drawn for P0896.png
# 📄 TXT saved: P0896.txt
# Processing P0898.png...
# ✅ Predictions drawn for P0898.png
# 📄 TXT saved: P0898.txt
# Processing P0899.png...
# ✅ Predictions drawn for P0899.png
# 📄 TXT saved: P0899.txt
# Processing P0900.png...
# ✅ Predictions drawn for P0900.png
# 📄 TXT saved: P0900.txt
# Processing P0905.png...
# ✅ Predictions drawn for P0905.png
# 📄 TXT saved: P0905.txt
# Processing P0906.png...
# ✅ Predictions drawn for P0906.png
# 📄 TXT saved: P0906.txt
# Processing P0907.png...
# ✅ Predictions drawn for P0907.png
# 📄 TXT saved: P0907.txt
# Processing P0908.png...
# ✅ Predictions drawn for P0908.png
# 📄 TXT saved: P0908.txt
# Processing P0909.png...
# ✅ Predictions drawn for P0909.png
# 📄 TXT saved: P0909.txt
# Processing P0911.png...
# ✅ Predictions drawn for P0911.png
# 📄 TXT saved: P0911.txt
# Processing P0913.png...
# ✅ Predictions drawn for P0913.png
# 📄 TXT saved: P0913.txt
# Processing P0914.png...
# ✅ Predictions drawn for P0914.png
# 📄 TXT saved: P0914.txt
# Processing P0915.png...
# ✅ Predictions drawn for P0915.png
# 📄 TXT saved: P0915.txt
# Processing P0918.png...
# ✅ Predictions drawn for P0918.png
# 📄 TXT saved: P0918.txt
# Processing P0920.png...
# ✅ Predictions drawn for P0920.png
# 📄 TXT saved: P0920.txt
# Processing P0921.png...
# ✅ Predictions drawn for P0921.png
# 📄 TXT saved: P0921.txt
# Processing P0922.png...
# ✅ Predictions drawn for P0922.png
# 📄 TXT saved: P0922.txt
# Processing P0925.png...
# ✅ Predictions drawn for P0925.png
# 📄 TXT saved: P0925.txt
# Processing P0926.png...
# ✅ Predictions drawn for P0926.png
# 📄 TXT saved: P0926.txt
# Processing P0928.png...
# ✅ Predictions drawn for P0928.png
# 📄 TXT saved: P0928.txt
# Processing P0933.png...
# ✅ Predictions drawn for P0933.png
# 📄 TXT saved: P0933.txt
# Processing P0934.png...
# ✅ Predictions drawn for P0934.png
# 📄 TXT saved: P0934.txt
# Processing P0938.png...
# ✅ Predictions drawn for P0938.png
# 📄 TXT saved: P0938.txt
# Processing P0940.png...
# ✅ Predictions drawn for P0940.png
# 📄 TXT saved: P0940.txt
# Processing P0941.png...
# ✅ Predictions drawn for P0941.png
# 📄 TXT saved: P0941.txt
# Processing P0944.png...
# ✅ Predictions drawn for P0944.png
# 📄 TXT saved: P0944.txt
# Processing P0946.png...
# ✅ Predictions drawn for P0946.png
# 📄 TXT saved: P0946.txt
# Processing P0947.png...
# ✅ Predictions drawn for P0947.png
# 📄 TXT saved: P0947.txt
# Processing P0948.png...
# ✅ Predictions drawn for P0948.png
# 📄 TXT saved: P0948.txt
# Processing P0950.png...
# ✅ Predictions drawn for P0950.png
# 📄 TXT saved: P0950.txt
# Processing P0951.png...
# ✅ Predictions drawn for P0951.png
# 📄 TXT saved: P0951.txt
# Processing P0952.png...
# ✅ Predictions drawn for P0952.png
# 📄 TXT saved: P0952.txt
# Processing P0957.png...
# ✅ Predictions drawn for P0957.png
# 📄 TXT saved: P0957.txt
# Processing P0960.png...
# ✅ Predictions drawn for P0960.png
# 📄 TXT saved: P0960.txt
# Processing P0963.png...
# ✅ Predictions drawn for P0963.png
# 📄 TXT saved: P0963.txt
# Processing P0966.png...
# ✅ Predictions drawn for P0966.png
# 📄 TXT saved: P0966.txt
# Processing P0967.png...
# ✅ Predictions drawn for P0967.png
# 📄 TXT saved: P0967.txt
# Processing P0972.png...
# ✅ Predictions drawn for P0972.png
# 📄 TXT saved: P0972.txt
# Processing P0973.png...
# ✅ Predictions drawn for P0973.png
# 📄 TXT saved: P0973.txt
# Processing P0975.png...
# ✅ Predictions drawn for P0975.png
# 📄 TXT saved: P0975.txt
# Processing P0978.png...
# ✅ Predictions drawn for P0978.png
# 📄 TXT saved: P0978.txt
# Processing P0979.png...
# ✅ Predictions drawn for P0979.png
# 📄 TXT saved: P0979.txt
# Processing P0980.png...
# ✅ Predictions drawn for P0980.png
# 📄 TXT saved: P0980.txt
# Processing P0981.png...
# ✅ Predictions drawn for P0981.png
# 📄 TXT saved: P0981.txt
# Processing P0986.png...
# ✅ Predictions drawn for P0986.png
# 📄 TXT saved: P0986.txt
# Processing P0987.png...
# ✅ Predictions drawn for P0987.png
# 📄 TXT saved: P0987.txt
# Processing P0991.png...
# ✅ Predictions drawn for P0991.png
# 📄 TXT saved: P0991.txt
# Processing P0993.png...
# ✅ Predictions drawn for P0993.png
# 📄 TXT saved: P0993.txt
# Processing P0995.png...
# ✅ Predictions drawn for P0995.png
# 📄 TXT saved: P0995.txt
# Processing P0999.png...
# ✅ Predictions drawn for P0999.png
# 📄 TXT saved: P0999.txt
# Processing P1003.png...
# ✅ Predictions drawn for P1003.png
# 📄 TXT saved: P1003.txt
# Processing P1006.png...
# ⚠️ No predictions for P1006.png, drawing dummy box.
# 📄 TXT saved: P1006.txt
# Processing P1010.png...
# ✅ Predictions drawn for P1010.png
# 📄 TXT saved: P1010.txt
# Processing P1012.png...
# ⚠️ No predictions for P1012.png, drawing dummy box.
# 📄 TXT saved: P1012.txt
# Processing P1015.png...
# ✅ Predictions drawn for P1015.png
# 📄 TXT saved: P1015.txt
# Processing P1016.png...
# ✅ Predictions drawn for P1016.png
# 📄 TXT saved: P1016.txt
# Processing P1019.png...
# ✅ Predictions drawn for P1019.png
# 📄 TXT saved: P1019.txt
# Processing P1020.png...
# ✅ Predictions drawn for P1020.png
# 📄 TXT saved: P1020.txt
# Processing P1026.png...
# ✅ Predictions drawn for P1026.png
# 📄 TXT saved: P1026.txt
# Processing P1027.png...
# ✅ Predictions drawn for P1027.png
# 📄 TXT saved: P1027.txt
# Processing P1037.png...
# ✅ Predictions drawn for P1037.png
# 📄 TXT saved: P1037.txt
# Processing P1043.png...
# ✅ Predictions drawn for P1043.png
# 📄 TXT saved: P1043.txt
# Processing P1046.png...
# ✅ Predictions drawn for P1046.png
# 📄 TXT saved: P1046.txt
# Processing P1047.png...
# ✅ Predictions drawn for P1047.png
# 📄 TXT saved: P1047.txt
# Processing P1049.png...
# ✅ Predictions drawn for P1049.png
# 📄 TXT saved: P1049.txt
# Processing P1052.png...
# ✅ Predictions drawn for P1052.png
# 📄 TXT saved: P1052.txt
# Processing P1053.png...
# ✅ Predictions drawn for P1053.png
# 📄 TXT saved: P1053.txt
# Processing P1054.png...
# ✅ Predictions drawn for P1054.png
# 📄 TXT saved: P1054.txt
# Processing P1055.png...
# ✅ Predictions drawn for P1055.png
# 📄 TXT saved: P1055.txt
# Processing P1057.png...
# ✅ Predictions drawn for P1057.png
# 📄 TXT saved: P1057.txt
# Processing P1059.png...
# ✅ Predictions drawn for P1059.png
# 📄 TXT saved: P1059.txt
# Processing P1060.png...
# ✅ Predictions drawn for P1060.png
# 📄 TXT saved: P1060.txt
# Processing P1061.png...
# ✅ Predictions drawn for P1061.png
# 📄 TXT saved: P1061.txt
# Processing P1062.png...
# ✅ Predictions drawn for P1062.png
# 📄 TXT saved: P1062.txt
# Processing P1063.png...
# ✅ Predictions drawn for P1063.png
# 📄 TXT saved: P1063.txt
# Processing P1067.png...
# ✅ Predictions drawn for P1067.png
# 📄 TXT saved: P1067.txt
# Processing P1069.png...
# ✅ Predictions drawn for P1069.png
# 📄 TXT saved: P1069.txt
# Processing P1070.png...
# ✅ Predictions drawn for P1070.png
# 📄 TXT saved: P1070.txt
# Processing P1071.png...
# ✅ Predictions drawn for P1071.png
# 📄 TXT saved: P1071.txt
# Processing P1073.png...
# ✅ Predictions drawn for P1073.png
# 📄 TXT saved: P1073.txt
# Processing P1076.png...
# ✅ Predictions drawn for P1076.png
# 📄 TXT saved: P1076.txt
# Processing P1077.png...
# ✅ Predictions drawn for P1077.png
# 📄 TXT saved: P1077.txt
# Processing P1078.png...
# ✅ Predictions drawn for P1078.png
# 📄 TXT saved: P1078.txt
# Processing P1079.png...
# ✅ Predictions drawn for P1079.png
# 📄 TXT saved: P1079.txt
# Processing P1080.png...
# ✅ Predictions drawn for P1080.png
# 📄 TXT saved: P1080.txt
# Processing P1084.png...
# ✅ Predictions drawn for P1084.png
# 📄 TXT saved: P1084.txt
# Processing P1087.png...
# ✅ Predictions drawn for P1087.png
# 📄 TXT saved: P1087.txt
# Processing P1089.png...
# ✅ Predictions drawn for P1089.png
# 📄 TXT saved: P1089.txt
# Processing P1092.png...
# ✅ Predictions drawn for P1092.png
# 📄 TXT saved: P1092.txt
# Processing P1094.png...
# ✅ Predictions drawn for P1094.png
# 📄 TXT saved: P1094.txt
# Processing P1096.png...
# ✅ Predictions drawn for P1096.png
# 📄 TXT saved: P1096.txt
# Processing P1098.png...
# ✅ Predictions drawn for P1098.png
# 📄 TXT saved: P1098.txt
# Processing P1105.png...
# ✅ Predictions drawn for P1105.png
# 📄 TXT saved: P1105.txt
# Processing P1107.png...
# ✅ Predictions drawn for P1107.png
# 📄 TXT saved: P1107.txt
# Processing P1108.png...
# ✅ Predictions drawn for P1108.png
# 📄 TXT saved: P1108.txt
# Processing P1109.png...
# ✅ Predictions drawn for P1109.png
# 📄 TXT saved: P1109.txt
# Processing P1110.png...
# ✅ Predictions drawn for P1110.png
# 📄 TXT saved: P1110.txt
# Processing P1113.png...
# ✅ Predictions drawn for P1113.png
# 📄 TXT saved: P1113.txt
# Processing P1114.png...
# ✅ Predictions drawn for P1114.png
# 📄 TXT saved: P1114.txt
# Processing P1116.png...
# ✅ Predictions drawn for P1116.png
# 📄 TXT saved: P1116.txt
# Processing P1117.png...
# ✅ Predictions drawn for P1117.png
# 📄 TXT saved: P1117.txt
# Processing P1118.png...
# ✅ Predictions drawn for P1118.png
# 📄 TXT saved: P1118.txt
# Processing P1119.png...
# ✅ Predictions drawn for P1119.png
# 📄 TXT saved: P1119.txt
# Processing P1121.png...
# ✅ Predictions drawn for P1121.png
# 📄 TXT saved: P1121.txt
# Processing P1130.png...
# ✅ Predictions drawn for P1130.png
# 📄 TXT saved: P1130.txt
# Processing P1131.png...
# ✅ Predictions drawn for P1131.png
# 📄 TXT saved: P1131.txt
# Processing P1132.png...
# ✅ Predictions drawn for P1132.png
# 📄 TXT saved: P1132.txt
# Processing P1139.png...
# ✅ Predictions drawn for P1139.png
# 📄 TXT saved: P1139.txt
# Processing P1140.png...
# ✅ Predictions drawn for P1140.png
# 📄 TXT saved: P1140.txt
# Processing P1141.png...
# ✅ Predictions drawn for P1141.png
# 📄 TXT saved: P1141.txt
# Processing P1142.png...
# ✅ Predictions drawn for P1142.png
# 📄 TXT saved: P1142.txt
# Processing P1144.png...
# ✅ Predictions drawn for P1144.png
# 📄 TXT saved: P1144.txt
# Processing P1148.png...
# ✅ Predictions drawn for P1148.png
# 📄 TXT saved: P1148.txt
# Processing P1150.png...
# ✅ Predictions drawn for P1150.png
# 📄 TXT saved: P1150.txt
# Processing P1152.png...
# ✅ Predictions drawn for P1152.png
# 📄 TXT saved: P1152.txt
# Processing P1155.png...
# ✅ Predictions drawn for P1155.png
# 📄 TXT saved: P1155.txt
# Processing P1158.png...
# ✅ Predictions drawn for P1158.png
# 📄 TXT saved: P1158.txt
# Processing P1159.png...
# ✅ Predictions drawn for P1159.png
# 📄 TXT saved: P1159.txt
# ...
# 📄 TXT saved: P2452.txt
# Processing P2453.png...
# ✅ Predictions drawn for P2453.png
# 📄 TXT saved: P2453.txt
# Processing P2454.png...
# ✅ Predictions drawn for P2454.png
# 📄 TXT saved: P2454.txt
# Processing P2456.png...
# ✅ Predictions drawn for P2456.png
# 📄 TXT saved: P2456.txt
# Processing P2457.png...
# ✅ Predictions drawn for P2457.png
# 📄 TXT saved: P2457.txt
# Processing P2458.png...
# ✅ Predictions drawn for P2458.png
# 📄 TXT saved: P2458.txt
# Processing P2460.png...
# ✅ Predictions drawn for P2460.png
# 📄 TXT saved: P2460.txt
# Processing P2464.png...
# ✅ Predictions drawn for P2464.png
# 📄 TXT saved: P2464.txt
# Processing P2465.png...
# ✅ Predictions drawn for P2465.png
# 📄 TXT saved: P2465.txt
# Processing P2466.png...
# ✅ Predictions drawn for P2466.png
# 📄 TXT saved: P2466.txt
# Processing P2467.png...
# ✅ Predictions drawn for P2467.png
# 📄 TXT saved: P2467.txt
# Processing P2468.png...
# ✅ Predictions drawn for P2468.png
# 📄 TXT saved: P2468.txt
# Processing P2469.png...
# ✅ Predictions drawn for P2469.png
# 📄 TXT saved: P2469.txt
# Processing P2470.png...
# ✅ Predictions drawn for P2470.png
# 📄 TXT saved: P2470.txt
# Processing P2471.png...
# ✅ Predictions drawn for P2471.png
# 📄 TXT saved: P2471.txt
# Processing P2472.png...
# ✅ Predictions drawn for P2472.png
# 📄 TXT saved: P2472.txt
# Processing P2475.png...
# ✅ Predictions drawn for P2475.png
# 📄 TXT saved: P2475.txt
# Processing P2476.png...
# ✅ Predictions drawn for P2476.png
# 📄 TXT saved: P2476.txt
# Processing P2479.png...
# ✅ Predictions drawn for P2479.png
# 📄 TXT saved: P2479.txt
# Processing P2482.png...
# ✅ Predictions drawn for P2482.png
# 📄 TXT saved: P2482.txt
# Processing P2483.png...
# ✅ Predictions drawn for P2483.png
# 📄 TXT saved: P2483.txt
# Processing P2485.png...
# ✅ Predictions drawn for P2485.png
# 📄 TXT saved: P2485.txt
# Processing P2490.png...
# ✅ Predictions drawn for P2490.png
# 📄 TXT saved: P2490.txt
# Processing P2491.png...
# ✅ Predictions drawn for P2491.png
# 📄 TXT saved: P2491.txt
# Processing P2492.png...
# ✅ Predictions drawn for P2492.png
# 📄 TXT saved: P2492.txt
# Processing P2494.png...
# ✅ Predictions drawn for P2494.png
# 📄 TXT saved: P2494.txt
# Processing P2495.png...
# ✅ Predictions drawn for P2495.png
# 📄 TXT saved: P2495.txt
# Processing P2496.png...
# ✅ Predictions drawn for P2496.png
# 📄 TXT saved: P2496.txt
# Processing P2497.png...
# ✅ Predictions drawn for P2497.png
# 📄 TXT saved: P2497.txt
# Processing P2501.png...
# ✅ Predictions drawn for P2501.png
# 📄 TXT saved: P2501.txt
# Processing P2503.png...
# ✅ Predictions drawn for P2503.png
# 📄 TXT saved: P2503.txt
# Processing P2505.png...
# ✅ Predictions drawn for P2505.png
# 📄 TXT saved: P2505.txt
# Processing P2506.png...
# ✅ Predictions drawn for P2506.png
# 📄 TXT saved: P2506.txt
# Processing P2507.png...
# ✅ Predictions drawn for P2507.png
# 📄 TXT saved: P2507.txt
# Processing P2509.png...
# ✅ Predictions drawn for P2509.png
# 📄 TXT saved: P2509.txt
# Processing P2512.png...
# ✅ Predictions drawn for P2512.png
# 📄 TXT saved: P2512.txt
# Processing P2513.png...
# ✅ Predictions drawn for P2513.png
# 📄 TXT saved: P2513.txt
# Processing P2514.png...
# ✅ Predictions drawn for P2514.png
# 📄 TXT saved: P2514.txt
# Processing P2516.png...
# ✅ Predictions drawn for P2516.png
# 📄 TXT saved: P2516.txt
# Processing P2517.png...
# ✅ Predictions drawn for P2517.png
# 📄 TXT saved: P2517.txt
# Processing P2518.png...
# ✅ Predictions drawn for P2518.png
# 📄 TXT saved: P2518.txt
# Processing P2519.png...
# ✅ Predictions drawn for P2519.png
# 📄 TXT saved: P2519.txt
# Processing P2520.png...
# ✅ Predictions drawn for P2520.png
# 📄 TXT saved: P2520.txt
# Processing P2522.png...
# ✅ Predictions drawn for P2522.png
# 📄 TXT saved: P2522.txt
# Processing P2523.png...
# ✅ Predictions drawn for P2523.png
# 📄 TXT saved: P2523.txt
# Processing P2527.png...
# ✅ Predictions drawn for P2527.png
# 📄 TXT saved: P2527.txt
# Processing P2528.png...
# ✅ Predictions drawn for P2528.png
# 📄 TXT saved: P2528.txt
# Processing P2529.png...
# ✅ Predictions drawn for P2529.png
# 📄 TXT saved: P2529.txt
# Processing P2531.png...
# ✅ Predictions drawn for P2531.png
# 📄 TXT saved: P2531.txt
# Processing P2532.png...
# ✅ Predictions drawn for P2532.png
# 📄 TXT saved: P2532.txt
# Processing P2533.png...
# ✅ Predictions drawn for P2533.png
# 📄 TXT saved: P2533.txt
# Processing P2534.png...
# ✅ Predictions drawn for P2534.png
# 📄 TXT saved: P2534.txt
# Processing P2536.png...
# ✅ Predictions drawn for P2536.png
# 📄 TXT saved: P2536.txt
# Processing P2538.png...
# ✅ Predictions drawn for P2538.png
# 📄 TXT saved: P2538.txt
# Processing P2543.png...
# ✅ Predictions drawn for P2543.png
# 📄 TXT saved: P2543.txt
# Processing P2545.png...
# ✅ Predictions drawn for P2545.png
# 📄 TXT saved: P2545.txt
# Processing P2548.png...
# ✅ Predictions drawn for P2548.png
# 📄 TXT saved: P2548.txt
# Processing P2550.png...
# ✅ Predictions drawn for P2550.png
# 📄 TXT saved: P2550.txt
# Processing P2551.png...
# ✅ Predictions drawn for P2551.png
# 📄 TXT saved: P2551.txt
# Processing P2552.png...
# ✅ Predictions drawn for P2552.png
# 📄 TXT saved: P2552.txt
# Processing P2553.png...
# ✅ Predictions drawn for P2553.png
# 📄 TXT saved: P2553.txt
# Processing P2554.png...
# ✅ Predictions drawn for P2554.png
# 📄 TXT saved: P2554.txt
# Processing P2557.png...
# ✅ Predictions drawn for P2557.png
# 📄 TXT saved: P2557.txt
# Processing P2558.png...
# ✅ Predictions drawn for P2558.png
# 📄 TXT saved: P2558.txt
# Processing P2560.png...
# ✅ Predictions drawn for P2560.png
# 📄 TXT saved: P2560.txt
# Processing P2561.png...
# ✅ Predictions drawn for P2561.png
# 📄 TXT saved: P2561.txt
# Processing P2565.png...
# ✅ Predictions drawn for P2565.png
# 📄 TXT saved: P2565.txt
# Processing P2566.png...
# ✅ Predictions drawn for P2566.png
# 📄 TXT saved: P2566.txt
# Processing P2569.png...
# ✅ Predictions drawn for P2569.png
# 📄 TXT saved: P2569.txt
# Processing P2572.png...
# ✅ Predictions drawn for P2572.png
# 📄 TXT saved: P2572.txt
# Processing P2576.png...
# ✅ Predictions drawn for P2576.png
# 📄 TXT saved: P2576.txt
# Processing P2578.png...
# ✅ Predictions drawn for P2578.png
# 📄 TXT saved: P2578.txt
# Processing P2579.png...
# ✅ Predictions drawn for P2579.png
# 📄 TXT saved: P2579.txt
# Processing P2584.png...
# ✅ Predictions drawn for P2584.png
# 📄 TXT saved: P2584.txt
# Processing P2585.png...
# ✅ Predictions drawn for P2585.png
# 📄 TXT saved: P2585.txt
# Processing P2590.png...
# ✅ Predictions drawn for P2590.png
# 📄 TXT saved: P2590.txt
# Processing P2591.png...
# ✅ Predictions drawn for P2591.png
# 📄 TXT saved: P2591.txt
# Processing P2594.png...
# ✅ Predictions drawn for P2594.png
# 📄 TXT saved: P2594.txt
# Processing P2597.png...
# ✅ Predictions drawn for P2597.png
# 📄 TXT saved: P2597.txt
# Processing P2600.png...
# ✅ Predictions drawn for P2600.png
# 📄 TXT saved: P2600.txt
# Processing P2601.png...
# ✅ Predictions drawn for P2601.png
# 📄 TXT saved: P2601.txt
# Processing P2604.png...
# ✅ Predictions drawn for P2604.png
# 📄 TXT saved: P2604.txt
# Processing P2605.png...
# ✅ Predictions drawn for P2605.png
# 📄 TXT saved: P2605.txt
# Processing P2606.png...
# ✅ Predictions drawn for P2606.png
# 📄 TXT saved: P2606.txt
# Processing P2609.png...
# ✅ Predictions drawn for P2609.png
# 📄 TXT saved: P2609.txt
# Processing P2611.png...
# ✅ Predictions drawn for P2611.png
# 📄 TXT saved: P2611.txt
# Processing P2612.png...
# ✅ Predictions drawn for P2612.png
# 📄 TXT saved: P2612.txt
# Processing P2613.png...
# ✅ Predictions drawn for P2613.png
# 📄 TXT saved: P2613.txt
# Processing P2614.png...
# ✅ Predictions drawn for P2614.png
# 📄 TXT saved: P2614.txt
# Processing P2615.png...
# ✅ Predictions drawn for P2615.png
# 📄 TXT saved: P2615.txt
# Processing P2616.png...
# ✅ Predictions drawn for P2616.png
# 📄 TXT saved: P2616.txt
# Processing P2618.png...
# ✅ Predictions drawn for P2618.png
# 📄 TXT saved: P2618.txt
# Processing P2621.png...
# ✅ Predictions drawn for P2621.png
# 📄 TXT saved: P2621.txt
# Processing P2622.png...
# ✅ Predictions drawn for P2622.png
# 📄 TXT saved: P2622.txt
# Processing P2626.png...
# ✅ Predictions drawn for P2626.png
# 📄 TXT saved: P2626.txt
# Processing P2627.png...
# ✅ Predictions drawn for P2627.png
# 📄 TXT saved: P2627.txt
# Processing P2628.png...
# ✅ Predictions drawn for P2628.png
# 📄 TXT saved: P2628.txt
# Processing P2629.png...
# ✅ Predictions drawn for P2629.png
# 📄 TXT saved: P2629.txt
# Processing P2631.png...
# ✅ Predictions drawn for P2631.png
# 📄 TXT saved: P2631.txt
# Processing P2632.png...
# ✅ Predictions drawn for P2632.png
# 📄 TXT saved: P2632.txt
# Processing P2634.png...
# ✅ Predictions drawn for P2634.png
# 📄 TXT saved: P2634.txt
# Processing P2637.png...
# ✅ Predictions drawn for P2637.png
# 📄 TXT saved: P2637.txt
# Processing P2638.png...
# ✅ Predictions drawn for P2638.png
# 📄 TXT saved: P2638.txt
# Processing P2639.png...
# ✅ Predictions drawn for P2639.png
# 📄 TXT saved: P2639.txt
# Processing P2641.png...
# ✅ Predictions drawn for P2641.png
# 📄 TXT saved: P2641.txt
# Processing P2642.png...
# ✅ Predictions drawn for P2642.png
# 📄 TXT saved: P2642.txt
# Processing P2644.png...
# ✅ Predictions drawn for P2644.png
# 📄 TXT saved: P2644.txt
# Processing P2646.png...
# ✅ Predictions drawn for P2646.png
# 📄 TXT saved: P2646.txt
# Processing P2650.png...
# ✅ Predictions drawn for P2650.png
# 📄 TXT saved: P2650.txt
# Processing P2651.png...
# ✅ Predictions drawn for P2651.png
# 📄 TXT saved: P2651.txt
# Processing P2653.png...
# ✅ Predictions drawn for P2653.png
# 📄 TXT saved: P2653.txt
# Processing P2655.png...
# ✅ Predictions drawn for P2655.png
# 📄 TXT saved: P2655.txt
# Processing P2656.png...
# ✅ Predictions drawn for P2656.png
# 📄 TXT saved: P2656.txt
# Processing P2657.png...
# ✅ Predictions drawn for P2657.png
# 📄 TXT saved: P2657.txt
# Processing P2659.png...
# ✅ Predictions drawn for P2659.png
# 📄 TXT saved: P2659.txt
# Processing P2662.png...
# ✅ Predictions drawn for P2662.png
# 📄 TXT saved: P2662.txt
# Processing P2663.png...
# ✅ Predictions drawn for P2663.png
# 📄 TXT saved: P2663.txt
# Processing P2664.png...
# ✅ Predictions drawn for P2664.png
# 📄 TXT saved: P2664.txt
# Processing P2665.png...
# ✅ Predictions drawn for P2665.png
# 📄 TXT saved: P2665.txt
# Processing P2668.png...
# ✅ Predictions drawn for P2668.png
# 📄 TXT saved: P2668.txt
# Processing P2669.png...
# ✅ Predictions drawn for P2669.png
# 📄 TXT saved: P2669.txt
# Processing P2670.png...
# ✅ Predictions drawn for P2670.png
# 📄 TXT saved: P2670.txt
# Processing P2671.png...
# ✅ Predictions drawn for P2671.png
# 📄 TXT saved: P2671.txt
# Processing P2672.png...
# ✅ Predictions drawn for P2672.png
# 📄 TXT saved: P2672.txt
# Processing P2673.png...
# ✅ Predictions drawn for P2673.png
# 📄 TXT saved: P2673.txt
# Processing P2674.png...
# ✅ Predictions drawn for P2674.png
# 📄 TXT saved: P2674.txt
# Processing P2676.png...
# ✅ Predictions drawn for P2676.png
# 📄 TXT saved: P2676.txt
# Processing P2680.png...
# ✅ Predictions drawn for P2680.png
# 📄 TXT saved: P2680.txt
# Processing P2681.png...
# ✅ Predictions drawn for P2681.png
# 📄 TXT saved: P2681.txt
# Processing P2682.png...
# ✅ Predictions drawn for P2682.png
# 📄 TXT saved: P2682.txt
# Processing P2685.png...
# ✅ Predictions drawn for P2685.png
# 📄 TXT saved: P2685.txt
# Processing P2686.png...
# ✅ Predictions drawn for P2686.png
# 📄 TXT saved: P2686.txt
# Processing P2687.png...
# ✅ Predictions drawn for P2687.png
# 📄 TXT saved: P2687.txt
# Processing P2690.png...
# ✅ Predictions drawn for P2690.png
# 📄 TXT saved: P2690.txt
# Processing P2691.png...
# ✅ Predictions drawn for P2691.png
# 📄 TXT saved: P2691.txt
# Processing P2692.png...
# ✅ Predictions drawn for P2692.png
# 📄 TXT saved: P2692.txt
# Processing P2693.png...
# ✅ Predictions drawn for P2693.png
# 📄 TXT saved: P2693.txt
# Processing P2696.png...
# ✅ Predictions drawn for P2696.png
# 📄 TXT saved: P2696.txt
# Processing P2700.png...
# ✅ Predictions drawn for P2700.png
# 📄 TXT saved: P2700.txt
# Processing P2702.png...
# ✅ Predictions drawn for P2702.png
# 📄 TXT saved: P2702.txt
# Processing P2704.png...
# ✅ Predictions drawn for P2704.png
# 📄 TXT saved: P2704.txt
# Processing P2705.png...
# ✅ Predictions drawn for P2705.png
# 📄 TXT saved: P2705.txt
# Processing P2706.png...
# ✅ Predictions drawn for P2706.png
# 📄 TXT saved: P2706.txt
# Processing P2708.png...
# ✅ Predictions drawn for P2708.png
# 📄 TXT saved: P2708.txt
# Processing P2710.png...
# ✅ Predictions drawn for P2710.png
# 📄 TXT saved: P2710.txt
# Processing P2712.png...
# ✅ Predictions drawn for P2712.png
# 📄 TXT saved: P2712.txt
# Processing P2716.png...
# ✅ Predictions drawn for P2716.png
# 📄 TXT saved: P2716.txt
# Processing P2719.png...
# ✅ Predictions drawn for P2719.png
# 📄 TXT saved: P2719.txt
# Processing P2720.png...
# ✅ Predictions drawn for P2720.png
# 📄 TXT saved: P2720.txt
# Processing P2725.png...
# ✅ Predictions drawn for P2725.png
# 📄 TXT saved: P2725.txt
# Processing P2727.png...
# ✅ Predictions drawn for P2727.png
# 📄 TXT saved: P2727.txt
# Processing P2728.png...
# ✅ Predictions drawn for P2728.png
# 📄 TXT saved: P2728.txt
# Processing P2729.png...
# ✅ Predictions drawn for P2729.png
# 📄 TXT saved: P2729.txt
# Processing P2730.png...
# ✅ Predictions drawn for P2730.png
# 📄 TXT saved: P2730.txt
# Processing P2731.png...
# ✅ Predictions drawn for P2731.png
# 📄 TXT saved: P2731.txt
# Processing P2732.png...
# ✅ Predictions drawn for P2732.png
# 📄 TXT saved: P2732.txt
# Processing P2734.png...
# ✅ Predictions drawn for P2734.png
# 📄 TXT saved: P2734.txt
# Processing P2735.png...
# ✅ Predictions drawn for P2735.png
# 📄 TXT saved: P2735.txt
# Processing P2739.png...
# ✅ Predictions drawn for P2739.png
# 📄 TXT saved: P2739.txt
# Processing P2740.png...
# ✅ Predictions drawn for P2740.png
# 📄 TXT saved: P2740.txt
# Processing P2741.png...
# ✅ Predictions drawn for P2741.png
# 📄 TXT saved: P2741.txt
# Processing P2742.png...
# ✅ Predictions drawn for P2742.png
# 📄 TXT saved: P2742.txt
# Processing P2743.png...
# ✅ Predictions drawn for P2743.png
# 📄 TXT saved: P2743.txt
# Processing P2746.png...
# ✅ Predictions drawn for P2746.png
# 📄 TXT saved: P2746.txt
# Processing P2747.png...
# ✅ Predictions drawn for P2747.png
# 📄 TXT saved: P2747.txt
# Processing P2748.png...
# ✅ Predictions drawn for P2748.png
# 📄 TXT saved: P2748.txt
# Processing P2750.png...
# ✅ Predictions drawn for P2750.png
# 📄 TXT saved: P2750.txt
# Processing P2751.png...
# ✅ Predictions drawn for P2751.png
# 📄 TXT saved: P2751.txt
# Processing P2753.png...
# ✅ Predictions drawn for P2753.png
# 📄 TXT saved: P2753.txt
# Processing P2755.png...
# ✅ Predictions drawn for P2755.png
# 📄 TXT saved: P2755.txt
# Processing P2756.png...
# ✅ Predictions drawn for P2756.png
# 📄 TXT saved: P2756.txt
# Processing P2759.png...
# ✅ Predictions drawn for P2759.png
# 📄 TXT saved: P2759.txt
# Processing P2761.png...
# ✅ Predictions drawn for P2761.png
# 📄 TXT saved: P2761.txt
# Processing P2764.png...
# ✅ Predictions drawn for P2764.png
# 📄 TXT saved: P2764.txt
# Processing P2769.png...
# ✅ Predictions drawn for P2769.png
# 📄 TXT saved: P2769.txt
# Processing P2770.png...
# ✅ Predictions drawn for P2770.png
# 📄 TXT saved: P2770.txt
# Processing P2775.png...
# ✅ Predictions drawn for P2775.png
# 📄 TXT saved: P2775.txt
# Processing P2777.png...
# ✅ Predictions drawn for P2777.png
# 📄 TXT saved: P2777.txt
# Processing P2783.png...
# ✅ Predictions drawn for P2783.png
# 📄 TXT saved: P2783.txt
# Processing P2787.png...
# ✅ Predictions drawn for P2787.png
# 📄 TXT saved: P2787.txt
# Processing P2788.png...
# ✅ Predictions drawn for P2788.png
# 📄 TXT saved: P2788.txt
# Processing P2790.png...
# ✅ Predictions drawn for P2790.png
# 📄 TXT saved: P2790.txt
# Processing P2792.png...
# ✅ Predictions drawn for P2792.png
# 📄 TXT saved: P2792.txt
# Processing P2793.png...
# ✅ Predictions drawn for P2793.png
# 📄 TXT saved: P2793.txt
# Processing P2797.png...
# ✅ Predictions drawn for P2797.png
# 📄 TXT saved: P2797.txt
# Processing P2800.png...
# ✅ Predictions drawn for P2800.png
# 📄 TXT saved: P2800.txt
# Processing P2801.png...
# ✅ Predictions drawn for P2801.png
# 📄 TXT saved: P2801.txt
# Processing P2804.png...
# ✅ Predictions drawn for P2804.png
# 📄 TXT saved: P2804.txt
# Processing P2805.png...
# ✅ Predictions drawn for P2805.png
# 📄 TXT saved: P2805.txt
#
# ===== Detection Summary =====
# Total images processed: 1411
# Images with detections: 1388 (98.4%)
# Images with dummy boxes: 23 (1.6%)
#
# 📊 Detections by class:
#   plane: 13316 detections
#   baseball-diamond: 416 detections
#   bridge: 1375 detections
#   ground-track-field: 550 detections
#   small-vehicle: 26156 detections
#   large-vehicle: 17007 detections
#   ship: 44596 detections
#   tennis-court: 2841 detections
#   basketball-court: 941 detections
#   storage-tank: 10396 detections
#   soccer-ball-field: 681 detections
#   roundabout: 587 detections
#   harbor: 5303 detections
#   swimming-pool: 2969 detections
#   helicopter: 535 detections
#   No_Detection: 23 detections
#
# 🎉 All images processed and saved with OBBs and TXT annotations.

# %%
import os
import numpy as np
import cv2
from shapely.geometry import Polygon
from collections import defaultdict
import matplotlib.pyplot as plt

class OBBEvaluator:
    def __init__(self, gt_dir, pred_dir, iou_threshold=0.5, confidence_threshold=0.01):
        """
        Initialize the OBB evaluator
        
        Args:
            gt_dir: Directory containing ground truth text files
            pred_dir: Directory containing prediction text files
            iou_threshold: IoU threshold for considering a detection as true positive
            confidence_threshold: Minimum confidence score to consider a prediction
        """
        self.gt_dir = gt_dir
        self.pred_dir = pred_dir
        self.iou_threshold = iou_threshold
        self.confidence_threshold = confidence_threshold
        self.class_names = set()
        self.results = {}
        # Store all predictions for PR curves
        self.all_predictions = defaultdict(list)
        # Store class cumulative stats
        self.class_cumulative = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        # Count of missing prediction files
        self.missing_pred_files = 0
    
    def parse_gt_file(self, gt_file):
        """
        Parse ground truth file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name difficulty_score
        """
        gts = []
        with open(gt_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + difficulty
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and ignore difficulty score
                    class_name = parts[8]
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    gts.append({
                        'polygon': points,
                        'class': class_name,
                        'detected': False  # Flag to mark if this gt is detected
                    })
                except Exception as e:
                    print(f"Error parsing GT line: {line}")
                    print(f"Exception: {e}")
        return gts
    
    def parse_pred_file(self, pred_file):
        """
        Parse prediction file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name confidence_score
        """
        preds = []
        if not os.path.exists(pred_file):
            return preds  # Return empty list if file doesn't exist
            
        with open(pred_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + confidence
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and confidence score
                    class_name = parts[8]
                    confidence = float(parts[9])
                    
                    # Skip predictions with confidence below threshold
                    if confidence < self.confidence_threshold:
                        continue
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    preds.append({
                        'polygon': points,
                        'class': class_name,
                        'confidence': confidence
                    })
                except Exception as e:
                    print(f"Error parsing prediction line: {line}")
                    print(f"Exception: {e}")
        
        # Sort predictions by confidence (descending)
        preds.sort(key=lambda x: x['confidence'], reverse=True)
        return preds
    
    def calculate_iou(self, poly1, poly2):
        """Calculate IoU between two polygons"""
        try:
            polygon1 = Polygon(poly1)
            polygon2 = Polygon(poly2)
            
            if not polygon1.is_valid or not polygon2.is_valid:
                return 0.0
            
            # Calculate intersection and union areas
            intersection_area = polygon1.intersection(polygon2).area
            union_area = polygon1.area + polygon2.area - intersection_area
            
            # Avoid division by zero
            if union_area == 0:
                return 0.0
                
            return intersection_area / union_area
        except Exception as e:
            print(f"Error calculating IoU: {e}")
            return 0.0
    
    def evaluate_image(self, gt_file, pred_file):
        """Evaluate a single image"""
        image_name = os.path.basename(gt_file).split('.')[0]
        
        # Parse GT and prediction files
        gts = self.parse_gt_file(gt_file)
        preds = self.parse_pred_file(pred_file)
        
        # Check if prediction file exists
        if not os.path.exists(pred_file):
            self.missing_pred_files += 1
            # Count all GTs as false negatives if no predictions
            for gt in gts:
                self.class_cumulative[gt['class']]['FN'] += 1
            return
        
        # Initialize per-class results for this image
        class_results = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        class_predictions = defaultdict(list)
        
        # For each prediction, find the best matching ground truth
        for pred in preds:
            pred_class = pred['class']
            pred_poly = pred['polygon']
            pred_conf = pred['confidence']
            
            best_iou = 0
            best_gt_idx = -1
            
            # Find the best matching GT of the same class
            for idx, gt in enumerate(gts):
                if gt['class'] != pred_class or gt['detected']:
                    continue
                
                iou = self.calculate_iou(pred_poly, gt['polygon'])
                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx
            
            # Record as TP or FP based on IoU threshold
            if best_gt_idx >= 0 and best_iou >= self.iou_threshold:
                class_predictions[pred_class].append((pred_conf, 1))  # True positive
                gts[best_gt_idx]['detected'] = True
                class_results[pred_class]['TP'] += 1
                self.class_cumulative[pred_class]['TP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 1))
            else:
                class_predictions[pred_class].append((pred_conf, 0))  # False positive
                class_results[pred_class]['FP'] += 1
                self.class_cumulative[pred_class]['FP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 0))
        
        # Count false negatives (undetected GTs)
        for gt in gts:
            if not gt['detected']:
                class_results[gt['class']]['FN'] += 1
                self.class_cumulative[gt['class']]['FN'] += 1
    
    def calculate_precision_recall(self, tp, fp, fn):
        """Calculate precision and recall"""
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        return precision, recall
    
    def calculate_f1(self, precision, recall):
        """Calculate F1 score"""
        return 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    def calculate_ap(self, precisions, recalls):
        """Calculate Average Precision using 11-point interpolation"""
        ap = 0
        for t in np.arange(0, 1.1, 0.1):
            if np.sum(recalls >= t) == 0:
                p = 0
            else:
                p = np.max(precisions[recalls >= t])
            ap += p / 11
        return ap
    
    def evaluate(self):
        """Evaluate all images and calculate metrics"""
        # Get list of files
        gt_files = sorted([f for f in os.listdir(self.gt_dir) if f.endswith('.txt')])
        print(f"Found {len(gt_files)} ground truth files")
        
        # Process each image
        for gt_file in gt_files:
            image_id = os.path.splitext(gt_file)[0]
            pred_file = image_id + '.txt'
            
            gt_path = os.path.join(self.gt_dir, gt_file)
            pred_path = os.path.join(self.pred_dir, pred_file)
            
            # Skip if prediction file doesn't exist but still record the missing files
            if not os.path.exists(pred_path):
                self.evaluate_image(gt_path, pred_path)  # This will handle missing files
                continue
            
            # Evaluate the image
            self.evaluate_image(gt_path, pred_path)
            
        if self.missing_pred_files > 0:
            print(f"\nWarning: {self.missing_pred_files} out of {len(gt_files)} prediction files were missing.")
            print(f"These are counted as having no detections (all ground truths counted as false negatives).")
        
        # Calculate metrics for each class
        self.results = {}
        mean_ap = 0
        processed_classes = 0
        
        for class_name in self.class_names:
            TP = self.class_cumulative[class_name]['TP']
            FP = self.class_cumulative[class_name]['FP']
            FN = self.class_cumulative[class_name]['FN']
            
            precision, recall = self.calculate_precision_recall(TP, FP, FN)
            f1 = self.calculate_f1(precision, recall)
            
            # Sort predictions by confidence for AP calculation
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            # Skip AP calculation if no ground truths or predictions
            if TP + FN == 0 or len(class_preds) == 0:
                ap = 0
            else:
                cumulative_tp = 0
                cumulative_fp = 0
                precisions = []
                recalls = []
                
                for conf, is_tp in class_preds:
                    if is_tp:
                        cumulative_tp += 1
                    else:
                        cumulative_fp += 1
                    
                    prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                    rec = cumulative_tp / (TP + FN)
                    
                    precisions.append(prec)
                    recalls.append(rec)
                
                precisions = np.array(precisions)
                recalls = np.array(recalls)
                ap = self.calculate_ap(precisions, recalls)
                processed_classes += 1
            
            self.results[class_name] = {
                'AP': ap,
                'Precision': precision,
                'Recall': recall,
                'F1': f1,
                'TP': TP,
                'FP': FP,
                'FN': FN
            }
            
            mean_ap += ap
        
        # Calculate mAP only over classes with predictions
        if processed_classes > 0:
            mean_ap /= processed_classes
        else:
            mean_ap = 0
        
        self.results['mAP'] = mean_ap
        
        return self.results
    
    def plot_precision_recall_curves(self, output_dir):
        """Plot precision-recall curves for all classes"""
        os.makedirs(output_dir, exist_ok=True)
        
        plt.figure(figsize=(10, 8))
        
        for class_name in sorted(self.class_names):
            # Skip classes with no predictions
            if class_name not in self.all_predictions or len(self.all_predictions[class_name]) == 0:
                continue
            
            # Sort predictions by confidence
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            TP = self.class_cumulative[class_name]['TP']
            FN = self.class_cumulative[class_name]['FN']
            
            # Skip if no ground truths
            if TP + FN == 0:
                continue
            
            # Calculate cumulative precision and recall
            cumulative_tp = 0
            cumulative_fp = 0
            precisions = []
            recalls = []
            
            for conf, is_tp in class_preds:
                if is_tp:
                    cumulative_tp += 1
                else:
                    cumulative_fp += 1
                
                prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                rec = cumulative_tp / (TP + FN)
                
                precisions.append(prec)
                recalls.append(rec)
            
            plt.plot(recalls, precisions, label=f"{class_name} (AP={self.results[class_name]['AP']:.3f})")
        
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curves')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(output_dir, 'precision_recall_curves_RNN.png'))
        plt.close()
    
    def print_results(self):
        """Print evaluation results"""
        print("\n===== EVALUATION RESULTS =====")
        print(f"IoU Threshold: {self.iou_threshold}")
        print(f"Confidence Threshold: {self.confidence_threshold}")
        print(f"mAP: {self.results['mAP']:.4f}")
        print("\nPer-class results:")
        
        # Print header
        print(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}")
        print('-' * 70)
        
        # Sort classes for consistent output
        for class_name in sorted(self.class_names):
            r = self.results[class_name]
            print(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}")
        
        print("=" * 70)
    
    def save_results_to_file(self, output_path):
        """Save results to file"""
        with open(output_path, 'w') as f:
            f.write("===== EVALUATION RESULTS =====\n")
            f.write(f"IoU Threshold: {self.iou_threshold}\n")
            f.write(f"Confidence Threshold: {self.confidence_threshold}\n")
            f.write(f"mAP: {self.results['mAP']:.4f}\n\n")
            
            # if self.missing_pred_files > 0:
            #     f.write(f"Note: {self.missing_pred_files} prediction files were missing and counted as no detections.\n\n")
                
            f.write("Per-class results:\n")
            
            # Print header
            f.write(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}\n")
            f.write('-' * 70 + '\n')
            
            # Sort classes for consistent output
            for class_name in sorted(self.class_names):
                r = self.results[class_name]
                f.write(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}\n")
            
            f.write("=" * 70 + '\n')


# Usage example
if __name__ == "__main__":
    # Define paths
    GT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\labels\train\labelTxt-v1.0\labelTxt"  # Ground truth directory
    PRED_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_rrn1\txt_annotations"  # Prediction directory
    OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results"  # Output directory
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Create evaluator with default parameters
    evaluator = OBBEvaluator(
        gt_dir=GT_DIR,
        pred_dir=PRED_DIR,
        iou_threshold=0.5,  # IoU threshold for TP/FP determination
        confidence_threshold=0.01  # Min confidence to consider a prediction
    )
    
    # Run evaluation
    results = evaluator.evaluate()
    
    # Print results
    evaluator.print_results()
    
    # Save results to file
    evaluator.save_results_to_file(os.path.join(OUTPUT_DIR, "evaluation_results_RRN.txt"))
    
    # Generate PR curves
    try:
        evaluator.plot_precision_recall_curves(OUTPUT_DIR)
        print(f"Precision-Recall curves saved to {OUTPUT_DIR}")
    except Exception as e:
        print(f"Error generating PR curves: {e}")
    
    print(f"Evaluation completed! Results saved to {OUTPUT_DIR}")
# Out:
# Found 1411 ground truth files
#
# ===== EVALUATION RESULTS =====
# IoU Threshold: 0.5
# Confidence Threshold: 0.01
# mAP: 0.3425
#
# Per-class results:
# Class           AP       Precision  Recall     F1       TP     FP     FN
# ----------------------------------------------------------------------
# baseball-diamond 0.4470   0.4447     0.4458     0.4452   185    231    230
# basketball-court 0.5250   0.3199     0.5845     0.4135   301    640    214
# bridge          0.0909   0.1265     0.0850     0.1017   174    1201   1873
# ground-track-field 0.3919   0.2491     0.4215     0.3131   137    413    188
# harbor          0.2276   0.3230     0.2863     0.3036   1713   3590   4270
# helicopter      0.0909   0.0579     0.0492     0.0532   31     504    599
# large-vehicle   0.4797   0.5345     0.5357     0.5351   9090   7917   7879
# plane           0.4205   0.2562     0.4236     0.3193   3412   9904   4643
# roundabout      0.2760   0.2112     0.3108     0.2515   124    463    275
# ship            0.1820   0.1793     0.2849     0.2201   7997   36599  20071
# small-vehicle   0.2674   0.3413     0.3417     0.3415   8927   17229  17199
# soccer-ball-field 0.3907   0.2320     0.4847     0.3138   158    523    168
# storage-tank    0.2487   0.1385     0.2863     0.1867   1440   8956   3589
# swimming-pool   0.2825   0.2213     0.3785     0.2793   657    2312   1079
# tennis-court    0.8167   0.7226     0.8673     0.7884   2053   788    314
# ======================================================================
# Precision-Recall curves saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results
# Evaluation completed! Results saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results

# %% [markdown]
# # ORIENTED RCNN

# %%
import os
import cv2
import torch
import mmrotate
import numpy as np
from mmdet.apis import init_detector, inference_detector

# -------------------- Path Setup --------------------
IMAGE_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\images\train\images"
OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_orcnn"
CONFIG_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\mmrotate\configs\oriented_rcnn\oriented_rcnn_r50_fpn_fp16_1x_dota_le90.py"
CHECKPOINT_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\oriented_rcnn_r50_fpn_fp16_1x_dota_le90-57c88621.pth"
LOW_CONFIDENCE = 0.1

os.makedirs(OUTPUT_DIR, exist_ok=True)
TXT_FOLDER = os.path.join(OUTPUT_DIR, "txt_annotations")
os.makedirs(TXT_FOLDER, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"✅ Using device: {device}")

model = init_detector(CONFIG_FILE, CHECKPOINT_FILE, device=device)
class_names = model.CLASSES if hasattr(model, 'CLASSES') else model.dataset_meta['CLASSES']
print(f"✅ Model loaded with {len(class_names)} classes: {class_names}")

def draw_obb(img, obb, label, score, color=(0, 255, 0), thickness=2):
    cx, cy, w, h, angle = obb
    rect = ((cx, cy), (w, h), angle * 180 / np.pi)
    box = cv2.boxPoints(rect)
    box = np.int0(box)
    cv2.drawContours(img, [box], 0, color, thickness)
    label_text = f"{class_names[label] if label < len(class_names) else 'No_Detection'}: {score:.2f}"
    cv2.putText(img, label_text, (int(cx), int(cy) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

# Gather image files
image_files = [f for f in os.listdir(IMAGE_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
if not image_files:
    print(f"❌ No image files found in {IMAGE_DIR}")
else:
    print(f"✅ Found {len(image_files)} image(s) to process")

total_images = 0
images_with_detections = 0
skipped_images = []
class_detection_counts = {i: 0 for i in range(len(class_names))}
class_detection_counts["No_Detection"] = 0

for img_name in image_files:
    total_images += 1
    img_path = os.path.join(IMAGE_DIR, img_name)
    print(f"Processing {img_name}...")

    img = cv2.imread(img_path)
    if img is None:
        print(f"⚠️ Failed to load image: {img_path}")
        skipped_images.append(img_name)
        continue

    result = inference_detector(model, img_path)

    drawn_any = False
    pred_data = []

    if isinstance(result, tuple):
        bbox_results, _ = result
        for class_id, bboxes in enumerate(bbox_results):
            for bbox in bboxes:
                score = bbox[5]
                obb = bbox[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })
    elif hasattr(result, 'pred_instances'):
        pred_instances = result.pred_instances
        bboxes = pred_instances.bboxes.cpu().numpy()
        scores = pred_instances.scores.cpu().numpy()
        labels = pred_instances.labels.cpu().numpy()
        for bbox, score, label in zip(bboxes, scores, labels):
            obb = bbox.tolist()
            if score >= LOW_CONFIDENCE:
                draw_obb(img, obb, label, score)
                drawn_any = True
                class_detection_counts[label.item()] += 1
                pred_data.append({
                    "obb": obb,
                    "score": float(score),
                    "label": int(label),
                    "label_name": class_names[label]
                })
    else:
        for class_id, class_result in enumerate(result):
            for res in class_result:
                score = res[-1]
                obb = res[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })

    # If no detection, draw dummy red box
    if not drawn_any:
        print(f"⚠️ No predictions for {img_name}, drawing dummy box.")
        h, w = img.shape[:2]
        dummy_cx, dummy_cy = w // 2, h // 2
        dummy_w, dummy_h = w // 5, h // 5
        dummy_angle = 0
        dummy_obb = [dummy_cx, dummy_cy, dummy_w, dummy_h, dummy_angle]
        dummy_score = 0.0
        draw_obb(img, dummy_obb, len(class_names), dummy_score, color=(0, 0, 255))
        pred_data.append({
            "obb": dummy_obb,
            "score": dummy_score,
            "label": len(class_names),
            "label_name": "No_Detection"
        })
        class_detection_counts["No_Detection"] += 1
    else:
        print(f"✅ Predictions drawn for {img_name}")
        images_with_detections += 1

    # Save image
    output_path = os.path.join(OUTPUT_DIR, img_name)
    cv2.imwrite(output_path, img)

    # Save .txt annotation
    txt_filename = os.path.splitext(img_name)[0] + ".txt"
    txt_path = os.path.join(TXT_FOLDER, txt_filename)

    with open(txt_path, 'w') as f:
        for pred in pred_data:
            cx, cy, w, h, angle = pred['obb']
            rect = ((cx, cy), (w, h), angle * 180 / np.pi)
            box = cv2.boxPoints(rect)
            box = np.int0(box)
            points_flat = box.flatten()
            coords = " ".join(map(str, points_flat))
            label_name = pred['label_name'].replace(" ", "_")  # Prevent space in label
            score = pred['score']
            line = f"{coords} {label_name} {score:.4f}\n"
            f.write(line)

    print(f"📄 TXT saved: {txt_filename}")

# ========== Summary ==========
print("\n===== Detection Summary =====")
print(f"Total images processed: {total_images}")
print(f"Images with detections: {images_with_detections} ({images_with_detections / total_images * 100:.1f}%)")
print(f"Images with dummy boxes: {total_images - images_with_detections} ({(total_images - images_with_detections) / total_images * 100:.1f}%)")

print("\n📊 Detections by class:")
for class_id, count in class_detection_counts.items():
    name = class_names[class_id] if isinstance(class_id, int) and class_id < len(class_names) else class_id
    if count > 0:
        print(f"  {name}: {count} detections")

if skipped_images:
    print("\n⚠️ Skipped the following images (could not load):")
    for name in skipped_images:
        print(f" - {name}")

print("\n🎉 All images processed and saved with OBBs and TXT annotations.")
# Out:
# d:\Anaconda\envs\cfi_net\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ✅ Using device: cuda
# d:\Anaconda\envs\cfi_net\lib\site-packages\mmdet\models\dense_heads\anchor_head.py:116: UserWarning: DeprecationWarning: `num_anchors` is deprecated, for consistency or also use `num_base_priors` instead
#   warnings.warn('DeprecationWarning: `num_anchors` is deprecated, '
# load checkpoint from local path: D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\oriented_rcnn_r50_fpn_fp16_1x_dota_le90-57c88621.pth
# ✅ Model loaded with 15 classes: ('plane', 'baseball-diamond', 'bridge', 'ground-track-field', 'small-vehicle', 'large-vehicle', 'ship', 'tennis-court', 'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout', 'harbor', 'swimming-pool', 'helicopter')
# ✅ Found 1411 image(s) to process
# Processing P0000.png...
# d:\Anaconda\envs\cfi_net\lib\site-packages\mmdet\models\dense_heads\anchor_head.py:123: UserWarning: DeprecationWarning: anchor_generator is deprecated, please use "prior_generator" instead
#   warnings.warn('DeprecationWarning: anchor_generator is deprecated, '
# ✅ Predictions drawn for P0000.png
# 📄 TXT saved: P0000.txt
# Processing P0001.png...
# ✅ Predictions drawn for P0001.png
# 📄 TXT saved: P0001.txt
# Processing P0002.png...
# ✅ Predictions drawn for P0002.png
# 📄 TXT saved: P0002.txt
# Processing P0005.png...
# ✅ Predictions drawn for P0005.png
# 📄 TXT saved: P0005.txt
# Processing P0008.png...
# ✅ Predictions drawn for P0008.png
# 📄 TXT saved: P0008.txt
# Processing P0010.png...
# ✅ Predictions drawn for P0010.png
# 📄 TXT saved: P0010.txt
# Processing P0011.png...
# ✅ Predictions drawn for P0011.png
# 📄 TXT saved: P0011.txt
# Processing P0012.png...
# ✅ Predictions drawn for P0012.png
# 📄 TXT saved: P0012.txt
# Processing P0013.png...
# ✅ Predictions drawn for P0013.png
# 📄 TXT saved: P0013.txt
# Processing P0018.png...
# ✅ Predictions drawn for P0018.png
# 📄 TXT saved: P0018.txt
# Processing P0020.png...
# ✅ Predictions drawn for P0020.png
# 📄 TXT saved: P0020.txt
# Processing P0021.png...
# ✅ Predictions drawn for P0021.png
# 📄 TXT saved: P0021.txt
# Processing P0022.png...
# ✅ Predictions drawn for P0022.png
# 📄 TXT saved: P0022.txt
# Processing P0023.png...
# ✅ Predictions drawn for P0023.png
# 📄 TXT saved: P0023.txt
# Processing P0025.png...
# ✅ Predictions drawn for P0025.png
# 📄 TXT saved: P0025.txt
# Processing P0029.png...
# ✅ Predictions drawn for P0029.png
# 📄 TXT saved: P0029.txt
# Processing P0030.png...
# ✅ Predictions drawn for P0030.png
# 📄 TXT saved: P0030.txt
# Processing P0032.png...
# ✅ Predictions drawn for P0032.png
# 📄 TXT saved: P0032.txt
# Processing P0036.png...
# ✅ Predictions drawn for P0036.png
# 📄 TXT saved: P0036.txt
# Processing P0038.png...
# ✅ Predictions drawn for P0038.png
# 📄 TXT saved: P0038.txt
# Processing P0039.png...
# ✅ Predictions drawn for P0039.png
# 📄 TXT saved: P0039.txt
# Processing P0041.png...
# ✅ Predictions drawn for P0041.png
# 📄 TXT saved: P0041.txt
# Processing P0042.png...
# ✅ Predictions drawn for P0042.png
# 📄 TXT saved: P0042.txt
# Processing P0044.png...
# ✅ Predictions drawn for P0044.png
# 📄 TXT saved: P0044.txt
# Processing P0049.png...
# ✅ Predictions drawn for P0049.png
# 📄 TXT saved: P0049.txt
# Processing P0050.png...
# ✅ Predictions drawn for P0050.png
# 📄 TXT saved: P0050.txt
# Processing P0052.png...
# ✅ Predictions drawn for P0052.png
# 📄 TXT saved: P0052.txt
# Processing P0054.png...
# ✅ Predictions drawn for P0054.png
# 📄 TXT saved: P0054.txt
# Processing P0058.png...
# ✅ Predictions drawn for P0058.png
# 📄 TXT saved: P0058.txt
# Processing P0061.png...
# ✅ Predictions drawn for P0061.png
# 📄 TXT saved: P0061.txt
# Processing P0063.png...
# ✅ Predictions drawn for P0063.png
# 📄 TXT saved: P0063.txt
# Processing P0064.png...
# ✅ Predictions drawn for P0064.png
# 📄 TXT saved: P0064.txt
# Processing P0065.png...
# ✅ Predictions drawn for P0065.png
# 📄 TXT saved: P0065.txt
# Processing P0066.png...
# ✅ Predictions drawn for P0066.png
# 📄 TXT saved: P0066.txt
# Processing P0067.png...
# ✅ Predictions drawn for P0067.png
# 📄 TXT saved: P0067.txt
# Processing P0068.png...
# ✅ Predictions drawn for P0068.png
# 📄 TXT saved: P0068.txt
# Processing P0070.png...
# ✅ Predictions drawn for P0070.png
# 📄 TXT saved: P0070.txt
# Processing P0071.png...
# ✅ Predictions drawn for P0071.png
# 📄 TXT saved: P0071.txt
# Processing P0074.png...
# ✅ Predictions drawn for P0074.png
# 📄 TXT saved: P0074.txt
# Processing P0076.png...
# ✅ Predictions drawn for P0076.png
# 📄 TXT saved: P0076.txt
# Processing P0078.png...
# ✅ Predictions drawn for P0078.png
# 📄 TXT saved: P0078.txt
# Processing P0082.png...
# ✅ Predictions drawn for P0082.png
# 📄 TXT saved: P0082.txt
# Processing P0083.png...
# ✅ Predictions drawn for P0083.png
# 📄 TXT saved: P0083.txt
# Processing P0085.png...
# ✅ Predictions drawn for P0085.png
# 📄 TXT saved: P0085.txt
# Processing P0087.png...
# ✅ Predictions drawn for P0087.png
# 📄 TXT saved: P0087.txt
# Processing P0091.png...
# ✅ Predictions drawn for P0091.png
# 📄 TXT saved: P0091.txt
# Processing P0093.png...
# ✅ Predictions drawn for P0093.png
# 📄 TXT saved: P0093.txt
# Processing P0094.png...
# ✅ Predictions drawn for P0094.png
# 📄 TXT saved: P0094.txt
# Processing P0095.png...
# ✅ Predictions drawn for P0095.png
# 📄 TXT saved: P0095.txt
# Processing P0096.png...
# ✅ Predictions drawn for P0096.png
# 📄 TXT saved: P0096.txt
# Processing P0098.png...
# ✅ Predictions drawn for P0098.png
# 📄 TXT saved: P0098.txt
# Processing P0099.png...
# ✅ Predictions drawn for P0099.png
# 📄 TXT saved: P0099.txt
# Processing P0100.png...
# ✅ Predictions drawn for P0100.png
# 📄 TXT saved: P0100.txt
# Processing P0103.png...
# ✅ Predictions drawn for P0103.png
# 📄 TXT saved: P0103.txt
# Processing P0109.png...
# ✅ Predictions drawn for P0109.png
# 📄 TXT saved: P0109.txt
# Processing P0111.png...
# ✅ Predictions drawn for P0111.png
# 📄 TXT saved: P0111.txt
# Processing P0113.png...
# ✅ Predictions drawn for P0113.png
# 📄 TXT saved: P0113.txt
# Processing P0116.png...
# ✅ Predictions drawn for P0116.png
# 📄 TXT saved: P0116.txt
# Processing P0119.png...
# ✅ Predictions drawn for P0119.png
# 📄 TXT saved: P0119.txt
# Processing P0122.png...
# ✅ Predictions drawn for P0122.png
# 📄 TXT saved: P0122.txt
# Processing P0124.png...
# ✅ Predictions drawn for P0124.png
# 📄 TXT saved: P0124.txt
# Processing P0126.png...
# ✅ Predictions drawn for P0126.png
# 📄 TXT saved: P0126.txt
# Processing P0129.png...
# ✅ Predictions drawn for P0129.png
# 📄 TXT saved: P0129.txt
# Processing P0133.png...
# ✅ Predictions drawn for P0133.png
# 📄 TXT saved: P0133.txt
# Processing P0136.png...
# ✅ Predictions drawn for P0136.png
# 📄 TXT saved: P0136.txt
# Processing P0139.png...
# ✅ Predictions drawn for P0139.png
# 📄 TXT saved: P0139.txt
# Processing P0140.png...
# ✅ Predictions drawn for P0140.png
# 📄 TXT saved: P0140.txt
# Processing P0141.png...
# ✅ Predictions drawn for P0141.png
# 📄 TXT saved: P0141.txt
# Processing P0142.png...
# ✅ Predictions drawn for P0142.png
# 📄 TXT saved: P0142.txt
# Processing P0144.png...
# ✅ Predictions drawn for P0144.png
# 📄 TXT saved: P0144.txt
# Processing P0147.png...
# ✅ Predictions drawn for P0147.png
# 📄 TXT saved: P0147.txt
# Processing P0149.png...
# ✅ Predictions drawn for P0149.png
# 📄 TXT saved: P0149.txt
# Processing P0151.png...
# ✅ Predictions drawn for P0151.png
# 📄 TXT saved: P0151.txt
# Processing P0152.png...
# ✅ Predictions drawn for P0152.png
# 📄 TXT saved: P0152.txt
# Processing P0158.png...
# ✅ Predictions drawn for P0158.png
# 📄 TXT saved: P0158.txt
# Processing P0159.png...
# ✅ Predictions drawn for P0159.png
# 📄 TXT saved: P0159.txt
# Processing P0160.png...
# ✅ Predictions drawn for P0160.png
# 📄 TXT saved: P0160.txt
# Processing P0162.png...
# ✅ Predictions drawn for P0162.png
# 📄 TXT saved: P0162.txt
# Processing P0163.png...
# ✅ Predictions drawn for P0163.png
# 📄 TXT saved: P0163.txt
# Processing P0164.png...
# ✅ Predictions drawn for P0164.png
# 📄 TXT saved: P0164.txt
# Processing P0167.png...
# ✅ Predictions drawn for P0167.png
# 📄 TXT saved: P0167.txt
# Processing P0169.png...
# ✅ Predictions drawn for P0169.png
# 📄 TXT saved: P0169.txt
# Processing P0171.png...
# ✅ Predictions drawn for P0171.png
# 📄 TXT saved: P0171.txt
# Processing P0172.png...
# ✅ Predictions drawn for P0172.png
# 📄 TXT saved: P0172.txt
# Processing P0174.png...
# ✅ Predictions drawn for P0174.png
# 📄 TXT saved: P0174.txt
# Processing P0176.png...
# ✅ Predictions drawn for P0176.png
# 📄 TXT saved: P0176.txt
# Processing P0178.png...
# ✅ Predictions drawn for P0178.png
# 📄 TXT saved: P0178.txt
# Processing P0183.png...
# ✅ Predictions drawn for P0183.png
# 📄 TXT saved: P0183.txt
# Processing P0187.png...
# ✅ Predictions drawn for P0187.png
# 📄 TXT saved: P0187.txt
# Processing P0188.png...
# ✅ Predictions drawn for P0188.png
# 📄 TXT saved: P0188.txt
# Processing P0190.png...
# ✅ Predictions drawn for P0190.png
# 📄 TXT saved: P0190.txt
# Processing P0200.png...
# ✅ Predictions drawn for P0200.png
# 📄 TXT saved: P0200.txt
# Processing P0201.png...
# ✅ Predictions drawn for P0201.png
# 📄 TXT saved: P0201.txt
# Processing P0202.png...
# ✅ Predictions drawn for P0202.png
# 📄 TXT saved: P0202.txt
# Processing P0203.png...
# ✅ Predictions drawn for P0203.png
# 📄 TXT saved: P0203.txt
# Processing P0204.png...
# ✅ Predictions drawn for P0204.png
# 📄 TXT saved: P0204.txt
# Processing P0207.png...
# ✅ Predictions drawn for P0207.png
# 📄 TXT saved: P0207.txt
# Processing P0209.png...
# ✅ Predictions drawn for P0209.png
# 📄 TXT saved: P0209.txt
# Processing P0210.png...
# ✅ Predictions drawn for P0210.png
# 📄 TXT saved: P0210.txt
# Processing P0212.png...
# ✅ Predictions drawn for P0212.png
# 📄 TXT saved: P0212.txt
# Processing P0215.png...
# ✅ Predictions drawn for P0215.png
# 📄 TXT saved: P0215.txt
# Processing P0218.png...
# ✅ Predictions drawn for P0218.png
# 📄 TXT saved: P0218.txt
# Processing P0219.png...
# ✅ Predictions drawn for P0219.png
# 📄 TXT saved: P0219.txt
# Processing P0220.png...
# ✅ Predictions drawn for P0220.png
# 📄 TXT saved: P0220.txt
# Processing P0221.png...
# ✅ Predictions drawn for P0221.png
# 📄 TXT saved: P0221.txt
# Processing P0222.png...
# ✅ Predictions drawn for P0222.png
# 📄 TXT saved: P0222.txt
# Processing P0223.png...
# ✅ Predictions drawn for P0223.png
# 📄 TXT saved: P0223.txt
# Processing P0224.png...
# ✅ Predictions drawn for P0224.png
# 📄 TXT saved: P0224.txt
# Processing P0225.png...
# ✅ Predictions drawn for P0225.png
# 📄 TXT saved: P0225.txt
# Processing P0226.png...
# ✅ Predictions drawn for P0226.png
# 📄 TXT saved: P0226.txt
# Processing P0227.png...
# ✅ Predictions drawn for P0227.png
# 📄 TXT saved: P0227.txt
# Processing P0229.png...
# ✅ Predictions drawn for P0229.png
# 📄 TXT saved: P0229.txt
# Processing P0232.png...
# ✅ Predictions drawn for P0232.png
# 📄 TXT saved: P0232.txt
# Processing P0233.png...
# ✅ Predictions drawn for P0233.png
# 📄 TXT saved: P0233.txt
# Processing P0235.png...
# ✅ Predictions drawn for P0235.png
# 📄 TXT saved: P0235.txt
# Processing P0236.png...
# ✅ Predictions drawn for P0236.png
# 📄 TXT saved: P0236.txt
# Processing P0238.png...
# ✅ Predictions drawn for P0238.png
# 📄 TXT saved: P0238.txt
# Processing P0241.png...
# ✅ Predictions drawn for P0241.png
# 📄 TXT saved: P0241.txt
# Processing P0244.png...
# ✅ Predictions drawn for P0244.png
# 📄 TXT saved: P0244.txt
# Processing P0248.png...
# ✅ Predictions drawn for P0248.png
# 📄 TXT saved: P0248.txt
# Processing P0250.png...
# ✅ Predictions drawn for P0250.png
# 📄 TXT saved: P0250.txt
# Processing P0251.png...
# ✅ Predictions drawn for P0251.png
# 📄 TXT saved: P0251.txt
# Processing P0252.png...
# ✅ Predictions drawn for P0252.png
# 📄 TXT saved: P0252.txt
# Processing P0254.png...
# ✅ Predictions drawn for P0254.png
# 📄 TXT saved: P0254.txt
# Processing P0255.png...
# ✅ Predictions drawn for P0255.png
# 📄 TXT saved: P0255.txt
# Processing P0256.png...
# ✅ Predictions drawn for P0256.png
# 📄 TXT saved: P0256.txt
# Processing P0258.png...
# ✅ Predictions drawn for P0258.png
# 📄 TXT saved: P0258.txt
# Processing P0260.png...
# ✅ Predictions drawn for P0260.png
# 📄 TXT saved: P0260.txt
# Processing P0263.png...
# ✅ Predictions drawn for P0263.png
# 📄 TXT saved: P0263.txt
# Processing P0264.png...
# ✅ Predictions drawn for P0264.png
# 📄 TXT saved: P0264.txt
# Processing P0270.png...
# ✅ Predictions drawn for P0270.png
# 📄 TXT saved: P0270.txt
# Processing P0272.png...
# ✅ Predictions drawn for P0272.png
# 📄 TXT saved: P0272.txt
# Processing P0273.png...
# ✅ Predictions drawn for P0273.png
# 📄 TXT saved: P0273.txt
# Processing P0275.png...
# ✅ Predictions drawn for P0275.png
# 📄 TXT saved: P0275.txt
# Processing P0276.png...
# ✅ Predictions drawn for P0276.png
# 📄 TXT saved: P0276.txt
# Processing P0280.png...
# ✅ Predictions drawn for P0280.png
# 📄 TXT saved: P0280.txt
# Processing P0281.png...
# ✅ Predictions drawn for P0281.png
# 📄 TXT saved: P0281.txt
# Processing P0282.png...
# ✅ Predictions drawn for P0282.png
# 📄 TXT saved: P0282.txt
# Processing P0283.png...
# ✅ Predictions drawn for P0283.png
# 📄 TXT saved: P0283.txt
# Processing P0285.png...
# ✅ Predictions drawn for P0285.png
# 📄 TXT saved: P0285.txt
# Processing P0286.png...
# ✅ Predictions drawn for P0286.png
# 📄 TXT saved: P0286.txt
# Processing P0288.png...
# ✅ Predictions drawn for P0288.png
# 📄 TXT saved: P0288.txt
# Processing P0289.png...
# ✅ Predictions drawn for P0289.png
# 📄 TXT saved: P0289.txt
# Processing P0292.png...
# ✅ Predictions drawn for P0292.png
# 📄 TXT saved: P0292.txt
# Processing P0293.png...
# ✅ Predictions drawn for P0293.png
# 📄 TXT saved: P0293.txt
# Processing P0294.png...
# ✅ Predictions drawn for P0294.png
# 📄 TXT saved: P0294.txt
# Processing P0296.png...
# ✅ Predictions drawn for P0296.png
# 📄 TXT saved: P0296.txt
# Processing P0299.png...
# ✅ Predictions drawn for P0299.png
# 📄 TXT saved: P0299.txt
# Processing P0301.png...
# ✅ Predictions drawn for P0301.png
# 📄 TXT saved: P0301.txt
# Processing P0303.png...
# ✅ Predictions drawn for P0303.png
# 📄 TXT saved: P0303.txt
# Processing P0308.png...
# ✅ Predictions drawn for P0308.png
# 📄 TXT saved: P0308.txt
# Processing P0310.png...
# ✅ Predictions drawn for P0310.png
# 📄 TXT saved: P0310.txt
# Processing P0313.png...
# ✅ Predictions drawn for P0313.png
# 📄 TXT saved: P0313.txt
# Processing P0314.png...
# ✅ Predictions drawn for P0314.png
# 📄 TXT saved: P0314.txt
# Processing P0315.png...
# ✅ Predictions drawn for P0315.png
# 📄 TXT saved: P0315.txt
# Processing P0317.png...
# ✅ Predictions drawn for P0317.png
# 📄 TXT saved: P0317.txt
# Processing P0321.png...
# ✅ Predictions drawn for P0321.png
# 📄 TXT saved: P0321.txt
# Processing P0322.png...
# ✅ Predictions drawn for P0322.png
# 📄 TXT saved: P0322.txt
# Processing P0324.png...
# ✅ Predictions drawn for P0324.png
# 📄 TXT saved: P0324.txt
# Processing P0327.png...
# ✅ Predictions drawn for P0327.png
# 📄 TXT saved: P0327.txt
# Processing P0330.png...
# ✅ Predictions drawn for P0330.png
# 📄 TXT saved: P0330.txt
# Processing P0332.png...
# ✅ Predictions drawn for P0332.png
# 📄 TXT saved: P0332.txt
# Processing P0334.png...
# ✅ Predictions drawn for P0334.png
# 📄 TXT saved: P0334.txt
# Processing P0335.png...
# ✅ Predictions drawn for P0335.png
# 📄 TXT saved: P0335.txt
# Processing P0337.png...
# ✅ Predictions drawn for P0337.png
# 📄 TXT saved: P0337.txt
# Processing P0338.png...
# ✅ Predictions drawn for P0338.png
# 📄 TXT saved: P0338.txt
# Processing P0339.png...
# ✅ Predictions drawn for P0339.png
# 📄 TXT saved: P0339.txt
# Processing P0340.png...
# ✅ Predictions drawn for P0340.png
# 📄 TXT saved: P0340.txt
# Processing P0343.png...
# ✅ Predictions drawn for P0343.png
# 📄 TXT saved: P0343.txt
# Processing P0344.png...
# ✅ Predictions drawn for P0344.png
# 📄 TXT saved: P0344.txt
# Processing P0345.png...
# ✅ Predictions drawn for P0345.png
# 📄 TXT saved: P0345.txt
# Processing P0346.png...
# ✅ Predictions drawn for P0346.png
# 📄 TXT saved: P0346.txt
# Processing P0349.png...
# ✅ Predictions drawn for P0349.png
# 📄 TXT saved: P0349.txt
# Processing P0350.png...
# ✅ Predictions drawn for P0350.png
# 📄 TXT saved: P0350.txt
# Processing P0355.png...
# ✅ Predictions drawn for P0355.png
# 📄 TXT saved: P0355.txt
# Processing P0357.png...
# ✅ Predictions drawn for P0357.png
# 📄 TXT saved: P0357.txt
# Processing P0358.png...
# ✅ Predictions drawn for P0358.png
# 📄 TXT saved: P0358.txt
# Processing P0360.png...
# ✅ Predictions drawn for P0360.png
# 📄 TXT saved: P0360.txt
# Processing P0361.png...
# ✅ Predictions drawn for P0361.png
# 📄 TXT saved: P0361.txt
# Processing P0362.png...
# ✅ Predictions drawn for P0362.png
# 📄 TXT saved: P0362.txt
# Processing P0363.png...
# ✅ Predictions drawn for P0363.png
# 📄 TXT saved: P0363.txt
# Processing P0364.png...
# ✅ Predictions drawn for P0364.png
# 📄 TXT saved: P0364.txt
# Processing P0365.png...
# ✅ Predictions drawn for P0365.png
# 📄 TXT saved: P0365.txt
# Processing P0366.png...
# ✅ Predictions drawn for P0366.png
# 📄 TXT saved: P0366.txt
# Processing P0367.png...
# ✅ Predictions drawn for P0367.png
# 📄 TXT saved: P0367.txt
# Processing P0370.png...
# ✅ Predictions drawn for P0370.png
# 📄 TXT saved: P0370.txt
# Processing P0371.png...
# ✅ Predictions drawn for P0371.png
# 📄 TXT saved: P0371.txt
# Processing P0373.png...
# ✅ Predictions drawn for P0373.png
# 📄 TXT saved: P0373.txt
# Processing P0376.png...
# ✅ Predictions drawn for P0376.png
# 📄 TXT saved: P0376.txt
# Processing P0378.png...
# ✅ Predictions drawn for P0378.png
# 📄 TXT saved: P0378.txt
# Processing P0379.png...
# ✅ Predictions drawn for P0379.png
# 📄 TXT saved: P0379.txt
# Processing P0380.png...
# ✅ Predictions drawn for P0380.png
# 📄 TXT saved: P0380.txt
# Processing P0381.png...
# ✅ Predictions drawn for P0381.png
# 📄 TXT saved: P0381.txt
# Processing P0383.png...
# ✅ Predictions drawn for P0383.png
# 📄 TXT saved: P0383.txt
# Processing P0384.png...
# ✅ Predictions drawn for P0384.png
# 📄 TXT saved: P0384.txt
# Processing P0386.png...
# ✅ Predictions drawn for P0386.png
# 📄 TXT saved: P0386.txt
# Processing P0387.png...
# ✅ Predictions drawn for P0387.png
# 📄 TXT saved: P0387.txt
# Processing P0388.png...
# ✅ Predictions drawn for P0388.png
# 📄 TXT saved: P0388.txt
# Processing P0389.png...
# ✅ Predictions drawn for P0389.png
# 📄 TXT saved: P0389.txt
# Processing P0391.png...
# ✅ Predictions drawn for P0391.png
# 📄 TXT saved: P0391.txt
# Processing P0392.png...
# ✅ Predictions drawn for P0392.png
# 📄 TXT saved: P0392.txt
# Processing P0393.png...
# ✅ Predictions drawn for P0393.png
# 📄 TXT saved: P0393.txt
# Processing P0395.png...
# ✅ Predictions drawn for P0395.png
# 📄 TXT saved: P0395.txt
# Processing P0400.png...
# ✅ Predictions drawn for P0400.png
# 📄 TXT saved: P0400.txt
# Processing P0401.png...
# ✅ Predictions drawn for P0401.png
# 📄 TXT saved: P0401.txt
# Processing P0404.png...
# ✅ Predictions drawn for P0404.png
# 📄 TXT saved: P0404.txt
# Processing P0405.png...
# ✅ Predictions drawn for P0405.png
# 📄 TXT saved: P0405.txt
# Processing P0406.png...
# ✅ Predictions drawn for P0406.png
# 📄 TXT saved: P0406.txt
# Processing P0407.png...
# ✅ Predictions drawn for P0407.png
# 📄 TXT saved: P0407.txt
# Processing P0413.png...
# ✅ Predictions drawn for P0413.png
# 📄 TXT saved: P0413.txt
# Processing P0415.png...
# ✅ Predictions drawn for P0415.png
# 📄 TXT saved: P0415.txt
# Processing P0416.png...
# ✅ Predictions drawn for P0416.png
# 📄 TXT saved: P0416.txt
# Processing P0417.png...
# ✅ Predictions drawn for P0417.png
# 📄 TXT saved: P0417.txt
# Processing P0418.png...
# ✅ Predictions drawn for P0418.png
# 📄 TXT saved: P0418.txt
# Processing P0419.png...
# ✅ Predictions drawn for P0419.png
# 📄 TXT saved: P0419.txt
# Processing P0421.png...
# ✅ Predictions drawn for P0421.png
# 📄 TXT saved: P0421.txt
# Processing P0422.png...
# ✅ Predictions drawn for P0422.png
# 📄 TXT saved: P0422.txt
# Processing P0424.png...
# ✅ Predictions drawn for P0424.png
# 📄 TXT saved: P0424.txt
# Processing P0425.png...
# ✅ Predictions drawn for P0425.png
# 📄 TXT saved: P0425.txt
# Processing P0426.png...
# ✅ Predictions drawn for P0426.png
# 📄 TXT saved: P0426.txt
# Processing P0428.png...
# ✅ Predictions drawn for P0428.png
# 📄 TXT saved: P0428.txt
# Processing P0430.png...
# ✅ Predictions drawn for P0430.png
# 📄 TXT saved: P0430.txt
# Processing P0431.png...
# ✅ Predictions drawn for P0431.png
# 📄 TXT saved: P0431.txt
# Processing P0434.png...
# ✅ Predictions drawn for P0434.png
# 📄 TXT saved: P0434.txt
# Processing P0435.png...
# ✅ Predictions drawn for P0435.png
# 📄 TXT saved: P0435.txt
# Processing P0436.png...
# ✅ Predictions drawn for P0436.png
# 📄 TXT saved: P0436.txt
# Processing P0437.png...
# ✅ Predictions drawn for P0437.png
# 📄 TXT saved: P0437.txt
# Processing P0438.png...
# ✅ Predictions drawn for P0438.png
# 📄 TXT saved: P0438.txt
# Processing P0439.png...
# ✅ Predictions drawn for P0439.png
# 📄 TXT saved: P0439.txt
# Processing P0440.png...
# ✅ Predictions drawn for P0440.png
# 📄 TXT saved: P0440.txt
# Processing P0441.png...
# ✅ Predictions drawn for P0441.png
# 📄 TXT saved: P0441.txt
# Processing P0442.png...
# ✅ Predictions drawn for P0442.png
# 📄 TXT saved: P0442.txt
# Processing P0443.png...
# ✅ Predictions drawn for P0443.png
# 📄 TXT saved: P0443.txt
# Processing P0445.png...
# ✅ Predictions drawn for P0445.png
# 📄 TXT saved: P0445.txt
# Processing P0446.png...
# ✅ Predictions drawn for P0446.png
# 📄 TXT saved: P0446.txt
# Processing P0448.png...
# ✅ Predictions drawn for P0448.png
# 📄 TXT saved: P0448.txt
# Processing P0450.png...
# ✅ Predictions drawn for P0450.png
# 📄 TXT saved: P0450.txt
# Processing P0452.png...
# ✅ Predictions drawn for P0452.png
# 📄 TXT saved: P0452.txt
# Processing P0453.png...
# ✅ Predictions drawn for P0453.png
# 📄 TXT saved: P0453.txt
# Processing P0455.png...
# ✅ Predictions drawn for P0455.png
# 📄 TXT saved: P0455.txt
# Processing P0458.png...
# ✅ Predictions drawn for P0458.png
# 📄 TXT saved: P0458.txt
# Processing P0459.png...
# ✅ Predictions drawn for P0459.png
# 📄 TXT saved: P0459.txt
# Processing P0460.png...
# ✅ Predictions drawn for P0460.png
# 📄 TXT saved: P0460.txt
# Processing P0461.png...
# ✅ Predictions drawn for P0461.png
# 📄 TXT saved: P0461.txt
# Processing P0464.png...
# ✅ Predictions drawn for P0464.png
# 📄 TXT saved: P0464.txt
# Processing P0465.png...
# ✅ Predictions drawn for P0465.png
# 📄 TXT saved: P0465.txt
# Processing P0468.png...
# ✅ Predictions drawn for P0468.png
# 📄 TXT saved: P0468.txt
# Processing P0469.png...
# ✅ Predictions drawn for P0469.png
# 📄 TXT saved: P0469.txt
# Processing P0471.png...
# ✅ Predictions drawn for P0471.png
# 📄 TXT saved: P0471.txt
# Processing P0475.png...
# ✅ Predictions drawn for P0475.png
# 📄 TXT saved: P0475.txt
# Processing P0477.png...
# ✅ Predictions drawn for P0477.png
# 📄 TXT saved: P0477.txt
# Processing P0478.png...
# ✅ Predictions drawn for P0478.png
# 📄 TXT saved: P0478.txt
# Processing P0479.png...
# ✅ Predictions drawn for P0479.png
# 📄 TXT saved: P0479.txt
# Processing P0481.png...
# ✅ Predictions drawn for P0481.png
# 📄 TXT saved: P0481.txt
# Processing P0482.png...
# ✅ Predictions drawn for P0482.png
# 📄 TXT saved: P0482.txt
# Processing P0483.png...
# ✅ Predictions drawn for P0483.png
# 📄 TXT saved: P0483.txt
# Processing P0484.png...
# ✅ Predictions drawn for P0484.png
# 📄 TXT saved: P0484.txt
# Processing P0487.png...
# ✅ Predictions drawn for P0487.png
# 📄 TXT saved: P0487.txt
# Processing P0488.png...
# ✅ Predictions drawn for P0488.png
# 📄 TXT saved: P0488.txt
# Processing P0489.png...
# ✅ Predictions drawn for P0489.png
# 📄 TXT saved: P0489.txt
# Processing P0493.png...
# ✅ Predictions drawn for P0493.png
# 📄 TXT saved: P0493.txt
# Processing P0494.png...
# ✅ Predictions drawn for P0494.png
# 📄 TXT saved: P0494.txt
# Processing P0495.png...
# ✅ Predictions drawn for P0495.png
# 📄 TXT saved: P0495.txt
# Processing P0503.png...
# ✅ Predictions drawn for P0503.png
# 📄 TXT saved: P0503.txt
# Processing P0504.png...
# ✅ Predictions drawn for P0504.png
# 📄 TXT saved: P0504.txt
# Processing P0505.png...
# ✅ Predictions drawn for P0505.png
# 📄 TXT saved: P0505.txt
# Processing P0510.png...
# ✅ Predictions drawn for P0510.png
# 📄 TXT saved: P0510.txt
# Processing P0512.png...
# ✅ Predictions drawn for P0512.png
# 📄 TXT saved: P0512.txt
# Processing P0516.png...
# ✅ Predictions drawn for P0516.png
# 📄 TXT saved: P0516.txt
# Processing P0517.png...
# ✅ Predictions drawn for P0517.png
# 📄 TXT saved: P0517.txt
# Processing P0520.png...
# ✅ Predictions drawn for P0520.png
# 📄 TXT saved: P0520.txt
# Processing P0521.png...
# ✅ Predictions drawn for P0521.png
# 📄 TXT saved: P0521.txt
# Processing P0522.png...
# ✅ Predictions drawn for P0522.png
# 📄 TXT saved: P0522.txt
# Processing P0527.png...
# ✅ Predictions drawn for P0527.png
# 📄 TXT saved: P0527.txt
# Processing P0531.png...
# ✅ Predictions drawn for P0531.png
# 📄 TXT saved: P0531.txt
# Processing P0533.png...
# ✅ Predictions drawn for P0533.png
# 📄 TXT saved: P0533.txt
# Processing P0535.png...
# ✅ Predictions drawn for P0535.png
# 📄 TXT saved: P0535.txt
# Processing P0537.png...
# ✅ Predictions drawn for P0537.png
# 📄 TXT saved: P0537.txt
# Processing P0538.png...
# ✅ Predictions drawn for P0538.png
# 📄 TXT saved: P0538.txt
# Processing P0541.png...
# ✅ Predictions drawn for P0541.png
# 📄 TXT saved: P0541.txt
# Processing P0542.png...
# ✅ Predictions drawn for P0542.png
# 📄 TXT saved: P0542.txt
# Processing P0544.png...
# ✅ Predictions drawn for P0544.png
# 📄 TXT saved: P0544.txt
# Processing P0546.png...
# ✅ Predictions drawn for P0546.png
# 📄 TXT saved: P0546.txt
# Processing P0548.png...
# ✅ Predictions drawn for P0548.png
# 📄 TXT saved: P0548.txt
# Processing P0549.png...
# ✅ Predictions drawn for P0549.png
# 📄 TXT saved: P0549.txt
# Processing P0553.png...
# ✅ Predictions drawn for P0553.png
# 📄 TXT saved: P0553.txt
# Processing P0554.png...
# ✅ Predictions drawn for P0554.png
# 📄 TXT saved: P0554.txt
# Processing P0555.png...
# ✅ Predictions drawn for P0555.png
# 📄 TXT saved: P0555.txt
# Processing P0556.png...
# ✅ Predictions drawn for P0556.png
# 📄 TXT saved: P0556.txt
# Processing P0562.png...
# ✅ Predictions drawn for P0562.png
# 📄 TXT saved: P0562.txt
# Processing P0563.png...
# ✅ Predictions drawn for P0563.png
# 📄 TXT saved: P0563.txt
# Processing P0565.png...
# ✅ Predictions drawn for P0565.png
# 📄 TXT saved: P0565.txt
# Processing P0567.png...
# ✅ Predictions drawn for P0567.png
# 📄 TXT saved: P0567.txt
# Processing P0568.png...
# ✅ Predictions drawn for P0568.png
# 📄 TXT saved: P0568.txt
# Processing P0569.png...
# ✅ Predictions drawn for P0569.png
# 📄 TXT saved: P0569.txt
# Processing P0571.png...
# ✅ Predictions drawn for P0571.png
# 📄 TXT saved: P0571.txt
# Processing P0572.png...
# ✅ Predictions drawn for P0572.png
# 📄 TXT saved: P0572.txt
# Processing P0573.png...
# ✅ Predictions drawn for P0573.png
# 📄 TXT saved: P0573.txt
# Processing P0578.png...
# ✅ Predictions drawn for P0578.png
# 📄 TXT saved: P0578.txt
# Processing P0580.png...
# ✅ Predictions drawn for P0580.png
# 📄 TXT saved: P0580.txt
# Processing P0581.png...
# ✅ Predictions drawn for P0581.png
# 📄 TXT saved: P0581.txt
# Processing P0582.png...
# ✅ Predictions drawn for P0582.png
# 📄 TXT saved: P0582.txt
# Processing P0586.png...
# ✅ Predictions drawn for P0586.png
# 📄 TXT saved: P0586.txt
# Processing P0587.png...
# ✅ Predictions drawn for P0587.png
# 📄 TXT saved: P0587.txt
# Processing P0591.png...
# ✅ Predictions drawn for P0591.png
# 📄 TXT saved: P0591.txt
# Processing P0593.png...
# ✅ Predictions drawn for P0593.png
# 📄 TXT saved: P0593.txt
# Processing P0595.png...
# ✅ Predictions drawn for P0595.png
# 📄 TXT saved: P0595.txt
# Processing P0596.png...
# ✅ Predictions drawn for P0596.png
# 📄 TXT saved: P0596.txt
# Processing P0597.png...
# ✅ Predictions drawn for P0597.png
# 📄 TXT saved: P0597.txt
# Processing P0601.png...
# ✅ Predictions drawn for P0601.png
# 📄 TXT saved: P0601.txt
# Processing P0602.png...
# ✅ Predictions drawn for P0602.png
# 📄 TXT saved: P0602.txt
# Processing P0603.png...
# ✅ Predictions drawn for P0603.png
# 📄 TXT saved: P0603.txt
# Processing P0605.png...
# ✅ Predictions drawn for P0605.png
# 📄 TXT saved: P0605.txt
# Processing P0607.png...
# ✅ Predictions drawn for P0607.png
# 📄 TXT saved: P0607.txt
# Processing P0609.png...
# ✅ Predictions drawn for P0609.png
# 📄 TXT saved: P0609.txt
# Processing P0610.png...
# ✅ Predictions drawn for P0610.png
# 📄 TXT saved: P0610.txt
# Processing P0611.png...
# ✅ Predictions drawn for P0611.png
# 📄 TXT saved: P0611.txt
# Processing P0612.png...
# ✅ Predictions drawn for P0612.png
# 📄 TXT saved: P0612.txt
# Processing P0614.png...
# ✅ Predictions drawn for P0614.png
# 📄 TXT saved: P0614.txt
# Processing P0617.png...
# ✅ Predictions drawn for P0617.png
# 📄 TXT saved: P0617.txt
# Processing P0618.png...
# ✅ Predictions drawn for P0618.png
# 📄 TXT saved: P0618.txt
# Processing P0619.png...
# ✅ Predictions drawn for P0619.png
# 📄 TXT saved: P0619.txt
# Processing P0620.png...
# ✅ Predictions drawn for P0620.png
# 📄 TXT saved: P0620.txt
# Processing P0624.png...
# ✅ Predictions drawn for P0624.png
# 📄 TXT saved: P0624.txt
# Processing P0625.png...
# ✅ Predictions drawn for P0625.png
# 📄 TXT saved: P0625.txt
# Processing P0626.png...
# ✅ Predictions drawn for P0626.png
# 📄 TXT saved: P0626.txt
# Processing P0627.png...
# ✅ Predictions drawn for P0627.png
# 📄 TXT saved: P0627.txt
# Processing P0629.png...
# ✅ Predictions drawn for P0629.png
# 📄 TXT saved: P0629.txt
# Processing P0630.png...
# ✅ Predictions drawn for P0630.png
# 📄 TXT saved: P0630.txt
# Processing P0631.png...
# ✅ Predictions drawn for P0631.png
# 📄 TXT saved: P0631.txt
# Processing P0632.png...
# ✅ Predictions drawn for P0632.png
# 📄 TXT saved: P0632.txt
# Processing P0634.png...
# ✅ Predictions drawn for P0634.png
# 📄 TXT saved: P0634.txt
# Processing P0637.png...
# ✅ Predictions drawn for P0637.png
# 📄 TXT saved: P0637.txt
# Processing P0638.png...
# ✅ Predictions drawn for P0638.png
# 📄 TXT saved: P0638.txt
# Processing P0641.png...
# ✅ Predictions drawn for P0641.png
# 📄 TXT saved: P0641.txt
# Processing P0642.png...
# ✅ Predictions drawn for P0642.png
# 📄 TXT saved: P0642.txt
# Processing P0646.png...
# ✅ Predictions drawn for P0646.png
# 📄 TXT saved: P0646.txt
# Processing P0648.png...
# ✅ Predictions drawn for P0648.png
# 📄 TXT saved: P0648.txt
# Processing P0649.png...
# ✅ Predictions drawn for P0649.png
# 📄 TXT saved: P0649.txt
# Processing P0652.png...
# ✅ Predictions drawn for P0652.png
# 📄 TXT saved: P0652.txt
# Processing P0653.png...
# ✅ Predictions drawn for P0653.png
# 📄 TXT saved: P0653.txt
# Processing P0656.png...
# ✅ Predictions drawn for P0656.png
# 📄 TXT saved: P0656.txt
# Processing P0658.png...
# ✅ Predictions drawn for P0658.png
# 📄 TXT saved: P0658.txt
# Processing P0664.png...
# ✅ Predictions drawn for P0664.png
# 📄 TXT saved: P0664.txt
# Processing P0666.png...
# ✅ Predictions drawn for P0666.png
# 📄 TXT saved: P0666.txt
# Processing P0668.png...
# ✅ Predictions drawn for P0668.png
# 📄 TXT saved: P0668.txt
# Processing P0676.png...
# ✅ Predictions drawn for P0676.png
# 📄 TXT saved: P0676.txt
# Processing P0677.png...
# ✅ Predictions drawn for P0677.png
# 📄 TXT saved: P0677.txt
# Processing P0685.png...
# ✅ Predictions drawn for P0685.png
# 📄 TXT saved: P0685.txt
# Processing P0687.png...
# ✅ Predictions drawn for P0687.png
# 📄 TXT saved: P0687.txt
# Processing P0688.png...
# ✅ Predictions drawn for P0688.png
# 📄 TXT saved: P0688.txt
# Processing P0689.png...
# ✅ Predictions drawn for P0689.png
# 📄 TXT saved: P0689.txt
# Processing P0691.png...
# ✅ Predictions drawn for P0691.png
# 📄 TXT saved: P0691.txt
# Processing P0692.png...
# ✅ Predictions drawn for P0692.png
# 📄 TXT saved: P0692.txt
# Processing P0693.png...
# ✅ Predictions drawn for P0693.png
# 📄 TXT saved: P0693.txt
# Processing P0695.png...
# ✅ Predictions drawn for P0695.png
# 📄 TXT saved: P0695.txt
# Processing P0697.png...
# ✅ Predictions drawn for P0697.png
# 📄 TXT saved: P0697.txt
# Processing P0699.png...
# ✅ Predictions drawn for P0699.png
# 📄 TXT saved: P0699.txt
# Processing P0700.png...
# ✅ Predictions drawn for P0700.png
# 📄 TXT saved: P0700.txt
# Processing P0702.png...
# ✅ Predictions drawn for P0702.png
# 📄 TXT saved: P0702.txt
# Processing P0703.png...
# ✅ Predictions drawn for P0703.png
# 📄 TXT saved: P0703.txt
# Processing P0707.png...
# ✅ Predictions drawn for P0707.png
# 📄 TXT saved: P0707.txt
# Processing P0711.png...
# ✅ Predictions drawn for P0711.png
# 📄 TXT saved: P0711.txt
# Processing P0713.png...
# ✅ Predictions drawn for P0713.png
# 📄 TXT saved: P0713.txt
# Processing P0714.png...
# ✅ Predictions drawn for P0714.png
# 📄 TXT saved: P0714.txt
# Processing P0716.png...
# ✅ Predictions drawn for P0716.png
# 📄 TXT saved: P0716.txt
# Processing P0719.png...
# ✅ Predictions drawn for P0719.png
# 📄 TXT saved: P0719.txt
# Processing P0722.png...
# ✅ Predictions drawn for P0722.png
# 📄 TXT saved: P0722.txt
# Processing P0723.png...
# ✅ Predictions drawn for P0723.png
# 📄 TXT saved: P0723.txt
# Processing P0724.png...
# ✅ Predictions drawn for P0724.png
# 📄 TXT saved: P0724.txt
# Processing P0726.png...
# ✅ Predictions drawn for P0726.png
# 📄 TXT saved: P0726.txt
# Processing P0727.png...
# ✅ Predictions drawn for P0727.png
# 📄 TXT saved: P0727.txt
# Processing P0728.png...
# ✅ Predictions drawn for P0728.png
# 📄 TXT saved: P0728.txt
# Processing P0730.png...
# ✅ Predictions drawn for P0730.png
# 📄 TXT saved: P0730.txt
# Processing P0731.png...
# ✅ Predictions drawn for P0731.png
# 📄 TXT saved: P0731.txt
# Processing P0732.png...
# ✅ Predictions drawn for P0732.png
# 📄 TXT saved: P0732.txt
# Processing P0733.png...
# ✅ Predictions drawn for P0733.png
# 📄 TXT saved: P0733.txt
# Processing P0734.png...
# ✅ Predictions drawn for P0734.png
# 📄 TXT saved: P0734.txt
# Processing P0737.png...
# ✅ Predictions drawn for P0737.png
# 📄 TXT saved: P0737.txt
# Processing P0738.png...
# ✅ Predictions drawn for P0738.png
# 📄 TXT saved: P0738.txt
# Processing P0743.png...
# ✅ Predictions drawn for P0743.png
# 📄 TXT saved: P0743.txt
# Processing P0744.png...
# ✅ Predictions drawn for P0744.png
# 📄 TXT saved: P0744.txt
# Processing P0745.png...
# ✅ Predictions drawn for P0745.png
# 📄 TXT saved: P0745.txt
# Processing P0746.png...
# ✅ Predictions drawn for P0746.png
# 📄 TXT saved: P0746.txt
# Processing P0750.png...
# ✅ Predictions drawn for P0750.png
# 📄 TXT saved: P0750.txt
# Processing P0753.png...
# ✅ Predictions drawn for P0753.png
# 📄 TXT saved: P0753.txt
# Processing P0754.png...
# ✅ Predictions drawn for P0754.png
# 📄 TXT saved: P0754.txt
# Processing P0755.png...
# ✅ Predictions drawn for P0755.png
# 📄 TXT saved: P0755.txt
# Processing P0757.png...
# ✅ Predictions drawn for P0757.png
# 📄 TXT saved: P0757.txt
# Processing P0759.png...
# ✅ Predictions drawn for P0759.png
# 📄 TXT saved: P0759.txt
# Processing P0760.png...
# ✅ Predictions drawn for P0760.png
# 📄 TXT saved: P0760.txt
# Processing P0762.png...
# ✅ Predictions drawn for P0762.png
# 📄 TXT saved: P0762.txt
# Processing P0766.png...
# ✅ Predictions drawn for P0766.png
# 📄 TXT saved: P0766.txt
# Processing P0768.png...
# ✅ Predictions drawn for P0768.png
# 📄 TXT saved: P0768.txt
# Processing P0769.png...
# ✅ Predictions drawn for P0769.png
# 📄 TXT saved: P0769.txt
# Processing P0775.png...
# ✅ Predictions drawn for P0775.png
# 📄 TXT saved: P0775.txt
# Processing P0777.png...
# ✅ Predictions drawn for P0777.png
# 📄 TXT saved: P0777.txt
# Processing P0778.png...
# ✅ Predictions drawn for P0778.png
# 📄 TXT saved: P0778.txt
# Processing P0779.png...
# ✅ Predictions drawn for P0779.png
# 📄 TXT saved: P0779.txt
# Processing P0780.png...
# ✅ Predictions drawn for P0780.png
# 📄 TXT saved: P0780.txt
# Processing P0781.png...
# ✅ Predictions drawn for P0781.png
# 📄 TXT saved: P0781.txt
# Processing P0782.png...
# ✅ Predictions drawn for P0782.png
# 📄 TXT saved: P0782.txt
# Processing P0783.png...
# ✅ Predictions drawn for P0783.png
# 📄 TXT saved: P0783.txt
# Processing P0785.png...
# ✅ Predictions drawn for P0785.png
# 📄 TXT saved: P0785.txt
# Processing P0786.png...
# ✅ Predictions drawn for P0786.png
# 📄 TXT saved: P0786.txt
# Processing P0790.png...
# ✅ Predictions drawn for P0790.png
# 📄 TXT saved: P0790.txt
# Processing P0792.png...
# ✅ Predictions drawn for P0792.png
# 📄 TXT saved: P0792.txt
# Processing P0794.png...
# ✅ Predictions drawn for P0794.png
# 📄 TXT saved: P0794.txt
# Processing P0800.png...
# ✅ Predictions drawn for P0800.png
# 📄 TXT saved: P0800.txt
# Processing P0803.png...
# ✅ Predictions drawn for P0803.png
# 📄 TXT saved: P0803.txt
# Processing P0804.png...
# ✅ Predictions drawn for P0804.png
# 📄 TXT saved: P0804.txt
# Processing P0805.png...
# ✅ Predictions drawn for P0805.png
# 📄 TXT saved: P0805.txt
# Processing P0806.png...
# ✅ Predictions drawn for P0806.png
# 📄 TXT saved: P0806.txt
# Processing P0809.png...
# ✅ Predictions drawn for P0809.png
# 📄 TXT saved: P0809.txt
# Processing P0810.png...
# ✅ Predictions drawn for P0810.png
# 📄 TXT saved: P0810.txt
# Processing P0817.png...
# ✅ Predictions drawn for P0817.png
# 📄 TXT saved: P0817.txt
# Processing P0818.png...
# ✅ Predictions drawn for P0818.png
# 📄 TXT saved: P0818.txt
# Processing P0819.png...
# ✅ Predictions drawn for P0819.png
# 📄 TXT saved: P0819.txt
# Processing P0821.png...
# ✅ Predictions drawn for P0821.png
# 📄 TXT saved: P0821.txt
# Processing P0823.png...
# ✅ Predictions drawn for P0823.png
# 📄 TXT saved: P0823.txt
# Processing P0825.png...
# ✅ Predictions drawn for P0825.png
# 📄 TXT saved: P0825.txt
# Processing P0826.png...
# ✅ Predictions drawn for P0826.png
# 📄 TXT saved: P0826.txt
# Processing P0827.png...
# ✅ Predictions drawn for P0827.png
# 📄 TXT saved: P0827.txt
# Processing P0828.png...
# ✅ Predictions drawn for P0828.png
# 📄 TXT saved: P0828.txt
# Processing P0829.png...
# ✅ Predictions drawn for P0829.png
# 📄 TXT saved: P0829.txt
# Processing P0831.png...
# ✅ Predictions drawn for P0831.png
# 📄 TXT saved: P0831.txt
# Processing P0832.png...
# ✅ Predictions drawn for P0832.png
# 📄 TXT saved: P0832.txt
# Processing P0835.png...
# ✅ Predictions drawn for P0835.png
# 📄 TXT saved: P0835.txt
# Processing P0840.png...
# ✅ Predictions drawn for P0840.png
# 📄 TXT saved: P0840.txt
# Processing P0843.png...
# ✅ Predictions drawn for P0843.png
# 📄 TXT saved: P0843.txt
# Processing P0845.png...
# ✅ Predictions drawn for P0845.png
# 📄 TXT saved: P0845.txt
# Processing P0846.png...
# ✅ Predictions drawn for P0846.png
# 📄 TXT saved: P0846.txt
# Processing P0848.png...
# ✅ Predictions drawn for P0848.png
# 📄 TXT saved: P0848.txt
# Processing P0849.png...
# ✅ Predictions drawn for P0849.png
# 📄 TXT saved: P0849.txt
# Processing P0850.png...
# ✅ Predictions drawn for P0850.png
# 📄 TXT saved: P0850.txt
# Processing P0851.png...
# ✅ Predictions drawn for P0851.png
# 📄 TXT saved: P0851.txt
# Processing P0853.png...
# ✅ Predictions drawn for P0853.png
# 📄 TXT saved: P0853.txt
# Processing P0855.png...
# ✅ Predictions drawn for P0855.png
# 📄 TXT saved: P0855.txt
# Processing P0856.png...
# ✅ Predictions drawn for P0856.png
# 📄 TXT saved: P0856.txt
# Processing P0857.png...
# ✅ Predictions drawn for P0857.png
# 📄 TXT saved: P0857.txt
# Processing P0860.png...
# ✅ Predictions drawn for P0860.png
# 📄 TXT saved: P0860.txt
# Processing P0861.png...
# ✅ Predictions drawn for P0861.png
# 📄 TXT saved: P0861.txt
# Processing P0867.png...
# ✅ Predictions drawn for P0867.png
# 📄 TXT saved: P0867.txt
# Processing P0868.png...
# ✅ Predictions drawn for P0868.png
# 📄 TXT saved: P0868.txt
# Processing P0869.png...
# ✅ Predictions drawn for P0869.png
# 📄 TXT saved: P0869.txt
# Processing P0870.png...
# ✅ Predictions drawn for P0870.png
# 📄 TXT saved: P0870.txt
# Processing P0871.png...
# ✅ Predictions drawn for P0871.png
# 📄 TXT saved: P0871.txt
# Processing P0872.png...
# ✅ Predictions drawn for P0872.png
# 📄 TXT saved: P0872.txt
# Processing P0873.png...
# ✅ Predictions drawn for P0873.png
# 📄 TXT saved: P0873.txt
# Processing P0874.png...
# ✅ Predictions drawn for P0874.png
# 📄 TXT saved: P0874.txt
# Processing P0875.png...
# ✅ Predictions drawn for P0875.png
# 📄 TXT saved: P0875.txt
# Processing P0878.png...
# ✅ Predictions drawn for P0878.png
# 📄 TXT saved: P0878.txt
# Processing P0879.png...
# ✅ Predictions drawn for P0879.png
# 📄 TXT saved: P0879.txt
# Processing P0881.png...
# ✅ Predictions drawn for P0881.png
# 📄 TXT saved: P0881.txt
# Processing P0883.png...
# ✅ Predictions drawn for P0883.png
# 📄 TXT saved: P0883.txt
# Processing P0884.png...
# ✅ Predictions drawn for P0884.png
# 📄 TXT saved: P0884.txt
# Processing P0885.png...
# ✅ Predictions drawn for P0885.png
# 📄 TXT saved: P0885.txt
# Processing P0888.png...
# ✅ Predictions drawn for P0888.png
# 📄 TXT saved: P0888.txt
# Processing P0890.png...
# ✅ Predictions drawn for P0890.png
# 📄 TXT saved: P0890.txt
# Processing P0892.png...
# ✅ Predictions drawn for P0892.png
# 📄 TXT saved: P0892.txt
# Processing P0893.png...
# ✅ Predictions drawn for P0893.png
# 📄 TXT saved: P0893.txt
# Processing P0894.png...
# ✅ Predictions drawn for P0894.png
# 📄 TXT saved: P0894.txt
# Processing P0895.png...
# ✅ Predictions drawn for P0895.png
# 📄 TXT saved: P0895.txt
# Processing P0896.png...
# ✅ Predictions drawn for P0896.png
# 📄 TXT saved: P0896.txt
# Processing P0898.png...
# ✅ Predictions drawn for P0898.png
# 📄 TXT saved: P0898.txt
# Processing P0899.png...
# ✅ Predictions drawn for P0899.png
# 📄 TXT saved: P0899.txt
# Processing P0900.png...
# ✅ Predictions drawn for P0900.png
# 📄 TXT saved: P0900.txt
# Processing P0905.png...
# ✅ Predictions drawn for P0905.png
# 📄 TXT saved: P0905.txt
# Processing P0906.png...
# ✅ Predictions drawn for P0906.png
# 📄 TXT saved: P0906.txt
# Processing P0907.png...
# ✅ Predictions drawn for P0907.png
# 📄 TXT saved: P0907.txt
# Processing P0908.png...
# ✅ Predictions drawn for P0908.png
# 📄 TXT saved: P0908.txt
# Processing P0909.png...
# ✅ Predictions drawn for P0909.png
# 📄 TXT saved: P0909.txt
# Processing P0911.png...
# ✅ Predictions drawn for P0911.png
# 📄 TXT saved: P0911.txt
# Processing P0913.png...
# ✅ Predictions drawn for P0913.png
# 📄 TXT saved: P0913.txt
# Processing P0914.png...
# ✅ Predictions drawn for P0914.png
# 📄 TXT saved: P0914.txt
# Processing P0915.png...
# ✅ Predictions drawn for P0915.png
# 📄 TXT saved: P0915.txt
# Processing P0918.png...
# ✅ Predictions drawn for P0918.png
# 📄 TXT saved: P0918.txt
# Processing P0920.png...
# ✅ Predictions drawn for P0920.png
# 📄 TXT saved: P0920.txt
# Processing P0921.png...
# ✅ Predictions drawn for P0921.png
# 📄 TXT saved: P0921.txt
# Processing P0922.png...
# ✅ Predictions drawn for P0922.png
# 📄 TXT saved: P0922.txt
# Processing P0925.png...
# ✅ Predictions drawn for P0925.png
# 📄 TXT saved: P0925.txt
# Processing P0926.png...
# ✅ Predictions drawn for P0926.png
# 📄 TXT saved: P0926.txt
# Processing P0928.png...
# ✅ Predictions drawn for P0928.png
# 📄 TXT saved: P0928.txt
# Processing P0933.png...
# ✅ Predictions drawn for P0933.png
# 📄 TXT saved: P0933.txt
# Processing P0934.png...
# ✅ Predictions drawn for P0934.png
# 📄 TXT saved: P0934.txt
# Processing P0938.png...
# ✅ Predictions drawn for P0938.png
# 📄 TXT saved: P0938.txt
# Processing P0940.png...
# ✅ Predictions drawn for P0940.png
# 📄 TXT saved: P0940.txt
# Processing P0941.png...
# ✅ Predictions drawn for P0941.png
# 📄 TXT saved: P0941.txt
# Processing P0944.png...
# ✅ Predictions drawn for P0944.png
# 📄 TXT saved: P0944.txt
# Processing P0946.png...
# ✅ Predictions drawn for P0946.png
# 📄 TXT saved: P0946.txt
# Processing P0947.png...
# ✅ Predictions drawn for P0947.png
# 📄 TXT saved: P0947.txt
# Processing P0948.png...
# ✅ Predictions drawn for P0948.png
# 📄 TXT saved: P0948.txt
# Processing P0950.png...
# ✅ Predictions drawn for P0950.png
# 📄 TXT saved: P0950.txt
# Processing P0951.png...
# ✅ Predictions drawn for P0951.png
# 📄 TXT saved: P0951.txt
# Processing P0952.png...
# ✅ Predictions drawn for P0952.png
# 📄 TXT saved: P0952.txt
# Processing P0957.png...
# ✅ Predictions drawn for P0957.png
# 📄 TXT saved: P0957.txt
# Processing P0960.png...
# ✅ Predictions drawn for P0960.png
# 📄 TXT saved: P0960.txt
# Processing P0963.png...
# ✅ Predictions drawn for P0963.png
# 📄 TXT saved: P0963.txt
# Processing P0966.png...
# ✅ Predictions drawn for P0966.png
# 📄 TXT saved: P0966.txt
# Processing P0967.png...
# ✅ Predictions drawn for P0967.png
# 📄 TXT saved: P0967.txt
# Processing P0972.png...
# ✅ Predictions drawn for P0972.png
# 📄 TXT saved: P0972.txt
# Processing P0973.png...
# ✅ Predictions drawn for P0973.png
# 📄 TXT saved: P0973.txt
# Processing P0975.png...
# ✅ Predictions drawn for P0975.png
# 📄 TXT saved: P0975.txt
# Processing P0978.png...
# ✅ Predictions drawn for P0978.png
# 📄 TXT saved: P0978.txt
# Processing P0979.png...
# ✅ Predictions drawn for P0979.png
# 📄 TXT saved: P0979.txt
# Processing P0980.png...
# ✅ Predictions drawn for P0980.png
# 📄 TXT saved: P0980.txt
# Processing P0981.png...
# ✅ Predictions drawn for P0981.png
# 📄 TXT saved: P0981.txt
# Processing P0986.png...
# ✅ Predictions drawn for P0986.png
# 📄 TXT saved: P0986.txt
# Processing P0987.png...
# ✅ Predictions drawn for P0987.png
# 📄 TXT saved: P0987.txt
# Processing P0991.png...
# ✅ Predictions drawn for P0991.png
# 📄 TXT saved: P0991.txt
# Processing P0993.png...
# ✅ Predictions drawn for P0993.png
# 📄 TXT saved: P0993.txt
# Processing P0995.png...
# ✅ Predictions drawn for P0995.png
# 📄 TXT saved: P0995.txt
# Processing P0999.png...
# ✅ Predictions drawn for P0999.png
# 📄 TXT saved: P0999.txt
# Processing P1003.png...
# ✅ Predictions drawn for P1003.png
# 📄 TXT saved: P1003.txt
# Processing P1006.png...
# ✅ Predictions drawn for P1006.png
# 📄 TXT saved: P1006.txt
# Processing P1010.png...
# ✅ Predictions drawn for P1010.png
# 📄 TXT saved: P1010.txt
# Processing P1012.png...
# ✅ Predictions drawn for P1012.png
# 📄 TXT saved: P1012.txt
# Processing P1015.png...
# ✅ Predictions drawn for P1015.png
# 📄 TXT saved: P1015.txt
# Processing P1016.png...
# ✅ Predictions drawn for P1016.png
# 📄 TXT saved: P1016.txt
# Processing P1019.png...
# ✅ Predictions drawn for P1019.png
# 📄 TXT saved: P1019.txt
# Processing P1020.png...
# ✅ Predictions drawn for P1020.png
# 📄 TXT saved: P1020.txt
# Processing P1026.png...
# ✅ Predictions drawn for P1026.png
# 📄 TXT saved: P1026.txt
# Processing P1027.png...
# ✅ Predictions drawn for P1027.png
# 📄 TXT saved: P1027.txt
# Processing P1037.png...
# ✅ Predictions drawn for P1037.png
# 📄 TXT saved: P1037.txt
# Processing P1043.png...
# ✅ Predictions drawn for P1043.png
# 📄 TXT saved: P1043.txt
# Processing P1046.png...
# ✅ Predictions drawn for P1046.png
# 📄 TXT saved: P1046.txt
# Processing P1047.png...
# ✅ Predictions drawn for P1047.png
# 📄 TXT saved: P1047.txt
# Processing P1049.png...
# ✅ Predictions drawn for P1049.png
# 📄 TXT saved: P1049.txt
# Processing P1052.png...
# ✅ Predictions drawn for P1052.png
# 📄 TXT saved: P1052.txt
# Processing P1053.png...
# ✅ Predictions drawn for P1053.png
# 📄 TXT saved: P1053.txt
# Processing P1054.png...
# ✅ Predictions drawn for P1054.png
# 📄 TXT saved: P1054.txt
# Processing P1055.png...
# ✅ Predictions drawn for P1055.png
# 📄 TXT saved: P1055.txt
# Processing P1057.png...
# ✅ Predictions drawn for P1057.png
# 📄 TXT saved: P1057.txt
# Processing P1059.png...
# ✅ Predictions drawn for P1059.png
# 📄 TXT saved: P1059.txt
# Processing P1060.png...
# ✅ Predictions drawn for P1060.png
# 📄 TXT saved: P1060.txt
# Processing P1061.png...
# ✅ Predictions drawn for P1061.png
# 📄 TXT saved: P1061.txt
# Processing P1062.png...
# ✅ Predictions drawn for P1062.png
# 📄 TXT saved: P1062.txt
# Processing P1063.png...
# ✅ Predictions drawn for P1063.png
# 📄 TXT saved: P1063.txt
# Processing P1067.png...
# ✅ Predictions drawn for P1067.png
# 📄 TXT saved: P1067.txt
# Processing P1069.png...
# ✅ Predictions drawn for P1069.png
# 📄 TXT saved: P1069.txt
# Processing P1070.png...
# ✅ Predictions drawn for P1070.png
# 📄 TXT saved: P1070.txt
# Processing P1071.png...
# ✅ Predictions drawn for P1071.png
# 📄 TXT saved: P1071.txt
# Processing P1073.png...
# ✅ Predictions drawn for P1073.png
# 📄 TXT saved: P1073.txt
# Processing P1076.png...
# ✅ Predictions drawn for P1076.png
# 📄 TXT saved: P1076.txt
# Processing P1077.png...
# ✅ Predictions drawn for P1077.png
# 📄 TXT saved: P1077.txt
# Processing P1078.png...
# ✅ Predictions drawn for P1078.png
# 📄 TXT saved: P1078.txt
# Processing P1079.png...
# ✅ Predictions drawn for P1079.png
# 📄 TXT saved: P1079.txt
# Processing P1080.png...
# ✅ Predictions drawn for P1080.png
# 📄 TXT saved: P1080.txt
# Processing P1084.png...
# ✅ Predictions drawn for P1084.png
# 📄 TXT saved: P1084.txt
# Processing P1087.png...
# ✅ Predictions drawn for P1087.png
# 📄 TXT saved: P1087.txt
# Processing P1089.png...
# ✅ Predictions drawn for P1089.png
# 📄 TXT saved: P1089.txt
# Processing P1092.png...
# ✅ Predictions drawn for P1092.png
# 📄 TXT saved: P1092.txt
# Processing P1094.png...
# ✅ Predictions drawn for P1094.png
# 📄 TXT saved: P1094.txt
# Processing P1096.png...
# ✅ Predictions drawn for P1096.png
# 📄 TXT saved: P1096.txt
# Processing P1098.png...
# ✅ Predictions drawn for P1098.png
# 📄 TXT saved: P1098.txt
# Processing P1105.png...
# ✅ Predictions drawn for P1105.png
# 📄 TXT saved: P1105.txt
# Processing P1107.png...
# ✅ Predictions drawn for P1107.png
# 📄 TXT saved: P1107.txt
# Processing P1108.png...
# ✅ Predictions drawn for P1108.png
# 📄 TXT saved: P1108.txt
# Processing P1109.png...
# ✅ Predictions drawn for P1109.png
# 📄 TXT saved: P1109.txt
# Processing P1110.png...
# ✅ Predictions drawn for P1110.png
# 📄 TXT saved: P1110.txt
# Processing P1113.png...
# ✅ Predictions drawn for P1113.png
# 📄 TXT saved: P1113.txt
# Processing P1114.png...
# ✅ Predictions drawn for P1114.png
# 📄 TXT saved: P1114.txt
# Processing P1116.png...
# ✅ Predictions drawn for P1116.png
# 📄 TXT saved: P1116.txt
# Processing P1117.png...
# ✅ Predictions drawn for P1117.png
# 📄 TXT saved: P1117.txt
# Processing P1118.png...
# ✅ Predictions drawn for P1118.png
# 📄 TXT saved: P1118.txt
# Processing P1119.png...
# ✅ Predictions drawn for P1119.png
# 📄 TXT saved: P1119.txt
# Processing P1121.png...
# ✅ Predictions drawn for P1121.png
# 📄 TXT saved: P1121.txt
# Processing P1130.png...
# ✅ Predictions drawn for P1130.png
# 📄 TXT saved: P1130.txt
# Processing P1131.png...
# ✅ Predictions drawn for P1131.png
# 📄 TXT saved: P1131.txt
# Processing P1132.png...
# ✅ Predictions drawn for P1132.png
# 📄 TXT saved: P1132.txt
# Processing P1139.png...
# ✅ Predictions drawn for P1139.png
# 📄 TXT saved: P1139.txt
# Processing P1140.png...
# ✅ Predictions drawn for P1140.png
# 📄 TXT saved: P1140.txt
# Processing P1141.png...
# ✅ Predictions drawn for P1141.png
# 📄 TXT saved: P1141.txt
# Processing P1142.png...
# ✅ Predictions drawn for P1142.png
# 📄 TXT saved: P1142.txt
# Processing P1144.png...
# ✅ Predictions drawn for P1144.png
# 📄 TXT saved: P1144.txt
# ...
# Processing P2453.png...
# ✅ Predictions drawn for P2453.png
# 📄 TXT saved: P2453.txt
# Processing P2454.png...
# ✅ Predictions drawn for P2454.png
# 📄 TXT saved: P2454.txt
# Processing P2456.png...
# ✅ Predictions drawn for P2456.png
# 📄 TXT saved: P2456.txt
# Processing P2457.png...
# ✅ Predictions drawn for P2457.png
# 📄 TXT saved: P2457.txt
# Processing P2458.png...
# ✅ Predictions drawn for P2458.png
# 📄 TXT saved: P2458.txt
# Processing P2460.png...
# ✅ Predictions drawn for P2460.png
# 📄 TXT saved: P2460.txt
# Processing P2464.png...
# ✅ Predictions drawn for P2464.png
# 📄 TXT saved: P2464.txt
# Processing P2465.png...
# ✅ Predictions drawn for P2465.png
# 📄 TXT saved: P2465.txt
# Processing P2466.png...
# ✅ Predictions drawn for P2466.png
# 📄 TXT saved: P2466.txt
# Processing P2467.png...
# ✅ Predictions drawn for P2467.png
# 📄 TXT saved: P2467.txt
# Processing P2468.png...
# ✅ Predictions drawn for P2468.png
# 📄 TXT saved: P2468.txt
# Processing P2469.png...
# ✅ Predictions drawn for P2469.png
# 📄 TXT saved: P2469.txt
# Processing P2470.png...
# ✅ Predictions drawn for P2470.png
# 📄 TXT saved: P2470.txt
# Processing P2471.png...
# ✅ Predictions drawn for P2471.png
# 📄 TXT saved: P2471.txt
# Processing P2472.png...
# ✅ Predictions drawn for P2472.png
# 📄 TXT saved: P2472.txt
# Processing P2475.png...
# ✅ Predictions drawn for P2475.png
# 📄 TXT saved: P2475.txt
# Processing P2476.png...
# ✅ Predictions drawn for P2476.png
# 📄 TXT saved: P2476.txt
# Processing P2479.png...
# ✅ Predictions drawn for P2479.png
# 📄 TXT saved: P2479.txt
# Processing P2482.png...
# ✅ Predictions drawn for P2482.png
# 📄 TXT saved: P2482.txt
# Processing P2483.png...
# ✅ Predictions drawn for P2483.png
# 📄 TXT saved: P2483.txt
# Processing P2485.png...
# ✅ Predictions drawn for P2485.png
# 📄 TXT saved: P2485.txt
# Processing P2490.png...
# ✅ Predictions drawn for P2490.png
# 📄 TXT saved: P2490.txt
# Processing P2491.png...
# ✅ Predictions drawn for P2491.png
# 📄 TXT saved: P2491.txt
# Processing P2492.png...
# ✅ Predictions drawn for P2492.png
# 📄 TXT saved: P2492.txt
# Processing P2494.png...
# ✅ Predictions drawn for P2494.png
# 📄 TXT saved: P2494.txt
# Processing P2495.png...
# ✅ Predictions drawn for P2495.png
# 📄 TXT saved: P2495.txt
# Processing P2496.png...
# ✅ Predictions drawn for P2496.png
# 📄 TXT saved: P2496.txt
# Processing P2497.png...
# ✅ Predictions drawn for P2497.png
# 📄 TXT saved: P2497.txt
# Processing P2501.png...
# ✅ Predictions drawn for P2501.png
# 📄 TXT saved: P2501.txt
# Processing P2503.png...
# ⚠️ No predictions for P2503.png, drawing dummy box.
# 📄 TXT saved: P2503.txt
# Processing P2505.png...
# ✅ Predictions drawn for P2505.png
# 📄 TXT saved: P2505.txt
# Processing P2506.png...
# ✅ Predictions drawn for P2506.png
# 📄 TXT saved: P2506.txt
# Processing P2507.png...
# ✅ Predictions drawn for P2507.png
# 📄 TXT saved: P2507.txt
# Processing P2509.png...
# ✅ Predictions drawn for P2509.png
# 📄 TXT saved: P2509.txt
# Processing P2512.png...
# ✅ Predictions drawn for P2512.png
# 📄 TXT saved: P2512.txt
# Processing P2513.png...
# ✅ Predictions drawn for P2513.png
# 📄 TXT saved: P2513.txt
# Processing P2514.png...
# ✅ Predictions drawn for P2514.png
# 📄 TXT saved: P2514.txt
# Processing P2516.png...
# ✅ Predictions drawn for P2516.png
# 📄 TXT saved: P2516.txt
# Processing P2517.png...
# ✅ Predictions drawn for P2517.png
# 📄 TXT saved: P2517.txt
# Processing P2518.png...
# ✅ Predictions drawn for P2518.png
# 📄 TXT saved: P2518.txt
# Processing P2519.png...
# ✅ Predictions drawn for P2519.png
# 📄 TXT saved: P2519.txt
# Processing P2520.png...
# ✅ Predictions drawn for P2520.png
# 📄 TXT saved: P2520.txt
# Processing P2522.png...
# ✅ Predictions drawn for P2522.png
# 📄 TXT saved: P2522.txt
# Processing P2523.png...
# ✅ Predictions drawn for P2523.png
# 📄 TXT saved: P2523.txt
# Processing P2527.png...
# ✅ Predictions drawn for P2527.png
# 📄 TXT saved: P2527.txt
# Processing P2528.png...
# ✅ Predictions drawn for P2528.png
# 📄 TXT saved: P2528.txt
# Processing P2529.png...
# ✅ Predictions drawn for P2529.png
# 📄 TXT saved: P2529.txt
# Processing P2531.png...
# ✅ Predictions drawn for P2531.png
# 📄 TXT saved: P2531.txt
# Processing P2532.png...
# ✅ Predictions drawn for P2532.png
# 📄 TXT saved: P2532.txt
# Processing P2533.png...
# ✅ Predictions drawn for P2533.png
# 📄 TXT saved: P2533.txt
# Processing P2534.png...
# ✅ Predictions drawn for P2534.png
# 📄 TXT saved: P2534.txt
# Processing P2536.png...
# ✅ Predictions drawn for P2536.png
# 📄 TXT saved: P2536.txt
# Processing P2538.png...
# ✅ Predictions drawn for P2538.png
# 📄 TXT saved: P2538.txt
# Processing P2543.png...
# ✅ Predictions drawn for P2543.png
# 📄 TXT saved: P2543.txt
# Processing P2545.png...
# ✅ Predictions drawn for P2545.png
# 📄 TXT saved: P2545.txt
# Processing P2548.png...
# ✅ Predictions drawn for P2548.png
# 📄 TXT saved: P2548.txt
# Processing P2550.png...
# ✅ Predictions drawn for P2550.png
# 📄 TXT saved: P2550.txt
# Processing P2551.png...
# ✅ Predictions drawn for P2551.png
# 📄 TXT saved: P2551.txt
# Processing P2552.png...
# ✅ Predictions drawn for P2552.png
# 📄 TXT saved: P2552.txt
# Processing P2553.png...
# ✅ Predictions drawn for P2553.png
# 📄 TXT saved: P2553.txt
# Processing P2554.png...
# ✅ Predictions drawn for P2554.png
# 📄 TXT saved: P2554.txt
# Processing P2557.png...
# ✅ Predictions drawn for P2557.png
# 📄 TXT saved: P2557.txt
# Processing P2558.png...
# ✅ Predictions drawn for P2558.png
# 📄 TXT saved: P2558.txt
# Processing P2560.png...
# ✅ Predictions drawn for P2560.png
# 📄 TXT saved: P2560.txt
# Processing P2561.png...
# ✅ Predictions drawn for P2561.png
# 📄 TXT saved: P2561.txt
# Processing P2565.png...
# ✅ Predictions drawn for P2565.png
# 📄 TXT saved: P2565.txt
# Processing P2566.png...
# ✅ Predictions drawn for P2566.png
# 📄 TXT saved: P2566.txt
# Processing P2569.png...
# ✅ Predictions drawn for P2569.png
# 📄 TXT saved: P2569.txt
# Processing P2572.png...
# ✅ Predictions drawn for P2572.png
# 📄 TXT saved: P2572.txt
# Processing P2576.png...
# ✅ Predictions drawn for P2576.png
# 📄 TXT saved: P2576.txt
# Processing P2578.png...
# ✅ Predictions drawn for P2578.png
# 📄 TXT saved: P2578.txt
# Processing P2579.png...
# ✅ Predictions drawn for P2579.png
# 📄 TXT saved: P2579.txt
# Processing P2584.png...
# ✅ Predictions drawn for P2584.png
# 📄 TXT saved: P2584.txt
# Processing P2585.png...
# ✅ Predictions drawn for P2585.png
# 📄 TXT saved: P2585.txt
# Processing P2590.png...
# ✅ Predictions drawn for P2590.png
# 📄 TXT saved: P2590.txt
# Processing P2591.png...
# ✅ Predictions drawn for P2591.png
# 📄 TXT saved: P2591.txt
# Processing P2594.png...
# ✅ Predictions drawn for P2594.png
# 📄 TXT saved: P2594.txt
# Processing P2597.png...
# ✅ Predictions drawn for P2597.png
# 📄 TXT saved: P2597.txt
# Processing P2600.png...
# ✅ Predictions drawn for P2600.png
# 📄 TXT saved: P2600.txt
# Processing P2601.png...
# ✅ Predictions drawn for P2601.png
# 📄 TXT saved: P2601.txt
# Processing P2604.png...
# ✅ Predictions drawn for P2604.png
# 📄 TXT saved: P2604.txt
# Processing P2605.png...
# ✅ Predictions drawn for P2605.png
# 📄 TXT saved: P2605.txt
# Processing P2606.png...
# ✅ Predictions drawn for P2606.png
# 📄 TXT saved: P2606.txt
# Processing P2609.png...
# ✅ Predictions drawn for P2609.png
# 📄 TXT saved: P2609.txt
# Processing P2611.png...
# ✅ Predictions drawn for P2611.png
# 📄 TXT saved: P2611.txt
# Processing P2612.png...
# ✅ Predictions drawn for P2612.png
# 📄 TXT saved: P2612.txt
# Processing P2613.png...
# ✅ Predictions drawn for P2613.png
# 📄 TXT saved: P2613.txt
# Processing P2614.png...
# ✅ Predictions drawn for P2614.png
# 📄 TXT saved: P2614.txt
# Processing P2615.png...
# ✅ Predictions drawn for P2615.png
# 📄 TXT saved: P2615.txt
# Processing P2616.png...
# ✅ Predictions drawn for P2616.png
# 📄 TXT saved: P2616.txt
# Processing P2618.png...
# ✅ Predictions drawn for P2618.png
# 📄 TXT saved: P2618.txt
# Processing P2621.png...
# ✅ Predictions drawn for P2621.png
# 📄 TXT saved: P2621.txt
# Processing P2622.png...
# ✅ Predictions drawn for P2622.png
# 📄 TXT saved: P2622.txt
# Processing P2626.png...
# ✅ Predictions drawn for P2626.png
# 📄 TXT saved: P2626.txt
# Processing P2627.png...
# ✅ Predictions drawn for P2627.png
# 📄 TXT saved: P2627.txt
# Processing P2628.png...
# ✅ Predictions drawn for P2628.png
# 📄 TXT saved: P2628.txt
# Processing P2629.png...
# ✅ Predictions drawn for P2629.png
# 📄 TXT saved: P2629.txt
# Processing P2631.png...
# ✅ Predictions drawn for P2631.png
# 📄 TXT saved: P2631.txt
# Processing P2632.png...
# ✅ Predictions drawn for P2632.png
# 📄 TXT saved: P2632.txt
# Processing P2634.png...
# ✅ Predictions drawn for P2634.png
# 📄 TXT saved: P2634.txt
# Processing P2637.png...
# ✅ Predictions drawn for P2637.png
# 📄 TXT saved: P2637.txt
# Processing P2638.png...
# ✅ Predictions drawn for P2638.png
# 📄 TXT saved: P2638.txt
# Processing P2639.png...
# ✅ Predictions drawn for P2639.png
# 📄 TXT saved: P2639.txt
# Processing P2641.png...
# ✅ Predictions drawn for P2641.png
# 📄 TXT saved: P2641.txt
# Processing P2642.png...
# ✅ Predictions drawn for P2642.png
# 📄 TXT saved: P2642.txt
# Processing P2644.png...
# ✅ Predictions drawn for P2644.png
# 📄 TXT saved: P2644.txt
# Processing P2646.png...
# ✅ Predictions drawn for P2646.png
# 📄 TXT saved: P2646.txt
# Processing P2650.png...
# ✅ Predictions drawn for P2650.png
# 📄 TXT saved: P2650.txt
# Processing P2651.png...
# ✅ Predictions drawn for P2651.png
# 📄 TXT saved: P2651.txt
# Processing P2653.png...
# ✅ Predictions drawn for P2653.png
# 📄 TXT saved: P2653.txt
# Processing P2655.png...
# ✅ Predictions drawn for P2655.png
# 📄 TXT saved: P2655.txt
# Processing P2656.png...
# ✅ Predictions drawn for P2656.png
# 📄 TXT saved: P2656.txt
# Processing P2657.png...
# ✅ Predictions drawn for P2657.png
# 📄 TXT saved: P2657.txt
# Processing P2659.png...
# ✅ Predictions drawn for P2659.png
# 📄 TXT saved: P2659.txt
# Processing P2662.png...
# ✅ Predictions drawn for P2662.png
# 📄 TXT saved: P2662.txt
# Processing P2663.png...
# ✅ Predictions drawn for P2663.png
# 📄 TXT saved: P2663.txt
# Processing P2664.png...
# ✅ Predictions drawn for P2664.png
# 📄 TXT saved: P2664.txt
# Processing P2665.png...
# ✅ Predictions drawn for P2665.png
# 📄 TXT saved: P2665.txt
# Processing P2668.png...
# ✅ Predictions drawn for P2668.png
# 📄 TXT saved: P2668.txt
# Processing P2669.png...
# ✅ Predictions drawn for P2669.png
# 📄 TXT saved: P2669.txt
# Processing P2670.png...
# ✅ Predictions drawn for P2670.png
# 📄 TXT saved: P2670.txt
# Processing P2671.png...
# ✅ Predictions drawn for P2671.png
# 📄 TXT saved: P2671.txt
# Processing P2672.png...
# ✅ Predictions drawn for P2672.png
# 📄 TXT saved: P2672.txt
# Processing P2673.png...
# ✅ Predictions drawn for P2673.png
# 📄 TXT saved: P2673.txt
# Processing P2674.png...
# ✅ Predictions drawn for P2674.png
# 📄 TXT saved: P2674.txt
# Processing P2676.png...
# ✅ Predictions drawn for P2676.png
# 📄 TXT saved: P2676.txt
# Processing P2680.png...
# ✅ Predictions drawn for P2680.png
# 📄 TXT saved: P2680.txt
# Processing P2681.png...
# ✅ Predictions drawn for P2681.png
# 📄 TXT saved: P2681.txt
# Processing P2682.png...
# ✅ Predictions drawn for P2682.png
# 📄 TXT saved: P2682.txt
# Processing P2685.png...
# ✅ Predictions drawn for P2685.png
# 📄 TXT saved: P2685.txt
# Processing P2686.png...
# ✅ Predictions drawn for P2686.png
# 📄 TXT saved: P2686.txt
# Processing P2687.png...
# ✅ Predictions drawn for P2687.png
# 📄 TXT saved: P2687.txt
# Processing P2690.png...
# ✅ Predictions drawn for P2690.png
# 📄 TXT saved: P2690.txt
# Processing P2691.png...
# ✅ Predictions drawn for P2691.png
# 📄 TXT saved: P2691.txt
# Processing P2692.png...
# ✅ Predictions drawn for P2692.png
# 📄 TXT saved: P2692.txt
# Processing P2693.png...
# ✅ Predictions drawn for P2693.png
# 📄 TXT saved: P2693.txt
# Processing P2696.png...
# ✅ Predictions drawn for P2696.png
# 📄 TXT saved: P2696.txt
# Processing P2700.png...
# ✅ Predictions drawn for P2700.png
# 📄 TXT saved: P2700.txt
# Processing P2702.png...
# ✅ Predictions drawn for P2702.png
# 📄 TXT saved: P2702.txt
# Processing P2704.png...
# ✅ Predictions drawn for P2704.png
# 📄 TXT saved: P2704.txt
# Processing P2705.png...
# ✅ Predictions drawn for P2705.png
# 📄 TXT saved: P2705.txt
# Processing P2706.png...
# ✅ Predictions drawn for P2706.png
# 📄 TXT saved: P2706.txt
# Processing P2708.png...
# ✅ Predictions drawn for P2708.png
# 📄 TXT saved: P2708.txt
# Processing P2710.png...
# ✅ Predictions drawn for P2710.png
# 📄 TXT saved: P2710.txt
# Processing P2712.png...
# ✅ Predictions drawn for P2712.png
# 📄 TXT saved: P2712.txt
# Processing P2716.png...
# ✅ Predictions drawn for P2716.png
# 📄 TXT saved: P2716.txt
# Processing P2719.png...
# ✅ Predictions drawn for P2719.png
# 📄 TXT saved: P2719.txt
# Processing P2720.png...
# ⚠️ No predictions for P2720.png, drawing dummy box.
# 📄 TXT saved: P2720.txt
# Processing P2725.png...
# ✅ Predictions drawn for P2725.png
# 📄 TXT saved: P2725.txt
# Processing P2727.png...
# ✅ Predictions drawn for P2727.png
# 📄 TXT saved: P2727.txt
# Processing P2728.png...
# ✅ Predictions drawn for P2728.png
# 📄 TXT saved: P2728.txt
# Processing P2729.png...
# ✅ Predictions drawn for P2729.png
# 📄 TXT saved: P2729.txt
# Processing P2730.png...
# ✅ Predictions drawn for P2730.png
# 📄 TXT saved: P2730.txt
# Processing P2731.png...
# ✅ Predictions drawn for P2731.png
# 📄 TXT saved: P2731.txt
# Processing P2732.png...
# ✅ Predictions drawn for P2732.png
# 📄 TXT saved: P2732.txt
# Processing P2734.png...
# ✅ Predictions drawn for P2734.png
# 📄 TXT saved: P2734.txt
# Processing P2735.png...
# ✅ Predictions drawn for P2735.png
# 📄 TXT saved: P2735.txt
# Processing P2739.png...
# ✅ Predictions drawn for P2739.png
# 📄 TXT saved: P2739.txt
# Processing P2740.png...
# ✅ Predictions drawn for P2740.png
# 📄 TXT saved: P2740.txt
# Processing P2741.png...
# ✅ Predictions drawn for P2741.png
# 📄 TXT saved: P2741.txt
# Processing P2742.png...
# ✅ Predictions drawn for P2742.png
# 📄 TXT saved: P2742.txt
# Processing P2743.png...
# ✅ Predictions drawn for P2743.png
# 📄 TXT saved: P2743.txt
# Processing P2746.png...
# ✅ Predictions drawn for P2746.png
# 📄 TXT saved: P2746.txt
# Processing P2747.png...
# ✅ Predictions drawn for P2747.png
# 📄 TXT saved: P2747.txt
# Processing P2748.png...
# ✅ Predictions drawn for P2748.png
# 📄 TXT saved: P2748.txt
# Processing P2750.png...
# ✅ Predictions drawn for P2750.png
# 📄 TXT saved: P2750.txt
# Processing P2751.png...
# ✅ Predictions drawn for P2751.png
# 📄 TXT saved: P2751.txt
# Processing P2753.png...
# ✅ Predictions drawn for P2753.png
# 📄 TXT saved: P2753.txt
# Processing P2755.png...
# ✅ Predictions drawn for P2755.png
# 📄 TXT saved: P2755.txt
# Processing P2756.png...
# ✅ Predictions drawn for P2756.png
# 📄 TXT saved: P2756.txt
# Processing P2759.png...
# ✅ Predictions drawn for P2759.png
# 📄 TXT saved: P2759.txt
# Processing P2761.png...
# ✅ Predictions drawn for P2761.png
# 📄 TXT saved: P2761.txt
# Processing P2764.png...
# ✅ Predictions drawn for P2764.png
# 📄 TXT saved: P2764.txt
# Processing P2769.png...
# ✅ Predictions drawn for P2769.png
# 📄 TXT saved: P2769.txt
# Processing P2770.png...
# ✅ Predictions drawn for P2770.png
# 📄 TXT saved: P2770.txt
# Processing P2775.png...
# ✅ Predictions drawn for P2775.png
# 📄 TXT saved: P2775.txt
# Processing P2777.png...
# ✅ Predictions drawn for P2777.png
# 📄 TXT saved: P2777.txt
# Processing P2783.png...
# ✅ Predictions drawn for P2783.png
# 📄 TXT saved: P2783.txt
# Processing P2787.png...
# ✅ Predictions drawn for P2787.png
# 📄 TXT saved: P2787.txt
# Processing P2788.png...
# ✅ Predictions drawn for P2788.png
# 📄 TXT saved: P2788.txt
# Processing P2790.png...
# ✅ Predictions drawn for P2790.png
# 📄 TXT saved: P2790.txt
# Processing P2792.png...
# ✅ Predictions drawn for P2792.png
# 📄 TXT saved: P2792.txt
# Processing P2793.png...
# ✅ Predictions drawn for P2793.png
# 📄 TXT saved: P2793.txt
# Processing P2797.png...
# ✅ Predictions drawn for P2797.png
# 📄 TXT saved: P2797.txt
# Processing P2800.png...
# ✅ Predictions drawn for P2800.png
# 📄 TXT saved: P2800.txt
# Processing P2801.png...
# ✅ Predictions drawn for P2801.png
# 📄 TXT saved: P2801.txt
# Processing P2804.png...
# ✅ Predictions drawn for P2804.png
# 📄 TXT saved: P2804.txt
# Processing P2805.png...
# ✅ Predictions drawn for P2805.png
# 📄 TXT saved: P2805.txt
#
# ===== Detection Summary =====
# Total images processed: 1411
# Images with detections: 1349 (95.6%)
# Images with dummy boxes: 62 (4.4%)
#
# 📊 Detections by class:
#   plane: 4828 detections
#   baseball-diamond: 223 detections
#   bridge: 453 detections
#   ground-track-field: 201 detections
#   small-vehicle: 13166 detections
#   large-vehicle: 13553 detections
#   ship: 13914 detections
#   tennis-court: 2280 detections
#   basketball-court: 452 detections
#   storage-tank: 1989 detections
#   soccer-ball-field: 360 detections
#   roundabout: 234 detections
#   harbor: 3529 detections
#   swimming-pool: 1248 detections
#   helicopter: 222 detections
#   No_Detection: 62 detections
#
# 🎉 All images processed and saved with OBBs and TXT annotations.

# %%
import os
import numpy as np
import cv2
from shapely.geometry import Polygon
from collections import defaultdict
import matplotlib.pyplot as plt

class OBBEvaluator:
    def __init__(self, gt_dir, pred_dir, iou_threshold=0.5, confidence_threshold=0.01):
        """
        Initialize the OBB evaluator
        
        Args:
            gt_dir: Directory containing ground truth text files
            pred_dir: Directory containing prediction text files
            iou_threshold: IoU threshold for considering a detection as true positive
            confidence_threshold: Minimum confidence score to consider a prediction
        """
        self.gt_dir = gt_dir
        self.pred_dir = pred_dir
        self.iou_threshold = iou_threshold
        self.confidence_threshold = confidence_threshold
        self.class_names = set()
        self.results = {}
        # Store all predictions for PR curves
        self.all_predictions = defaultdict(list)
        # Store class cumulative stats
        self.class_cumulative = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        # Count of missing prediction files
        self.missing_pred_files = 0
    
    def parse_gt_file(self, gt_file):
        """
        Parse ground truth file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name difficulty_score
        """
        gts = []
        with open(gt_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + difficulty
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and ignore difficulty score
                    class_name = parts[8]
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    gts.append({
                        'polygon': points,
                        'class': class_name,
                        'detected': False  # Flag to mark if this gt is detected
                    })
                except Exception as e:
                    print(f"Error parsing GT line: {line}")
                    print(f"Exception: {e}")
        return gts
    
    def parse_pred_file(self, pred_file):
        """
        Parse prediction file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name confidence_score
        """
        preds = []
        if not os.path.exists(pred_file):
            return preds  # Return empty list if file doesn't exist
            
        with open(pred_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + confidence
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and confidence score
                    class_name = parts[8]
                    confidence = float(parts[9])
                    
                    # Skip predictions with confidence below threshold
                    if confidence < self.confidence_threshold:
                        continue
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    preds.append({
                        'polygon': points,
                        'class': class_name,
                        'confidence': confidence
                    })
                except Exception as e:
                    print(f"Error parsing prediction line: {line}")
                    print(f"Exception: {e}")
        
        # Sort predictions by confidence (descending)
        preds.sort(key=lambda x: x['confidence'], reverse=True)
        return preds
    
    def calculate_iou(self, poly1, poly2):
        """Calculate IoU between two polygons"""
        try:
            polygon1 = Polygon(poly1)
            polygon2 = Polygon(poly2)
            
            if not polygon1.is_valid or not polygon2.is_valid:
                return 0.0
            
            # Calculate intersection and union areas
            intersection_area = polygon1.intersection(polygon2).area
            union_area = polygon1.area + polygon2.area - intersection_area
            
            # Avoid division by zero
            if union_area == 0:
                return 0.0
                
            return intersection_area / union_area
        except Exception as e:
            print(f"Error calculating IoU: {e}")
            return 0.0
    
    def evaluate_image(self, gt_file, pred_file):
        """Evaluate a single image"""
        image_name = os.path.basename(gt_file).split('.')[0]
        
        # Parse GT and prediction files
        gts = self.parse_gt_file(gt_file)
        preds = self.parse_pred_file(pred_file)
        
        # Check if prediction file exists
        if not os.path.exists(pred_file):
            self.missing_pred_files += 1
            # Count all GTs as false negatives if no predictions
            for gt in gts:
                self.class_cumulative[gt['class']]['FN'] += 1
            return
        
        # Initialize per-class results for this image
        class_results = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        class_predictions = defaultdict(list)
        
        # For each prediction, find the best matching ground truth
        for pred in preds:
            pred_class = pred['class']
            pred_poly = pred['polygon']
            pred_conf = pred['confidence']
            
            best_iou = 0
            best_gt_idx = -1
            
            # Find the best matching GT of the same class
            for idx, gt in enumerate(gts):
                if gt['class'] != pred_class or gt['detected']:
                    continue
                
                iou = self.calculate_iou(pred_poly, gt['polygon'])
                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx
            
            # Record as TP or FP based on IoU threshold
            if best_gt_idx >= 0 and best_iou >= self.iou_threshold:
                class_predictions[pred_class].append((pred_conf, 1))  # True positive
                gts[best_gt_idx]['detected'] = True
                class_results[pred_class]['TP'] += 1
                self.class_cumulative[pred_class]['TP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 1))
            else:
                class_predictions[pred_class].append((pred_conf, 0))  # False positive
                class_results[pred_class]['FP'] += 1
                self.class_cumulative[pred_class]['FP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 0))
        
        # Count false negatives (undetected GTs)
        for gt in gts:
            if not gt['detected']:
                class_results[gt['class']]['FN'] += 1
                self.class_cumulative[gt['class']]['FN'] += 1
    
    def calculate_precision_recall(self, tp, fp, fn):
        """Calculate precision and recall"""
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        return precision, recall
    
    def calculate_f1(self, precision, recall):
        """Calculate F1 score"""
        return 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    def calculate_ap(self, precisions, recalls):
        """Calculate Average Precision using 11-point interpolation"""
        ap = 0
        for t in np.arange(0, 1.1, 0.1):
            if np.sum(recalls >= t) == 0:
                p = 0
            else:
                p = np.max(precisions[recalls >= t])
            ap += p / 11
        return ap
    
    def evaluate(self):
        """Evaluate all images and calculate metrics"""
        # Get list of files
        gt_files = sorted([f for f in os.listdir(self.gt_dir) if f.endswith('.txt')])
        print(f"Found {len(gt_files)} ground truth files")
        
        # Process each image
        for gt_file in gt_files:
            image_id = os.path.splitext(gt_file)[0]
            pred_file = image_id + '.txt'
            
            gt_path = os.path.join(self.gt_dir, gt_file)
            pred_path = os.path.join(self.pred_dir, pred_file)
            
            # Skip if prediction file doesn't exist but still record the missing files
            if not os.path.exists(pred_path):
                self.evaluate_image(gt_path, pred_path)  # This will handle missing files
                continue
            
            # Evaluate the image
            self.evaluate_image(gt_path, pred_path)
            
        if self.missing_pred_files > 0:
            print(f"\nWarning: {self.missing_pred_files} out of {len(gt_files)} prediction files were missing.")
            print(f"These are counted as having no detections (all ground truths counted as false negatives).")
        
        # Calculate metrics for each class
        self.results = {}
        mean_ap = 0
        processed_classes = 0
        
        for class_name in self.class_names:
            TP = self.class_cumulative[class_name]['TP']
            FP = self.class_cumulative[class_name]['FP']
            FN = self.class_cumulative[class_name]['FN']
            
            precision, recall = self.calculate_precision_recall(TP, FP, FN)
            f1 = self.calculate_f1(precision, recall)
            
            # Sort predictions by confidence for AP calculation
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            # Skip AP calculation if no ground truths or predictions
            if TP + FN == 0 or len(class_preds) == 0:
                ap = 0
            else:
                cumulative_tp = 0
                cumulative_fp = 0
                precisions = []
                recalls = []
                
                for conf, is_tp in class_preds:
                    if is_tp:
                        cumulative_tp += 1
                    else:
                        cumulative_fp += 1
                    
                    prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                    rec = cumulative_tp / (TP + FN)
                    
                    precisions.append(prec)
                    recalls.append(rec)
                
                precisions = np.array(precisions)
                recalls = np.array(recalls)
                ap = self.calculate_ap(precisions, recalls)
                processed_classes += 1
            
            self.results[class_name] = {
                'AP': ap,
                'Precision': precision,
                'Recall': recall,
                'F1': f1,
                'TP': TP,
                'FP': FP,
                'FN': FN
            }
            
            mean_ap += ap
        
        # Calculate mAP only over classes with predictions
        if processed_classes > 0:
            mean_ap /= processed_classes
        else:
            mean_ap = 0
        
        self.results['mAP'] = mean_ap
        
        return self.results
    
    def plot_precision_recall_curves(self, output_dir):
        """Plot precision-recall curves for all classes"""
        os.makedirs(output_dir, exist_ok=True)
        
        plt.figure(figsize=(10, 8))
        
        for class_name in sorted(self.class_names):
            # Skip classes with no predictions
            if class_name not in self.all_predictions or len(self.all_predictions[class_name]) == 0:
                continue
            
            # Sort predictions by confidence
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            TP = self.class_cumulative[class_name]['TP']
            FN = self.class_cumulative[class_name]['FN']
            
            # Skip if no ground truths
            if TP + FN == 0:
                continue
            
            # Calculate cumulative precision and recall
            cumulative_tp = 0
            cumulative_fp = 0
            precisions = []
            recalls = []
            
            for conf, is_tp in class_preds:
                if is_tp:
                    cumulative_tp += 1
                else:
                    cumulative_fp += 1
                
                prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                rec = cumulative_tp / (TP + FN)
                
                precisions.append(prec)
                recalls.append(rec)
            
            plt.plot(recalls, precisions, label=f"{class_name} (AP={self.results[class_name]['AP']:.3f})")
        
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curves')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(output_dir, 'precision_recall_curves_ORCNN.png'))
        plt.close()
    
    def print_results(self):
        """Print evaluation results"""
        print("\n===== EVALUATION RESULTS =====")
        print(f"IoU Threshold: {self.iou_threshold}")
        print(f"Confidence Threshold: {self.confidence_threshold}")
        print(f"mAP: {self.results['mAP']:.4f}")
        print("\nPer-class results:")
        
        # Print header
        print(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}")
        print('-' * 70)
        
        # Sort classes for consistent output
        for class_name in sorted(self.class_names):
            r = self.results[class_name]
            print(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}")
        
        print("=" * 70)
    
    def save_results_to_file(self, output_path):
        """Save results to file"""
        with open(output_path, 'w') as f:
            f.write("===== EVALUATION RESULTS =====\n")
            f.write(f"IoU Threshold: {self.iou_threshold}\n")
            f.write(f"Confidence Threshold: {self.confidence_threshold}\n")
            f.write(f"mAP: {self.results['mAP']:.4f}\n\n")
            
            # if self.missing_pred_files > 0:
            #     f.write(f"Note: {self.missing_pred_files} prediction files were missing and counted as no detections.\n\n")
                
            f.write("Per-class results:\n")
            
            # Print header
            f.write(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}\n")
            f.write('-' * 70 + '\n')
            
            # Sort classes for consistent output
            for class_name in sorted(self.class_names):
                r = self.results[class_name]
                f.write(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}\n")
            
            f.write("=" * 70 + '\n')


# Usage example
if __name__ == "__main__":
    # Define paths
    GT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\labels\train\labelTxt-v1.0\labelTxt"  # Ground truth directory
    PRED_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_orcnn\txt_annotations"  # Prediction directory
    OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results"  # Output directory
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Create evaluator with default parameters
    evaluator = OBBEvaluator(
        gt_dir=GT_DIR,
        pred_dir=PRED_DIR,
        iou_threshold=0.5,  # IoU threshold for TP/FP determination
        confidence_threshold=0.01  # Min confidence to consider a prediction
    )
    
    # Run evaluation
    results = evaluator.evaluate()
    
    # Print results
    evaluator.print_results()
    
    # Save results to file
    evaluator.save_results_to_file(os.path.join(OUTPUT_DIR, "evaluation_results_ORCNN.txt"))
    
    # Generate PR curves
    try:
        evaluator.plot_precision_recall_curves(OUTPUT_DIR)
        print(f"Precision-Recall curves saved to {OUTPUT_DIR}")
    except Exception as e:
        print(f"Error generating PR curves: {e}")
    
    print(f"Evaluation completed! Results saved to {OUTPUT_DIR}")
# Out:
# Found 1411 ground truth files
#
# ===== EVALUATION RESULTS =====
# IoU Threshold: 0.5
# Confidence Threshold: 0.01
# mAP: 0.4070
#
# Per-class results:
# Class           AP       Precision  Recall     F1       TP     FP     FN
# ----------------------------------------------------------------------
# baseball-diamond 0.4495   0.8341     0.4482     0.5831   186    37     229
# basketball-court 0.6236   0.7235     0.6350     0.6763   327    125    188
# bridge          0.0909   0.3731     0.0826     0.1352   169    284    1878
# ground-track-field 0.4484   0.6866     0.4246     0.5247   138    63     187
# harbor          0.4059   0.7073     0.4172     0.5248   2496   1033   3487
# helicopter      0.0909   0.1667     0.0587     0.0869   37     185    593
# large-vehicle   0.6143   0.7995     0.6385     0.7100   10835  2718   6134
# plane           0.5369   0.8741     0.5239     0.6551   4220   608    3835
# roundabout      0.2434   0.4573     0.2682     0.3381   107    127    292
# ship            0.3280   0.6219     0.3083     0.4122   8653   5261   19415
# small-vehicle   0.3176   0.6587     0.3319     0.4414   8672   4494   17454
# soccer-ball-field 0.4661   0.4667     0.5153     0.4898   168    192    158
# storage-tank    0.2665   0.7526     0.2977     0.4266   1497   492    3532
# swimming-pool   0.4069   0.6579     0.4729     0.5503   821    427    915
# tennis-court    0.8169   0.9180     0.8842     0.9008   2093   187    274
# ======================================================================
# Precision-Recall curves saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results
# Evaluation completed! Results saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results

# %% [markdown]
# # ROTATED FASTER RCNN

# %%
import os
import cv2
import torch
import mmrotate
import numpy as np
from mmdet.apis import init_detector, inference_detector

# -------------------- Path Setup --------------------
IMAGE_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\images\train\images"
OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_rfrcnn"
CONFIG_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\mmrotate\configs\rotated_faster_rcnn\rotated_faster_rcnn_r50_fpn_1x_dota_le90.py"
CHECKPOINT_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\rotated_faster_rcnn_r50_fpn_1x_dota_le90-0393aa5c.pth"
LOW_CONFIDENCE = 0.1

os.makedirs(OUTPUT_DIR, exist_ok=True)
TXT_FOLDER = os.path.join(OUTPUT_DIR, "txt_annotations")
os.makedirs(TXT_FOLDER, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"✅ Using device: {device}")

model = init_detector(CONFIG_FILE, CHECKPOINT_FILE, device=device)
class_names = model.CLASSES if hasattr(model, 'CLASSES') else model.dataset_meta['CLASSES']
print(f"✅ Model loaded with {len(class_names)} classes: {class_names}")

def draw_obb(img, obb, label, score, color=(0, 255, 0), thickness=2):
    cx, cy, w, h, angle = obb
    rect = ((cx, cy), (w, h), angle * 180 / np.pi)
    box = cv2.boxPoints(rect)
    box = np.int0(box)
    cv2.drawContours(img, [box], 0, color, thickness)
    label_text = f"{class_names[label] if label < len(class_names) else 'No_Detection'}: {score:.2f}"
    cv2.putText(img, label_text, (int(cx), int(cy) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

# Gather image files
image_files = [f for f in os.listdir(IMAGE_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
if not image_files:
    print(f"❌ No image files found in {IMAGE_DIR}")
else:
    print(f"✅ Found {len(image_files)} image(s) to process")

total_images = 0
images_with_detections = 0
skipped_images = []
class_detection_counts = {i: 0 for i in range(len(class_names))}
class_detection_counts["No_Detection"] = 0

for img_name in image_files:
    total_images += 1
    img_path = os.path.join(IMAGE_DIR, img_name)
    print(f"Processing {img_name}...")

    img = cv2.imread(img_path)
    if img is None:
        print(f"⚠️ Failed to load image: {img_path}")
        skipped_images.append(img_name)
        continue

    result = inference_detector(model, img_path)

    drawn_any = False
    pred_data = []

    if isinstance(result, tuple):
        bbox_results, _ = result
        for class_id, bboxes in enumerate(bbox_results):
            for bbox in bboxes:
                score = bbox[5]
                obb = bbox[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })
    elif hasattr(result, 'pred_instances'):
        pred_instances = result.pred_instances
        bboxes = pred_instances.bboxes.cpu().numpy()
        scores = pred_instances.scores.cpu().numpy()
        labels = pred_instances.labels.cpu().numpy()
        for bbox, score, label in zip(bboxes, scores, labels):
            obb = bbox.tolist()
            if score >= LOW_CONFIDENCE:
                draw_obb(img, obb, label, score)
                drawn_any = True
                class_detection_counts[label.item()] += 1
                pred_data.append({
                    "obb": obb,
                    "score": float(score),
                    "label": int(label),
                    "label_name": class_names[label]
                })
    else:
        for class_id, class_result in enumerate(result):
            for res in class_result:
                score = res[-1]
                obb = res[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })

    # If no detection, draw dummy red box
    if not drawn_any:
        print(f"⚠️ No predictions for {img_name}, drawing dummy box.")
        h, w = img.shape[:2]
        dummy_cx, dummy_cy = w // 2, h // 2
        dummy_w, dummy_h = w // 5, h // 5
        dummy_angle = 0
        dummy_obb = [dummy_cx, dummy_cy, dummy_w, dummy_h, dummy_angle]
        dummy_score = 0.0
        draw_obb(img, dummy_obb, len(class_names), dummy_score, color=(0, 0, 255))
        pred_data.append({
            "obb": dummy_obb,
            "score": dummy_score,
            "label": len(class_names),
            "label_name": "No_Detection"
        })
        class_detection_counts["No_Detection"] += 1
    else:
        print(f"✅ Predictions drawn for {img_name}")
        images_with_detections += 1

    # Save image
    output_path = os.path.join(OUTPUT_DIR, img_name)
    cv2.imwrite(output_path, img)

    # Save .txt annotation
    txt_filename = os.path.splitext(img_name)[0] + ".txt"
    txt_path = os.path.join(TXT_FOLDER, txt_filename)

    with open(txt_path, 'w') as f:
        for pred in pred_data:
            cx, cy, w, h, angle = pred['obb']
            rect = ((cx, cy), (w, h), angle * 180 / np.pi)
            box = cv2.boxPoints(rect)
            box = np.int0(box)
            points_flat = box.flatten()
            coords = " ".join(map(str, points_flat))
            label_name = pred['label_name'].replace(" ", "_")  # Prevent space in label
            score = pred['score']
            line = f"{coords} {label_name} {score:.4f}\n"
            f.write(line)

    print(f"📄 TXT saved: {txt_filename}")

# ========== Summary ==========
print("\n===== Detection Summary =====")
print(f"Total images processed: {total_images}")
print(f"Images with detections: {images_with_detections} ({images_with_detections / total_images * 100:.1f}%)")
print(f"Images with dummy boxes: {total_images - images_with_detections} ({(total_images - images_with_detections) / total_images * 100:.1f}%)")

print("\n📊 Detections by class:")
for class_id, count in class_detection_counts.items():
    name = class_names[class_id] if isinstance(class_id, int) and class_id < len(class_names) else class_id
    if count > 0:
        print(f"  {name}: {count} detections")

if skipped_images:
    print("\n⚠️ Skipped the following images (could not load):")
    for name in skipped_images:
        print(f" - {name}")

print("\n🎉 All images processed and saved with OBBs and TXT annotations.")
# Out:
# ✅ Using device: cuda
# d:\Anaconda\envs\cfi_net\lib\site-packages\mmdet\models\dense_heads\anchor_head.py:116: UserWarning: DeprecationWarning: `num_anchors` is deprecated, for consistency or also use `num_base_priors` instead
#   warnings.warn('DeprecationWarning: `num_anchors` is deprecated, '
# load checkpoint from local path: D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\rotated_faster_rcnn_r50_fpn_1x_dota_le90-0393aa5c.pth
# ✅ Model loaded with 15 classes: ('plane', 'baseball-diamond', 'bridge', 'ground-track-field', 'small-vehicle', 'large-vehicle', 'ship', 'tennis-court', 'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout', 'harbor', 'swimming-pool', 'helicopter')
# ✅ Found 1411 image(s) to process
# Processing P0000.png...
# d:\Anaconda\envs\cfi_net\lib\site-packages\mmdet\models\dense_heads\anchor_head.py:123: UserWarning: DeprecationWarning: anchor_generator is deprecated, please use "prior_generator" instead
#   warnings.warn('DeprecationWarning: anchor_generator is deprecated, '
# ✅ Predictions drawn for P0000.png
# 📄 TXT saved: P0000.txt
# Processing P0001.png...
# ✅ Predictions drawn for P0001.png
# 📄 TXT saved: P0001.txt
# Processing P0002.png...
# ✅ Predictions drawn for P0002.png
# 📄 TXT saved: P0002.txt
# Processing P0005.png...
# ✅ Predictions drawn for P0005.png
# 📄 TXT saved: P0005.txt
# Processing P0008.png...
# ✅ Predictions drawn for P0008.png
# 📄 TXT saved: P0008.txt
# Processing P0010.png...
# ✅ Predictions drawn for P0010.png
# 📄 TXT saved: P0010.txt
# Processing P0011.png...
# ✅ Predictions drawn for P0011.png
# 📄 TXT saved: P0011.txt
# Processing P0012.png...
# ✅ Predictions drawn for P0012.png
# 📄 TXT saved: P0012.txt
# Processing P0013.png...
# ✅ Predictions drawn for P0013.png
# 📄 TXT saved: P0013.txt
# Processing P0018.png...
# ✅ Predictions drawn for P0018.png
# 📄 TXT saved: P0018.txt
# Processing P0020.png...
# ✅ Predictions drawn for P0020.png
# 📄 TXT saved: P0020.txt
# Processing P0021.png...
# ✅ Predictions drawn for P0021.png
# 📄 TXT saved: P0021.txt
# Processing P0022.png...
# ✅ Predictions drawn for P0022.png
# 📄 TXT saved: P0022.txt
# Processing P0023.png...
# ✅ Predictions drawn for P0023.png
# 📄 TXT saved: P0023.txt
# Processing P0025.png...
# ✅ Predictions drawn for P0025.png
# 📄 TXT saved: P0025.txt
# Processing P0029.png...
# ✅ Predictions drawn for P0029.png
# 📄 TXT saved: P0029.txt
# Processing P0030.png...
# ✅ Predictions drawn for P0030.png
# 📄 TXT saved: P0030.txt
# Processing P0032.png...
# ✅ Predictions drawn for P0032.png
# 📄 TXT saved: P0032.txt
# Processing P0036.png...
# ✅ Predictions drawn for P0036.png
# 📄 TXT saved: P0036.txt
# Processing P0038.png...
# ✅ Predictions drawn for P0038.png
# 📄 TXT saved: P0038.txt
# Processing P0039.png...
# ✅ Predictions drawn for P0039.png
# 📄 TXT saved: P0039.txt
# Processing P0041.png...
# ✅ Predictions drawn for P0041.png
# 📄 TXT saved: P0041.txt
# Processing P0042.png...
# ✅ Predictions drawn for P0042.png
# 📄 TXT saved: P0042.txt
# Processing P0044.png...
# ✅ Predictions drawn for P0044.png
# 📄 TXT saved: P0044.txt
# Processing P0049.png...
# ✅ Predictions drawn for P0049.png
# 📄 TXT saved: P0049.txt
# Processing P0050.png...
# ✅ Predictions drawn for P0050.png
# 📄 TXT saved: P0050.txt
# Processing P0052.png...
# ✅ Predictions drawn for P0052.png
# 📄 TXT saved: P0052.txt
# Processing P0054.png...
# ✅ Predictions drawn for P0054.png
# 📄 TXT saved: P0054.txt
# Processing P0058.png...
# ✅ Predictions drawn for P0058.png
# 📄 TXT saved: P0058.txt
# Processing P0061.png...
# ✅ Predictions drawn for P0061.png
# 📄 TXT saved: P0061.txt
# Processing P0063.png...
# ✅ Predictions drawn for P0063.png
# 📄 TXT saved: P0063.txt
# Processing P0064.png...
# ✅ Predictions drawn for P0064.png
# 📄 TXT saved: P0064.txt
# Processing P0065.png...
# ✅ Predictions drawn for P0065.png
# 📄 TXT saved: P0065.txt
# Processing P0066.png...
# ✅ Predictions drawn for P0066.png
# 📄 TXT saved: P0066.txt
# Processing P0067.png...
# ✅ Predictions drawn for P0067.png
# 📄 TXT saved: P0067.txt
# Processing P0068.png...
# ✅ Predictions drawn for P0068.png
# 📄 TXT saved: P0068.txt
# Processing P0070.png...
# ✅ Predictions drawn for P0070.png
# 📄 TXT saved: P0070.txt
# Processing P0071.png...
# ✅ Predictions drawn for P0071.png
# 📄 TXT saved: P0071.txt
# Processing P0074.png...
# ✅ Predictions drawn for P0074.png
# 📄 TXT saved: P0074.txt
# Processing P0076.png...
# ✅ Predictions drawn for P0076.png
# 📄 TXT saved: P0076.txt
# Processing P0078.png...
# ✅ Predictions drawn for P0078.png
# 📄 TXT saved: P0078.txt
# Processing P0082.png...
# ✅ Predictions drawn for P0082.png
# 📄 TXT saved: P0082.txt
# Processing P0083.png...
# ✅ Predictions drawn for P0083.png
# 📄 TXT saved: P0083.txt
# Processing P0085.png...
# ✅ Predictions drawn for P0085.png
# 📄 TXT saved: P0085.txt
# Processing P0087.png...
# ✅ Predictions drawn for P0087.png
# 📄 TXT saved: P0087.txt
# Processing P0091.png...
# ✅ Predictions drawn for P0091.png
# 📄 TXT saved: P0091.txt
# Processing P0093.png...
# ✅ Predictions drawn for P0093.png
# 📄 TXT saved: P0093.txt
# Processing P0094.png...
# ✅ Predictions drawn for P0094.png
# 📄 TXT saved: P0094.txt
# Processing P0095.png...
# ✅ Predictions drawn for P0095.png
# 📄 TXT saved: P0095.txt
# Processing P0096.png...
# ✅ Predictions drawn for P0096.png
# 📄 TXT saved: P0096.txt
# Processing P0098.png...
# ✅ Predictions drawn for P0098.png
# 📄 TXT saved: P0098.txt
# Processing P0099.png...
# ✅ Predictions drawn for P0099.png
# 📄 TXT saved: P0099.txt
# Processing P0100.png...
# ✅ Predictions drawn for P0100.png
# 📄 TXT saved: P0100.txt
# Processing P0103.png...
# ✅ Predictions drawn for P0103.png
# 📄 TXT saved: P0103.txt
# Processing P0109.png...
# ✅ Predictions drawn for P0109.png
# 📄 TXT saved: P0109.txt
# Processing P0111.png...
# ✅ Predictions drawn for P0111.png
# 📄 TXT saved: P0111.txt
# Processing P0113.png...
# ✅ Predictions drawn for P0113.png
# 📄 TXT saved: P0113.txt
# Processing P0116.png...
# ✅ Predictions drawn for P0116.png
# 📄 TXT saved: P0116.txt
# Processing P0119.png...
# ✅ Predictions drawn for P0119.png
# 📄 TXT saved: P0119.txt
# Processing P0122.png...
# ✅ Predictions drawn for P0122.png
# 📄 TXT saved: P0122.txt
# Processing P0124.png...
# ✅ Predictions drawn for P0124.png
# 📄 TXT saved: P0124.txt
# Processing P0126.png...
# ✅ Predictions drawn for P0126.png
# 📄 TXT saved: P0126.txt
# Processing P0129.png...
# ✅ Predictions drawn for P0129.png
# 📄 TXT saved: P0129.txt
# Processing P0133.png...
# ✅ Predictions drawn for P0133.png
# 📄 TXT saved: P0133.txt
# Processing P0136.png...
# ✅ Predictions drawn for P0136.png
# 📄 TXT saved: P0136.txt
# Processing P0139.png...
# ✅ Predictions drawn for P0139.png
# 📄 TXT saved: P0139.txt
# Processing P0140.png...
# ✅ Predictions drawn for P0140.png
# 📄 TXT saved: P0140.txt
# Processing P0141.png...
# ✅ Predictions drawn for P0141.png
# 📄 TXT saved: P0141.txt
# Processing P0142.png...
# ✅ Predictions drawn for P0142.png
# 📄 TXT saved: P0142.txt
# Processing P0144.png...
# ✅ Predictions drawn for P0144.png
# 📄 TXT saved: P0144.txt
# Processing P0147.png...
# ✅ Predictions drawn for P0147.png
# 📄 TXT saved: P0147.txt
# Processing P0149.png...
# ✅ Predictions drawn for P0149.png
# 📄 TXT saved: P0149.txt
# Processing P0151.png...
# ✅ Predictions drawn for P0151.png
# 📄 TXT saved: P0151.txt
# Processing P0152.png...
# ✅ Predictions drawn for P0152.png
# 📄 TXT saved: P0152.txt
# Processing P0158.png...
# ✅ Predictions drawn for P0158.png
# 📄 TXT saved: P0158.txt
# Processing P0159.png...
# ✅ Predictions drawn for P0159.png
# 📄 TXT saved: P0159.txt
# Processing P0160.png...
# ✅ Predictions drawn for P0160.png
# 📄 TXT saved: P0160.txt
# Processing P0162.png...
# ✅ Predictions drawn for P0162.png
# 📄 TXT saved: P0162.txt
# Processing P0163.png...
# ✅ Predictions drawn for P0163.png
# 📄 TXT saved: P0163.txt
# Processing P0164.png...
# ✅ Predictions drawn for P0164.png
# 📄 TXT saved: P0164.txt
# Processing P0167.png...
# ✅ Predictions drawn for P0167.png
# 📄 TXT saved: P0167.txt
# Processing P0169.png...
# ✅ Predictions drawn for P0169.png
# 📄 TXT saved: P0169.txt
# Processing P0171.png...
# ✅ Predictions drawn for P0171.png
# 📄 TXT saved: P0171.txt
# Processing P0172.png...
# ✅ Predictions drawn for P0172.png
# 📄 TXT saved: P0172.txt
# Processing P0174.png...
# ✅ Predictions drawn for P0174.png
# 📄 TXT saved: P0174.txt
# Processing P0176.png...
# ✅ Predictions drawn for P0176.png
# 📄 TXT saved: P0176.txt
# Processing P0178.png...
# ✅ Predictions drawn for P0178.png
# 📄 TXT saved: P0178.txt
# Processing P0183.png...
# ✅ Predictions drawn for P0183.png
# 📄 TXT saved: P0183.txt
# Processing P0187.png...
# ✅ Predictions drawn for P0187.png
# 📄 TXT saved: P0187.txt
# Processing P0188.png...
# ✅ Predictions drawn for P0188.png
# 📄 TXT saved: P0188.txt
# Processing P0190.png...
# ✅ Predictions drawn for P0190.png
# 📄 TXT saved: P0190.txt
# Processing P0200.png...
# ✅ Predictions drawn for P0200.png
# 📄 TXT saved: P0200.txt
# Processing P0201.png...
# ✅ Predictions drawn for P0201.png
# 📄 TXT saved: P0201.txt
# Processing P0202.png...
# ✅ Predictions drawn for P0202.png
# 📄 TXT saved: P0202.txt
# Processing P0203.png...
# ✅ Predictions drawn for P0203.png
# 📄 TXT saved: P0203.txt
# Processing P0204.png...
# ✅ Predictions drawn for P0204.png
# 📄 TXT saved: P0204.txt
# Processing P0207.png...
# ✅ Predictions drawn for P0207.png
# 📄 TXT saved: P0207.txt
# Processing P0209.png...
# ✅ Predictions drawn for P0209.png
# 📄 TXT saved: P0209.txt
# Processing P0210.png...
# ✅ Predictions drawn for P0210.png
# 📄 TXT saved: P0210.txt
# Processing P0212.png...
# ✅ Predictions drawn for P0212.png
# 📄 TXT saved: P0212.txt
# Processing P0215.png...
# ✅ Predictions drawn for P0215.png
# 📄 TXT saved: P0215.txt
# Processing P0218.png...
# ✅ Predictions drawn for P0218.png
# 📄 TXT saved: P0218.txt
# Processing P0219.png...
# ✅ Predictions drawn for P0219.png
# 📄 TXT saved: P0219.txt
# Processing P0220.png...
# ✅ Predictions drawn for P0220.png
# 📄 TXT saved: P0220.txt
# Processing P0221.png...
# ✅ Predictions drawn for P0221.png
# 📄 TXT saved: P0221.txt
# Processing P0222.png...
# ✅ Predictions drawn for P0222.png
# 📄 TXT saved: P0222.txt
# Processing P0223.png...
# ✅ Predictions drawn for P0223.png
# 📄 TXT saved: P0223.txt
# Processing P0224.png...
# ✅ Predictions drawn for P0224.png
# 📄 TXT saved: P0224.txt
# Processing P0225.png...
# ✅ Predictions drawn for P0225.png
# 📄 TXT saved: P0225.txt
# Processing P0226.png...
# ✅ Predictions drawn for P0226.png
# 📄 TXT saved: P0226.txt
# Processing P0227.png...
# ✅ Predictions drawn for P0227.png
# 📄 TXT saved: P0227.txt
# Processing P0229.png...
# ✅ Predictions drawn for P0229.png
# 📄 TXT saved: P0229.txt
# Processing P0232.png...
# ✅ Predictions drawn for P0232.png
# 📄 TXT saved: P0232.txt
# Processing P0233.png...
# ✅ Predictions drawn for P0233.png
# 📄 TXT saved: P0233.txt
# Processing P0235.png...
# ✅ Predictions drawn for P0235.png
# 📄 TXT saved: P0235.txt
# Processing P0236.png...
# ✅ Predictions drawn for P0236.png
# 📄 TXT saved: P0236.txt
# Processing P0238.png...
# ✅ Predictions drawn for P0238.png
# 📄 TXT saved: P0238.txt
# Processing P0241.png...
# ✅ Predictions drawn for P0241.png
# 📄 TXT saved: P0241.txt
# Processing P0244.png...
# ✅ Predictions drawn for P0244.png
# 📄 TXT saved: P0244.txt
# Processing P0248.png...
# ✅ Predictions drawn for P0248.png
# 📄 TXT saved: P0248.txt
# Processing P0250.png...
# ✅ Predictions drawn for P0250.png
# 📄 TXT saved: P0250.txt
# Processing P0251.png...
# ✅ Predictions drawn for P0251.png
# 📄 TXT saved: P0251.txt
# Processing P0252.png...
# ✅ Predictions drawn for P0252.png
# 📄 TXT saved: P0252.txt
# Processing P0254.png...
# ✅ Predictions drawn for P0254.png
# 📄 TXT saved: P0254.txt
# Processing P0255.png...
# ✅ Predictions drawn for P0255.png
# 📄 TXT saved: P0255.txt
# Processing P0256.png...
# ✅ Predictions drawn for P0256.png
# 📄 TXT saved: P0256.txt
# Processing P0258.png...
# ✅ Predictions drawn for P0258.png
# 📄 TXT saved: P0258.txt
# Processing P0260.png...
# ✅ Predictions drawn for P0260.png
# 📄 TXT saved: P0260.txt
# Processing P0263.png...
# ✅ Predictions drawn for P0263.png
# 📄 TXT saved: P0263.txt
# Processing P0264.png...
# ✅ Predictions drawn for P0264.png
# 📄 TXT saved: P0264.txt
# Processing P0270.png...
# ✅ Predictions drawn for P0270.png
# 📄 TXT saved: P0270.txt
# Processing P0272.png...
# ✅ Predictions drawn for P0272.png
# 📄 TXT saved: P0272.txt
# Processing P0273.png...
# ✅ Predictions drawn for P0273.png
# 📄 TXT saved: P0273.txt
# Processing P0275.png...
# ✅ Predictions drawn for P0275.png
# 📄 TXT saved: P0275.txt
# Processing P0276.png...
# ✅ Predictions drawn for P0276.png
# 📄 TXT saved: P0276.txt
# Processing P0280.png...
# ✅ Predictions drawn for P0280.png
# 📄 TXT saved: P0280.txt
# Processing P0281.png...
# ✅ Predictions drawn for P0281.png
# 📄 TXT saved: P0281.txt
# Processing P0282.png...
# ✅ Predictions drawn for P0282.png
# 📄 TXT saved: P0282.txt
# Processing P0283.png...
# ✅ Predictions drawn for P0283.png
# 📄 TXT saved: P0283.txt
# Processing P0285.png...
# ✅ Predictions drawn for P0285.png
# 📄 TXT saved: P0285.txt
# Processing P0286.png...
# ✅ Predictions drawn for P0286.png
# 📄 TXT saved: P0286.txt
# Processing P0288.png...
# ✅ Predictions drawn for P0288.png
# 📄 TXT saved: P0288.txt
# Processing P0289.png...
# ✅ Predictions drawn for P0289.png
# 📄 TXT saved: P0289.txt
# Processing P0292.png...
# ✅ Predictions drawn for P0292.png
# 📄 TXT saved: P0292.txt
# Processing P0293.png...
# ✅ Predictions drawn for P0293.png
# 📄 TXT saved: P0293.txt
# Processing P0294.png...
# ✅ Predictions drawn for P0294.png
# 📄 TXT saved: P0294.txt
# Processing P0296.png...
# ✅ Predictions drawn for P0296.png
# 📄 TXT saved: P0296.txt
# Processing P0299.png...
# ✅ Predictions drawn for P0299.png
# 📄 TXT saved: P0299.txt
# Processing P0301.png...
# ✅ Predictions drawn for P0301.png
# 📄 TXT saved: P0301.txt
# Processing P0303.png...
# ✅ Predictions drawn for P0303.png
# 📄 TXT saved: P0303.txt
# Processing P0308.png...
# ✅ Predictions drawn for P0308.png
# 📄 TXT saved: P0308.txt
# Processing P0310.png...
# ✅ Predictions drawn for P0310.png
# 📄 TXT saved: P0310.txt
# Processing P0313.png...
# ✅ Predictions drawn for P0313.png
# 📄 TXT saved: P0313.txt
# Processing P0314.png...
# ✅ Predictions drawn for P0314.png
# 📄 TXT saved: P0314.txt
# Processing P0315.png...
# ✅ Predictions drawn for P0315.png
# 📄 TXT saved: P0315.txt
# Processing P0317.png...
# ✅ Predictions drawn for P0317.png
# 📄 TXT saved: P0317.txt
# Processing P0321.png...
# ✅ Predictions drawn for P0321.png
# 📄 TXT saved: P0321.txt
# Processing P0322.png...
# ✅ Predictions drawn for P0322.png
# 📄 TXT saved: P0322.txt
# Processing P0324.png...
# ✅ Predictions drawn for P0324.png
# 📄 TXT saved: P0324.txt
# Processing P0327.png...
# ✅ Predictions drawn for P0327.png
# 📄 TXT saved: P0327.txt
# Processing P0330.png...
# ✅ Predictions drawn for P0330.png
# 📄 TXT saved: P0330.txt
# Processing P0332.png...
# ✅ Predictions drawn for P0332.png
# 📄 TXT saved: P0332.txt
# Processing P0334.png...
# ✅ Predictions drawn for P0334.png
# 📄 TXT saved: P0334.txt
# Processing P0335.png...
# ✅ Predictions drawn for P0335.png
# 📄 TXT saved: P0335.txt
# Processing P0337.png...
# ✅ Predictions drawn for P0337.png
# 📄 TXT saved: P0337.txt
# Processing P0338.png...
# ✅ Predictions drawn for P0338.png
# 📄 TXT saved: P0338.txt
# Processing P0339.png...
# ✅ Predictions drawn for P0339.png
# 📄 TXT saved: P0339.txt
# Processing P0340.png...
# ✅ Predictions drawn for P0340.png
# 📄 TXT saved: P0340.txt
# Processing P0343.png...
# ✅ Predictions drawn for P0343.png
# 📄 TXT saved: P0343.txt
# Processing P0344.png...
# ✅ Predictions drawn for P0344.png
# 📄 TXT saved: P0344.txt
# Processing P0345.png...
# ✅ Predictions drawn for P0345.png
# 📄 TXT saved: P0345.txt
# Processing P0346.png...
# ✅ Predictions drawn for P0346.png
# 📄 TXT saved: P0346.txt
# Processing P0349.png...
# ✅ Predictions drawn for P0349.png
# 📄 TXT saved: P0349.txt
# Processing P0350.png...
# ✅ Predictions drawn for P0350.png
# 📄 TXT saved: P0350.txt
# Processing P0355.png...
# ✅ Predictions drawn for P0355.png
# 📄 TXT saved: P0355.txt
# Processing P0357.png...
# ✅ Predictions drawn for P0357.png
# 📄 TXT saved: P0357.txt
# Processing P0358.png...
# ✅ Predictions drawn for P0358.png
# 📄 TXT saved: P0358.txt
# Processing P0360.png...
# ✅ Predictions drawn for P0360.png
# 📄 TXT saved: P0360.txt
# Processing P0361.png...
# ✅ Predictions drawn for P0361.png
# 📄 TXT saved: P0361.txt
# Processing P0362.png...
# ✅ Predictions drawn for P0362.png
# 📄 TXT saved: P0362.txt
# Processing P0363.png...
# ✅ Predictions drawn for P0363.png
# 📄 TXT saved: P0363.txt
# Processing P0364.png...
# ✅ Predictions drawn for P0364.png
# 📄 TXT saved: P0364.txt
# Processing P0365.png...
# ✅ Predictions drawn for P0365.png
# 📄 TXT saved: P0365.txt
# Processing P0366.png...
# ✅ Predictions drawn for P0366.png
# 📄 TXT saved: P0366.txt
# Processing P0367.png...
# ✅ Predictions drawn for P0367.png
# 📄 TXT saved: P0367.txt
# Processing P0370.png...
# ✅ Predictions drawn for P0370.png
# 📄 TXT saved: P0370.txt
# Processing P0371.png...
# ✅ Predictions drawn for P0371.png
# 📄 TXT saved: P0371.txt
# Processing P0373.png...
# ✅ Predictions drawn for P0373.png
# 📄 TXT saved: P0373.txt
# Processing P0376.png...
# ✅ Predictions drawn for P0376.png
# 📄 TXT saved: P0376.txt
# Processing P0378.png...
# ✅ Predictions drawn for P0378.png
# 📄 TXT saved: P0378.txt
# Processing P0379.png...
# ✅ Predictions drawn for P0379.png
# 📄 TXT saved: P0379.txt
# Processing P0380.png...
# ✅ Predictions drawn for P0380.png
# 📄 TXT saved: P0380.txt
# Processing P0381.png...
# ✅ Predictions drawn for P0381.png
# 📄 TXT saved: P0381.txt
# Processing P0383.png...
# ✅ Predictions drawn for P0383.png
# 📄 TXT saved: P0383.txt
# Processing P0384.png...
# ✅ Predictions drawn for P0384.png
# 📄 TXT saved: P0384.txt
# Processing P0386.png...
# ✅ Predictions drawn for P0386.png
# 📄 TXT saved: P0386.txt
# Processing P0387.png...
# ✅ Predictions drawn for P0387.png
# 📄 TXT saved: P0387.txt
# Processing P0388.png...
# ✅ Predictions drawn for P0388.png
# 📄 TXT saved: P0388.txt
# Processing P0389.png...
# ✅ Predictions drawn for P0389.png
# 📄 TXT saved: P0389.txt
# Processing P0391.png...
# ✅ Predictions drawn for P0391.png
# 📄 TXT saved: P0391.txt
# Processing P0392.png...
# ✅ Predictions drawn for P0392.png
# 📄 TXT saved: P0392.txt
# Processing P0393.png...
# ✅ Predictions drawn for P0393.png
# 📄 TXT saved: P0393.txt
# Processing P0395.png...
# ✅ Predictions drawn for P0395.png
# 📄 TXT saved: P0395.txt
# Processing P0400.png...
# ✅ Predictions drawn for P0400.png
# 📄 TXT saved: P0400.txt
# Processing P0401.png...
# ✅ Predictions drawn for P0401.png
# 📄 TXT saved: P0401.txt
# Processing P0404.png...
# ✅ Predictions drawn for P0404.png
# 📄 TXT saved: P0404.txt
# Processing P0405.png...
# ✅ Predictions drawn for P0405.png
# 📄 TXT saved: P0405.txt
# Processing P0406.png...
# ✅ Predictions drawn for P0406.png
# 📄 TXT saved: P0406.txt
# Processing P0407.png...
# ✅ Predictions drawn for P0407.png
# 📄 TXT saved: P0407.txt
# Processing P0413.png...
# ✅ Predictions drawn for P0413.png
# 📄 TXT saved: P0413.txt
# Processing P0415.png...
# ✅ Predictions drawn for P0415.png
# 📄 TXT saved: P0415.txt
# Processing P0416.png...
# ✅ Predictions drawn for P0416.png
# 📄 TXT saved: P0416.txt
# Processing P0417.png...
# ✅ Predictions drawn for P0417.png
# 📄 TXT saved: P0417.txt
# Processing P0418.png...
# ✅ Predictions drawn for P0418.png
# 📄 TXT saved: P0418.txt
# Processing P0419.png...
# ✅ Predictions drawn for P0419.png
# 📄 TXT saved: P0419.txt
# Processing P0421.png...
# ✅ Predictions drawn for P0421.png
# 📄 TXT saved: P0421.txt
# Processing P0422.png...
# ✅ Predictions drawn for P0422.png
# 📄 TXT saved: P0422.txt
# Processing P0424.png...
# ✅ Predictions drawn for P0424.png
# 📄 TXT saved: P0424.txt
# Processing P0425.png...
# ✅ Predictions drawn for P0425.png
# 📄 TXT saved: P0425.txt
# Processing P0426.png...
# ✅ Predictions drawn for P0426.png
# 📄 TXT saved: P0426.txt
# Processing P0428.png...
# ✅ Predictions drawn for P0428.png
# 📄 TXT saved: P0428.txt
# Processing P0430.png...
# ✅ Predictions drawn for P0430.png
# 📄 TXT saved: P0430.txt
# Processing P0431.png...
# ✅ Predictions drawn for P0431.png
# 📄 TXT saved: P0431.txt
# Processing P0434.png...
# ✅ Predictions drawn for P0434.png
# 📄 TXT saved: P0434.txt
# Processing P0435.png...
# ✅ Predictions drawn for P0435.png
# 📄 TXT saved: P0435.txt
# Processing P0436.png...
# ✅ Predictions drawn for P0436.png
# 📄 TXT saved: P0436.txt
# Processing P0437.png...
# ✅ Predictions drawn for P0437.png
# 📄 TXT saved: P0437.txt
# Processing P0438.png...
# ✅ Predictions drawn for P0438.png
# 📄 TXT saved: P0438.txt
# Processing P0439.png...
# ✅ Predictions drawn for P0439.png
# 📄 TXT saved: P0439.txt
# Processing P0440.png...
# ✅ Predictions drawn for P0440.png
# 📄 TXT saved: P0440.txt
# Processing P0441.png...
# ✅ Predictions drawn for P0441.png
# 📄 TXT saved: P0441.txt
# Processing P0442.png...
# ✅ Predictions drawn for P0442.png
# 📄 TXT saved: P0442.txt
# Processing P0443.png...
# ✅ Predictions drawn for P0443.png
# 📄 TXT saved: P0443.txt
# Processing P0445.png...
# ✅ Predictions drawn for P0445.png
# 📄 TXT saved: P0445.txt
# Processing P0446.png...
# ✅ Predictions drawn for P0446.png
# 📄 TXT saved: P0446.txt
# Processing P0448.png...
# ✅ Predictions drawn for P0448.png
# 📄 TXT saved: P0448.txt
# Processing P0450.png...
# ✅ Predictions drawn for P0450.png
# 📄 TXT saved: P0450.txt
# Processing P0452.png...
# ✅ Predictions drawn for P0452.png
# 📄 TXT saved: P0452.txt
# Processing P0453.png...
# ✅ Predictions drawn for P0453.png
# 📄 TXT saved: P0453.txt
# Processing P0455.png...
# ✅ Predictions drawn for P0455.png
# 📄 TXT saved: P0455.txt
# Processing P0458.png...
# ✅ Predictions drawn for P0458.png
# 📄 TXT saved: P0458.txt
# Processing P0459.png...
# ✅ Predictions drawn for P0459.png
# 📄 TXT saved: P0459.txt
# Processing P0460.png...
# ✅ Predictions drawn for P0460.png
# 📄 TXT saved: P0460.txt
# Processing P0461.png...
# ✅ Predictions drawn for P0461.png
# 📄 TXT saved: P0461.txt
# Processing P0464.png...
# ✅ Predictions drawn for P0464.png
# 📄 TXT saved: P0464.txt
# Processing P0465.png...
# ✅ Predictions drawn for P0465.png
# 📄 TXT saved: P0465.txt
# Processing P0468.png...
# ✅ Predictions drawn for P0468.png
# 📄 TXT saved: P0468.txt
# Processing P0469.png...
# ✅ Predictions drawn for P0469.png
# 📄 TXT saved: P0469.txt
# Processing P0471.png...
# ✅ Predictions drawn for P0471.png
# 📄 TXT saved: P0471.txt
# Processing P0475.png...
# ✅ Predictions drawn for P0475.png
# 📄 TXT saved: P0475.txt
# Processing P0477.png...
# ✅ Predictions drawn for P0477.png
# 📄 TXT saved: P0477.txt
# Processing P0478.png...
# ✅ Predictions drawn for P0478.png
# 📄 TXT saved: P0478.txt
# Processing P0479.png...
# ✅ Predictions drawn for P0479.png
# 📄 TXT saved: P0479.txt
# Processing P0481.png...
# ✅ Predictions drawn for P0481.png
# 📄 TXT saved: P0481.txt
# Processing P0482.png...
# ✅ Predictions drawn for P0482.png
# 📄 TXT saved: P0482.txt
# Processing P0483.png...
# ✅ Predictions drawn for P0483.png
# 📄 TXT saved: P0483.txt
# Processing P0484.png...
# ✅ Predictions drawn for P0484.png
# 📄 TXT saved: P0484.txt
# Processing P0487.png...
# ✅ Predictions drawn for P0487.png
# 📄 TXT saved: P0487.txt
# Processing P0488.png...
# ✅ Predictions drawn for P0488.png
# 📄 TXT saved: P0488.txt
# Processing P0489.png...
# ✅ Predictions drawn for P0489.png
# 📄 TXT saved: P0489.txt
# Processing P0493.png...
# ✅ Predictions drawn for P0493.png
# 📄 TXT saved: P0493.txt
# Processing P0494.png...
# ✅ Predictions drawn for P0494.png
# 📄 TXT saved: P0494.txt
# Processing P0495.png...
# ✅ Predictions drawn for P0495.png
# 📄 TXT saved: P0495.txt
# Processing P0503.png...
# ✅ Predictions drawn for P0503.png
# 📄 TXT saved: P0503.txt
# Processing P0504.png...
# ✅ Predictions drawn for P0504.png
# 📄 TXT saved: P0504.txt
# Processing P0505.png...
# ✅ Predictions drawn for P0505.png
# 📄 TXT saved: P0505.txt
# Processing P0510.png...
# ✅ Predictions drawn for P0510.png
# 📄 TXT saved: P0510.txt
# Processing P0512.png...
# ✅ Predictions drawn for P0512.png
# 📄 TXT saved: P0512.txt
# Processing P0516.png...
# ✅ Predictions drawn for P0516.png
# 📄 TXT saved: P0516.txt
# Processing P0517.png...
# ✅ Predictions drawn for P0517.png
# 📄 TXT saved: P0517.txt
# Processing P0520.png...
# ✅ Predictions drawn for P0520.png
# 📄 TXT saved: P0520.txt
# Processing P0521.png...
# ✅ Predictions drawn for P0521.png
# 📄 TXT saved: P0521.txt
# Processing P0522.png...
# ✅ Predictions drawn for P0522.png
# 📄 TXT saved: P0522.txt
# Processing P0527.png...
# ✅ Predictions drawn for P0527.png
# 📄 TXT saved: P0527.txt
# Processing P0531.png...
# ✅ Predictions drawn for P0531.png
# 📄 TXT saved: P0531.txt
# Processing P0533.png...
# ✅ Predictions drawn for P0533.png
# 📄 TXT saved: P0533.txt
# Processing P0535.png...
# ✅ Predictions drawn for P0535.png
# 📄 TXT saved: P0535.txt
# Processing P0537.png...
# ✅ Predictions drawn for P0537.png
# 📄 TXT saved: P0537.txt
# Processing P0538.png...
# ✅ Predictions drawn for P0538.png
# 📄 TXT saved: P0538.txt
# Processing P0541.png...
# ✅ Predictions drawn for P0541.png
# 📄 TXT saved: P0541.txt
# Processing P0542.png...
# ✅ Predictions drawn for P0542.png
# 📄 TXT saved: P0542.txt
# Processing P0544.png...
# ✅ Predictions drawn for P0544.png
# 📄 TXT saved: P0544.txt
# Processing P0546.png...
# ✅ Predictions drawn for P0546.png
# 📄 TXT saved: P0546.txt
# Processing P0548.png...
# ✅ Predictions drawn for P0548.png
# 📄 TXT saved: P0548.txt
# Processing P0549.png...
# ✅ Predictions drawn for P0549.png
# 📄 TXT saved: P0549.txt
# Processing P0553.png...
# ✅ Predictions drawn for P0553.png
# 📄 TXT saved: P0553.txt
# Processing P0554.png...
# ✅ Predictions drawn for P0554.png
# 📄 TXT saved: P0554.txt
# Processing P0555.png...
# ✅ Predictions drawn for P0555.png
# 📄 TXT saved: P0555.txt
# Processing P0556.png...
# ✅ Predictions drawn for P0556.png
# 📄 TXT saved: P0556.txt
# Processing P0562.png...
# ✅ Predictions drawn for P0562.png
# 📄 TXT saved: P0562.txt
# Processing P0563.png...
# ✅ Predictions drawn for P0563.png
# 📄 TXT saved: P0563.txt
# Processing P0565.png...
# ✅ Predictions drawn for P0565.png
# 📄 TXT saved: P0565.txt
# Processing P0567.png...
# ✅ Predictions drawn for P0567.png
# 📄 TXT saved: P0567.txt
# Processing P0568.png...
# ✅ Predictions drawn for P0568.png
# 📄 TXT saved: P0568.txt
# Processing P0569.png...
# ✅ Predictions drawn for P0569.png
# 📄 TXT saved: P0569.txt
# Processing P0571.png...
# ✅ Predictions drawn for P0571.png
# 📄 TXT saved: P0571.txt
# Processing P0572.png...
# ✅ Predictions drawn for P0572.png
# 📄 TXT saved: P0572.txt
# Processing P0573.png...
# ✅ Predictions drawn for P0573.png
# 📄 TXT saved: P0573.txt
# Processing P0578.png...
# ✅ Predictions drawn for P0578.png
# 📄 TXT saved: P0578.txt
# Processing P0580.png...
# ✅ Predictions drawn for P0580.png
# 📄 TXT saved: P0580.txt
# Processing P0581.png...
# ✅ Predictions drawn for P0581.png
# 📄 TXT saved: P0581.txt
# Processing P0582.png...
# ✅ Predictions drawn for P0582.png
# 📄 TXT saved: P0582.txt
# Processing P0586.png...
# ✅ Predictions drawn for P0586.png
# 📄 TXT saved: P0586.txt
# Processing P0587.png...
# ✅ Predictions drawn for P0587.png
# 📄 TXT saved: P0587.txt
# Processing P0591.png...
# ✅ Predictions drawn for P0591.png
# 📄 TXT saved: P0591.txt
# Processing P0593.png...
# ✅ Predictions drawn for P0593.png
# 📄 TXT saved: P0593.txt
# Processing P0595.png...
# ✅ Predictions drawn for P0595.png
# 📄 TXT saved: P0595.txt
# Processing P0596.png...
# ✅ Predictions drawn for P0596.png
# 📄 TXT saved: P0596.txt
# Processing P0597.png...
# ✅ Predictions drawn for P0597.png
# 📄 TXT saved: P0597.txt
# Processing P0601.png...
# ✅ Predictions drawn for P0601.png
# 📄 TXT saved: P0601.txt
# Processing P0602.png...
# ✅ Predictions drawn for P0602.png
# 📄 TXT saved: P0602.txt
# Processing P0603.png...
# ✅ Predictions drawn for P0603.png
# 📄 TXT saved: P0603.txt
# Processing P0605.png...
# ✅ Predictions drawn for P0605.png
# 📄 TXT saved: P0605.txt
# Processing P0607.png...
# ✅ Predictions drawn for P0607.png
# 📄 TXT saved: P0607.txt
# Processing P0609.png...
# ✅ Predictions drawn for P0609.png
# 📄 TXT saved: P0609.txt
# Processing P0610.png...
# ✅ Predictions drawn for P0610.png
# 📄 TXT saved: P0610.txt
# Processing P0611.png...
# ✅ Predictions drawn for P0611.png
# 📄 TXT saved: P0611.txt
# Processing P0612.png...
# ✅ Predictions drawn for P0612.png
# 📄 TXT saved: P0612.txt
# Processing P0614.png...
# ✅ Predictions drawn for P0614.png
# 📄 TXT saved: P0614.txt
# Processing P0617.png...
# ✅ Predictions drawn for P0617.png
# 📄 TXT saved: P0617.txt
# Processing P0618.png...
# ✅ Predictions drawn for P0618.png
# 📄 TXT saved: P0618.txt
# Processing P0619.png...
# ✅ Predictions drawn for P0619.png
# 📄 TXT saved: P0619.txt
# Processing P0620.png...
# ✅ Predictions drawn for P0620.png
# 📄 TXT saved: P0620.txt
# Processing P0624.png...
# ✅ Predictions drawn for P0624.png
# 📄 TXT saved: P0624.txt
# Processing P0625.png...
# ✅ Predictions drawn for P0625.png
# 📄 TXT saved: P0625.txt
# Processing P0626.png...
# ✅ Predictions drawn for P0626.png
# 📄 TXT saved: P0626.txt
# Processing P0627.png...
# ✅ Predictions drawn for P0627.png
# 📄 TXT saved: P0627.txt
# Processing P0629.png...
# ✅ Predictions drawn for P0629.png
# 📄 TXT saved: P0629.txt
# Processing P0630.png...
# ✅ Predictions drawn for P0630.png
# 📄 TXT saved: P0630.txt
# Processing P0631.png...
# ✅ Predictions drawn for P0631.png
# 📄 TXT saved: P0631.txt
# Processing P0632.png...
# ✅ Predictions drawn for P0632.png
# 📄 TXT saved: P0632.txt
# Processing P0634.png...
# ✅ Predictions drawn for P0634.png
# 📄 TXT saved: P0634.txt
# Processing P0637.png...
# ✅ Predictions drawn for P0637.png
# 📄 TXT saved: P0637.txt
# Processing P0638.png...
# ✅ Predictions drawn for P0638.png
# 📄 TXT saved: P0638.txt
# Processing P0641.png...
# ✅ Predictions drawn for P0641.png
# 📄 TXT saved: P0641.txt
# Processing P0642.png...
# ✅ Predictions drawn for P0642.png
# 📄 TXT saved: P0642.txt
# Processing P0646.png...
# ✅ Predictions drawn for P0646.png
# 📄 TXT saved: P0646.txt
# Processing P0648.png...
# ✅ Predictions drawn for P0648.png
# 📄 TXT saved: P0648.txt
# Processing P0649.png...
# ✅ Predictions drawn for P0649.png
# 📄 TXT saved: P0649.txt
# Processing P0652.png...
# ✅ Predictions drawn for P0652.png
# 📄 TXT saved: P0652.txt
# Processing P0653.png...
# ✅ Predictions drawn for P0653.png
# 📄 TXT saved: P0653.txt
# Processing P0656.png...
# ✅ Predictions drawn for P0656.png
# 📄 TXT saved: P0656.txt
# Processing P0658.png...
# ✅ Predictions drawn for P0658.png
# 📄 TXT saved: P0658.txt
# Processing P0664.png...
# ✅ Predictions drawn for P0664.png
# 📄 TXT saved: P0664.txt
# Processing P0666.png...
# ✅ Predictions drawn for P0666.png
# 📄 TXT saved: P0666.txt
# Processing P0668.png...
# ✅ Predictions drawn for P0668.png
# 📄 TXT saved: P0668.txt
# Processing P0676.png...
# ✅ Predictions drawn for P0676.png
# 📄 TXT saved: P0676.txt
# Processing P0677.png...
# ✅ Predictions drawn for P0677.png
# 📄 TXT saved: P0677.txt
# Processing P0685.png...
# ✅ Predictions drawn for P0685.png
# 📄 TXT saved: P0685.txt
# Processing P0687.png...
# ✅ Predictions drawn for P0687.png
# 📄 TXT saved: P0687.txt
# Processing P0688.png...
# ✅ Predictions drawn for P0688.png
# 📄 TXT saved: P0688.txt
# Processing P0689.png...
# ✅ Predictions drawn for P0689.png
# 📄 TXT saved: P0689.txt
# Processing P0691.png...
# ✅ Predictions drawn for P0691.png
# 📄 TXT saved: P0691.txt
# Processing P0692.png...
# ✅ Predictions drawn for P0692.png
# 📄 TXT saved: P0692.txt
# Processing P0693.png...
# ✅ Predictions drawn for P0693.png
# 📄 TXT saved: P0693.txt
# Processing P0695.png...
# ✅ Predictions drawn for P0695.png
# 📄 TXT saved: P0695.txt
# Processing P0697.png...
# ✅ Predictions drawn for P0697.png
# 📄 TXT saved: P0697.txt
# Processing P0699.png...
# ✅ Predictions drawn for P0699.png
# 📄 TXT saved: P0699.txt
# Processing P0700.png...
# ✅ Predictions drawn for P0700.png
# 📄 TXT saved: P0700.txt
# Processing P0702.png...
# ✅ Predictions drawn for P0702.png
# 📄 TXT saved: P0702.txt
# Processing P0703.png...
# ✅ Predictions drawn for P0703.png
# 📄 TXT saved: P0703.txt
# Processing P0707.png...
# ✅ Predictions drawn for P0707.png
# 📄 TXT saved: P0707.txt
# Processing P0711.png...
# ✅ Predictions drawn for P0711.png
# 📄 TXT saved: P0711.txt
# Processing P0713.png...
# ✅ Predictions drawn for P0713.png
# 📄 TXT saved: P0713.txt
# Processing P0714.png...
# ✅ Predictions drawn for P0714.png
# 📄 TXT saved: P0714.txt
# Processing P0716.png...
# ✅ Predictions drawn for P0716.png
# 📄 TXT saved: P0716.txt
# Processing P0719.png...
# ✅ Predictions drawn for P0719.png
# 📄 TXT saved: P0719.txt
# Processing P0722.png...
# ✅ Predictions drawn for P0722.png
# 📄 TXT saved: P0722.txt
# Processing P0723.png...
# ✅ Predictions drawn for P0723.png
# 📄 TXT saved: P0723.txt
# Processing P0724.png...
# ✅ Predictions drawn for P0724.png
# 📄 TXT saved: P0724.txt
# Processing P0726.png...
# ✅ Predictions drawn for P0726.png
# 📄 TXT saved: P0726.txt
# Processing P0727.png...
# ✅ Predictions drawn for P0727.png
# 📄 TXT saved: P0727.txt
# Processing P0728.png...
# ✅ Predictions drawn for P0728.png
# 📄 TXT saved: P0728.txt
# Processing P0730.png...
# ✅ Predictions drawn for P0730.png
# 📄 TXT saved: P0730.txt
# Processing P0731.png...
# ✅ Predictions drawn for P0731.png
# 📄 TXT saved: P0731.txt
# Processing P0732.png...
# ✅ Predictions drawn for P0732.png
# 📄 TXT saved: P0732.txt
# Processing P0733.png...
# ✅ Predictions drawn for P0733.png
# 📄 TXT saved: P0733.txt
# Processing P0734.png...
# ✅ Predictions drawn for P0734.png
# 📄 TXT saved: P0734.txt
# Processing P0737.png...
# ✅ Predictions drawn for P0737.png
# 📄 TXT saved: P0737.txt
# Processing P0738.png...
# ✅ Predictions drawn for P0738.png
# 📄 TXT saved: P0738.txt
# Processing P0743.png...
# ✅ Predictions drawn for P0743.png
# 📄 TXT saved: P0743.txt
# Processing P0744.png...
# ✅ Predictions drawn for P0744.png
# 📄 TXT saved: P0744.txt
# Processing P0745.png...
# ✅ Predictions drawn for P0745.png
# 📄 TXT saved: P0745.txt
# Processing P0746.png...
# ✅ Predictions drawn for P0746.png
# 📄 TXT saved: P0746.txt
# Processing P0750.png...
# ✅ Predictions drawn for P0750.png
# 📄 TXT saved: P0750.txt
# Processing P0753.png...
# ✅ Predictions drawn for P0753.png
# 📄 TXT saved: P0753.txt
# Processing P0754.png...
# ✅ Predictions drawn for P0754.png
# 📄 TXT saved: P0754.txt
# Processing P0755.png...
# ✅ Predictions drawn for P0755.png
# 📄 TXT saved: P0755.txt
# Processing P0757.png...
# ✅ Predictions drawn for P0757.png
# 📄 TXT saved: P0757.txt
# Processing P0759.png...
# ✅ Predictions drawn for P0759.png
# 📄 TXT saved: P0759.txt
# Processing P0760.png...
# ✅ Predictions drawn for P0760.png
# 📄 TXT saved: P0760.txt
# Processing P0762.png...
# ✅ Predictions drawn for P0762.png
# 📄 TXT saved: P0762.txt
# Processing P0766.png...
# ✅ Predictions drawn for P0766.png
# 📄 TXT saved: P0766.txt
# Processing P0768.png...
# ✅ Predictions drawn for P0768.png
# 📄 TXT saved: P0768.txt
# Processing P0769.png...
# ✅ Predictions drawn for P0769.png
# 📄 TXT saved: P0769.txt
# Processing P0775.png...
# ✅ Predictions drawn for P0775.png
# 📄 TXT saved: P0775.txt
# Processing P0777.png...
# ✅ Predictions drawn for P0777.png
# 📄 TXT saved: P0777.txt
# Processing P0778.png...
# ✅ Predictions drawn for P0778.png
# 📄 TXT saved: P0778.txt
# Processing P0779.png...
# ✅ Predictions drawn for P0779.png
# 📄 TXT saved: P0779.txt
# Processing P0780.png...
# ✅ Predictions drawn for P0780.png
# 📄 TXT saved: P0780.txt
# Processing P0781.png...
# ✅ Predictions drawn for P0781.png
# 📄 TXT saved: P0781.txt
# Processing P0782.png...
# ✅ Predictions drawn for P0782.png
# 📄 TXT saved: P0782.txt
# Processing P0783.png...
# ✅ Predictions drawn for P0783.png
# 📄 TXT saved: P0783.txt
# Processing P0785.png...
# ✅ Predictions drawn for P0785.png
# 📄 TXT saved: P0785.txt
# Processing P0786.png...
# ✅ Predictions drawn for P0786.png
# 📄 TXT saved: P0786.txt
# Processing P0790.png...
# ✅ Predictions drawn for P0790.png
# 📄 TXT saved: P0790.txt
# Processing P0792.png...
# ✅ Predictions drawn for P0792.png
# 📄 TXT saved: P0792.txt
# Processing P0794.png...
# ✅ Predictions drawn for P0794.png
# 📄 TXT saved: P0794.txt
# Processing P0800.png...
# ✅ Predictions drawn for P0800.png
# 📄 TXT saved: P0800.txt
# Processing P0803.png...
# ✅ Predictions drawn for P0803.png
# 📄 TXT saved: P0803.txt
# Processing P0804.png...
# ✅ Predictions drawn for P0804.png
# 📄 TXT saved: P0804.txt
# Processing P0805.png...
# ✅ Predictions drawn for P0805.png
# 📄 TXT saved: P0805.txt
# Processing P0806.png...
# ✅ Predictions drawn for P0806.png
# 📄 TXT saved: P0806.txt
# Processing P0809.png...
# ✅ Predictions drawn for P0809.png
# 📄 TXT saved: P0809.txt
# Processing P0810.png...
# ✅ Predictions drawn for P0810.png
# 📄 TXT saved: P0810.txt
# Processing P0817.png...
# ✅ Predictions drawn for P0817.png
# 📄 TXT saved: P0817.txt
# Processing P0818.png...
# ✅ Predictions drawn for P0818.png
# 📄 TXT saved: P0818.txt
# Processing P0819.png...
# ✅ Predictions drawn for P0819.png
# 📄 TXT saved: P0819.txt
# Processing P0821.png...
# ✅ Predictions drawn for P0821.png
# 📄 TXT saved: P0821.txt
# Processing P0823.png...
# ✅ Predictions drawn for P0823.png
# 📄 TXT saved: P0823.txt
# Processing P0825.png...
# ✅ Predictions drawn for P0825.png
# 📄 TXT saved: P0825.txt
# Processing P0826.png...
# ✅ Predictions drawn for P0826.png
# 📄 TXT saved: P0826.txt
# Processing P0827.png...
# ✅ Predictions drawn for P0827.png
# 📄 TXT saved: P0827.txt
# Processing P0828.png...
# ✅ Predictions drawn for P0828.png
# 📄 TXT saved: P0828.txt
# Processing P0829.png...
# ✅ Predictions drawn for P0829.png
# 📄 TXT saved: P0829.txt
# Processing P0831.png...
# ✅ Predictions drawn for P0831.png
# 📄 TXT saved: P0831.txt
# Processing P0832.png...
# ✅ Predictions drawn for P0832.png
# 📄 TXT saved: P0832.txt
# Processing P0835.png...
# ✅ Predictions drawn for P0835.png
# 📄 TXT saved: P0835.txt
# Processing P0840.png...
# ✅ Predictions drawn for P0840.png
# 📄 TXT saved: P0840.txt
# Processing P0843.png...
# ✅ Predictions drawn for P0843.png
# 📄 TXT saved: P0843.txt
# Processing P0845.png...
# ✅ Predictions drawn for P0845.png
# 📄 TXT saved: P0845.txt
# Processing P0846.png...
# ✅ Predictions drawn for P0846.png
# 📄 TXT saved: P0846.txt
# Processing P0848.png...
# ✅ Predictions drawn for P0848.png
# 📄 TXT saved: P0848.txt
# Processing P0849.png...
# ✅ Predictions drawn for P0849.png
# 📄 TXT saved: P0849.txt
# Processing P0850.png...
# ✅ Predictions drawn for P0850.png
# 📄 TXT saved: P0850.txt
# Processing P0851.png...
# ✅ Predictions drawn for P0851.png
# 📄 TXT saved: P0851.txt
# Processing P0853.png...
# ✅ Predictions drawn for P0853.png
# 📄 TXT saved: P0853.txt
# Processing P0855.png...
# ✅ Predictions drawn for P0855.png
# 📄 TXT saved: P0855.txt
# Processing P0856.png...
# ✅ Predictions drawn for P0856.png
# 📄 TXT saved: P0856.txt
# Processing P0857.png...
# ✅ Predictions drawn for P0857.png
# 📄 TXT saved: P0857.txt
# Processing P0860.png...
# ✅ Predictions drawn for P0860.png
# 📄 TXT saved: P0860.txt
# Processing P0861.png...
# ✅ Predictions drawn for P0861.png
# 📄 TXT saved: P0861.txt
# Processing P0867.png...
# ✅ Predictions drawn for P0867.png
# 📄 TXT saved: P0867.txt
# Processing P0868.png...
# ✅ Predictions drawn for P0868.png
# 📄 TXT saved: P0868.txt
# Processing P0869.png...
# ✅ Predictions drawn for P0869.png
# 📄 TXT saved: P0869.txt
# Processing P0870.png...
# ✅ Predictions drawn for P0870.png
# 📄 TXT saved: P0870.txt
# Processing P0871.png...
# ✅ Predictions drawn for P0871.png
# 📄 TXT saved: P0871.txt
# Processing P0872.png...
# ✅ Predictions drawn for P0872.png
# 📄 TXT saved: P0872.txt
# Processing P0873.png...
# ✅ Predictions drawn for P0873.png
# 📄 TXT saved: P0873.txt
# Processing P0874.png...
# ✅ Predictions drawn for P0874.png
# 📄 TXT saved: P0874.txt
# Processing P0875.png...
# ✅ Predictions drawn for P0875.png
# 📄 TXT saved: P0875.txt
# Processing P0878.png...
# ✅ Predictions drawn for P0878.png
# 📄 TXT saved: P0878.txt
# Processing P0879.png...
# ✅ Predictions drawn for P0879.png
# 📄 TXT saved: P0879.txt
# Processing P0881.png...
# ✅ Predictions drawn for P0881.png
# 📄 TXT saved: P0881.txt
# Processing P0883.png...
# ✅ Predictions drawn for P0883.png
# 📄 TXT saved: P0883.txt
# Processing P0884.png...
# ✅ Predictions drawn for P0884.png
# 📄 TXT saved: P0884.txt
# Processing P0885.png...
# ✅ Predictions drawn for P0885.png
# 📄 TXT saved: P0885.txt
# Processing P0888.png...
# ✅ Predictions drawn for P0888.png
# 📄 TXT saved: P0888.txt
# Processing P0890.png...
# ✅ Predictions drawn for P0890.png
# 📄 TXT saved: P0890.txt
# Processing P0892.png...
# ✅ Predictions drawn for P0892.png
# 📄 TXT saved: P0892.txt
# Processing P0893.png...
# ✅ Predictions drawn for P0893.png
# 📄 TXT saved: P0893.txt
# Processing P0894.png...
# ✅ Predictions drawn for P0894.png
# 📄 TXT saved: P0894.txt
# Processing P0895.png...
# ✅ Predictions drawn for P0895.png
# 📄 TXT saved: P0895.txt
# Processing P0896.png...
# ✅ Predictions drawn for P0896.png
# 📄 TXT saved: P0896.txt
# Processing P0898.png...
# ✅ Predictions drawn for P0898.png
# 📄 TXT saved: P0898.txt
# Processing P0899.png...
# ✅ Predictions drawn for P0899.png
# 📄 TXT saved: P0899.txt
# Processing P0900.png...
# ✅ Predictions drawn for P0900.png
# 📄 TXT saved: P0900.txt
# Processing P0905.png...
# ✅ Predictions drawn for P0905.png
# 📄 TXT saved: P0905.txt
# Processing P0906.png...
# ✅ Predictions drawn for P0906.png
# 📄 TXT saved: P0906.txt
# Processing P0907.png...
# ✅ Predictions drawn for P0907.png
# 📄 TXT saved: P0907.txt
# Processing P0908.png...
# ✅ Predictions drawn for P0908.png
# 📄 TXT saved: P0908.txt
# Processing P0909.png...
# ✅ Predictions drawn for P0909.png
# 📄 TXT saved: P0909.txt
# Processing P0911.png...
# ✅ Predictions drawn for P0911.png
# 📄 TXT saved: P0911.txt
# Processing P0913.png...
# ✅ Predictions drawn for P0913.png
# 📄 TXT saved: P0913.txt
# Processing P0914.png...
# ✅ Predictions drawn for P0914.png
# 📄 TXT saved: P0914.txt
# Processing P0915.png...
# ✅ Predictions drawn for P0915.png
# 📄 TXT saved: P0915.txt
# Processing P0918.png...
# ✅ Predictions drawn for P0918.png
# 📄 TXT saved: P0918.txt
# Processing P0920.png...
# ✅ Predictions drawn for P0920.png
# 📄 TXT saved: P0920.txt
# Processing P0921.png...
# ✅ Predictions drawn for P0921.png
# 📄 TXT saved: P0921.txt
# Processing P0922.png...
# ✅ Predictions drawn for P0922.png
# 📄 TXT saved: P0922.txt
# Processing P0925.png...
# ✅ Predictions drawn for P0925.png
# 📄 TXT saved: P0925.txt
# Processing P0926.png...
# ✅ Predictions drawn for P0926.png
# 📄 TXT saved: P0926.txt
# Processing P0928.png...
# ✅ Predictions drawn for P0928.png
# 📄 TXT saved: P0928.txt
# Processing P0933.png...
# ✅ Predictions drawn for P0933.png
# 📄 TXT saved: P0933.txt
# Processing P0934.png...
# ✅ Predictions drawn for P0934.png
# 📄 TXT saved: P0934.txt
# Processing P0938.png...
# ✅ Predictions drawn for P0938.png
# 📄 TXT saved: P0938.txt
# Processing P0940.png...
# ✅ Predictions drawn for P0940.png
# 📄 TXT saved: P0940.txt
# Processing P0941.png...
# ✅ Predictions drawn for P0941.png
# 📄 TXT saved: P0941.txt
# Processing P0944.png...
# ✅ Predictions drawn for P0944.png
# 📄 TXT saved: P0944.txt
# Processing P0946.png...
# ✅ Predictions drawn for P0946.png
# 📄 TXT saved: P0946.txt
# Processing P0947.png...
# ✅ Predictions drawn for P0947.png
# 📄 TXT saved: P0947.txt
# Processing P0948.png...
# ✅ Predictions drawn for P0948.png
# 📄 TXT saved: P0948.txt
# Processing P0950.png...
# ✅ Predictions drawn for P0950.png
# 📄 TXT saved: P0950.txt
# Processing P0951.png...
# ✅ Predictions drawn for P0951.png
# 📄 TXT saved: P0951.txt
# Processing P0952.png...
# ✅ Predictions drawn for P0952.png
# 📄 TXT saved: P0952.txt
# Processing P0957.png...
# ✅ Predictions drawn for P0957.png
# 📄 TXT saved: P0957.txt
# Processing P0960.png...
# ✅ Predictions drawn for P0960.png
# 📄 TXT saved: P0960.txt
# Processing P0963.png...
# ✅ Predictions drawn for P0963.png
# 📄 TXT saved: P0963.txt
# Processing P0966.png...
# ✅ Predictions drawn for P0966.png
# 📄 TXT saved: P0966.txt
# Processing P0967.png...
# ✅ Predictions drawn for P0967.png
# 📄 TXT saved: P0967.txt
# Processing P0972.png...
# ✅ Predictions drawn for P0972.png
# 📄 TXT saved: P0972.txt
# Processing P0973.png...
# ✅ Predictions drawn for P0973.png
# 📄 TXT saved: P0973.txt
# Processing P0975.png...
# ✅ Predictions drawn for P0975.png
# 📄 TXT saved: P0975.txt
# Processing P0978.png...
# ✅ Predictions drawn for P0978.png
# 📄 TXT saved: P0978.txt
# Processing P0979.png...
# ✅ Predictions drawn for P0979.png
# 📄 TXT saved: P0979.txt
# Processing P0980.png...
# ✅ Predictions drawn for P0980.png
# 📄 TXT saved: P0980.txt
# Processing P0981.png...
# ✅ Predictions drawn for P0981.png
# 📄 TXT saved: P0981.txt
# Processing P0986.png...
# ✅ Predictions drawn for P0986.png
# 📄 TXT saved: P0986.txt
# Processing P0987.png...
# ✅ Predictions drawn for P0987.png
# 📄 TXT saved: P0987.txt
# Processing P0991.png...
# ✅ Predictions drawn for P0991.png
# 📄 TXT saved: P0991.txt
# Processing P0993.png...
# ✅ Predictions drawn for P0993.png
# 📄 TXT saved: P0993.txt
# Processing P0995.png...
# ✅ Predictions drawn for P0995.png
# 📄 TXT saved: P0995.txt
# Processing P0999.png...
# ✅ Predictions drawn for P0999.png
# 📄 TXT saved: P0999.txt
# Processing P1003.png...
# ✅ Predictions drawn for P1003.png
# 📄 TXT saved: P1003.txt
# Processing P1006.png...
# ✅ Predictions drawn for P1006.png
# 📄 TXT saved: P1006.txt
# Processing P1010.png...
# ✅ Predictions drawn for P1010.png
# 📄 TXT saved: P1010.txt
# Processing P1012.png...
# ✅ Predictions drawn for P1012.png
# 📄 TXT saved: P1012.txt
# Processing P1015.png...
# ✅ Predictions drawn for P1015.png
# 📄 TXT saved: P1015.txt
# Processing P1016.png...
# ✅ Predictions drawn for P1016.png
# 📄 TXT saved: P1016.txt
# Processing P1019.png...
# ✅ Predictions drawn for P1019.png
# 📄 TXT saved: P1019.txt
# Processing P1020.png...
# ✅ Predictions drawn for P1020.png
# 📄 TXT saved: P1020.txt
# Processing P1026.png...
# ✅ Predictions drawn for P1026.png
# 📄 TXT saved: P1026.txt
# Processing P1027.png...
# ✅ Predictions drawn for P1027.png
# 📄 TXT saved: P1027.txt
# Processing P1037.png...
# ✅ Predictions drawn for P1037.png
# 📄 TXT saved: P1037.txt
# Processing P1043.png...
# ✅ Predictions drawn for P1043.png
# 📄 TXT saved: P1043.txt
# Processing P1046.png...
# ✅ Predictions drawn for P1046.png
# 📄 TXT saved: P1046.txt
# Processing P1047.png...
# ✅ Predictions drawn for P1047.png
# 📄 TXT saved: P1047.txt
# Processing P1049.png...
# ✅ Predictions drawn for P1049.png
# 📄 TXT saved: P1049.txt
# Processing P1052.png...
# ✅ Predictions drawn for P1052.png
# 📄 TXT saved: P1052.txt
# Processing P1053.png...
# ✅ Predictions drawn for P1053.png
# 📄 TXT saved: P1053.txt
# Processing P1054.png...
# ✅ Predictions drawn for P1054.png
# 📄 TXT saved: P1054.txt
# Processing P1055.png...
# ✅ Predictions drawn for P1055.png
# 📄 TXT saved: P1055.txt
# Processing P1057.png...
# ✅ Predictions drawn for P1057.png
# 📄 TXT saved: P1057.txt
# Processing P1059.png...
# ✅ Predictions drawn for P1059.png
# 📄 TXT saved: P1059.txt
# Processing P1060.png...
# ✅ Predictions drawn for P1060.png
# 📄 TXT saved: P1060.txt
# Processing P1061.png...
# ✅ Predictions drawn for P1061.png
# 📄 TXT saved: P1061.txt
# Processing P1062.png...
# ✅ Predictions drawn for P1062.png
# 📄 TXT saved: P1062.txt
# Processing P1063.png...
# ✅ Predictions drawn for P1063.png
# 📄 TXT saved: P1063.txt
# Processing P1067.png...
# ✅ Predictions drawn for P1067.png
# 📄 TXT saved: P1067.txt
# Processing P1069.png...
# ✅ Predictions drawn for P1069.png
# 📄 TXT saved: P1069.txt
# Processing P1070.png...
# ✅ Predictions drawn for P1070.png
# 📄 TXT saved: P1070.txt
# Processing P1071.png...
# ✅ Predictions drawn for P1071.png
# 📄 TXT saved: P1071.txt
# Processing P1073.png...
# ✅ Predictions drawn for P1073.png
# 📄 TXT saved: P1073.txt
# Processing P1076.png...
# ✅ Predictions drawn for P1076.png
# 📄 TXT saved: P1076.txt
# Processing P1077.png...
# ✅ Predictions drawn for P1077.png
# 📄 TXT saved: P1077.txt
# Processing P1078.png...
# ✅ Predictions drawn for P1078.png
# 📄 TXT saved: P1078.txt
# Processing P1079.png...
# ✅ Predictions drawn for P1079.png
# 📄 TXT saved: P1079.txt
# Processing P1080.png...
# ✅ Predictions drawn for P1080.png
# 📄 TXT saved: P1080.txt
# Processing P1084.png...
# ✅ Predictions drawn for P1084.png
# 📄 TXT saved: P1084.txt
# Processing P1087.png...
# ✅ Predictions drawn for P1087.png
# 📄 TXT saved: P1087.txt
# Processing P1089.png...
# ✅ Predictions drawn for P1089.png
# 📄 TXT saved: P1089.txt
# Processing P1092.png...
# ✅ Predictions drawn for P1092.png
# 📄 TXT saved: P1092.txt
# Processing P1094.png...
# ✅ Predictions drawn for P1094.png
# 📄 TXT saved: P1094.txt
# Processing P1096.png...
# ✅ Predictions drawn for P1096.png
# 📄 TXT saved: P1096.txt
# Processing P1098.png...
# ✅ Predictions drawn for P1098.png
# 📄 TXT saved: P1098.txt
# Processing P1105.png...
# ✅ Predictions drawn for P1105.png
# 📄 TXT saved: P1105.txt
# Processing P1107.png...
# ✅ Predictions drawn for P1107.png
# 📄 TXT saved: P1107.txt
# Processing P1108.png...
# ✅ Predictions drawn for P1108.png
# 📄 TXT saved: P1108.txt
# Processing P1109.png...
# ✅ Predictions drawn for P1109.png
# 📄 TXT saved: P1109.txt
# Processing P1110.png...
# ✅ Predictions drawn for P1110.png
# 📄 TXT saved: P1110.txt
# Processing P1113.png...
# ✅ Predictions drawn for P1113.png
# 📄 TXT saved: P1113.txt
# Processing P1114.png...
# ✅ Predictions drawn for P1114.png
# 📄 TXT saved: P1114.txt
# Processing P1116.png...
# ✅ Predictions drawn for P1116.png
# 📄 TXT saved: P1116.txt
# Processing P1117.png...
# ✅ Predictions drawn for P1117.png
# 📄 TXT saved: P1117.txt
# Processing P1118.png...
# ✅ Predictions drawn for P1118.png
# 📄 TXT saved: P1118.txt
# Processing P1119.png...
# ✅ Predictions drawn for P1119.png
# 📄 TXT saved: P1119.txt
# Processing P1121.png...
# ✅ Predictions drawn for P1121.png
# 📄 TXT saved: P1121.txt
# Processing P1130.png...
# ✅ Predictions drawn for P1130.png
# 📄 TXT saved: P1130.txt
# Processing P1131.png...
# ✅ Predictions drawn for P1131.png
# 📄 TXT saved: P1131.txt
# Processing P1132.png...
# ✅ Predictions drawn for P1132.png
# 📄 TXT saved: P1132.txt
# Processing P1139.png...
# ✅ Predictions drawn for P1139.png
# 📄 TXT saved: P1139.txt
# Processing P1140.png...
# ✅ Predictions drawn for P1140.png
# 📄 TXT saved: P1140.txt
# Processing P1141.png...
# ✅ Predictions drawn for P1141.png
# 📄 TXT saved: P1141.txt
# Processing P1142.png...
# ✅ Predictions drawn for P1142.png
# 📄 TXT saved: P1142.txt
# Processing P1144.png...
# ✅ Predictions drawn for P1144.png
# 📄 TXT saved: P1144.txt
# Processing P1148.png...
# ✅ Predictions drawn for P1148.png
# 📄 TXT saved: P1148.txt
# Processing P1150.png...
# ✅ Predictions drawn for P1150.png
# 📄 TXT saved: P1150.txt
# Processing P1152.png...
# ✅ Predictions drawn for P1152.png
# 📄 TXT saved: P1152.txt
# Processing P1155.png...
# ✅ Predictions drawn for P1155.png
# 📄 TXT saved: P1155.txt
# Processing P1158.png...
# ✅ Predictions drawn for P1158.png
# 📄 TXT saved: P1158.txt
# Processing P1159.png...
# ...
# 📄 TXT saved: P2452.txt
# Processing P2453.png...
# ✅ Predictions drawn for P2453.png
# 📄 TXT saved: P2453.txt
# Processing P2454.png...
# ✅ Predictions drawn for P2454.png
# 📄 TXT saved: P2454.txt
# Processing P2456.png...
# ✅ Predictions drawn for P2456.png
# 📄 TXT saved: P2456.txt
# Processing P2457.png...
# ✅ Predictions drawn for P2457.png
# 📄 TXT saved: P2457.txt
# Processing P2458.png...
# ✅ Predictions drawn for P2458.png
# 📄 TXT saved: P2458.txt
# Processing P2460.png...
# ✅ Predictions drawn for P2460.png
# 📄 TXT saved: P2460.txt
# Processing P2464.png...
# ✅ Predictions drawn for P2464.png
# 📄 TXT saved: P2464.txt
# Processing P2465.png...
# ✅ Predictions drawn for P2465.png
# 📄 TXT saved: P2465.txt
# Processing P2466.png...
# ✅ Predictions drawn for P2466.png
# 📄 TXT saved: P2466.txt
# Processing P2467.png...
# ✅ Predictions drawn for P2467.png
# 📄 TXT saved: P2467.txt
# Processing P2468.png...
# ✅ Predictions drawn for P2468.png
# 📄 TXT saved: P2468.txt
# Processing P2469.png...
# ✅ Predictions drawn for P2469.png
# 📄 TXT saved: P2469.txt
# Processing P2470.png...
# ✅ Predictions drawn for P2470.png
# 📄 TXT saved: P2470.txt
# Processing P2471.png...
# ✅ Predictions drawn for P2471.png
# 📄 TXT saved: P2471.txt
# Processing P2472.png...
# ✅ Predictions drawn for P2472.png
# 📄 TXT saved: P2472.txt
# Processing P2475.png...
# ✅ Predictions drawn for P2475.png
# 📄 TXT saved: P2475.txt
# Processing P2476.png...
# ✅ Predictions drawn for P2476.png
# 📄 TXT saved: P2476.txt
# Processing P2479.png...
# ✅ Predictions drawn for P2479.png
# 📄 TXT saved: P2479.txt
# Processing P2482.png...
# ✅ Predictions drawn for P2482.png
# 📄 TXT saved: P2482.txt
# Processing P2483.png...
# ✅ Predictions drawn for P2483.png
# 📄 TXT saved: P2483.txt
# Processing P2485.png...
# ✅ Predictions drawn for P2485.png
# 📄 TXT saved: P2485.txt
# Processing P2490.png...
# ✅ Predictions drawn for P2490.png
# 📄 TXT saved: P2490.txt
# Processing P2491.png...
# ✅ Predictions drawn for P2491.png
# 📄 TXT saved: P2491.txt
# Processing P2492.png...
# ✅ Predictions drawn for P2492.png
# 📄 TXT saved: P2492.txt
# Processing P2494.png...
# ✅ Predictions drawn for P2494.png
# 📄 TXT saved: P2494.txt
# Processing P2495.png...
# ✅ Predictions drawn for P2495.png
# 📄 TXT saved: P2495.txt
# Processing P2496.png...
# ✅ Predictions drawn for P2496.png
# 📄 TXT saved: P2496.txt
# Processing P2497.png...
# ✅ Predictions drawn for P2497.png
# 📄 TXT saved: P2497.txt
# Processing P2501.png...
# ✅ Predictions drawn for P2501.png
# 📄 TXT saved: P2501.txt
# Processing P2503.png...
# ✅ Predictions drawn for P2503.png
# 📄 TXT saved: P2503.txt
# Processing P2505.png...
# ✅ Predictions drawn for P2505.png
# 📄 TXT saved: P2505.txt
# Processing P2506.png...
# ✅ Predictions drawn for P2506.png
# 📄 TXT saved: P2506.txt
# Processing P2507.png...
# ✅ Predictions drawn for P2507.png
# 📄 TXT saved: P2507.txt
# Processing P2509.png...
# ✅ Predictions drawn for P2509.png
# 📄 TXT saved: P2509.txt
# Processing P2512.png...
# ✅ Predictions drawn for P2512.png
# 📄 TXT saved: P2512.txt
# Processing P2513.png...
# ✅ Predictions drawn for P2513.png
# 📄 TXT saved: P2513.txt
# Processing P2514.png...
# ✅ Predictions drawn for P2514.png
# 📄 TXT saved: P2514.txt
# Processing P2516.png...
# ✅ Predictions drawn for P2516.png
# 📄 TXT saved: P2516.txt
# Processing P2517.png...
# ✅ Predictions drawn for P2517.png
# 📄 TXT saved: P2517.txt
# Processing P2518.png...
# ✅ Predictions drawn for P2518.png
# 📄 TXT saved: P2518.txt
# Processing P2519.png...
# ✅ Predictions drawn for P2519.png
# 📄 TXT saved: P2519.txt
# Processing P2520.png...
# ⚠️ No predictions for P2520.png, drawing dummy box.
# 📄 TXT saved: P2520.txt
# Processing P2522.png...
# ✅ Predictions drawn for P2522.png
# 📄 TXT saved: P2522.txt
# Processing P2523.png...
# ✅ Predictions drawn for P2523.png
# 📄 TXT saved: P2523.txt
# Processing P2527.png...
# ✅ Predictions drawn for P2527.png
# 📄 TXT saved: P2527.txt
# Processing P2528.png...
# ✅ Predictions drawn for P2528.png
# 📄 TXT saved: P2528.txt
# Processing P2529.png...
# ✅ Predictions drawn for P2529.png
# 📄 TXT saved: P2529.txt
# Processing P2531.png...
# ✅ Predictions drawn for P2531.png
# 📄 TXT saved: P2531.txt
# Processing P2532.png...
# ✅ Predictions drawn for P2532.png
# 📄 TXT saved: P2532.txt
# Processing P2533.png...
# ✅ Predictions drawn for P2533.png
# 📄 TXT saved: P2533.txt
# Processing P2534.png...
# ✅ Predictions drawn for P2534.png
# 📄 TXT saved: P2534.txt
# Processing P2536.png...
# ✅ Predictions drawn for P2536.png
# 📄 TXT saved: P2536.txt
# Processing P2538.png...
# ✅ Predictions drawn for P2538.png
# 📄 TXT saved: P2538.txt
# Processing P2543.png...
# ✅ Predictions drawn for P2543.png
# 📄 TXT saved: P2543.txt
# Processing P2545.png...
# ✅ Predictions drawn for P2545.png
# 📄 TXT saved: P2545.txt
# Processing P2548.png...
# ✅ Predictions drawn for P2548.png
# 📄 TXT saved: P2548.txt
# Processing P2550.png...
# ✅ Predictions drawn for P2550.png
# 📄 TXT saved: P2550.txt
# Processing P2551.png...
# ✅ Predictions drawn for P2551.png
# 📄 TXT saved: P2551.txt
# Processing P2552.png...
# ✅ Predictions drawn for P2552.png
# 📄 TXT saved: P2552.txt
# Processing P2553.png...
# ✅ Predictions drawn for P2553.png
# 📄 TXT saved: P2553.txt
# Processing P2554.png...
# ✅ Predictions drawn for P2554.png
# 📄 TXT saved: P2554.txt
# Processing P2557.png...
# ✅ Predictions drawn for P2557.png
# 📄 TXT saved: P2557.txt
# Processing P2558.png...
# ✅ Predictions drawn for P2558.png
# 📄 TXT saved: P2558.txt
# Processing P2560.png...
# ✅ Predictions drawn for P2560.png
# 📄 TXT saved: P2560.txt
# Processing P2561.png...
# ✅ Predictions drawn for P2561.png
# 📄 TXT saved: P2561.txt
# Processing P2565.png...
# ✅ Predictions drawn for P2565.png
# 📄 TXT saved: P2565.txt
# Processing P2566.png...
# ✅ Predictions drawn for P2566.png
# 📄 TXT saved: P2566.txt
# Processing P2569.png...
# ✅ Predictions drawn for P2569.png
# 📄 TXT saved: P2569.txt
# Processing P2572.png...
# ✅ Predictions drawn for P2572.png
# 📄 TXT saved: P2572.txt
# Processing P2576.png...
# ✅ Predictions drawn for P2576.png
# 📄 TXT saved: P2576.txt
# Processing P2578.png...
# ✅ Predictions drawn for P2578.png
# 📄 TXT saved: P2578.txt
# Processing P2579.png...
# ✅ Predictions drawn for P2579.png
# 📄 TXT saved: P2579.txt
# Processing P2584.png...
# ✅ Predictions drawn for P2584.png
# 📄 TXT saved: P2584.txt
# Processing P2585.png...
# ✅ Predictions drawn for P2585.png
# 📄 TXT saved: P2585.txt
# Processing P2590.png...
# ✅ Predictions drawn for P2590.png
# 📄 TXT saved: P2590.txt
# Processing P2591.png...
# ✅ Predictions drawn for P2591.png
# 📄 TXT saved: P2591.txt
# Processing P2594.png...
# ✅ Predictions drawn for P2594.png
# 📄 TXT saved: P2594.txt
# Processing P2597.png...
# ✅ Predictions drawn for P2597.png
# 📄 TXT saved: P2597.txt
# Processing P2600.png...
# ✅ Predictions drawn for P2600.png
# 📄 TXT saved: P2600.txt
# Processing P2601.png...
# ✅ Predictions drawn for P2601.png
# 📄 TXT saved: P2601.txt
# Processing P2604.png...
# ✅ Predictions drawn for P2604.png
# 📄 TXT saved: P2604.txt
# Processing P2605.png...
# ✅ Predictions drawn for P2605.png
# 📄 TXT saved: P2605.txt
# Processing P2606.png...
# ✅ Predictions drawn for P2606.png
# 📄 TXT saved: P2606.txt
# Processing P2609.png...
# ✅ Predictions drawn for P2609.png
# 📄 TXT saved: P2609.txt
# Processing P2611.png...
# ✅ Predictions drawn for P2611.png
# 📄 TXT saved: P2611.txt
# Processing P2612.png...
# ✅ Predictions drawn for P2612.png
# 📄 TXT saved: P2612.txt
# Processing P2613.png...
# ✅ Predictions drawn for P2613.png
# 📄 TXT saved: P2613.txt
# Processing P2614.png...
# ✅ Predictions drawn for P2614.png
# 📄 TXT saved: P2614.txt
# Processing P2615.png...
# ✅ Predictions drawn for P2615.png
# 📄 TXT saved: P2615.txt
# Processing P2616.png...
# ✅ Predictions drawn for P2616.png
# 📄 TXT saved: P2616.txt
# Processing P2618.png...
# ✅ Predictions drawn for P2618.png
# 📄 TXT saved: P2618.txt
# Processing P2621.png...
# ✅ Predictions drawn for P2621.png
# 📄 TXT saved: P2621.txt
# Processing P2622.png...
# ✅ Predictions drawn for P2622.png
# 📄 TXT saved: P2622.txt
# Processing P2626.png...
# ✅ Predictions drawn for P2626.png
# 📄 TXT saved: P2626.txt
# Processing P2627.png...
# ✅ Predictions drawn for P2627.png
# 📄 TXT saved: P2627.txt
# Processing P2628.png...
# ✅ Predictions drawn for P2628.png
# 📄 TXT saved: P2628.txt
# Processing P2629.png...
# ✅ Predictions drawn for P2629.png
# 📄 TXT saved: P2629.txt
# Processing P2631.png...
# ✅ Predictions drawn for P2631.png
# 📄 TXT saved: P2631.txt
# Processing P2632.png...
# ✅ Predictions drawn for P2632.png
# 📄 TXT saved: P2632.txt
# Processing P2634.png...
# ✅ Predictions drawn for P2634.png
# 📄 TXT saved: P2634.txt
# Processing P2637.png...
# ✅ Predictions drawn for P2637.png
# 📄 TXT saved: P2637.txt
# Processing P2638.png...
# ✅ Predictions drawn for P2638.png
# 📄 TXT saved: P2638.txt
# Processing P2639.png...
# ✅ Predictions drawn for P2639.png
# 📄 TXT saved: P2639.txt
# Processing P2641.png...
# ✅ Predictions drawn for P2641.png
# 📄 TXT saved: P2641.txt
# Processing P2642.png...
# ✅ Predictions drawn for P2642.png
# 📄 TXT saved: P2642.txt
# Processing P2644.png...
# ✅ Predictions drawn for P2644.png
# 📄 TXT saved: P2644.txt
# Processing P2646.png...
# ✅ Predictions drawn for P2646.png
# 📄 TXT saved: P2646.txt
# Processing P2650.png...
# ✅ Predictions drawn for P2650.png
# 📄 TXT saved: P2650.txt
# Processing P2651.png...
# ✅ Predictions drawn for P2651.png
# 📄 TXT saved: P2651.txt
# Processing P2653.png...
# ✅ Predictions drawn for P2653.png
# 📄 TXT saved: P2653.txt
# Processing P2655.png...
# ✅ Predictions drawn for P2655.png
# 📄 TXT saved: P2655.txt
# Processing P2656.png...
# ✅ Predictions drawn for P2656.png
# 📄 TXT saved: P2656.txt
# Processing P2657.png...
# ✅ Predictions drawn for P2657.png
# 📄 TXT saved: P2657.txt
# Processing P2659.png...
# ✅ Predictions drawn for P2659.png
# 📄 TXT saved: P2659.txt
# Processing P2662.png...
# ✅ Predictions drawn for P2662.png
# 📄 TXT saved: P2662.txt
# Processing P2663.png...
# ✅ Predictions drawn for P2663.png
# 📄 TXT saved: P2663.txt
# Processing P2664.png...
# ✅ Predictions drawn for P2664.png
# 📄 TXT saved: P2664.txt
# Processing P2665.png...
# ✅ Predictions drawn for P2665.png
# 📄 TXT saved: P2665.txt
# Processing P2668.png...
# ✅ Predictions drawn for P2668.png
# 📄 TXT saved: P2668.txt
# Processing P2669.png...
# ✅ Predictions drawn for P2669.png
# 📄 TXT saved: P2669.txt
# Processing P2670.png...
# ✅ Predictions drawn for P2670.png
# 📄 TXT saved: P2670.txt
# Processing P2671.png...
# ✅ Predictions drawn for P2671.png
# 📄 TXT saved: P2671.txt
# Processing P2672.png...
# ✅ Predictions drawn for P2672.png
# 📄 TXT saved: P2672.txt
# Processing P2673.png...
# ✅ Predictions drawn for P2673.png
# 📄 TXT saved: P2673.txt
# Processing P2674.png...
# ✅ Predictions drawn for P2674.png
# 📄 TXT saved: P2674.txt
# Processing P2676.png...
# ✅ Predictions drawn for P2676.png
# 📄 TXT saved: P2676.txt
# Processing P2680.png...
# ✅ Predictions drawn for P2680.png
# 📄 TXT saved: P2680.txt
# Processing P2681.png...
# ✅ Predictions drawn for P2681.png
# 📄 TXT saved: P2681.txt
# Processing P2682.png...
# ✅ Predictions drawn for P2682.png
# 📄 TXT saved: P2682.txt
# Processing P2685.png...
# ✅ Predictions drawn for P2685.png
# 📄 TXT saved: P2685.txt
# Processing P2686.png...
# ✅ Predictions drawn for P2686.png
# 📄 TXT saved: P2686.txt
# Processing P2687.png...
# ✅ Predictions drawn for P2687.png
# 📄 TXT saved: P2687.txt
# Processing P2690.png...
# ✅ Predictions drawn for P2690.png
# 📄 TXT saved: P2690.txt
# Processing P2691.png...
# ✅ Predictions drawn for P2691.png
# 📄 TXT saved: P2691.txt
# Processing P2692.png...
# ✅ Predictions drawn for P2692.png
# 📄 TXT saved: P2692.txt
# Processing P2693.png...
# ✅ Predictions drawn for P2693.png
# 📄 TXT saved: P2693.txt
# Processing P2696.png...
# ✅ Predictions drawn for P2696.png
# 📄 TXT saved: P2696.txt
# Processing P2700.png...
# ✅ Predictions drawn for P2700.png
# 📄 TXT saved: P2700.txt
# Processing P2702.png...
# ✅ Predictions drawn for P2702.png
# 📄 TXT saved: P2702.txt
# Processing P2704.png...
# ✅ Predictions drawn for P2704.png
# 📄 TXT saved: P2704.txt
# Processing P2705.png...
# ✅ Predictions drawn for P2705.png
# 📄 TXT saved: P2705.txt
# Processing P2706.png...
# ✅ Predictions drawn for P2706.png
# 📄 TXT saved: P2706.txt
# Processing P2708.png...
# ✅ Predictions drawn for P2708.png
# 📄 TXT saved: P2708.txt
# Processing P2710.png...
# ✅ Predictions drawn for P2710.png
# 📄 TXT saved: P2710.txt
# Processing P2712.png...
# ✅ Predictions drawn for P2712.png
# 📄 TXT saved: P2712.txt
# Processing P2716.png...
# ✅ Predictions drawn for P2716.png
# 📄 TXT saved: P2716.txt
# Processing P2719.png...
# ✅ Predictions drawn for P2719.png
# 📄 TXT saved: P2719.txt
# Processing P2720.png...
# ✅ Predictions drawn for P2720.png
# 📄 TXT saved: P2720.txt
# Processing P2725.png...
# ✅ Predictions drawn for P2725.png
# 📄 TXT saved: P2725.txt
# Processing P2727.png...
# ✅ Predictions drawn for P2727.png
# 📄 TXT saved: P2727.txt
# Processing P2728.png...
# ✅ Predictions drawn for P2728.png
# 📄 TXT saved: P2728.txt
# Processing P2729.png...
# ✅ Predictions drawn for P2729.png
# 📄 TXT saved: P2729.txt
# Processing P2730.png...
# ✅ Predictions drawn for P2730.png
# 📄 TXT saved: P2730.txt
# Processing P2731.png...
# ✅ Predictions drawn for P2731.png
# 📄 TXT saved: P2731.txt
# Processing P2732.png...
# ✅ Predictions drawn for P2732.png
# 📄 TXT saved: P2732.txt
# Processing P2734.png...
# ✅ Predictions drawn for P2734.png
# 📄 TXT saved: P2734.txt
# Processing P2735.png...
# ✅ Predictions drawn for P2735.png
# 📄 TXT saved: P2735.txt
# Processing P2739.png...
# ✅ Predictions drawn for P2739.png
# 📄 TXT saved: P2739.txt
# Processing P2740.png...
# ✅ Predictions drawn for P2740.png
# 📄 TXT saved: P2740.txt
# Processing P2741.png...
# ✅ Predictions drawn for P2741.png
# 📄 TXT saved: P2741.txt
# Processing P2742.png...
# ✅ Predictions drawn for P2742.png
# 📄 TXT saved: P2742.txt
# Processing P2743.png...
# ✅ Predictions drawn for P2743.png
# 📄 TXT saved: P2743.txt
# Processing P2746.png...
# ✅ Predictions drawn for P2746.png
# 📄 TXT saved: P2746.txt
# Processing P2747.png...
# ✅ Predictions drawn for P2747.png
# 📄 TXT saved: P2747.txt
# Processing P2748.png...
# ✅ Predictions drawn for P2748.png
# 📄 TXT saved: P2748.txt
# Processing P2750.png...
# ✅ Predictions drawn for P2750.png
# 📄 TXT saved: P2750.txt
# Processing P2751.png...
# ✅ Predictions drawn for P2751.png
# 📄 TXT saved: P2751.txt
# Processing P2753.png...
# ✅ Predictions drawn for P2753.png
# 📄 TXT saved: P2753.txt
# Processing P2755.png...
# ✅ Predictions drawn for P2755.png
# 📄 TXT saved: P2755.txt
# Processing P2756.png...
# ✅ Predictions drawn for P2756.png
# 📄 TXT saved: P2756.txt
# Processing P2759.png...
# ✅ Predictions drawn for P2759.png
# 📄 TXT saved: P2759.txt
# Processing P2761.png...
# ✅ Predictions drawn for P2761.png
# 📄 TXT saved: P2761.txt
# Processing P2764.png...
# ✅ Predictions drawn for P2764.png
# 📄 TXT saved: P2764.txt
# Processing P2769.png...
# ✅ Predictions drawn for P2769.png
# 📄 TXT saved: P2769.txt
# Processing P2770.png...
# ✅ Predictions drawn for P2770.png
# 📄 TXT saved: P2770.txt
# Processing P2775.png...
# ✅ Predictions drawn for P2775.png
# 📄 TXT saved: P2775.txt
# Processing P2777.png...
# ✅ Predictions drawn for P2777.png
# 📄 TXT saved: P2777.txt
# Processing P2783.png...
# ✅ Predictions drawn for P2783.png
# 📄 TXT saved: P2783.txt
# Processing P2787.png...
# ✅ Predictions drawn for P2787.png
# 📄 TXT saved: P2787.txt
# Processing P2788.png...
# ✅ Predictions drawn for P2788.png
# 📄 TXT saved: P2788.txt
# Processing P2790.png...
# ✅ Predictions drawn for P2790.png
# 📄 TXT saved: P2790.txt
# Processing P2792.png...
# ✅ Predictions drawn for P2792.png
# 📄 TXT saved: P2792.txt
# Processing P2793.png...
# ✅ Predictions drawn for P2793.png
# 📄 TXT saved: P2793.txt
# Processing P2797.png...
# ✅ Predictions drawn for P2797.png
# 📄 TXT saved: P2797.txt
# Processing P2800.png...
# ✅ Predictions drawn for P2800.png
# 📄 TXT saved: P2800.txt
# Processing P2801.png...
# ✅ Predictions drawn for P2801.png
# 📄 TXT saved: P2801.txt
# Processing P2804.png...
# ✅ Predictions drawn for P2804.png
# 📄 TXT saved: P2804.txt
# Processing P2805.png...
# ✅ Predictions drawn for P2805.png
# 📄 TXT saved: P2805.txt
#
# ===== Detection Summary =====
# Total images processed: 1411
# Images with detections: 1365 (96.7%)
# Images with dummy boxes: 46 (3.3%)
#
# 📊 Detections by class:
#   plane: 5500 detections
#   baseball-diamond: 232 detections
#   bridge: 563 detections
#   ground-track-field: 215 detections
#   small-vehicle: 14800 detections
#   large-vehicle: 14685 detections
#   ship: 14887 detections
#   tennis-court: 2319 detections
#   basketball-court: 490 detections
#   storage-tank: 1973 detections
#   soccer-ball-field: 325 detections
#   roundabout: 295 detections
#   harbor: 4599 detections
#   swimming-pool: 1336 detections
#   helicopter: 219 detections
#   No_Detection: 46 detections
#
# 🎉 All images processed and saved with OBBs and TXT annotations.

# %%
import os
import numpy as np
import cv2
from shapely.geometry import Polygon
from collections import defaultdict
import matplotlib.pyplot as plt

class OBBEvaluator:
    def __init__(self, gt_dir, pred_dir, iou_threshold=0.5, confidence_threshold=0.01):
        """
        Initialize the OBB evaluator
        
        Args:
            gt_dir: Directory containing ground truth text files
            pred_dir: Directory containing prediction text files
            iou_threshold: IoU threshold for considering a detection as true positive
            confidence_threshold: Minimum confidence score to consider a prediction
        """
        self.gt_dir = gt_dir
        self.pred_dir = pred_dir
        self.iou_threshold = iou_threshold
        self.confidence_threshold = confidence_threshold
        self.class_names = set()
        self.results = {}
        # Store all predictions for PR curves
        self.all_predictions = defaultdict(list)
        # Store class cumulative stats
        self.class_cumulative = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        # Count of missing prediction files
        self.missing_pred_files = 0
    
    def parse_gt_file(self, gt_file):
        """
        Parse ground truth file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name difficulty_score
        """
        gts = []
        with open(gt_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + difficulty
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and ignore difficulty score
                    class_name = parts[8]
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    gts.append({
                        'polygon': points,
                        'class': class_name,
                        'detected': False  # Flag to mark if this gt is detected
                    })
                except Exception as e:
                    print(f"Error parsing GT line: {line}")
                    print(f"Exception: {e}")
        return gts
    
    def parse_pred_file(self, pred_file):
        """
        Parse prediction file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name confidence_score
        """
        preds = []
        if not os.path.exists(pred_file):
            return preds  # Return empty list if file doesn't exist
            
        with open(pred_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + confidence
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and confidence score
                    class_name = parts[8]
                    confidence = float(parts[9])
                    
                    # Skip predictions with confidence below threshold
                    if confidence < self.confidence_threshold:
                        continue
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    preds.append({
                        'polygon': points,
                        'class': class_name,
                        'confidence': confidence
                    })
                except Exception as e:
                    print(f"Error parsing prediction line: {line}")
                    print(f"Exception: {e}")
        
        # Sort predictions by confidence (descending)
        preds.sort(key=lambda x: x['confidence'], reverse=True)
        return preds
    
    def calculate_iou(self, poly1, poly2):
        """Calculate IoU between two polygons"""
        try:
            polygon1 = Polygon(poly1)
            polygon2 = Polygon(poly2)
            
            if not polygon1.is_valid or not polygon2.is_valid:
                return 0.0
            
            # Calculate intersection and union areas
            intersection_area = polygon1.intersection(polygon2).area
            union_area = polygon1.area + polygon2.area - intersection_area
            
            # Avoid division by zero
            if union_area == 0:
                return 0.0
                
            return intersection_area / union_area
        except Exception as e:
            print(f"Error calculating IoU: {e}")
            return 0.0
    
    def evaluate_image(self, gt_file, pred_file):
        """Evaluate a single image"""
        image_name = os.path.basename(gt_file).split('.')[0]
        
        # Parse GT and prediction files
        gts = self.parse_gt_file(gt_file)
        preds = self.parse_pred_file(pred_file)
        
        # Check if prediction file exists
        if not os.path.exists(pred_file):
            self.missing_pred_files += 1
            # Count all GTs as false negatives if no predictions
            for gt in gts:
                self.class_cumulative[gt['class']]['FN'] += 1
            return
        
        # Initialize per-class results for this image
        class_results = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        class_predictions = defaultdict(list)
        
        # For each prediction, find the best matching ground truth
        for pred in preds:
            pred_class = pred['class']
            pred_poly = pred['polygon']
            pred_conf = pred['confidence']
            
            best_iou = 0
            best_gt_idx = -1
            
            # Find the best matching GT of the same class
            for idx, gt in enumerate(gts):
                if gt['class'] != pred_class or gt['detected']:
                    continue
                
                iou = self.calculate_iou(pred_poly, gt['polygon'])
                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx
            
            # Record as TP or FP based on IoU threshold
            if best_gt_idx >= 0 and best_iou >= self.iou_threshold:
                class_predictions[pred_class].append((pred_conf, 1))  # True positive
                gts[best_gt_idx]['detected'] = True
                class_results[pred_class]['TP'] += 1
                self.class_cumulative[pred_class]['TP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 1))
            else:
                class_predictions[pred_class].append((pred_conf, 0))  # False positive
                class_results[pred_class]['FP'] += 1
                self.class_cumulative[pred_class]['FP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 0))
        
        # Count false negatives (undetected GTs)
        for gt in gts:
            if not gt['detected']:
                class_results[gt['class']]['FN'] += 1
                self.class_cumulative[gt['class']]['FN'] += 1
    
    def calculate_precision_recall(self, tp, fp, fn):
        """Calculate precision and recall"""
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        return precision, recall
    
    def calculate_f1(self, precision, recall):
        """Calculate F1 score"""
        return 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    def calculate_ap(self, precisions, recalls):
        """Calculate Average Precision using 11-point interpolation"""
        ap = 0
        for t in np.arange(0, 1.1, 0.1):
            if np.sum(recalls >= t) == 0:
                p = 0
            else:
                p = np.max(precisions[recalls >= t])
            ap += p / 11
        return ap
    
    def evaluate(self):
        """Evaluate all images and calculate metrics"""
        # Get list of files
        gt_files = sorted([f for f in os.listdir(self.gt_dir) if f.endswith('.txt')])
        print(f"Found {len(gt_files)} ground truth files")
        
        # Process each image
        for gt_file in gt_files:
            image_id = os.path.splitext(gt_file)[0]
            pred_file = image_id + '.txt'
            
            gt_path = os.path.join(self.gt_dir, gt_file)
            pred_path = os.path.join(self.pred_dir, pred_file)
            
            # Skip if prediction file doesn't exist but still record the missing files
            if not os.path.exists(pred_path):
                self.evaluate_image(gt_path, pred_path)  # This will handle missing files
                continue
            
            # Evaluate the image
            self.evaluate_image(gt_path, pred_path)
            
        if self.missing_pred_files > 0:
            print(f"\nWarning: {self.missing_pred_files} out of {len(gt_files)} prediction files were missing.")
            print(f"These are counted as having no detections (all ground truths counted as false negatives).")
        
        # Calculate metrics for each class
        self.results = {}
        mean_ap = 0
        processed_classes = 0
        
        for class_name in self.class_names:
            TP = self.class_cumulative[class_name]['TP']
            FP = self.class_cumulative[class_name]['FP']
            FN = self.class_cumulative[class_name]['FN']
            
            precision, recall = self.calculate_precision_recall(TP, FP, FN)
            f1 = self.calculate_f1(precision, recall)
            
            # Sort predictions by confidence for AP calculation
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            # Skip AP calculation if no ground truths or predictions
            if TP + FN == 0 or len(class_preds) == 0:
                ap = 0
            else:
                cumulative_tp = 0
                cumulative_fp = 0
                precisions = []
                recalls = []
                
                for conf, is_tp in class_preds:
                    if is_tp:
                        cumulative_tp += 1
                    else:
                        cumulative_fp += 1
                    
                    prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                    rec = cumulative_tp / (TP + FN)
                    
                    precisions.append(prec)
                    recalls.append(rec)
                
                precisions = np.array(precisions)
                recalls = np.array(recalls)
                ap = self.calculate_ap(precisions, recalls)
                processed_classes += 1
            
            self.results[class_name] = {
                'AP': ap,
                'Precision': precision,
                'Recall': recall,
                'F1': f1,
                'TP': TP,
                'FP': FP,
                'FN': FN
            }
            
            mean_ap += ap
        
        # Calculate mAP only over classes with predictions
        if processed_classes > 0:
            mean_ap /= processed_classes
        else:
            mean_ap = 0
        
        self.results['mAP'] = mean_ap
        
        return self.results
    
    def plot_precision_recall_curves(self, output_dir):
        """Plot precision-recall curves for all classes"""
        os.makedirs(output_dir, exist_ok=True)
        
        plt.figure(figsize=(10, 8))
        
        for class_name in sorted(self.class_names):
            # Skip classes with no predictions
            if class_name not in self.all_predictions or len(self.all_predictions[class_name]) == 0:
                continue
            
            # Sort predictions by confidence
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            TP = self.class_cumulative[class_name]['TP']
            FN = self.class_cumulative[class_name]['FN']
            
            # Skip if no ground truths
            if TP + FN == 0:
                continue
            
            # Calculate cumulative precision and recall
            cumulative_tp = 0
            cumulative_fp = 0
            precisions = []
            recalls = []
            
            for conf, is_tp in class_preds:
                if is_tp:
                    cumulative_tp += 1
                else:
                    cumulative_fp += 1
                
                prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                rec = cumulative_tp / (TP + FN)
                
                precisions.append(prec)
                recalls.append(rec)
            
            plt.plot(recalls, precisions, label=f"{class_name} (AP={self.results[class_name]['AP']:.3f})")
        
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curves')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(output_dir, 'precision_recall_curves_RFRCNN.png'))
        plt.close()
    
    def print_results(self):
        """Print evaluation results"""
        print("\n===== EVALUATION RESULTS =====")
        print(f"IoU Threshold: {self.iou_threshold}")
        print(f"Confidence Threshold: {self.confidence_threshold}")
        print(f"mAP: {self.results['mAP']:.4f}")
        print("\nPer-class results:")
        
        # Print header
        print(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}")
        print('-' * 70)
        
        # Sort classes for consistent output
        for class_name in sorted(self.class_names):
            r = self.results[class_name]
            print(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}")
        
        print("=" * 70)
    
    def save_results_to_file(self, output_path):
        """Save results to file"""
        with open(output_path, 'w') as f:
            f.write("===== EVALUATION RESULTS =====\n")
            f.write(f"IoU Threshold: {self.iou_threshold}\n")
            f.write(f"Confidence Threshold: {self.confidence_threshold}\n")
            f.write(f"mAP: {self.results['mAP']:.4f}\n\n")
            
            # if self.missing_pred_files > 0:
            #     f.write(f"Note: {self.missing_pred_files} prediction files were missing and counted as no detections.\n\n")
                
            f.write("Per-class results:\n")
            
            # Print header
            f.write(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}\n")
            f.write('-' * 70 + '\n')
            
            # Sort classes for consistent output
            for class_name in sorted(self.class_names):
                r = self.results[class_name]
                f.write(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}\n")
            
            f.write("=" * 70 + '\n')


# Usage example
if __name__ == "__main__":
    # Define paths
    GT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\labels\train\labelTxt-v1.0\labelTxt"  # Ground truth directory
    PRED_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_rfrcnn\txt_annotations"  # Prediction directory
    OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results"  # Output directory
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Create evaluator with default parameters
    evaluator = OBBEvaluator(
        gt_dir=GT_DIR,
        pred_dir=PRED_DIR,
        iou_threshold=0.5,  # IoU threshold for TP/FP determination
        confidence_threshold=0.01  # Min confidence to consider a prediction
    )
    
    # Run evaluation
    results = evaluator.evaluate()
    
    # Print results
    evaluator.print_results()
    
    # Save results to file
    evaluator.save_results_to_file(os.path.join(OUTPUT_DIR, "evaluation_results_RFRCNN.txt"))
    
    # Generate PR curves
    try:
        evaluator.plot_precision_recall_curves(OUTPUT_DIR)
        print(f"Precision-Recall curves saved to {OUTPUT_DIR}")
    except Exception as e:
        print(f"Error generating PR curves: {e}")
    
    print(f"Evaluation completed! Results saved to {OUTPUT_DIR}")
# Out:
# Found 1411 ground truth files
#
# ===== EVALUATION RESULTS =====
# IoU Threshold: 0.5
# Confidence Threshold: 0.01
# mAP: 0.3904
#
# Per-class results:
# Class           AP       Precision  Recall     F1       TP     FP     FN
# ----------------------------------------------------------------------
# baseball-diamond 0.4481   0.7802     0.4361     0.5595   181    51     234
# basketball-court 0.5397   0.6184     0.5883     0.6030   303    187    212
# bridge          0.0718   0.2895     0.0796     0.1249   163    400    1884
# ground-track-field 0.4461   0.6651     0.4400     0.5296   143    72     182
# harbor          0.3819   0.5595     0.4301     0.4863   2573   2026   3410
# helicopter      0.0909   0.1826     0.0635     0.0942   40     179    590
# large-vehicle   0.5940   0.7201     0.6231     0.6681   10574  4111   6395
# plane           0.5367   0.8055     0.5500     0.6536   4430   1070   3625
# roundabout      0.2381   0.3797     0.2807     0.3228   112    183    287
# ship            0.3131   0.5787     0.3069     0.4011   8615   6272   19453
# small-vehicle   0.3161   0.6118     0.3466     0.4425   9055   5745   17071
# soccer-ball-field 0.4075   0.4954     0.4939     0.4946   161    164    165
# storage-tank    0.2677   0.7349     0.2883     0.4142   1450   523    3579
# swimming-pool   0.3870   0.5756     0.4430     0.5007   769    567    967
# tennis-court    0.8170   0.8991     0.8809     0.8899   2085   234    282
# ======================================================================
# Precision-Recall curves saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results
# Evaluation completed! Results saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results

# %% [markdown]
# # S2ANET

# %%
import os
import cv2
import torch
import mmrotate
import numpy as np
from mmdet.apis import init_detector, inference_detector

# -------------------- Path Setup --------------------
IMAGE_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\images\train\images"
OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_s2anet"
CONFIG_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\mmrotate\configs\s2anet\s2anet_r50_fpn_fp16_1x_dota_le135.py"
CHECKPOINT_FILE = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\s2anet_r50_fpn_fp16_1x_dota_le135-5cac515c.pth"
LOW_CONFIDENCE = 0.1

os.makedirs(OUTPUT_DIR, exist_ok=True)
TXT_FOLDER = os.path.join(OUTPUT_DIR, "txt_annotations")
os.makedirs(TXT_FOLDER, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"✅ Using device: {device}")

model = init_detector(CONFIG_FILE, CHECKPOINT_FILE, device=device)
class_names = model.CLASSES if hasattr(model, 'CLASSES') else model.dataset_meta['CLASSES']
print(f"✅ Model loaded with {len(class_names)} classes: {class_names}")

def draw_obb(img, obb, label, score, color=(0, 255, 0), thickness=2):
    cx, cy, w, h, angle = obb
    rect = ((cx, cy), (w, h), angle * 180 / np.pi)
    box = cv2.boxPoints(rect)
    box = np.int0(box)
    cv2.drawContours(img, [box], 0, color, thickness)
    label_text = f"{class_names[label] if label < len(class_names) else 'No_Detection'}: {score:.2f}"
    cv2.putText(img, label_text, (int(cx), int(cy) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

# Gather image files
image_files = [f for f in os.listdir(IMAGE_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
if not image_files:
    print(f"❌ No image files found in {IMAGE_DIR}")
else:
    print(f"✅ Found {len(image_files)} image(s) to process")

total_images = 0
images_with_detections = 0
skipped_images = []
class_detection_counts = {i: 0 for i in range(len(class_names))}
class_detection_counts["No_Detection"] = 0

for img_name in image_files:
    total_images += 1
    img_path = os.path.join(IMAGE_DIR, img_name)
    print(f"Processing {img_name}...")

    img = cv2.imread(img_path)
    if img is None:
        print(f"⚠️ Failed to load image: {img_path}")
        skipped_images.append(img_name)
        continue

    result = inference_detector(model, img_path)

    drawn_any = False
    pred_data = []

    if isinstance(result, tuple):
        bbox_results, _ = result
        for class_id, bboxes in enumerate(bbox_results):
            for bbox in bboxes:
                score = bbox[5]
                obb = bbox[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })
    elif hasattr(result, 'pred_instances'):
        pred_instances = result.pred_instances
        bboxes = pred_instances.bboxes.cpu().numpy()
        scores = pred_instances.scores.cpu().numpy()
        labels = pred_instances.labels.cpu().numpy()
        for bbox, score, label in zip(bboxes, scores, labels):
            obb = bbox.tolist()
            if score >= LOW_CONFIDENCE:
                draw_obb(img, obb, label, score)
                drawn_any = True
                class_detection_counts[label.item()] += 1
                pred_data.append({
                    "obb": obb,
                    "score": float(score),
                    "label": int(label),
                    "label_name": class_names[label]
                })
    else:
        for class_id, class_result in enumerate(result):
            for res in class_result:
                score = res[-1]
                obb = res[:5].tolist()
                if score >= LOW_CONFIDENCE:
                    draw_obb(img, obb, class_id, score)
                    drawn_any = True
                    class_detection_counts[class_id] += 1
                    pred_data.append({
                        "obb": obb,
                        "score": float(score),
                        "label": int(class_id),
                        "label_name": class_names[class_id]
                    })

    # If no detection, draw dummy red box
    if not drawn_any:
        print(f"⚠️ No predictions for {img_name}, drawing dummy box.")
        h, w = img.shape[:2]
        dummy_cx, dummy_cy = w // 2, h // 2
        dummy_w, dummy_h = w // 5, h // 5
        dummy_angle = 0
        dummy_obb = [dummy_cx, dummy_cy, dummy_w, dummy_h, dummy_angle]
        dummy_score = 0.0
        draw_obb(img, dummy_obb, len(class_names), dummy_score, color=(0, 0, 255))
        pred_data.append({
            "obb": dummy_obb,
            "score": dummy_score,
            "label": len(class_names),
            "label_name": "No_Detection"
        })
        class_detection_counts["No_Detection"] += 1
    else:
        print(f"✅ Predictions drawn for {img_name}")
        images_with_detections += 1

    # Save image
    output_path = os.path.join(OUTPUT_DIR, img_name)
    cv2.imwrite(output_path, img)

    # Save .txt annotation
    txt_filename = os.path.splitext(img_name)[0] + ".txt"
    txt_path = os.path.join(TXT_FOLDER, txt_filename)

    with open(txt_path, 'w') as f:
        for pred in pred_data:
            cx, cy, w, h, angle = pred['obb']
            rect = ((cx, cy), (w, h), angle * 180 / np.pi)
            box = cv2.boxPoints(rect)
            box = np.int0(box)
            points_flat = box.flatten()
            coords = " ".join(map(str, points_flat))
            label_name = pred['label_name'].replace(" ", "_")  # Prevent space in label
            score = pred['score']
            line = f"{coords} {label_name} {score:.4f}\n"
            f.write(line)

    print(f"📄 TXT saved: {txt_filename}")

# ========== Summary ==========
print("\n===== Detection Summary =====")
print(f"Total images processed: {total_images}")
print(f"Images with detections: {images_with_detections} ({images_with_detections / total_images * 100:.1f}%)")
print(f"Images with dummy boxes: {total_images - images_with_detections} ({(total_images - images_with_detections) / total_images * 100:.1f}%)")

print("\n📊 Detections by class:")
for class_id, count in class_detection_counts.items():
    name = class_names[class_id] if isinstance(class_id, int) and class_id < len(class_names) else class_id
    if count > 0:
        print(f"  {name}: {count} detections")

if skipped_images:
    print("\n⚠️ Skipped the following images (could not load):")
    for name in skipped_images:
        print(f" - {name}")

print("\n🎉 All images processed and saved with OBBs and TXT annotations.")
# Out:
# ✅ Using device: cuda
# load checkpoint from local path: D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\pth files\s2anet_r50_fpn_fp16_1x_dota_le135-5cac515c.pth
# ✅ Model loaded with 15 classes: ('plane', 'baseball-diamond', 'bridge', 'ground-track-field', 'small-vehicle', 'large-vehicle', 'ship', 'tennis-court', 'basketball-court', 'storage-tank', 'soccer-ball-field', 'roundabout', 'harbor', 'swimming-pool', 'helicopter')
# ✅ Found 1411 image(s) to process
# Processing P0000.png...
# d:\Anaconda\envs\cfi_net\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3527.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ✅ Predictions drawn for P0000.png
# 📄 TXT saved: P0000.txt
# Processing P0001.png...
# ✅ Predictions drawn for P0001.png
# 📄 TXT saved: P0001.txt
# Processing P0002.png...
# ✅ Predictions drawn for P0002.png
# 📄 TXT saved: P0002.txt
# Processing P0005.png...
# ✅ Predictions drawn for P0005.png
# 📄 TXT saved: P0005.txt
# Processing P0008.png...
# ✅ Predictions drawn for P0008.png
# 📄 TXT saved: P0008.txt
# Processing P0010.png...
# ✅ Predictions drawn for P0010.png
# 📄 TXT saved: P0010.txt
# Processing P0011.png...
# ✅ Predictions drawn for P0011.png
# 📄 TXT saved: P0011.txt
# Processing P0012.png...
# ✅ Predictions drawn for P0012.png
# 📄 TXT saved: P0012.txt
# Processing P0013.png...
# ✅ Predictions drawn for P0013.png
# 📄 TXT saved: P0013.txt
# Processing P0018.png...
# ✅ Predictions drawn for P0018.png
# 📄 TXT saved: P0018.txt
# Processing P0020.png...
# ✅ Predictions drawn for P0020.png
# 📄 TXT saved: P0020.txt
# Processing P0021.png...
# ✅ Predictions drawn for P0021.png
# 📄 TXT saved: P0021.txt
# Processing P0022.png...
# ✅ Predictions drawn for P0022.png
# 📄 TXT saved: P0022.txt
# Processing P0023.png...
# ✅ Predictions drawn for P0023.png
# 📄 TXT saved: P0023.txt
# Processing P0025.png...
# ✅ Predictions drawn for P0025.png
# 📄 TXT saved: P0025.txt
# Processing P0029.png...
# ✅ Predictions drawn for P0029.png
# 📄 TXT saved: P0029.txt
# Processing P0030.png...
# ✅ Predictions drawn for P0030.png
# 📄 TXT saved: P0030.txt
# Processing P0032.png...
# ✅ Predictions drawn for P0032.png
# 📄 TXT saved: P0032.txt
# Processing P0036.png...
# ✅ Predictions drawn for P0036.png
# 📄 TXT saved: P0036.txt
# Processing P0038.png...
# ✅ Predictions drawn for P0038.png
# 📄 TXT saved: P0038.txt
# Processing P0039.png...
# ✅ Predictions drawn for P0039.png
# 📄 TXT saved: P0039.txt
# Processing P0041.png...
# ✅ Predictions drawn for P0041.png
# 📄 TXT saved: P0041.txt
# Processing P0042.png...
# ✅ Predictions drawn for P0042.png
# 📄 TXT saved: P0042.txt
# Processing P0044.png...
# ✅ Predictions drawn for P0044.png
# 📄 TXT saved: P0044.txt
# Processing P0049.png...
# ✅ Predictions drawn for P0049.png
# 📄 TXT saved: P0049.txt
# Processing P0050.png...
# ✅ Predictions drawn for P0050.png
# 📄 TXT saved: P0050.txt
# Processing P0052.png...
# ✅ Predictions drawn for P0052.png
# 📄 TXT saved: P0052.txt
# Processing P0054.png...
# ✅ Predictions drawn for P0054.png
# 📄 TXT saved: P0054.txt
# Processing P0058.png...
# ✅ Predictions drawn for P0058.png
# 📄 TXT saved: P0058.txt
# Processing P0061.png...
# ✅ Predictions drawn for P0061.png
# 📄 TXT saved: P0061.txt
# Processing P0063.png...
# ✅ Predictions drawn for P0063.png
# 📄 TXT saved: P0063.txt
# Processing P0064.png...
# ✅ Predictions drawn for P0064.png
# 📄 TXT saved: P0064.txt
# Processing P0065.png...
# ✅ Predictions drawn for P0065.png
# 📄 TXT saved: P0065.txt
# Processing P0066.png...
# ✅ Predictions drawn for P0066.png
# 📄 TXT saved: P0066.txt
# Processing P0067.png...
# ✅ Predictions drawn for P0067.png
# 📄 TXT saved: P0067.txt
# Processing P0068.png...
# ✅ Predictions drawn for P0068.png
# 📄 TXT saved: P0068.txt
# Processing P0070.png...
# ✅ Predictions drawn for P0070.png
# 📄 TXT saved: P0070.txt
# Processing P0071.png...
# ✅ Predictions drawn for P0071.png
# 📄 TXT saved: P0071.txt
# Processing P0074.png...
# ✅ Predictions drawn for P0074.png
# 📄 TXT saved: P0074.txt
# Processing P0076.png...
# ✅ Predictions drawn for P0076.png
# 📄 TXT saved: P0076.txt
# Processing P0078.png...
# ✅ Predictions drawn for P0078.png
# 📄 TXT saved: P0078.txt
# Processing P0082.png...
# ✅ Predictions drawn for P0082.png
# 📄 TXT saved: P0082.txt
# Processing P0083.png...
# ✅ Predictions drawn for P0083.png
# 📄 TXT saved: P0083.txt
# Processing P0085.png...
# ✅ Predictions drawn for P0085.png
# 📄 TXT saved: P0085.txt
# Processing P0087.png...
# ✅ Predictions drawn for P0087.png
# 📄 TXT saved: P0087.txt
# Processing P0091.png...
# ✅ Predictions drawn for P0091.png
# 📄 TXT saved: P0091.txt
# Processing P0093.png...
# ✅ Predictions drawn for P0093.png
# 📄 TXT saved: P0093.txt
# Processing P0094.png...
# ✅ Predictions drawn for P0094.png
# 📄 TXT saved: P0094.txt
# Processing P0095.png...
# ✅ Predictions drawn for P0095.png
# 📄 TXT saved: P0095.txt
# Processing P0096.png...
# ✅ Predictions drawn for P0096.png
# 📄 TXT saved: P0096.txt
# Processing P0098.png...
# ✅ Predictions drawn for P0098.png
# 📄 TXT saved: P0098.txt
# Processing P0099.png...
# ✅ Predictions drawn for P0099.png
# 📄 TXT saved: P0099.txt
# Processing P0100.png...
# ✅ Predictions drawn for P0100.png
# 📄 TXT saved: P0100.txt
# Processing P0103.png...
# ✅ Predictions drawn for P0103.png
# 📄 TXT saved: P0103.txt
# Processing P0109.png...
# ✅ Predictions drawn for P0109.png
# 📄 TXT saved: P0109.txt
# Processing P0111.png...
# ✅ Predictions drawn for P0111.png
# 📄 TXT saved: P0111.txt
# Processing P0113.png...
# ✅ Predictions drawn for P0113.png
# 📄 TXT saved: P0113.txt
# Processing P0116.png...
# ✅ Predictions drawn for P0116.png
# 📄 TXT saved: P0116.txt
# Processing P0119.png...
# ✅ Predictions drawn for P0119.png
# 📄 TXT saved: P0119.txt
# Processing P0122.png...
# ✅ Predictions drawn for P0122.png
# 📄 TXT saved: P0122.txt
# Processing P0124.png...
# ✅ Predictions drawn for P0124.png
# 📄 TXT saved: P0124.txt
# Processing P0126.png...
# ✅ Predictions drawn for P0126.png
# 📄 TXT saved: P0126.txt
# Processing P0129.png...
# ✅ Predictions drawn for P0129.png
# 📄 TXT saved: P0129.txt
# Processing P0133.png...
# ✅ Predictions drawn for P0133.png
# 📄 TXT saved: P0133.txt
# Processing P0136.png...
# ✅ Predictions drawn for P0136.png
# 📄 TXT saved: P0136.txt
# Processing P0139.png...
# ✅ Predictions drawn for P0139.png
# 📄 TXT saved: P0139.txt
# Processing P0140.png...
# ✅ Predictions drawn for P0140.png
# 📄 TXT saved: P0140.txt
# Processing P0141.png...
# ✅ Predictions drawn for P0141.png
# 📄 TXT saved: P0141.txt
# Processing P0142.png...
# ✅ Predictions drawn for P0142.png
# 📄 TXT saved: P0142.txt
# Processing P0144.png...
# ✅ Predictions drawn for P0144.png
# 📄 TXT saved: P0144.txt
# Processing P0147.png...
# ✅ Predictions drawn for P0147.png
# 📄 TXT saved: P0147.txt
# Processing P0149.png...
# ✅ Predictions drawn for P0149.png
# 📄 TXT saved: P0149.txt
# Processing P0151.png...
# ✅ Predictions drawn for P0151.png
# 📄 TXT saved: P0151.txt
# Processing P0152.png...
# ✅ Predictions drawn for P0152.png
# 📄 TXT saved: P0152.txt
# Processing P0158.png...
# ✅ Predictions drawn for P0158.png
# 📄 TXT saved: P0158.txt
# Processing P0159.png...
# ✅ Predictions drawn for P0159.png
# 📄 TXT saved: P0159.txt
# Processing P0160.png...
# ✅ Predictions drawn for P0160.png
# 📄 TXT saved: P0160.txt
# Processing P0162.png...
# ✅ Predictions drawn for P0162.png
# 📄 TXT saved: P0162.txt
# Processing P0163.png...
# ✅ Predictions drawn for P0163.png
# 📄 TXT saved: P0163.txt
# Processing P0164.png...
# ✅ Predictions drawn for P0164.png
# 📄 TXT saved: P0164.txt
# Processing P0167.png...
# ✅ Predictions drawn for P0167.png
# 📄 TXT saved: P0167.txt
# Processing P0169.png...
# ✅ Predictions drawn for P0169.png
# 📄 TXT saved: P0169.txt
# Processing P0171.png...
# ✅ Predictions drawn for P0171.png
# 📄 TXT saved: P0171.txt
# Processing P0172.png...
# ✅ Predictions drawn for P0172.png
# 📄 TXT saved: P0172.txt
# Processing P0174.png...
# ✅ Predictions drawn for P0174.png
# 📄 TXT saved: P0174.txt
# Processing P0176.png...
# ✅ Predictions drawn for P0176.png
# 📄 TXT saved: P0176.txt
# Processing P0178.png...
# ✅ Predictions drawn for P0178.png
# 📄 TXT saved: P0178.txt
# Processing P0183.png...
# ✅ Predictions drawn for P0183.png
# 📄 TXT saved: P0183.txt
# Processing P0187.png...
# ✅ Predictions drawn for P0187.png
# 📄 TXT saved: P0187.txt
# Processing P0188.png...
# ✅ Predictions drawn for P0188.png
# 📄 TXT saved: P0188.txt
# Processing P0190.png...
# ✅ Predictions drawn for P0190.png
# 📄 TXT saved: P0190.txt
# Processing P0200.png...
# ✅ Predictions drawn for P0200.png
# 📄 TXT saved: P0200.txt
# Processing P0201.png...
# ✅ Predictions drawn for P0201.png
# 📄 TXT saved: P0201.txt
# Processing P0202.png...
# ✅ Predictions drawn for P0202.png
# 📄 TXT saved: P0202.txt
# Processing P0203.png...
# ✅ Predictions drawn for P0203.png
# 📄 TXT saved: P0203.txt
# Processing P0204.png...
# ✅ Predictions drawn for P0204.png
# 📄 TXT saved: P0204.txt
# Processing P0207.png...
# ✅ Predictions drawn for P0207.png
# 📄 TXT saved: P0207.txt
# Processing P0209.png...
# ✅ Predictions drawn for P0209.png
# 📄 TXT saved: P0209.txt
# Processing P0210.png...
# ✅ Predictions drawn for P0210.png
# 📄 TXT saved: P0210.txt
# Processing P0212.png...
# ✅ Predictions drawn for P0212.png
# 📄 TXT saved: P0212.txt
# Processing P0215.png...
# ✅ Predictions drawn for P0215.png
# 📄 TXT saved: P0215.txt
# Processing P0218.png...
# ✅ Predictions drawn for P0218.png
# 📄 TXT saved: P0218.txt
# Processing P0219.png...
# ✅ Predictions drawn for P0219.png
# 📄 TXT saved: P0219.txt
# Processing P0220.png...
# ✅ Predictions drawn for P0220.png
# 📄 TXT saved: P0220.txt
# Processing P0221.png...
# ✅ Predictions drawn for P0221.png
# 📄 TXT saved: P0221.txt
# Processing P0222.png...
# ✅ Predictions drawn for P0222.png
# 📄 TXT saved: P0222.txt
# Processing P0223.png...
# ✅ Predictions drawn for P0223.png
# 📄 TXT saved: P0223.txt
# Processing P0224.png...
# ✅ Predictions drawn for P0224.png
# 📄 TXT saved: P0224.txt
# Processing P0225.png...
# ✅ Predictions drawn for P0225.png
# 📄 TXT saved: P0225.txt
# Processing P0226.png...
# ✅ Predictions drawn for P0226.png
# 📄 TXT saved: P0226.txt
# Processing P0227.png...
# ✅ Predictions drawn for P0227.png
# 📄 TXT saved: P0227.txt
# Processing P0229.png...
# ✅ Predictions drawn for P0229.png
# 📄 TXT saved: P0229.txt
# Processing P0232.png...
# ✅ Predictions drawn for P0232.png
# 📄 TXT saved: P0232.txt
# Processing P0233.png...
# ✅ Predictions drawn for P0233.png
# 📄 TXT saved: P0233.txt
# Processing P0235.png...
# ✅ Predictions drawn for P0235.png
# 📄 TXT saved: P0235.txt
# Processing P0236.png...
# ✅ Predictions drawn for P0236.png
# 📄 TXT saved: P0236.txt
# Processing P0238.png...
# ✅ Predictions drawn for P0238.png
# 📄 TXT saved: P0238.txt
# Processing P0241.png...
# ✅ Predictions drawn for P0241.png
# 📄 TXT saved: P0241.txt
# Processing P0244.png...
# ✅ Predictions drawn for P0244.png
# 📄 TXT saved: P0244.txt
# Processing P0248.png...
# ✅ Predictions drawn for P0248.png
# 📄 TXT saved: P0248.txt
# Processing P0250.png...
# ✅ Predictions drawn for P0250.png
# 📄 TXT saved: P0250.txt
# Processing P0251.png...
# ✅ Predictions drawn for P0251.png
# 📄 TXT saved: P0251.txt
# Processing P0252.png...
# ✅ Predictions drawn for P0252.png
# 📄 TXT saved: P0252.txt
# Processing P0254.png...
# ✅ Predictions drawn for P0254.png
# 📄 TXT saved: P0254.txt
# Processing P0255.png...
# ✅ Predictions drawn for P0255.png
# 📄 TXT saved: P0255.txt
# Processing P0256.png...
# ✅ Predictions drawn for P0256.png
# 📄 TXT saved: P0256.txt
# Processing P0258.png...
# ✅ Predictions drawn for P0258.png
# 📄 TXT saved: P0258.txt
# Processing P0260.png...
# ✅ Predictions drawn for P0260.png
# 📄 TXT saved: P0260.txt
# Processing P0263.png...
# ✅ Predictions drawn for P0263.png
# 📄 TXT saved: P0263.txt
# Processing P0264.png...
# ✅ Predictions drawn for P0264.png
# 📄 TXT saved: P0264.txt
# Processing P0270.png...
# ✅ Predictions drawn for P0270.png
# 📄 TXT saved: P0270.txt
# Processing P0272.png...
# ✅ Predictions drawn for P0272.png
# 📄 TXT saved: P0272.txt
# Processing P0273.png...
# ✅ Predictions drawn for P0273.png
# 📄 TXT saved: P0273.txt
# Processing P0275.png...
# ✅ Predictions drawn for P0275.png
# 📄 TXT saved: P0275.txt
# Processing P0276.png...
# ✅ Predictions drawn for P0276.png
# 📄 TXT saved: P0276.txt
# Processing P0280.png...
# ✅ Predictions drawn for P0280.png
# 📄 TXT saved: P0280.txt
# Processing P0281.png...
# ✅ Predictions drawn for P0281.png
# 📄 TXT saved: P0281.txt
# Processing P0282.png...
# ✅ Predictions drawn for P0282.png
# 📄 TXT saved: P0282.txt
# Processing P0283.png...
# ✅ Predictions drawn for P0283.png
# 📄 TXT saved: P0283.txt
# Processing P0285.png...
# ✅ Predictions drawn for P0285.png
# 📄 TXT saved: P0285.txt
# Processing P0286.png...
# ✅ Predictions drawn for P0286.png
# 📄 TXT saved: P0286.txt
# Processing P0288.png...
# ✅ Predictions drawn for P0288.png
# 📄 TXT saved: P0288.txt
# Processing P0289.png...
# ✅ Predictions drawn for P0289.png
# 📄 TXT saved: P0289.txt
# Processing P0292.png...
# ✅ Predictions drawn for P0292.png
# 📄 TXT saved: P0292.txt
# Processing P0293.png...
# ✅ Predictions drawn for P0293.png
# 📄 TXT saved: P0293.txt
# Processing P0294.png...
# ✅ Predictions drawn for P0294.png
# 📄 TXT saved: P0294.txt
# Processing P0296.png...
# ✅ Predictions drawn for P0296.png
# 📄 TXT saved: P0296.txt
# Processing P0299.png...
# ✅ Predictions drawn for P0299.png
# 📄 TXT saved: P0299.txt
# Processing P0301.png...
# ✅ Predictions drawn for P0301.png
# 📄 TXT saved: P0301.txt
# Processing P0303.png...
# ✅ Predictions drawn for P0303.png
# 📄 TXT saved: P0303.txt
# Processing P0308.png...
# ✅ Predictions drawn for P0308.png
# 📄 TXT saved: P0308.txt
# Processing P0310.png...
# ✅ Predictions drawn for P0310.png
# 📄 TXT saved: P0310.txt
# Processing P0313.png...
# ✅ Predictions drawn for P0313.png
# 📄 TXT saved: P0313.txt
# Processing P0314.png...
# ✅ Predictions drawn for P0314.png
# 📄 TXT saved: P0314.txt
# Processing P0315.png...
# ✅ Predictions drawn for P0315.png
# 📄 TXT saved: P0315.txt
# Processing P0317.png...
# ✅ Predictions drawn for P0317.png
# 📄 TXT saved: P0317.txt
# Processing P0321.png...
# ✅ Predictions drawn for P0321.png
# 📄 TXT saved: P0321.txt
# Processing P0322.png...
# ✅ Predictions drawn for P0322.png
# 📄 TXT saved: P0322.txt
# Processing P0324.png...
# ✅ Predictions drawn for P0324.png
# 📄 TXT saved: P0324.txt
# Processing P0327.png...
# ✅ Predictions drawn for P0327.png
# 📄 TXT saved: P0327.txt
# Processing P0330.png...
# ✅ Predictions drawn for P0330.png
# 📄 TXT saved: P0330.txt
# Processing P0332.png...
# ✅ Predictions drawn for P0332.png
# 📄 TXT saved: P0332.txt
# Processing P0334.png...
# ✅ Predictions drawn for P0334.png
# 📄 TXT saved: P0334.txt
# Processing P0335.png...
# ✅ Predictions drawn for P0335.png
# 📄 TXT saved: P0335.txt
# Processing P0337.png...
# ✅ Predictions drawn for P0337.png
# 📄 TXT saved: P0337.txt
# Processing P0338.png...
# ✅ Predictions drawn for P0338.png
# 📄 TXT saved: P0338.txt
# Processing P0339.png...
# ✅ Predictions drawn for P0339.png
# 📄 TXT saved: P0339.txt
# Processing P0340.png...
# ✅ Predictions drawn for P0340.png
# 📄 TXT saved: P0340.txt
# Processing P0343.png...
# ✅ Predictions drawn for P0343.png
# 📄 TXT saved: P0343.txt
# Processing P0344.png...
# ✅ Predictions drawn for P0344.png
# 📄 TXT saved: P0344.txt
# Processing P0345.png...
# ✅ Predictions drawn for P0345.png
# 📄 TXT saved: P0345.txt
# Processing P0346.png...
# ✅ Predictions drawn for P0346.png
# 📄 TXT saved: P0346.txt
# Processing P0349.png...
# ✅ Predictions drawn for P0349.png
# 📄 TXT saved: P0349.txt
# Processing P0350.png...
# ✅ Predictions drawn for P0350.png
# 📄 TXT saved: P0350.txt
# Processing P0355.png...
# ✅ Predictions drawn for P0355.png
# 📄 TXT saved: P0355.txt
# Processing P0357.png...
# ✅ Predictions drawn for P0357.png
# 📄 TXT saved: P0357.txt
# Processing P0358.png...
# ✅ Predictions drawn for P0358.png
# 📄 TXT saved: P0358.txt
# Processing P0360.png...
# ✅ Predictions drawn for P0360.png
# 📄 TXT saved: P0360.txt
# Processing P0361.png...
# ✅ Predictions drawn for P0361.png
# 📄 TXT saved: P0361.txt
# Processing P0362.png...
# ✅ Predictions drawn for P0362.png
# 📄 TXT saved: P0362.txt
# Processing P0363.png...
# ✅ Predictions drawn for P0363.png
# 📄 TXT saved: P0363.txt
# Processing P0364.png...
# ✅ Predictions drawn for P0364.png
# 📄 TXT saved: P0364.txt
# Processing P0365.png...
# ✅ Predictions drawn for P0365.png
# 📄 TXT saved: P0365.txt
# Processing P0366.png...
# ✅ Predictions drawn for P0366.png
# 📄 TXT saved: P0366.txt
# Processing P0367.png...
# ✅ Predictions drawn for P0367.png
# 📄 TXT saved: P0367.txt
# Processing P0370.png...
# ✅ Predictions drawn for P0370.png
# 📄 TXT saved: P0370.txt
# Processing P0371.png...
# ✅ Predictions drawn for P0371.png
# 📄 TXT saved: P0371.txt
# Processing P0373.png...
# ✅ Predictions drawn for P0373.png
# 📄 TXT saved: P0373.txt
# Processing P0376.png...
# ✅ Predictions drawn for P0376.png
# 📄 TXT saved: P0376.txt
# Processing P0378.png...
# ✅ Predictions drawn for P0378.png
# 📄 TXT saved: P0378.txt
# Processing P0379.png...
# ✅ Predictions drawn for P0379.png
# 📄 TXT saved: P0379.txt
# Processing P0380.png...
# ✅ Predictions drawn for P0380.png
# 📄 TXT saved: P0380.txt
# Processing P0381.png...
# ✅ Predictions drawn for P0381.png
# 📄 TXT saved: P0381.txt
# Processing P0383.png...
# ✅ Predictions drawn for P0383.png
# 📄 TXT saved: P0383.txt
# Processing P0384.png...
# ✅ Predictions drawn for P0384.png
# 📄 TXT saved: P0384.txt
# Processing P0386.png...
# ✅ Predictions drawn for P0386.png
# 📄 TXT saved: P0386.txt
# Processing P0387.png...
# ✅ Predictions drawn for P0387.png
# 📄 TXT saved: P0387.txt
# Processing P0388.png...
# ✅ Predictions drawn for P0388.png
# 📄 TXT saved: P0388.txt
# Processing P0389.png...
# ✅ Predictions drawn for P0389.png
# 📄 TXT saved: P0389.txt
# Processing P0391.png...
# ✅ Predictions drawn for P0391.png
# 📄 TXT saved: P0391.txt
# Processing P0392.png...
# ✅ Predictions drawn for P0392.png
# 📄 TXT saved: P0392.txt
# Processing P0393.png...
# ✅ Predictions drawn for P0393.png
# 📄 TXT saved: P0393.txt
# Processing P0395.png...
# ✅ Predictions drawn for P0395.png
# 📄 TXT saved: P0395.txt
# Processing P0400.png...
# ✅ Predictions drawn for P0400.png
# 📄 TXT saved: P0400.txt
# Processing P0401.png...
# ✅ Predictions drawn for P0401.png
# 📄 TXT saved: P0401.txt
# Processing P0404.png...
# ✅ Predictions drawn for P0404.png
# 📄 TXT saved: P0404.txt
# Processing P0405.png...
# ✅ Predictions drawn for P0405.png
# 📄 TXT saved: P0405.txt
# Processing P0406.png...
# ✅ Predictions drawn for P0406.png
# 📄 TXT saved: P0406.txt
# Processing P0407.png...
# ✅ Predictions drawn for P0407.png
# 📄 TXT saved: P0407.txt
# Processing P0413.png...
# ✅ Predictions drawn for P0413.png
# 📄 TXT saved: P0413.txt
# Processing P0415.png...
# ✅ Predictions drawn for P0415.png
# 📄 TXT saved: P0415.txt
# Processing P0416.png...
# ✅ Predictions drawn for P0416.png
# 📄 TXT saved: P0416.txt
# Processing P0417.png...
# ✅ Predictions drawn for P0417.png
# 📄 TXT saved: P0417.txt
# Processing P0418.png...
# ✅ Predictions drawn for P0418.png
# 📄 TXT saved: P0418.txt
# Processing P0419.png...
# ✅ Predictions drawn for P0419.png
# 📄 TXT saved: P0419.txt
# Processing P0421.png...
# ✅ Predictions drawn for P0421.png
# 📄 TXT saved: P0421.txt
# Processing P0422.png...
# ✅ Predictions drawn for P0422.png
# 📄 TXT saved: P0422.txt
# Processing P0424.png...
# ✅ Predictions drawn for P0424.png
# 📄 TXT saved: P0424.txt
# Processing P0425.png...
# ✅ Predictions drawn for P0425.png
# 📄 TXT saved: P0425.txt
# Processing P0426.png...
# ✅ Predictions drawn for P0426.png
# 📄 TXT saved: P0426.txt
# Processing P0428.png...
# ✅ Predictions drawn for P0428.png
# 📄 TXT saved: P0428.txt
# Processing P0430.png...
# ✅ Predictions drawn for P0430.png
# 📄 TXT saved: P0430.txt
# Processing P0431.png...
# ✅ Predictions drawn for P0431.png
# 📄 TXT saved: P0431.txt
# Processing P0434.png...
# ✅ Predictions drawn for P0434.png
# 📄 TXT saved: P0434.txt
# Processing P0435.png...
# ✅ Predictions drawn for P0435.png
# 📄 TXT saved: P0435.txt
# Processing P0436.png...
# ✅ Predictions drawn for P0436.png
# 📄 TXT saved: P0436.txt
# Processing P0437.png...
# ✅ Predictions drawn for P0437.png
# 📄 TXT saved: P0437.txt
# Processing P0438.png...
# ✅ Predictions drawn for P0438.png
# 📄 TXT saved: P0438.txt
# Processing P0439.png...
# ✅ Predictions drawn for P0439.png
# 📄 TXT saved: P0439.txt
# Processing P0440.png...
# ✅ Predictions drawn for P0440.png
# 📄 TXT saved: P0440.txt
# Processing P0441.png...
# ✅ Predictions drawn for P0441.png
# 📄 TXT saved: P0441.txt
# Processing P0442.png...
# ✅ Predictions drawn for P0442.png
# 📄 TXT saved: P0442.txt
# Processing P0443.png...
# ✅ Predictions drawn for P0443.png
# 📄 TXT saved: P0443.txt
# Processing P0445.png...
# ✅ Predictions drawn for P0445.png
# 📄 TXT saved: P0445.txt
# Processing P0446.png...
# ✅ Predictions drawn for P0446.png
# 📄 TXT saved: P0446.txt
# Processing P0448.png...
# ✅ Predictions drawn for P0448.png
# 📄 TXT saved: P0448.txt
# Processing P0450.png...
# ✅ Predictions drawn for P0450.png
# 📄 TXT saved: P0450.txt
# Processing P0452.png...
# ✅ Predictions drawn for P0452.png
# 📄 TXT saved: P0452.txt
# Processing P0453.png...
# ✅ Predictions drawn for P0453.png
# 📄 TXT saved: P0453.txt
# Processing P0455.png...
# ✅ Predictions drawn for P0455.png
# 📄 TXT saved: P0455.txt
# Processing P0458.png...
# ✅ Predictions drawn for P0458.png
# 📄 TXT saved: P0458.txt
# Processing P0459.png...
# ✅ Predictions drawn for P0459.png
# 📄 TXT saved: P0459.txt
# Processing P0460.png...
# ✅ Predictions drawn for P0460.png
# 📄 TXT saved: P0460.txt
# Processing P0461.png...
# ✅ Predictions drawn for P0461.png
# 📄 TXT saved: P0461.txt
# Processing P0464.png...
# ✅ Predictions drawn for P0464.png
# 📄 TXT saved: P0464.txt
# Processing P0465.png...
# ✅ Predictions drawn for P0465.png
# 📄 TXT saved: P0465.txt
# Processing P0468.png...
# ✅ Predictions drawn for P0468.png
# 📄 TXT saved: P0468.txt
# Processing P0469.png...
# ✅ Predictions drawn for P0469.png
# 📄 TXT saved: P0469.txt
# Processing P0471.png...
# ✅ Predictions drawn for P0471.png
# 📄 TXT saved: P0471.txt
# Processing P0475.png...
# ✅ Predictions drawn for P0475.png
# 📄 TXT saved: P0475.txt
# Processing P0477.png...
# ✅ Predictions drawn for P0477.png
# 📄 TXT saved: P0477.txt
# Processing P0478.png...
# ✅ Predictions drawn for P0478.png
# 📄 TXT saved: P0478.txt
# Processing P0479.png...
# ✅ Predictions drawn for P0479.png
# 📄 TXT saved: P0479.txt
# Processing P0481.png...
# ✅ Predictions drawn for P0481.png
# 📄 TXT saved: P0481.txt
# Processing P0482.png...
# ✅ Predictions drawn for P0482.png
# 📄 TXT saved: P0482.txt
# Processing P0483.png...
# ✅ Predictions drawn for P0483.png
# 📄 TXT saved: P0483.txt
# Processing P0484.png...
# ✅ Predictions drawn for P0484.png
# 📄 TXT saved: P0484.txt
# Processing P0487.png...
# ✅ Predictions drawn for P0487.png
# 📄 TXT saved: P0487.txt
# Processing P0488.png...
# ✅ Predictions drawn for P0488.png
# 📄 TXT saved: P0488.txt
# Processing P0489.png...
# ✅ Predictions drawn for P0489.png
# 📄 TXT saved: P0489.txt
# Processing P0493.png...
# ✅ Predictions drawn for P0493.png
# 📄 TXT saved: P0493.txt
# Processing P0494.png...
# ✅ Predictions drawn for P0494.png
# 📄 TXT saved: P0494.txt
# Processing P0495.png...
# ✅ Predictions drawn for P0495.png
# 📄 TXT saved: P0495.txt
# Processing P0503.png...
# ✅ Predictions drawn for P0503.png
# 📄 TXT saved: P0503.txt
# Processing P0504.png...
# ✅ Predictions drawn for P0504.png
# 📄 TXT saved: P0504.txt
# Processing P0505.png...
# ✅ Predictions drawn for P0505.png
# 📄 TXT saved: P0505.txt
# Processing P0510.png...
# ✅ Predictions drawn for P0510.png
# 📄 TXT saved: P0510.txt
# Processing P0512.png...
# ✅ Predictions drawn for P0512.png
# 📄 TXT saved: P0512.txt
# Processing P0516.png...
# ✅ Predictions drawn for P0516.png
# 📄 TXT saved: P0516.txt
# Processing P0517.png...
# ✅ Predictions drawn for P0517.png
# 📄 TXT saved: P0517.txt
# Processing P0520.png...
# ✅ Predictions drawn for P0520.png
# 📄 TXT saved: P0520.txt
# Processing P0521.png...
# ✅ Predictions drawn for P0521.png
# 📄 TXT saved: P0521.txt
# Processing P0522.png...
# ✅ Predictions drawn for P0522.png
# 📄 TXT saved: P0522.txt
# Processing P0527.png...
# ✅ Predictions drawn for P0527.png
# 📄 TXT saved: P0527.txt
# Processing P0531.png...
# ✅ Predictions drawn for P0531.png
# 📄 TXT saved: P0531.txt
# Processing P0533.png...
# ✅ Predictions drawn for P0533.png
# 📄 TXT saved: P0533.txt
# Processing P0535.png...
# ✅ Predictions drawn for P0535.png
# 📄 TXT saved: P0535.txt
# Processing P0537.png...
# ✅ Predictions drawn for P0537.png
# 📄 TXT saved: P0537.txt
# Processing P0538.png...
# ✅ Predictions drawn for P0538.png
# 📄 TXT saved: P0538.txt
# Processing P0541.png...
# ✅ Predictions drawn for P0541.png
# 📄 TXT saved: P0541.txt
# Processing P0542.png...
# ✅ Predictions drawn for P0542.png
# 📄 TXT saved: P0542.txt
# Processing P0544.png...
# ✅ Predictions drawn for P0544.png
# 📄 TXT saved: P0544.txt
# Processing P0546.png...
# ✅ Predictions drawn for P0546.png
# 📄 TXT saved: P0546.txt
# Processing P0548.png...
# ✅ Predictions drawn for P0548.png
# 📄 TXT saved: P0548.txt
# Processing P0549.png...
# ✅ Predictions drawn for P0549.png
# 📄 TXT saved: P0549.txt
# Processing P0553.png...
# ✅ Predictions drawn for P0553.png
# 📄 TXT saved: P0553.txt
# Processing P0554.png...
# ✅ Predictions drawn for P0554.png
# 📄 TXT saved: P0554.txt
# Processing P0555.png...
# ✅ Predictions drawn for P0555.png
# 📄 TXT saved: P0555.txt
# Processing P0556.png...
# ✅ Predictions drawn for P0556.png
# 📄 TXT saved: P0556.txt
# Processing P0562.png...
# ✅ Predictions drawn for P0562.png
# 📄 TXT saved: P0562.txt
# Processing P0563.png...
# ✅ Predictions drawn for P0563.png
# 📄 TXT saved: P0563.txt
# Processing P0565.png...
# ✅ Predictions drawn for P0565.png
# 📄 TXT saved: P0565.txt
# Processing P0567.png...
# ✅ Predictions drawn for P0567.png
# 📄 TXT saved: P0567.txt
# Processing P0568.png...
# ✅ Predictions drawn for P0568.png
# 📄 TXT saved: P0568.txt
# Processing P0569.png...
# ✅ Predictions drawn for P0569.png
# 📄 TXT saved: P0569.txt
# Processing P0571.png...
# ✅ Predictions drawn for P0571.png
# 📄 TXT saved: P0571.txt
# Processing P0572.png...
# ✅ Predictions drawn for P0572.png
# 📄 TXT saved: P0572.txt
# Processing P0573.png...
# ✅ Predictions drawn for P0573.png
# 📄 TXT saved: P0573.txt
# Processing P0578.png...
# ✅ Predictions drawn for P0578.png
# 📄 TXT saved: P0578.txt
# Processing P0580.png...
# ✅ Predictions drawn for P0580.png
# 📄 TXT saved: P0580.txt
# Processing P0581.png...
# ✅ Predictions drawn for P0581.png
# 📄 TXT saved: P0581.txt
# Processing P0582.png...
# ✅ Predictions drawn for P0582.png
# 📄 TXT saved: P0582.txt
# Processing P0586.png...
# ✅ Predictions drawn for P0586.png
# 📄 TXT saved: P0586.txt
# Processing P0587.png...
# ✅ Predictions drawn for P0587.png
# 📄 TXT saved: P0587.txt
# Processing P0591.png...
# ✅ Predictions drawn for P0591.png
# 📄 TXT saved: P0591.txt
# Processing P0593.png...
# ✅ Predictions drawn for P0593.png
# 📄 TXT saved: P0593.txt
# Processing P0595.png...
# ✅ Predictions drawn for P0595.png
# 📄 TXT saved: P0595.txt
# Processing P0596.png...
# ✅ Predictions drawn for P0596.png
# 📄 TXT saved: P0596.txt
# Processing P0597.png...
# ✅ Predictions drawn for P0597.png
# 📄 TXT saved: P0597.txt
# Processing P0601.png...
# ✅ Predictions drawn for P0601.png
# 📄 TXT saved: P0601.txt
# Processing P0602.png...
# ✅ Predictions drawn for P0602.png
# 📄 TXT saved: P0602.txt
# Processing P0603.png...
# ✅ Predictions drawn for P0603.png
# 📄 TXT saved: P0603.txt
# Processing P0605.png...
# ✅ Predictions drawn for P0605.png
# 📄 TXT saved: P0605.txt
# Processing P0607.png...
# ✅ Predictions drawn for P0607.png
# 📄 TXT saved: P0607.txt
# Processing P0609.png...
# ✅ Predictions drawn for P0609.png
# 📄 TXT saved: P0609.txt
# Processing P0610.png...
# ✅ Predictions drawn for P0610.png
# 📄 TXT saved: P0610.txt
# Processing P0611.png...
# ✅ Predictions drawn for P0611.png
# 📄 TXT saved: P0611.txt
# Processing P0612.png...
# ✅ Predictions drawn for P0612.png
# 📄 TXT saved: P0612.txt
# Processing P0614.png...
# ✅ Predictions drawn for P0614.png
# 📄 TXT saved: P0614.txt
# Processing P0617.png...
# ✅ Predictions drawn for P0617.png
# 📄 TXT saved: P0617.txt
# Processing P0618.png...
# ✅ Predictions drawn for P0618.png
# 📄 TXT saved: P0618.txt
# Processing P0619.png...
# ✅ Predictions drawn for P0619.png
# 📄 TXT saved: P0619.txt
# Processing P0620.png...
# ✅ Predictions drawn for P0620.png
# 📄 TXT saved: P0620.txt
# Processing P0624.png...
# ✅ Predictions drawn for P0624.png
# 📄 TXT saved: P0624.txt
# Processing P0625.png...
# ✅ Predictions drawn for P0625.png
# 📄 TXT saved: P0625.txt
# Processing P0626.png...
# ✅ Predictions drawn for P0626.png
# 📄 TXT saved: P0626.txt
# Processing P0627.png...
# ✅ Predictions drawn for P0627.png
# 📄 TXT saved: P0627.txt
# Processing P0629.png...
# ✅ Predictions drawn for P0629.png
# 📄 TXT saved: P0629.txt
# Processing P0630.png...
# ✅ Predictions drawn for P0630.png
# 📄 TXT saved: P0630.txt
# Processing P0631.png...
# ✅ Predictions drawn for P0631.png
# 📄 TXT saved: P0631.txt
# Processing P0632.png...
# ✅ Predictions drawn for P0632.png
# 📄 TXT saved: P0632.txt
# Processing P0634.png...
# ✅ Predictions drawn for P0634.png
# 📄 TXT saved: P0634.txt
# Processing P0637.png...
# ✅ Predictions drawn for P0637.png
# 📄 TXT saved: P0637.txt
# Processing P0638.png...
# ✅ Predictions drawn for P0638.png
# 📄 TXT saved: P0638.txt
# Processing P0641.png...
# ✅ Predictions drawn for P0641.png
# 📄 TXT saved: P0641.txt
# Processing P0642.png...
# ✅ Predictions drawn for P0642.png
# 📄 TXT saved: P0642.txt
# Processing P0646.png...
# ✅ Predictions drawn for P0646.png
# 📄 TXT saved: P0646.txt
# Processing P0648.png...
# ✅ Predictions drawn for P0648.png
# 📄 TXT saved: P0648.txt
# Processing P0649.png...
# ✅ Predictions drawn for P0649.png
# 📄 TXT saved: P0649.txt
# Processing P0652.png...
# ✅ Predictions drawn for P0652.png
# 📄 TXT saved: P0652.txt
# Processing P0653.png...
# ✅ Predictions drawn for P0653.png
# 📄 TXT saved: P0653.txt
# Processing P0656.png...
# ✅ Predictions drawn for P0656.png
# 📄 TXT saved: P0656.txt
# Processing P0658.png...
# ✅ Predictions drawn for P0658.png
# 📄 TXT saved: P0658.txt
# Processing P0664.png...
# ✅ Predictions drawn for P0664.png
# 📄 TXT saved: P0664.txt
# Processing P0666.png...
# ✅ Predictions drawn for P0666.png
# 📄 TXT saved: P0666.txt
# Processing P0668.png...
# ✅ Predictions drawn for P0668.png
# 📄 TXT saved: P0668.txt
# Processing P0676.png...
# ✅ Predictions drawn for P0676.png
# 📄 TXT saved: P0676.txt
# Processing P0677.png...
# ✅ Predictions drawn for P0677.png
# 📄 TXT saved: P0677.txt
# Processing P0685.png...
# ✅ Predictions drawn for P0685.png
# 📄 TXT saved: P0685.txt
# Processing P0687.png...
# ✅ Predictions drawn for P0687.png
# 📄 TXT saved: P0687.txt
# Processing P0688.png...
# ✅ Predictions drawn for P0688.png
# 📄 TXT saved: P0688.txt
# Processing P0689.png...
# ✅ Predictions drawn for P0689.png
# 📄 TXT saved: P0689.txt
# Processing P0691.png...
# ✅ Predictions drawn for P0691.png
# 📄 TXT saved: P0691.txt
# Processing P0692.png...
# ✅ Predictions drawn for P0692.png
# 📄 TXT saved: P0692.txt
# Processing P0693.png...
# ✅ Predictions drawn for P0693.png
# 📄 TXT saved: P0693.txt
# Processing P0695.png...
# ✅ Predictions drawn for P0695.png
# 📄 TXT saved: P0695.txt
# Processing P0697.png...
# ✅ Predictions drawn for P0697.png
# 📄 TXT saved: P0697.txt
# Processing P0699.png...
# ✅ Predictions drawn for P0699.png
# 📄 TXT saved: P0699.txt
# Processing P0700.png...
# ✅ Predictions drawn for P0700.png
# 📄 TXT saved: P0700.txt
# Processing P0702.png...
# ✅ Predictions drawn for P0702.png
# 📄 TXT saved: P0702.txt
# Processing P0703.png...
# ✅ Predictions drawn for P0703.png
# 📄 TXT saved: P0703.txt
# Processing P0707.png...
# ✅ Predictions drawn for P0707.png
# 📄 TXT saved: P0707.txt
# Processing P0711.png...
# ✅ Predictions drawn for P0711.png
# 📄 TXT saved: P0711.txt
# Processing P0713.png...
# ✅ Predictions drawn for P0713.png
# 📄 TXT saved: P0713.txt
# Processing P0714.png...
# ✅ Predictions drawn for P0714.png
# 📄 TXT saved: P0714.txt
# Processing P0716.png...
# ✅ Predictions drawn for P0716.png
# 📄 TXT saved: P0716.txt
# Processing P0719.png...
# ✅ Predictions drawn for P0719.png
# 📄 TXT saved: P0719.txt
# Processing P0722.png...
# ✅ Predictions drawn for P0722.png
# 📄 TXT saved: P0722.txt
# Processing P0723.png...
# ✅ Predictions drawn for P0723.png
# 📄 TXT saved: P0723.txt
# Processing P0724.png...
# ✅ Predictions drawn for P0724.png
# 📄 TXT saved: P0724.txt
# Processing P0726.png...
# ✅ Predictions drawn for P0726.png
# 📄 TXT saved: P0726.txt
# Processing P0727.png...
# ✅ Predictions drawn for P0727.png
# 📄 TXT saved: P0727.txt
# Processing P0728.png...
# ✅ Predictions drawn for P0728.png
# 📄 TXT saved: P0728.txt
# Processing P0730.png...
# ✅ Predictions drawn for P0730.png
# 📄 TXT saved: P0730.txt
# Processing P0731.png...
# ✅ Predictions drawn for P0731.png
# 📄 TXT saved: P0731.txt
# Processing P0732.png...
# ✅ Predictions drawn for P0732.png
# 📄 TXT saved: P0732.txt
# Processing P0733.png...
# ✅ Predictions drawn for P0733.png
# 📄 TXT saved: P0733.txt
# Processing P0734.png...
# ✅ Predictions drawn for P0734.png
# 📄 TXT saved: P0734.txt
# Processing P0737.png...
# ✅ Predictions drawn for P0737.png
# 📄 TXT saved: P0737.txt
# Processing P0738.png...
# ✅ Predictions drawn for P0738.png
# 📄 TXT saved: P0738.txt
# Processing P0743.png...
# ✅ Predictions drawn for P0743.png
# 📄 TXT saved: P0743.txt
# Processing P0744.png...
# ✅ Predictions drawn for P0744.png
# 📄 TXT saved: P0744.txt
# Processing P0745.png...
# ✅ Predictions drawn for P0745.png
# 📄 TXT saved: P0745.txt
# Processing P0746.png...
# ✅ Predictions drawn for P0746.png
# 📄 TXT saved: P0746.txt
# Processing P0750.png...
# ✅ Predictions drawn for P0750.png
# 📄 TXT saved: P0750.txt
# Processing P0753.png...
# ✅ Predictions drawn for P0753.png
# 📄 TXT saved: P0753.txt
# Processing P0754.png...
# ✅ Predictions drawn for P0754.png
# 📄 TXT saved: P0754.txt
# Processing P0755.png...
# ✅ Predictions drawn for P0755.png
# 📄 TXT saved: P0755.txt
# Processing P0757.png...
# ✅ Predictions drawn for P0757.png
# 📄 TXT saved: P0757.txt
# Processing P0759.png...
# ✅ Predictions drawn for P0759.png
# 📄 TXT saved: P0759.txt
# Processing P0760.png...
# ✅ Predictions drawn for P0760.png
# 📄 TXT saved: P0760.txt
# Processing P0762.png...
# ✅ Predictions drawn for P0762.png
# 📄 TXT saved: P0762.txt
# Processing P0766.png...
# ✅ Predictions drawn for P0766.png
# 📄 TXT saved: P0766.txt
# Processing P0768.png...
# ✅ Predictions drawn for P0768.png
# 📄 TXT saved: P0768.txt
# Processing P0769.png...
# ✅ Predictions drawn for P0769.png
# 📄 TXT saved: P0769.txt
# Processing P0775.png...
# ✅ Predictions drawn for P0775.png
# 📄 TXT saved: P0775.txt
# Processing P0777.png...
# ✅ Predictions drawn for P0777.png
# 📄 TXT saved: P0777.txt
# Processing P0778.png...
# ✅ Predictions drawn for P0778.png
# 📄 TXT saved: P0778.txt
# Processing P0779.png...
# ✅ Predictions drawn for P0779.png
# 📄 TXT saved: P0779.txt
# Processing P0780.png...
# ✅ Predictions drawn for P0780.png
# 📄 TXT saved: P0780.txt
# Processing P0781.png...
# ✅ Predictions drawn for P0781.png
# 📄 TXT saved: P0781.txt
# Processing P0782.png...
# ✅ Predictions drawn for P0782.png
# 📄 TXT saved: P0782.txt
# Processing P0783.png...
# ✅ Predictions drawn for P0783.png
# 📄 TXT saved: P0783.txt
# Processing P0785.png...
# ✅ Predictions drawn for P0785.png
# 📄 TXT saved: P0785.txt
# Processing P0786.png...
# ✅ Predictions drawn for P0786.png
# 📄 TXT saved: P0786.txt
# Processing P0790.png...
# ✅ Predictions drawn for P0790.png
# 📄 TXT saved: P0790.txt
# Processing P0792.png...
# ✅ Predictions drawn for P0792.png
# 📄 TXT saved: P0792.txt
# Processing P0794.png...
# ✅ Predictions drawn for P0794.png
# 📄 TXT saved: P0794.txt
# Processing P0800.png...
# ✅ Predictions drawn for P0800.png
# 📄 TXT saved: P0800.txt
# Processing P0803.png...
# ✅ Predictions drawn for P0803.png
# 📄 TXT saved: P0803.txt
# Processing P0804.png...
# ✅ Predictions drawn for P0804.png
# 📄 TXT saved: P0804.txt
# Processing P0805.png...
# ✅ Predictions drawn for P0805.png
# 📄 TXT saved: P0805.txt
# Processing P0806.png...
# ✅ Predictions drawn for P0806.png
# 📄 TXT saved: P0806.txt
# Processing P0809.png...
# ✅ Predictions drawn for P0809.png
# 📄 TXT saved: P0809.txt
# Processing P0810.png...
# ✅ Predictions drawn for P0810.png
# 📄 TXT saved: P0810.txt
# Processing P0817.png...
# ✅ Predictions drawn for P0817.png
# 📄 TXT saved: P0817.txt
# Processing P0818.png...
# ✅ Predictions drawn for P0818.png
# 📄 TXT saved: P0818.txt
# Processing P0819.png...
# ✅ Predictions drawn for P0819.png
# 📄 TXT saved: P0819.txt
# Processing P0821.png...
# ✅ Predictions drawn for P0821.png
# 📄 TXT saved: P0821.txt
# Processing P0823.png...
# ✅ Predictions drawn for P0823.png
# 📄 TXT saved: P0823.txt
# Processing P0825.png...
# ✅ Predictions drawn for P0825.png
# 📄 TXT saved: P0825.txt
# Processing P0826.png...
# ✅ Predictions drawn for P0826.png
# 📄 TXT saved: P0826.txt
# Processing P0827.png...
# ✅ Predictions drawn for P0827.png
# 📄 TXT saved: P0827.txt
# Processing P0828.png...
# ✅ Predictions drawn for P0828.png
# 📄 TXT saved: P0828.txt
# Processing P0829.png...
# ✅ Predictions drawn for P0829.png
# 📄 TXT saved: P0829.txt
# Processing P0831.png...
# ✅ Predictions drawn for P0831.png
# 📄 TXT saved: P0831.txt
# Processing P0832.png...
# ✅ Predictions drawn for P0832.png
# 📄 TXT saved: P0832.txt
# Processing P0835.png...
# ✅ Predictions drawn for P0835.png
# 📄 TXT saved: P0835.txt
# Processing P0840.png...
# ✅ Predictions drawn for P0840.png
# 📄 TXT saved: P0840.txt
# Processing P0843.png...
# ✅ Predictions drawn for P0843.png
# 📄 TXT saved: P0843.txt
# Processing P0845.png...
# ✅ Predictions drawn for P0845.png
# 📄 TXT saved: P0845.txt
# Processing P0846.png...
# ✅ Predictions drawn for P0846.png
# 📄 TXT saved: P0846.txt
# Processing P0848.png...
# ✅ Predictions drawn for P0848.png
# 📄 TXT saved: P0848.txt
# Processing P0849.png...
# ✅ Predictions drawn for P0849.png
# 📄 TXT saved: P0849.txt
# Processing P0850.png...
# ✅ Predictions drawn for P0850.png
# 📄 TXT saved: P0850.txt
# Processing P0851.png...
# ✅ Predictions drawn for P0851.png
# 📄 TXT saved: P0851.txt
# Processing P0853.png...
# ✅ Predictions drawn for P0853.png
# 📄 TXT saved: P0853.txt
# Processing P0855.png...
# ✅ Predictions drawn for P0855.png
# 📄 TXT saved: P0855.txt
# Processing P0856.png...
# ✅ Predictions drawn for P0856.png
# 📄 TXT saved: P0856.txt
# Processing P0857.png...
# ✅ Predictions drawn for P0857.png
# 📄 TXT saved: P0857.txt
# Processing P0860.png...
# ✅ Predictions drawn for P0860.png
# 📄 TXT saved: P0860.txt
# Processing P0861.png...
# ✅ Predictions drawn for P0861.png
# 📄 TXT saved: P0861.txt
# Processing P0867.png...
# ✅ Predictions drawn for P0867.png
# 📄 TXT saved: P0867.txt
# Processing P0868.png...
# ✅ Predictions drawn for P0868.png
# 📄 TXT saved: P0868.txt
# Processing P0869.png...
# ✅ Predictions drawn for P0869.png
# 📄 TXT saved: P0869.txt
# Processing P0870.png...
# ✅ Predictions drawn for P0870.png
# 📄 TXT saved: P0870.txt
# Processing P0871.png...
# ✅ Predictions drawn for P0871.png
# 📄 TXT saved: P0871.txt
# Processing P0872.png...
# ✅ Predictions drawn for P0872.png
# 📄 TXT saved: P0872.txt
# Processing P0873.png...
# ✅ Predictions drawn for P0873.png
# 📄 TXT saved: P0873.txt
# Processing P0874.png...
# ✅ Predictions drawn for P0874.png
# 📄 TXT saved: P0874.txt
# Processing P0875.png...
# ✅ Predictions drawn for P0875.png
# 📄 TXT saved: P0875.txt
# Processing P0878.png...
# ✅ Predictions drawn for P0878.png
# 📄 TXT saved: P0878.txt
# Processing P0879.png...
# ✅ Predictions drawn for P0879.png
# 📄 TXT saved: P0879.txt
# Processing P0881.png...
# ✅ Predictions drawn for P0881.png
# 📄 TXT saved: P0881.txt
# Processing P0883.png...
# ✅ Predictions drawn for P0883.png
# 📄 TXT saved: P0883.txt
# Processing P0884.png...
# ✅ Predictions drawn for P0884.png
# 📄 TXT saved: P0884.txt
# Processing P0885.png...
# ✅ Predictions drawn for P0885.png
# 📄 TXT saved: P0885.txt
# Processing P0888.png...
# ✅ Predictions drawn for P0888.png
# 📄 TXT saved: P0888.txt
# Processing P0890.png...
# ✅ Predictions drawn for P0890.png
# 📄 TXT saved: P0890.txt
# Processing P0892.png...
# ✅ Predictions drawn for P0892.png
# 📄 TXT saved: P0892.txt
# Processing P0893.png...
# ✅ Predictions drawn for P0893.png
# 📄 TXT saved: P0893.txt
# Processing P0894.png...
# ✅ Predictions drawn for P0894.png
# 📄 TXT saved: P0894.txt
# Processing P0895.png...
# ✅ Predictions drawn for P0895.png
# 📄 TXT saved: P0895.txt
# Processing P0896.png...
# ✅ Predictions drawn for P0896.png
# 📄 TXT saved: P0896.txt
# Processing P0898.png...
# ✅ Predictions drawn for P0898.png
# 📄 TXT saved: P0898.txt
# Processing P0899.png...
# ✅ Predictions drawn for P0899.png
# 📄 TXT saved: P0899.txt
# Processing P0900.png...
# ✅ Predictions drawn for P0900.png
# 📄 TXT saved: P0900.txt
# Processing P0905.png...
# ✅ Predictions drawn for P0905.png
# 📄 TXT saved: P0905.txt
# Processing P0906.png...
# ✅ Predictions drawn for P0906.png
# 📄 TXT saved: P0906.txt
# Processing P0907.png...
# ✅ Predictions drawn for P0907.png
# 📄 TXT saved: P0907.txt
# Processing P0908.png...
# ✅ Predictions drawn for P0908.png
# 📄 TXT saved: P0908.txt
# Processing P0909.png...
# ✅ Predictions drawn for P0909.png
# 📄 TXT saved: P0909.txt
# Processing P0911.png...
# ✅ Predictions drawn for P0911.png
# 📄 TXT saved: P0911.txt
# Processing P0913.png...
# ✅ Predictions drawn for P0913.png
# 📄 TXT saved: P0913.txt
# Processing P0914.png...
# ✅ Predictions drawn for P0914.png
# 📄 TXT saved: P0914.txt
# Processing P0915.png...
# ✅ Predictions drawn for P0915.png
# 📄 TXT saved: P0915.txt
# Processing P0918.png...
# ✅ Predictions drawn for P0918.png
# 📄 TXT saved: P0918.txt
# Processing P0920.png...
# ✅ Predictions drawn for P0920.png
# 📄 TXT saved: P0920.txt
# Processing P0921.png...
# ✅ Predictions drawn for P0921.png
# 📄 TXT saved: P0921.txt
# Processing P0922.png...
# ✅ Predictions drawn for P0922.png
# 📄 TXT saved: P0922.txt
# Processing P0925.png...
# ✅ Predictions drawn for P0925.png
# 📄 TXT saved: P0925.txt
# Processing P0926.png...
# ✅ Predictions drawn for P0926.png
# 📄 TXT saved: P0926.txt
# Processing P0928.png...
# ✅ Predictions drawn for P0928.png
# 📄 TXT saved: P0928.txt
# Processing P0933.png...
# ✅ Predictions drawn for P0933.png
# 📄 TXT saved: P0933.txt
# Processing P0934.png...
# ✅ Predictions drawn for P0934.png
# 📄 TXT saved: P0934.txt
# Processing P0938.png...
# ✅ Predictions drawn for P0938.png
# 📄 TXT saved: P0938.txt
# Processing P0940.png...
# ✅ Predictions drawn for P0940.png
# 📄 TXT saved: P0940.txt
# Processing P0941.png...
# ✅ Predictions drawn for P0941.png
# 📄 TXT saved: P0941.txt
# Processing P0944.png...
# ✅ Predictions drawn for P0944.png
# 📄 TXT saved: P0944.txt
# Processing P0946.png...
# ✅ Predictions drawn for P0946.png
# 📄 TXT saved: P0946.txt
# Processing P0947.png...
# ✅ Predictions drawn for P0947.png
# 📄 TXT saved: P0947.txt
# Processing P0948.png...
# ✅ Predictions drawn for P0948.png
# 📄 TXT saved: P0948.txt
# Processing P0950.png...
# ✅ Predictions drawn for P0950.png
# 📄 TXT saved: P0950.txt
# Processing P0951.png...
# ✅ Predictions drawn for P0951.png
# 📄 TXT saved: P0951.txt
# Processing P0952.png...
# ✅ Predictions drawn for P0952.png
# 📄 TXT saved: P0952.txt
# Processing P0957.png...
# ✅ Predictions drawn for P0957.png
# 📄 TXT saved: P0957.txt
# Processing P0960.png...
# ✅ Predictions drawn for P0960.png
# 📄 TXT saved: P0960.txt
# Processing P0963.png...
# ✅ Predictions drawn for P0963.png
# 📄 TXT saved: P0963.txt
# Processing P0966.png...
# ✅ Predictions drawn for P0966.png
# 📄 TXT saved: P0966.txt
# Processing P0967.png...
# ✅ Predictions drawn for P0967.png
# 📄 TXT saved: P0967.txt
# Processing P0972.png...
# ✅ Predictions drawn for P0972.png
# 📄 TXT saved: P0972.txt
# Processing P0973.png...
# ✅ Predictions drawn for P0973.png
# 📄 TXT saved: P0973.txt
# Processing P0975.png...
# ✅ Predictions drawn for P0975.png
# 📄 TXT saved: P0975.txt
# Processing P0978.png...
# ✅ Predictions drawn for P0978.png
# 📄 TXT saved: P0978.txt
# Processing P0979.png...
# ✅ Predictions drawn for P0979.png
# 📄 TXT saved: P0979.txt
# Processing P0980.png...
# ✅ Predictions drawn for P0980.png
# 📄 TXT saved: P0980.txt
# Processing P0981.png...
# ✅ Predictions drawn for P0981.png
# 📄 TXT saved: P0981.txt
# Processing P0986.png...
# ✅ Predictions drawn for P0986.png
# 📄 TXT saved: P0986.txt
# Processing P0987.png...
# ✅ Predictions drawn for P0987.png
# 📄 TXT saved: P0987.txt
# Processing P0991.png...
# ✅ Predictions drawn for P0991.png
# 📄 TXT saved: P0991.txt
# Processing P0993.png...
# ✅ Predictions drawn for P0993.png
# 📄 TXT saved: P0993.txt
# Processing P0995.png...
# ✅ Predictions drawn for P0995.png
# 📄 TXT saved: P0995.txt
# Processing P0999.png...
# ✅ Predictions drawn for P0999.png
# 📄 TXT saved: P0999.txt
# Processing P1003.png...
# ✅ Predictions drawn for P1003.png
# 📄 TXT saved: P1003.txt
# Processing P1006.png...
# ⚠️ No predictions for P1006.png, drawing dummy box.
# 📄 TXT saved: P1006.txt
# Processing P1010.png...
# ✅ Predictions drawn for P1010.png
# 📄 TXT saved: P1010.txt
# Processing P1012.png...
# ✅ Predictions drawn for P1012.png
# 📄 TXT saved: P1012.txt
# Processing P1015.png...
# ✅ Predictions drawn for P1015.png
# 📄 TXT saved: P1015.txt
# Processing P1016.png...
# ✅ Predictions drawn for P1016.png
# 📄 TXT saved: P1016.txt
# Processing P1019.png...
# ✅ Predictions drawn for P1019.png
# 📄 TXT saved: P1019.txt
# Processing P1020.png...
# ✅ Predictions drawn for P1020.png
# 📄 TXT saved: P1020.txt
# Processing P1026.png...
# ✅ Predictions drawn for P1026.png
# 📄 TXT saved: P1026.txt
# Processing P1027.png...
# ✅ Predictions drawn for P1027.png
# 📄 TXT saved: P1027.txt
# Processing P1037.png...
# ✅ Predictions drawn for P1037.png
# 📄 TXT saved: P1037.txt
# Processing P1043.png...
# ✅ Predictions drawn for P1043.png
# 📄 TXT saved: P1043.txt
# Processing P1046.png...
# ✅ Predictions drawn for P1046.png
# 📄 TXT saved: P1046.txt
# Processing P1047.png...
# ✅ Predictions drawn for P1047.png
# 📄 TXT saved: P1047.txt
# Processing P1049.png...
# ✅ Predictions drawn for P1049.png
# 📄 TXT saved: P1049.txt
# Processing P1052.png...
# ✅ Predictions drawn for P1052.png
# 📄 TXT saved: P1052.txt
# Processing P1053.png...
# ✅ Predictions drawn for P1053.png
# 📄 TXT saved: P1053.txt
# Processing P1054.png...
# ✅ Predictions drawn for P1054.png
# 📄 TXT saved: P1054.txt
# Processing P1055.png...
# ✅ Predictions drawn for P1055.png
# 📄 TXT saved: P1055.txt
# Processing P1057.png...
# ✅ Predictions drawn for P1057.png
# 📄 TXT saved: P1057.txt
# Processing P1059.png...
# ✅ Predictions drawn for P1059.png
# 📄 TXT saved: P1059.txt
# Processing P1060.png...
# ✅ Predictions drawn for P1060.png
# 📄 TXT saved: P1060.txt
# Processing P1061.png...
# ✅ Predictions drawn for P1061.png
# 📄 TXT saved: P1061.txt
# Processing P1062.png...
# ✅ Predictions drawn for P1062.png
# 📄 TXT saved: P1062.txt
# Processing P1063.png...
# ✅ Predictions drawn for P1063.png
# 📄 TXT saved: P1063.txt
# Processing P1067.png...
# ✅ Predictions drawn for P1067.png
# 📄 TXT saved: P1067.txt
# Processing P1069.png...
# ✅ Predictions drawn for P1069.png
# 📄 TXT saved: P1069.txt
# Processing P1070.png...
# ✅ Predictions drawn for P1070.png
# 📄 TXT saved: P1070.txt
# Processing P1071.png...
# ✅ Predictions drawn for P1071.png
# 📄 TXT saved: P1071.txt
# Processing P1073.png...
# ✅ Predictions drawn for P1073.png
# 📄 TXT saved: P1073.txt
# Processing P1076.png...
# ✅ Predictions drawn for P1076.png
# 📄 TXT saved: P1076.txt
# Processing P1077.png...
# ✅ Predictions drawn for P1077.png
# 📄 TXT saved: P1077.txt
# Processing P1078.png...
# ✅ Predictions drawn for P1078.png
# 📄 TXT saved: P1078.txt
# Processing P1079.png...
# ✅ Predictions drawn for P1079.png
# 📄 TXT saved: P1079.txt
# Processing P1080.png...
# ✅ Predictions drawn for P1080.png
# 📄 TXT saved: P1080.txt
# Processing P1084.png...
# ✅ Predictions drawn for P1084.png
# 📄 TXT saved: P1084.txt
# Processing P1087.png...
# ✅ Predictions drawn for P1087.png
# 📄 TXT saved: P1087.txt
# Processing P1089.png...
# ✅ Predictions drawn for P1089.png
# 📄 TXT saved: P1089.txt
# Processing P1092.png...
# ✅ Predictions drawn for P1092.png
# 📄 TXT saved: P1092.txt
# Processing P1094.png...
# ✅ Predictions drawn for P1094.png
# 📄 TXT saved: P1094.txt
# Processing P1096.png...
# ✅ Predictions drawn for P1096.png
# 📄 TXT saved: P1096.txt
# Processing P1098.png...
# ✅ Predictions drawn for P1098.png
# 📄 TXT saved: P1098.txt
# Processing P1105.png...
# ✅ Predictions drawn for P1105.png
# 📄 TXT saved: P1105.txt
# Processing P1107.png...
# ✅ Predictions drawn for P1107.png
# 📄 TXT saved: P1107.txt
# Processing P1108.png...
# ✅ Predictions drawn for P1108.png
# 📄 TXT saved: P1108.txt
# Processing P1109.png...
# ✅ Predictions drawn for P1109.png
# 📄 TXT saved: P1109.txt
# Processing P1110.png...
# ✅ Predictions drawn for P1110.png
# 📄 TXT saved: P1110.txt
# Processing P1113.png...
# ✅ Predictions drawn for P1113.png
# 📄 TXT saved: P1113.txt
# Processing P1114.png...
# ✅ Predictions drawn for P1114.png
# 📄 TXT saved: P1114.txt
# Processing P1116.png...
# ✅ Predictions drawn for P1116.png
# 📄 TXT saved: P1116.txt
# Processing P1117.png...
# ✅ Predictions drawn for P1117.png
# 📄 TXT saved: P1117.txt
# Processing P1118.png...
# ✅ Predictions drawn for P1118.png
# 📄 TXT saved: P1118.txt
# Processing P1119.png...
# ✅ Predictions drawn for P1119.png
# 📄 TXT saved: P1119.txt
# Processing P1121.png...
# ✅ Predictions drawn for P1121.png
# 📄 TXT saved: P1121.txt
# Processing P1130.png...
# ✅ Predictions drawn for P1130.png
# 📄 TXT saved: P1130.txt
# Processing P1131.png...
# ✅ Predictions drawn for P1131.png
# 📄 TXT saved: P1131.txt
# Processing P1132.png...
# ✅ Predictions drawn for P1132.png
# 📄 TXT saved: P1132.txt
# Processing P1139.png...
# ✅ Predictions drawn for P1139.png
# 📄 TXT saved: P1139.txt
# Processing P1140.png...
# ✅ Predictions drawn for P1140.png
# 📄 TXT saved: P1140.txt
# Processing P1141.png...
# ✅ Predictions drawn for P1141.png
# 📄 TXT saved: P1141.txt
# Processing P1142.png...
# ✅ Predictions drawn for P1142.png
# 📄 TXT saved: P1142.txt
# Processing P1144.png...
# ✅ Predictions drawn for P1144.png
# 📄 TXT saved: P1144.txt
# Processing P1148.png...
# ✅ Predictions drawn for P1148.png
# 📄 TXT saved: P1148.txt
# Processing P1150.png...
# ✅ Predictions drawn for P1150.png
# 📄 TXT saved: P1150.txt
# Processing P1152.png...
# ✅ Predictions drawn for P1152.png
# 📄 TXT saved: P1152.txt
# Processing P1155.png...
# ✅ Predictions drawn for P1155.png
# 📄 TXT saved: P1155.txt
# Processing P1158.png...
# ✅ Predictions drawn for P1158.png
# 📄 TXT saved: P1158.txt
# Processing P1159.png...
# ✅ Predictions drawn for P1159.png
# 📄 TXT saved: P1159.txt
# Processing P1161.png...
# ✅ Predictions drawn for P1161.png
# 📄 TXT saved: P1161.txt
# ...
# 📄 TXT saved: P2452.txt
# Processing P2453.png...
# ✅ Predictions drawn for P2453.png
# 📄 TXT saved: P2453.txt
# Processing P2454.png...
# ✅ Predictions drawn for P2454.png
# 📄 TXT saved: P2454.txt
# Processing P2456.png...
# ✅ Predictions drawn for P2456.png
# 📄 TXT saved: P2456.txt
# Processing P2457.png...
# ✅ Predictions drawn for P2457.png
# 📄 TXT saved: P2457.txt
# Processing P2458.png...
# ✅ Predictions drawn for P2458.png
# 📄 TXT saved: P2458.txt
# Processing P2460.png...
# ✅ Predictions drawn for P2460.png
# 📄 TXT saved: P2460.txt
# Processing P2464.png...
# ✅ Predictions drawn for P2464.png
# 📄 TXT saved: P2464.txt
# Processing P2465.png...
# ✅ Predictions drawn for P2465.png
# 📄 TXT saved: P2465.txt
# Processing P2466.png...
# ✅ Predictions drawn for P2466.png
# 📄 TXT saved: P2466.txt
# Processing P2467.png...
# ✅ Predictions drawn for P2467.png
# 📄 TXT saved: P2467.txt
# Processing P2468.png...
# ✅ Predictions drawn for P2468.png
# 📄 TXT saved: P2468.txt
# Processing P2469.png...
# ✅ Predictions drawn for P2469.png
# 📄 TXT saved: P2469.txt
# Processing P2470.png...
# ✅ Predictions drawn for P2470.png
# 📄 TXT saved: P2470.txt
# Processing P2471.png...
# ✅ Predictions drawn for P2471.png
# 📄 TXT saved: P2471.txt
# Processing P2472.png...
# ✅ Predictions drawn for P2472.png
# 📄 TXT saved: P2472.txt
# Processing P2475.png...
# ✅ Predictions drawn for P2475.png
# 📄 TXT saved: P2475.txt
# Processing P2476.png...
# ✅ Predictions drawn for P2476.png
# 📄 TXT saved: P2476.txt
# Processing P2479.png...
# ✅ Predictions drawn for P2479.png
# 📄 TXT saved: P2479.txt
# Processing P2482.png...
# ✅ Predictions drawn for P2482.png
# 📄 TXT saved: P2482.txt
# Processing P2483.png...
# ✅ Predictions drawn for P2483.png
# 📄 TXT saved: P2483.txt
# Processing P2485.png...
# ✅ Predictions drawn for P2485.png
# 📄 TXT saved: P2485.txt
# Processing P2490.png...
# ✅ Predictions drawn for P2490.png
# 📄 TXT saved: P2490.txt
# Processing P2491.png...
# ✅ Predictions drawn for P2491.png
# 📄 TXT saved: P2491.txt
# Processing P2492.png...
# ✅ Predictions drawn for P2492.png
# 📄 TXT saved: P2492.txt
# Processing P2494.png...
# ✅ Predictions drawn for P2494.png
# 📄 TXT saved: P2494.txt
# Processing P2495.png...
# ✅ Predictions drawn for P2495.png
# 📄 TXT saved: P2495.txt
# Processing P2496.png...
# ✅ Predictions drawn for P2496.png
# 📄 TXT saved: P2496.txt
# Processing P2497.png...
# ✅ Predictions drawn for P2497.png
# 📄 TXT saved: P2497.txt
# Processing P2501.png...
# ✅ Predictions drawn for P2501.png
# 📄 TXT saved: P2501.txt
# Processing P2503.png...
# ✅ Predictions drawn for P2503.png
# 📄 TXT saved: P2503.txt
# Processing P2505.png...
# ✅ Predictions drawn for P2505.png
# 📄 TXT saved: P2505.txt
# Processing P2506.png...
# ✅ Predictions drawn for P2506.png
# 📄 TXT saved: P2506.txt
# Processing P2507.png...
# ✅ Predictions drawn for P2507.png
# 📄 TXT saved: P2507.txt
# Processing P2509.png...
# ✅ Predictions drawn for P2509.png
# 📄 TXT saved: P2509.txt
# Processing P2512.png...
# ✅ Predictions drawn for P2512.png
# 📄 TXT saved: P2512.txt
# Processing P2513.png...
# ✅ Predictions drawn for P2513.png
# 📄 TXT saved: P2513.txt
# Processing P2514.png...
# ✅ Predictions drawn for P2514.png
# 📄 TXT saved: P2514.txt
# Processing P2516.png...
# ✅ Predictions drawn for P2516.png
# 📄 TXT saved: P2516.txt
# Processing P2517.png...
# ✅ Predictions drawn for P2517.png
# 📄 TXT saved: P2517.txt
# Processing P2518.png...
# ✅ Predictions drawn for P2518.png
# 📄 TXT saved: P2518.txt
# Processing P2519.png...
# ✅ Predictions drawn for P2519.png
# 📄 TXT saved: P2519.txt
# Processing P2520.png...
# ✅ Predictions drawn for P2520.png
# 📄 TXT saved: P2520.txt
# Processing P2522.png...
# ✅ Predictions drawn for P2522.png
# 📄 TXT saved: P2522.txt
# Processing P2523.png...
# ✅ Predictions drawn for P2523.png
# 📄 TXT saved: P2523.txt
# Processing P2527.png...
# ✅ Predictions drawn for P2527.png
# 📄 TXT saved: P2527.txt
# Processing P2528.png...
# ✅ Predictions drawn for P2528.png
# 📄 TXT saved: P2528.txt
# Processing P2529.png...
# ✅ Predictions drawn for P2529.png
# 📄 TXT saved: P2529.txt
# Processing P2531.png...
# ✅ Predictions drawn for P2531.png
# 📄 TXT saved: P2531.txt
# Processing P2532.png...
# ✅ Predictions drawn for P2532.png
# 📄 TXT saved: P2532.txt
# Processing P2533.png...
# ✅ Predictions drawn for P2533.png
# 📄 TXT saved: P2533.txt
# Processing P2534.png...
# ✅ Predictions drawn for P2534.png
# 📄 TXT saved: P2534.txt
# Processing P2536.png...
# ✅ Predictions drawn for P2536.png
# 📄 TXT saved: P2536.txt
# Processing P2538.png...
# ✅ Predictions drawn for P2538.png
# 📄 TXT saved: P2538.txt
# Processing P2543.png...
# ✅ Predictions drawn for P2543.png
# 📄 TXT saved: P2543.txt
# Processing P2545.png...
# ✅ Predictions drawn for P2545.png
# 📄 TXT saved: P2545.txt
# Processing P2548.png...
# ✅ Predictions drawn for P2548.png
# 📄 TXT saved: P2548.txt
# Processing P2550.png...
# ✅ Predictions drawn for P2550.png
# 📄 TXT saved: P2550.txt
# Processing P2551.png...
# ✅ Predictions drawn for P2551.png
# 📄 TXT saved: P2551.txt
# Processing P2552.png...
# ✅ Predictions drawn for P2552.png
# 📄 TXT saved: P2552.txt
# Processing P2553.png...
# ✅ Predictions drawn for P2553.png
# 📄 TXT saved: P2553.txt
# Processing P2554.png...
# ✅ Predictions drawn for P2554.png
# 📄 TXT saved: P2554.txt
# Processing P2557.png...
# ✅ Predictions drawn for P2557.png
# 📄 TXT saved: P2557.txt
# Processing P2558.png...
# ✅ Predictions drawn for P2558.png
# 📄 TXT saved: P2558.txt
# Processing P2560.png...
# ✅ Predictions drawn for P2560.png
# 📄 TXT saved: P2560.txt
# Processing P2561.png...
# ✅ Predictions drawn for P2561.png
# 📄 TXT saved: P2561.txt
# Processing P2565.png...
# ✅ Predictions drawn for P2565.png
# 📄 TXT saved: P2565.txt
# Processing P2566.png...
# ✅ Predictions drawn for P2566.png
# 📄 TXT saved: P2566.txt
# Processing P2569.png...
# ✅ Predictions drawn for P2569.png
# 📄 TXT saved: P2569.txt
# Processing P2572.png...
# ✅ Predictions drawn for P2572.png
# 📄 TXT saved: P2572.txt
# Processing P2576.png...
# ✅ Predictions drawn for P2576.png
# 📄 TXT saved: P2576.txt
# Processing P2578.png...
# ✅ Predictions drawn for P2578.png
# 📄 TXT saved: P2578.txt
# Processing P2579.png...
# ✅ Predictions drawn for P2579.png
# 📄 TXT saved: P2579.txt
# Processing P2584.png...
# ✅ Predictions drawn for P2584.png
# 📄 TXT saved: P2584.txt
# Processing P2585.png...
# ✅ Predictions drawn for P2585.png
# 📄 TXT saved: P2585.txt
# Processing P2590.png...
# ✅ Predictions drawn for P2590.png
# 📄 TXT saved: P2590.txt
# Processing P2591.png...
# ✅ Predictions drawn for P2591.png
# 📄 TXT saved: P2591.txt
# Processing P2594.png...
# ✅ Predictions drawn for P2594.png
# 📄 TXT saved: P2594.txt
# Processing P2597.png...
# ✅ Predictions drawn for P2597.png
# 📄 TXT saved: P2597.txt
# Processing P2600.png...
# ✅ Predictions drawn for P2600.png
# 📄 TXT saved: P2600.txt
# Processing P2601.png...
# ✅ Predictions drawn for P2601.png
# 📄 TXT saved: P2601.txt
# Processing P2604.png...
# ✅ Predictions drawn for P2604.png
# 📄 TXT saved: P2604.txt
# Processing P2605.png...
# ✅ Predictions drawn for P2605.png
# 📄 TXT saved: P2605.txt
# Processing P2606.png...
# ✅ Predictions drawn for P2606.png
# 📄 TXT saved: P2606.txt
# Processing P2609.png...
# ✅ Predictions drawn for P2609.png
# 📄 TXT saved: P2609.txt
# Processing P2611.png...
# ✅ Predictions drawn for P2611.png
# 📄 TXT saved: P2611.txt
# Processing P2612.png...
# ✅ Predictions drawn for P2612.png
# 📄 TXT saved: P2612.txt
# Processing P2613.png...
# ✅ Predictions drawn for P2613.png
# 📄 TXT saved: P2613.txt
# Processing P2614.png...
# ✅ Predictions drawn for P2614.png
# 📄 TXT saved: P2614.txt
# Processing P2615.png...
# ✅ Predictions drawn for P2615.png
# 📄 TXT saved: P2615.txt
# Processing P2616.png...
# ✅ Predictions drawn for P2616.png
# 📄 TXT saved: P2616.txt
# Processing P2618.png...
# ✅ Predictions drawn for P2618.png
# 📄 TXT saved: P2618.txt
# Processing P2621.png...
# ✅ Predictions drawn for P2621.png
# 📄 TXT saved: P2621.txt
# Processing P2622.png...
# ✅ Predictions drawn for P2622.png
# 📄 TXT saved: P2622.txt
# Processing P2626.png...
# ✅ Predictions drawn for P2626.png
# 📄 TXT saved: P2626.txt
# Processing P2627.png...
# ✅ Predictions drawn for P2627.png
# 📄 TXT saved: P2627.txt
# Processing P2628.png...
# ✅ Predictions drawn for P2628.png
# 📄 TXT saved: P2628.txt
# Processing P2629.png...
# ✅ Predictions drawn for P2629.png
# 📄 TXT saved: P2629.txt
# Processing P2631.png...
# ✅ Predictions drawn for P2631.png
# 📄 TXT saved: P2631.txt
# Processing P2632.png...
# ✅ Predictions drawn for P2632.png
# 📄 TXT saved: P2632.txt
# Processing P2634.png...
# ✅ Predictions drawn for P2634.png
# 📄 TXT saved: P2634.txt
# Processing P2637.png...
# ✅ Predictions drawn for P2637.png
# 📄 TXT saved: P2637.txt
# Processing P2638.png...
# ✅ Predictions drawn for P2638.png
# 📄 TXT saved: P2638.txt
# Processing P2639.png...
# ✅ Predictions drawn for P2639.png
# 📄 TXT saved: P2639.txt
# Processing P2641.png...
# ✅ Predictions drawn for P2641.png
# 📄 TXT saved: P2641.txt
# Processing P2642.png...
# ✅ Predictions drawn for P2642.png
# 📄 TXT saved: P2642.txt
# Processing P2644.png...
# ✅ Predictions drawn for P2644.png
# 📄 TXT saved: P2644.txt
# Processing P2646.png...
# ✅ Predictions drawn for P2646.png
# 📄 TXT saved: P2646.txt
# Processing P2650.png...
# ✅ Predictions drawn for P2650.png
# 📄 TXT saved: P2650.txt
# Processing P2651.png...
# ✅ Predictions drawn for P2651.png
# 📄 TXT saved: P2651.txt
# Processing P2653.png...
# ✅ Predictions drawn for P2653.png
# 📄 TXT saved: P2653.txt
# Processing P2655.png...
# ✅ Predictions drawn for P2655.png
# 📄 TXT saved: P2655.txt
# Processing P2656.png...
# ✅ Predictions drawn for P2656.png
# 📄 TXT saved: P2656.txt
# Processing P2657.png...
# ✅ Predictions drawn for P2657.png
# 📄 TXT saved: P2657.txt
# Processing P2659.png...
# ✅ Predictions drawn for P2659.png
# 📄 TXT saved: P2659.txt
# Processing P2662.png...
# ✅ Predictions drawn for P2662.png
# 📄 TXT saved: P2662.txt
# Processing P2663.png...
# ✅ Predictions drawn for P2663.png
# 📄 TXT saved: P2663.txt
# Processing P2664.png...
# ✅ Predictions drawn for P2664.png
# 📄 TXT saved: P2664.txt
# Processing P2665.png...
# ✅ Predictions drawn for P2665.png
# 📄 TXT saved: P2665.txt
# Processing P2668.png...
# ✅ Predictions drawn for P2668.png
# 📄 TXT saved: P2668.txt
# Processing P2669.png...
# ✅ Predictions drawn for P2669.png
# 📄 TXT saved: P2669.txt
# Processing P2670.png...
# ✅ Predictions drawn for P2670.png
# 📄 TXT saved: P2670.txt
# Processing P2671.png...
# ✅ Predictions drawn for P2671.png
# 📄 TXT saved: P2671.txt
# Processing P2672.png...
# ✅ Predictions drawn for P2672.png
# 📄 TXT saved: P2672.txt
# Processing P2673.png...
# ✅ Predictions drawn for P2673.png
# 📄 TXT saved: P2673.txt
# Processing P2674.png...
# ✅ Predictions drawn for P2674.png
# 📄 TXT saved: P2674.txt
# Processing P2676.png...
# ✅ Predictions drawn for P2676.png
# 📄 TXT saved: P2676.txt
# Processing P2680.png...
# ✅ Predictions drawn for P2680.png
# 📄 TXT saved: P2680.txt
# Processing P2681.png...
# ✅ Predictions drawn for P2681.png
# 📄 TXT saved: P2681.txt
# Processing P2682.png...
# ✅ Predictions drawn for P2682.png
# 📄 TXT saved: P2682.txt
# Processing P2685.png...
# ✅ Predictions drawn for P2685.png
# 📄 TXT saved: P2685.txt
# Processing P2686.png...
# ✅ Predictions drawn for P2686.png
# 📄 TXT saved: P2686.txt
# Processing P2687.png...
# ✅ Predictions drawn for P2687.png
# 📄 TXT saved: P2687.txt
# Processing P2690.png...
# ✅ Predictions drawn for P2690.png
# 📄 TXT saved: P2690.txt
# Processing P2691.png...
# ✅ Predictions drawn for P2691.png
# 📄 TXT saved: P2691.txt
# Processing P2692.png...
# ✅ Predictions drawn for P2692.png
# 📄 TXT saved: P2692.txt
# Processing P2693.png...
# ✅ Predictions drawn for P2693.png
# 📄 TXT saved: P2693.txt
# Processing P2696.png...
# ✅ Predictions drawn for P2696.png
# 📄 TXT saved: P2696.txt
# Processing P2700.png...
# ✅ Predictions drawn for P2700.png
# 📄 TXT saved: P2700.txt
# Processing P2702.png...
# ✅ Predictions drawn for P2702.png
# 📄 TXT saved: P2702.txt
# Processing P2704.png...
# ✅ Predictions drawn for P2704.png
# 📄 TXT saved: P2704.txt
# Processing P2705.png...
# ✅ Predictions drawn for P2705.png
# 📄 TXT saved: P2705.txt
# Processing P2706.png...
# ✅ Predictions drawn for P2706.png
# 📄 TXT saved: P2706.txt
# Processing P2708.png...
# ✅ Predictions drawn for P2708.png
# 📄 TXT saved: P2708.txt
# Processing P2710.png...
# ✅ Predictions drawn for P2710.png
# 📄 TXT saved: P2710.txt
# Processing P2712.png...
# ✅ Predictions drawn for P2712.png
# 📄 TXT saved: P2712.txt
# Processing P2716.png...
# ✅ Predictions drawn for P2716.png
# 📄 TXT saved: P2716.txt
# Processing P2719.png...
# ✅ Predictions drawn for P2719.png
# 📄 TXT saved: P2719.txt
# Processing P2720.png...
# ✅ Predictions drawn for P2720.png
# 📄 TXT saved: P2720.txt
# Processing P2725.png...
# ✅ Predictions drawn for P2725.png
# 📄 TXT saved: P2725.txt
# Processing P2727.png...
# ✅ Predictions drawn for P2727.png
# 📄 TXT saved: P2727.txt
# Processing P2728.png...
# ✅ Predictions drawn for P2728.png
# 📄 TXT saved: P2728.txt
# Processing P2729.png...
# ✅ Predictions drawn for P2729.png
# 📄 TXT saved: P2729.txt
# Processing P2730.png...
# ✅ Predictions drawn for P2730.png
# 📄 TXT saved: P2730.txt
# Processing P2731.png...
# ✅ Predictions drawn for P2731.png
# 📄 TXT saved: P2731.txt
# Processing P2732.png...
# ✅ Predictions drawn for P2732.png
# 📄 TXT saved: P2732.txt
# Processing P2734.png...
# ✅ Predictions drawn for P2734.png
# 📄 TXT saved: P2734.txt
# Processing P2735.png...
# ✅ Predictions drawn for P2735.png
# 📄 TXT saved: P2735.txt
# Processing P2739.png...
# ✅ Predictions drawn for P2739.png
# 📄 TXT saved: P2739.txt
# Processing P2740.png...
# ✅ Predictions drawn for P2740.png
# 📄 TXT saved: P2740.txt
# Processing P2741.png...
# ✅ Predictions drawn for P2741.png
# 📄 TXT saved: P2741.txt
# Processing P2742.png...
# ✅ Predictions drawn for P2742.png
# 📄 TXT saved: P2742.txt
# Processing P2743.png...
# ✅ Predictions drawn for P2743.png
# 📄 TXT saved: P2743.txt
# Processing P2746.png...
# ✅ Predictions drawn for P2746.png
# 📄 TXT saved: P2746.txt
# Processing P2747.png...
# ✅ Predictions drawn for P2747.png
# 📄 TXT saved: P2747.txt
# Processing P2748.png...
# ✅ Predictions drawn for P2748.png
# 📄 TXT saved: P2748.txt
# Processing P2750.png...
# ✅ Predictions drawn for P2750.png
# 📄 TXT saved: P2750.txt
# Processing P2751.png...
# ✅ Predictions drawn for P2751.png
# 📄 TXT saved: P2751.txt
# Processing P2753.png...
# ✅ Predictions drawn for P2753.png
# 📄 TXT saved: P2753.txt
# Processing P2755.png...
# ✅ Predictions drawn for P2755.png
# 📄 TXT saved: P2755.txt
# Processing P2756.png...
# ✅ Predictions drawn for P2756.png
# 📄 TXT saved: P2756.txt
# Processing P2759.png...
# ✅ Predictions drawn for P2759.png
# 📄 TXT saved: P2759.txt
# Processing P2761.png...
# ✅ Predictions drawn for P2761.png
# 📄 TXT saved: P2761.txt
# Processing P2764.png...
# ✅ Predictions drawn for P2764.png
# 📄 TXT saved: P2764.txt
# Processing P2769.png...
# ✅ Predictions drawn for P2769.png
# 📄 TXT saved: P2769.txt
# Processing P2770.png...
# ✅ Predictions drawn for P2770.png
# 📄 TXT saved: P2770.txt
# Processing P2775.png...
# ✅ Predictions drawn for P2775.png
# 📄 TXT saved: P2775.txt
# Processing P2777.png...
# ✅ Predictions drawn for P2777.png
# 📄 TXT saved: P2777.txt
# Processing P2783.png...
# ✅ Predictions drawn for P2783.png
# 📄 TXT saved: P2783.txt
# Processing P2787.png...
# ✅ Predictions drawn for P2787.png
# 📄 TXT saved: P2787.txt
# Processing P2788.png...
# ✅ Predictions drawn for P2788.png
# 📄 TXT saved: P2788.txt
# Processing P2790.png...
# ✅ Predictions drawn for P2790.png
# 📄 TXT saved: P2790.txt
# Processing P2792.png...
# ✅ Predictions drawn for P2792.png
# 📄 TXT saved: P2792.txt
# Processing P2793.png...
# ✅ Predictions drawn for P2793.png
# 📄 TXT saved: P2793.txt
# Processing P2797.png...
# ✅ Predictions drawn for P2797.png
# 📄 TXT saved: P2797.txt
# Processing P2800.png...
# ✅ Predictions drawn for P2800.png
# 📄 TXT saved: P2800.txt
# Processing P2801.png...
# ✅ Predictions drawn for P2801.png
# 📄 TXT saved: P2801.txt
# Processing P2804.png...
# ✅ Predictions drawn for P2804.png
# 📄 TXT saved: P2804.txt
# Processing P2805.png...
# ✅ Predictions drawn for P2805.png
# 📄 TXT saved: P2805.txt
#
# ===== Detection Summary =====
# Total images processed: 1411
# Images with detections: 1387 (98.3%)
# Images with dummy boxes: 24 (1.7%)
#
# 📊 Detections by class:
#   plane: 6752 detections
#   baseball-diamond: 343 detections
#   bridge: 1192 detections
#   ground-track-field: 356 detections
#   small-vehicle: 24723 detections
#   large-vehicle: 19779 detections
#   ship: 29904 detections
#   tennis-court: 2957 detections
#   basketball-court: 1433 detections
#   storage-tank: 4319 detections
#   soccer-ball-field: 707 detections
#   roundabout: 588 detections
#   harbor: 5533 detections
#   swimming-pool: 2701 detections
#   helicopter: 1332 detections
#   No_Detection: 24 detections
#
# 🎉 All images processed and saved with OBBs and TXT annotations.

# %%
import os
import numpy as np
import cv2
from shapely.geometry import Polygon
from collections import defaultdict
import matplotlib.pyplot as plt

class OBBEvaluator:
    def __init__(self, gt_dir, pred_dir, iou_threshold=0.5, confidence_threshold=0.01):
        """
        Initialize the OBB evaluator
        
        Args:
            gt_dir: Directory containing ground truth text files
            pred_dir: Directory containing prediction text files
            iou_threshold: IoU threshold for considering a detection as true positive
            confidence_threshold: Minimum confidence score to consider a prediction
        """
        self.gt_dir = gt_dir
        self.pred_dir = pred_dir
        self.iou_threshold = iou_threshold
        self.confidence_threshold = confidence_threshold
        self.class_names = set()
        self.results = {}
        # Store all predictions for PR curves
        self.all_predictions = defaultdict(list)
        # Store class cumulative stats
        self.class_cumulative = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        # Count of missing prediction files
        self.missing_pred_files = 0
    
    def parse_gt_file(self, gt_file):
        """
        Parse ground truth file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name difficulty_score
        """
        gts = []
        with open(gt_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + difficulty
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and ignore difficulty score
                    class_name = parts[8]
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    gts.append({
                        'polygon': points,
                        'class': class_name,
                        'detected': False  # Flag to mark if this gt is detected
                    })
                except Exception as e:
                    print(f"Error parsing GT line: {line}")
                    print(f"Exception: {e}")
        return gts
    
    def parse_pred_file(self, pred_file):
        """
        Parse prediction file with format:
        x1 y1 x2 y2 x3 y3 x4 y4 class_name confidence_score
        """
        preds = []
        if not os.path.exists(pred_file):
            return preds  # Return empty list if file doesn't exist
            
        with open(pred_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 10:  # Need at least 8 coordinates + class + confidence
                    continue
                try:
                    # Extract coordinates as integers
                    coords = list(map(int, parts[:8]))
                    # Extract class name and confidence score
                    class_name = parts[8]
                    confidence = float(parts[9])
                    
                    # Skip predictions with confidence below threshold
                    if confidence < self.confidence_threshold:
                        continue
                    
                    # Add class to known classes
                    self.class_names.add(class_name)
                    
                    # Create polygon from coordinates
                    points = np.array(coords).reshape(-1, 2)
                    
                    preds.append({
                        'polygon': points,
                        'class': class_name,
                        'confidence': confidence
                    })
                except Exception as e:
                    print(f"Error parsing prediction line: {line}")
                    print(f"Exception: {e}")
        
        # Sort predictions by confidence (descending)
        preds.sort(key=lambda x: x['confidence'], reverse=True)
        return preds
    
    def calculate_iou(self, poly1, poly2):
        """Calculate IoU between two polygons"""
        try:
            polygon1 = Polygon(poly1)
            polygon2 = Polygon(poly2)
            
            if not polygon1.is_valid or not polygon2.is_valid:
                return 0.0
            
            # Calculate intersection and union areas
            intersection_area = polygon1.intersection(polygon2).area
            union_area = polygon1.area + polygon2.area - intersection_area
            
            # Avoid division by zero
            if union_area == 0:
                return 0.0
                
            return intersection_area / union_area
        except Exception as e:
            print(f"Error calculating IoU: {e}")
            return 0.0
    
    def evaluate_image(self, gt_file, pred_file):
        """Evaluate a single image"""
        image_name = os.path.basename(gt_file).split('.')[0]
        
        # Parse GT and prediction files
        gts = self.parse_gt_file(gt_file)
        preds = self.parse_pred_file(pred_file)
        
        # Check if prediction file exists
        if not os.path.exists(pred_file):
            self.missing_pred_files += 1
            # Count all GTs as false negatives if no predictions
            for gt in gts:
                self.class_cumulative[gt['class']]['FN'] += 1
            return
        
        # Initialize per-class results for this image
        class_results = defaultdict(lambda: {'TP': 0, 'FP': 0, 'FN': 0})
        class_predictions = defaultdict(list)
        
        # For each prediction, find the best matching ground truth
        for pred in preds:
            pred_class = pred['class']
            pred_poly = pred['polygon']
            pred_conf = pred['confidence']
            
            best_iou = 0
            best_gt_idx = -1
            
            # Find the best matching GT of the same class
            for idx, gt in enumerate(gts):
                if gt['class'] != pred_class or gt['detected']:
                    continue
                
                iou = self.calculate_iou(pred_poly, gt['polygon'])
                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx
            
            # Record as TP or FP based on IoU threshold
            if best_gt_idx >= 0 and best_iou >= self.iou_threshold:
                class_predictions[pred_class].append((pred_conf, 1))  # True positive
                gts[best_gt_idx]['detected'] = True
                class_results[pred_class]['TP'] += 1
                self.class_cumulative[pred_class]['TP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 1))
            else:
                class_predictions[pred_class].append((pred_conf, 0))  # False positive
                class_results[pred_class]['FP'] += 1
                self.class_cumulative[pred_class]['FP'] += 1
                # Store for PR curve
                self.all_predictions[pred_class].append((pred_conf, 0))
        
        # Count false negatives (undetected GTs)
        for gt in gts:
            if not gt['detected']:
                class_results[gt['class']]['FN'] += 1
                self.class_cumulative[gt['class']]['FN'] += 1
    
    def calculate_precision_recall(self, tp, fp, fn):
        """Calculate precision and recall"""
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        return precision, recall
    
    def calculate_f1(self, precision, recall):
        """Calculate F1 score"""
        return 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    def calculate_ap(self, precisions, recalls):
        """Calculate Average Precision using 11-point interpolation"""
        ap = 0
        for t in np.arange(0, 1.1, 0.1):
            if np.sum(recalls >= t) == 0:
                p = 0
            else:
                p = np.max(precisions[recalls >= t])
            ap += p / 11
        return ap
    
    def evaluate(self):
        """Evaluate all images and calculate metrics"""
        # Get list of files
        gt_files = sorted([f for f in os.listdir(self.gt_dir) if f.endswith('.txt')])
        print(f"Found {len(gt_files)} ground truth files")
        
        # Process each image
        for gt_file in gt_files:
            image_id = os.path.splitext(gt_file)[0]
            pred_file = image_id + '.txt'
            
            gt_path = os.path.join(self.gt_dir, gt_file)
            pred_path = os.path.join(self.pred_dir, pred_file)
            
            # Skip if prediction file doesn't exist but still record the missing files
            if not os.path.exists(pred_path):
                self.evaluate_image(gt_path, pred_path)  # This will handle missing files
                continue
            
            # Evaluate the image
            self.evaluate_image(gt_path, pred_path)
            
        if self.missing_pred_files > 0:
            print(f"\nWarning: {self.missing_pred_files} out of {len(gt_files)} prediction files were missing.")
            print(f"These are counted as having no detections (all ground truths counted as false negatives).")
        
        # Calculate metrics for each class
        self.results = {}
        mean_ap = 0
        processed_classes = 0
        
        for class_name in self.class_names:
            TP = self.class_cumulative[class_name]['TP']
            FP = self.class_cumulative[class_name]['FP']
            FN = self.class_cumulative[class_name]['FN']
            
            precision, recall = self.calculate_precision_recall(TP, FP, FN)
            f1 = self.calculate_f1(precision, recall)
            
            # Sort predictions by confidence for AP calculation
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            # Skip AP calculation if no ground truths or predictions
            if TP + FN == 0 or len(class_preds) == 0:
                ap = 0
            else:
                cumulative_tp = 0
                cumulative_fp = 0
                precisions = []
                recalls = []
                
                for conf, is_tp in class_preds:
                    if is_tp:
                        cumulative_tp += 1
                    else:
                        cumulative_fp += 1
                    
                    prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                    rec = cumulative_tp / (TP + FN)
                    
                    precisions.append(prec)
                    recalls.append(rec)
                
                precisions = np.array(precisions)
                recalls = np.array(recalls)
                ap = self.calculate_ap(precisions, recalls)
                processed_classes += 1
            
            self.results[class_name] = {
                'AP': ap,
                'Precision': precision,
                'Recall': recall,
                'F1': f1,
                'TP': TP,
                'FP': FP,
                'FN': FN
            }
            
            mean_ap += ap
        
        # Calculate mAP only over classes with predictions
        if processed_classes > 0:
            mean_ap /= processed_classes
        else:
            mean_ap = 0
        
        self.results['mAP'] = mean_ap
        
        return self.results
    
    def plot_precision_recall_curves(self, output_dir):
        """Plot precision-recall curves for all classes"""
        os.makedirs(output_dir, exist_ok=True)
        
        plt.figure(figsize=(10, 8))
        
        for class_name in sorted(self.class_names):
            # Skip classes with no predictions
            if class_name not in self.all_predictions or len(self.all_predictions[class_name]) == 0:
                continue
            
            # Sort predictions by confidence
            class_preds = sorted(self.all_predictions[class_name], key=lambda x: x[0], reverse=True)
            
            TP = self.class_cumulative[class_name]['TP']
            FN = self.class_cumulative[class_name]['FN']
            
            # Skip if no ground truths
            if TP + FN == 0:
                continue
            
            # Calculate cumulative precision and recall
            cumulative_tp = 0
            cumulative_fp = 0
            precisions = []
            recalls = []
            
            for conf, is_tp in class_preds:
                if is_tp:
                    cumulative_tp += 1
                else:
                    cumulative_fp += 1
                
                prec = cumulative_tp / (cumulative_tp + cumulative_fp)
                rec = cumulative_tp / (TP + FN)
                
                precisions.append(prec)
                recalls.append(rec)
            
            plt.plot(recalls, precisions, label=f"{class_name} (AP={self.results[class_name]['AP']:.3f})")
        
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curves')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(output_dir, 'precision_recall_curves_S2ANET.png'))
        plt.close()
    
    def print_results(self):
        """Print evaluation results"""
        print("\n===== EVALUATION RESULTS =====")
        print(f"IoU Threshold: {self.iou_threshold}")
        print(f"Confidence Threshold: {self.confidence_threshold}")
        print(f"mAP: {self.results['mAP']:.4f}")
        print("\nPer-class results:")
        
        # Print header
        print(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}")
        print('-' * 70)
        
        # Sort classes for consistent output
        for class_name in sorted(self.class_names):
            r = self.results[class_name]
            print(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}")
        
        print("=" * 70)
    
    def save_results_to_file(self, output_path):
        """Save results to file"""
        with open(output_path, 'w') as f:
            f.write("===== EVALUATION RESULTS =====\n")
            f.write(f"IoU Threshold: {self.iou_threshold}\n")
            f.write(f"Confidence Threshold: {self.confidence_threshold}\n")
            f.write(f"mAP: {self.results['mAP']:.4f}\n\n")
            
            # if self.missing_pred_files > 0:
            #     f.write(f"Note: {self.missing_pred_files} prediction files were missing and counted as no detections.\n\n")
                
            f.write("Per-class results:\n")
            
            # Print header
            f.write(f"{'Class':<15} {'AP':<8} {'Precision':<10} {'Recall':<10} {'F1':<8} {'TP':<6} {'FP':<6} {'FN':<6}\n")
            f.write('-' * 70 + '\n')
            
            # Sort classes for consistent output
            for class_name in sorted(self.class_names):
                r = self.results[class_name]
                f.write(f"{class_name:<15} {r['AP']:.4f}   {r['Precision']:.4f}     {r['Recall']:.4f}     {r['F1']:.4f}   {r['TP']:<6} {r['FP']:<6} {r['FN']:<6}\n")
            
            f.write("=" * 70 + '\n')


# Usage example
if __name__ == "__main__":
    # Define paths
    GT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\DOTA V1\labels\train\labelTxt-v1.0\labelTxt"  # Ground truth directory
    PRED_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\output_s2anet\txt_annotations"  # Prediction directory
    OUTPUT_DIR = r"D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results"  # Output directory
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Create evaluator with default parameters
    evaluator = OBBEvaluator(
        gt_dir=GT_DIR,
        pred_dir=PRED_DIR,
        iou_threshold=0.5,  # IoU threshold for TP/FP determination
        confidence_threshold=0.01  # Min confidence to consider a prediction
    )
    
    # Run evaluation
    results = evaluator.evaluate()
    
    # Print results
    evaluator.print_results()
    
    # Save results to file
    evaluator.save_results_to_file(os.path.join(OUTPUT_DIR, "evaluation_results_S2ANET.txt"))
    
    # Generate PR curves
    try:
        evaluator.plot_precision_recall_curves(OUTPUT_DIR)
        print(f"Precision-Recall curves saved to {OUTPUT_DIR}")
    except Exception as e:
        print(f"Error generating PR curves: {e}")
    
    print(f"Evaluation completed! Results saved to {OUTPUT_DIR}")
# Out:
# Found 1411 ground truth files
#
# ===== EVALUATION RESULTS =====
# IoU Threshold: 0.5
# Confidence Threshold: 0.01
# mAP: 0.3786
#
# Per-class results:
# Class           AP       Precision  Recall     F1       TP     FP     FN
# ----------------------------------------------------------------------
# baseball-diamond 0.4430   0.5248     0.4337     0.4749   180    163    235
# basketball-court 0.5298   0.2052     0.5709     0.3018   294    1139   221
# bridge          0.0909   0.1502     0.0874     0.1105   179    1013   1868
# ground-track-field 0.4113   0.3820     0.4185     0.3994   136    220    189
# harbor          0.3127   0.3591     0.3321     0.3451   1987   3546   3996
# helicopter      0.0909   0.0255     0.0540     0.0347   34     1298   596
# large-vehicle   0.5741   0.5208     0.6070     0.5606   10300  9479   6669
# plane           0.4385   0.5548     0.4651     0.5060   3746   3006   4309
# roundabout      0.2725   0.2092     0.3083     0.2492   123    465    276
# ship            0.2841   0.3026     0.3224     0.3122   9049   20855  19019
# small-vehicle   0.2821   0.3902     0.3692     0.3794   9646   15077  16480
# soccer-ball-field 0.3936   0.2235     0.4847     0.3059   158    549    168
# storage-tank    0.3499   0.4140     0.3555     0.3825   1788   2531   3241
# swimming-pool   0.3879   0.3088     0.4804     0.3759   834    1867   902
# tennis-court    0.8172   0.6994     0.8737     0.7769   2068   889    299
# ======================================================================
# Precision-Recall curves saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results
# Evaluation completed! Results saved to D:\AU MATERIAL\2 SEM\CV\PROJECT\codes\evaluation_results
